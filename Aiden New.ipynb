# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import missingno
from collections import Counter

# Data visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Machine learning models
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier

from sklearn.ensemble import VotingClassifier

# Model evaluation
from sklearn.model_selection import cross_val_score

# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Remove warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Import and read data
#
# Now import and read the 3 datasets as outlined in the introduction.

# %%
#Gia
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # 3. Data description

# %% [markdown]
# Gia
# The data provided is split into two groups:
# 1) The training set (train.csv)
# 2) The testing set (test.csv)
#
# The training set includes a survival column which indicates whether or not the passenger survived. This data set is used to create the machine learning model.
# The testing set is used to determine how well the model (generated from the training data set) performs on new unseen data. The testing data set does not provide the passengers' survival status. The model generated predicts the passengers' survival status of the test set.
#
# The table below provides all the relevant information about the columns in the data sets:
#
# | Column Name          | Description                                                | Key                    |
# | ---------------------| ---------------------------------------------------------- | ---------------------- |
# | __PassengerId__      | Passenger Identity                                         |                        |
# | __Survived__         | Passenger survival status                                  | 0 = No, 1 = Yes        |
# | __Pclass__           | Ticket class, a representation of socio-economic status (SES)| 1 = 1st class, 2 = 2nd class, 3 = 3rd class |
# | __Name__             | Passenger's name                                           |                        |
# | __Sex__              | Passenger's sex                                            |                        |
# | __Age__              | Passengers age (in years)                                  |                        |
# | __SibSp__            | Number of siblings and/or spouse travelling with passenger  |                        |
# | __Parch__            | Number of parents and/or children travelling with passenger |                        |
# | __Ticket__           | Ticket number                                              |                        |
# | __Fare__             | Price of the ticket                                        |                        |
# | __Cabin__            | Cabin number                                               |                        |
# | __Embarked__         | Point of embarkation                                       | C = Cherbourg, Q = Queenstown, S = Southampton |
#
# More information can be found under the [data](https://www.kaggle.com/c/titanic/)

# %% [markdown]
# # 4. Exploratory Data Analysis (EDA)

# %% [markdown]
# Gia
# Exploratory data analysis is used to gain insight on the data provided. This is achieved by using visualisation tools such as graphs and tables. It will allow us to understand the data and derive preliminary conclusions. Furthermore, it will summerise important trends, characteristics, and abnormalities in the dataset which will ultimately aid in training the model.
#
# The following is explored and analysed:
# - Data Types
# - The shape of the data
# - Missing values in the data
# - Statistics derived from the data

# %% [markdown]
# ## 4.1 Data types,data shapes, missing data and summary statistics

# %% [markdown]
# ### 4.1.1.Data Types

# %%
# Non-null count and data types of the training
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Gia <font color='pink'>Observation:</font>  The training-set has 891 rows and 11 features including the __target variable (survived).__ 2 of the features are floats, 5 are integers and 5 are objects. The model requires the data to all be in the form of numbers when testing, therefore these columns will be converted later on.

# %% [markdown]
# ### 4.1.2.Data Shape

# %%
#Gia
print("The shape of the training data set: ", train.shape)
print("The shape of the testing data set: ", test.shape)
# Out:
# The shape of the training data set:  (891, 12)
# The shape of the testing data set:  (418, 11)

# %% [markdown]
# Gia <font color='pink'>Observation:</font> The testing data set has one column less column than the training data set (the Survived column). As discussed above in section 3, survived is our response/target variable and will therefore be determined by the model derived from the training data.

# %% [markdown]
# ### 4.1.3.Missing Values

# %%
#Gia
#Determine what percentage of data is missing values in each column of the training dataset
totalNumberOfDataPoints = train.isnull().sum().sort_values(ascending=False)
percentMissing = train.isnull().sum()/train.isnull().count()*100
percentMissingRounded = (round(percentMissing, 1)).sort_values(ascending=False)
missingData = pd.concat([totalNumberOfDataPoints, percentMissingRounded], axis=1, keys=['Total missing', '%'])
missingData.head(13)
# Out:
#              Total missing     %
# Cabin                  687  77.1
# Age                    177  19.9
# Embarked                 2   0.2
# PassengerId              0   0.0
# Survived                 0   0.0
# Pclass                   0   0.0
# Name                     0   0.0
# Sex                      0   0.0
# SibSp                    0   0.0
# Parch                    0   0.0
# Ticket                   0   0.0
# Fare                     0   0.0

# %%
#Gia
#Determine what percentage of data is missing values in each column of the testing dataset
totalNumberOfDataPoints = test.isnull().sum().sort_values(ascending=False)
percentMissing = test.isnull().sum()/test.isnull().count()*100
percentMissingRounded = (round(percentMissing, 1)).sort_values(ascending=False)
missingData = pd.concat([totalNumberOfDataPoints, percentMissingRounded], axis=1, keys=['Total missing', '%'])
missingData.head(13)
# Out:
#              Total missing     %
# Cabin                  327  78.2
# Age                     86  20.6
# Fare                     1   0.2
# PassengerId              0   0.0
# Pclass                   0   0.0
# Name                     0   0.0
# Sex                      0   0.0
# SibSp                    0   0.0
# Parch                    0   0.0
# Ticket                   0   0.0
# Embarked                 0   0.0

# %% [markdown]
# Gia <font color='pink'>Observation:</font> From the two tables above it can be seen that the training set has missing values in the Cabin, Age and Embarked columns. The testing dataset has missing values in the Cabin, Age and Fare columns.
# For the training dataset, the Embarked column only contains two missing values which can be easily dropped or filled. The Age column on the other hand has 177 missing values. We therefore, cannot drop the rows which have missing values in the age column as this will eliminate 20% of the training data. Therefore, these values need to be filled in. The approach taken to fill in the missing values is discussed below in section 5.2. Since the Cabin column is missing 77% of data points, we have decided to drop this column.

# %% [markdown]
# ### 4.1.4.Statistics

# %%
#Gia
# Summary of the statistics for the training data set 
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Gia
# The table above gives an overview of the central tendencies of the numeric data in the testing dataset. <br /> <font color='pink'>Observations:</font>
# - 38% of people in the training dataset survived the Titanic
# - The passenger age ranges from 0.4 to 80 years old.
# - There is an outlier in the Fare column because of the differences between the 75th percentile, standard deviation, and the max value (512). We will thus determine how to deal with this outlier by either dropping its corresponding row or filling the outlier with an appropriate value.

# %% [markdown]
# ## 4.2 Feature analysis

# %% [markdown]
# Gia
# For feature analysis the training dataset will be split into two categories:
# 1) Categorical variables
# 2) Numerical variables
#
# Categorical variables have values belonging to one of two or more categories. Numerical variables have a continuous distribution.
# Identifying which variables are categorical and which variables are numerical will help structure the data analysis properly. For example it makes no sense to determine the average of a categorical variable such as sex or class. Furthermore, sex, class and embarked have no intrinsic ordering to its value.

# %% [markdown]
# ### 4.2.1 Categorical variables

# %% [markdown]
# Gia
# In this data set the categorical variables are:
# 1) Sex
# 2) Pclass
# 3) Embarked.

# %% [markdown]
# #### 4.2.1.1.Categorical variable: Sex

# %%
#Gia
# Value counts of the sex column
train['Sex'].value_counts(dropna = False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# Gia <font color='pink'>Observation:</font> There are 263 more male passengers than female passengers in the training dataset. Therefore there it is assumend that the test dataset will follow the same pattern.

# %%
#Gia
# Mean of survival according to sex
train[['Sex', 'Survived']].groupby('Sex', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
#Gia
# visualisation for the probability of survival according to sex
sns.barplot(x = 'Sex', y ='Survived', data = train)
plt.ylabel('Probability of survival')
plt.title('Survival Probability by Sex')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Sex')

# %% [markdown]
# Gia <font color='pink'>Observation:</font> Female passengers are more likely to survive.

# %% [markdown]
# #### 4.2.1.2.Categorical variable: Pclass

# %%
#Gia
# Value counts of the Pclass column in the training dataset

train['Pclass'].value_counts(dropna = False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#Gia
# Mean of survival by passenger class in the training dataset

train[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
#Gia 
#Pclass distributions for survived and not survived
ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Pclass'],shade=True,color='r',label='Not Survived')
ax.legend()
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Pclass'],shade=True,color='b',label='Survived')
ax.legend()

plt.title("Passenger Class Distribution - Survived vs Non-Survived", fontsize = 25)
labels = ['First', 'Second', 'Third']
plt.xticks(sorted(train.Pclass.unique()),labels);

# %%
#Gia
sns.barplot(x = 'Pclass', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Passenger Class')

# %% [markdown]
# <font color='pink'>Observation:</font> The probability of survival decreases with a decrease in passenger class. It can therefore be assumed that first class passengers were prioritised during the evacuation. Evidently, from the two graphs above, Pclass plays an important role in determining whether a passenger did or did not survive. According to the training dataset, 63% of the 1st class passengers survived, 48% of the 2nd class passengers survived and only 24% of the 3rd class passengers survived.

# %% [markdown]
# #### 4.2.1.3.Categorical variables combined: Sex and Plass

# %%
#Gia
# Survival by gender and passenger class
sns.factorplot(x = 'Pclass', y = 'Survived', hue = 'Sex', data = train, kind = 'bar').despine(left = True)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Sex and Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Sex and Passenger Class')

# %% [markdown]
# #Aiden did this
# Gia <font color='pink'>Observation:</font>The graph above indicates that in every class, females where always more likely to survive. However, it can also be seen that males in the first class were more likely to survive than in any other class.

# %% [markdown]
# #### 4.2.1.4.Categorical variable: Embarked

# %%
# Value counts of the Embarked column 
#NAN is the missing values in Embarked
train['Embarked'].value_counts(dropna = False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
#Gia
# Mean of survival by point of embarkation
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
#Gia
#Visualisation for the probability of survival according to point of embarkation
sns.barplot(x = 'Embarked', y ='Survived', data = train)
plt.ylabel('Probability of Survival')
plt.title('Survival Probability by Point of Embarkation')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Point of Embarkation')

# %% [markdown]
# <font color='pink'>Observation:</font>Perhaps the majority of passengers embarking from location C were in first class and thus, because 1st class passengers had a higher chance of survival so too does location C. Similarly it is assumed that the majority of passsengers leaving location S were from the 3rd class and thus the probablity of survival is less.This hypothesis is tested in section 4.2.1.5 below.

# %% [markdown]
# #### 4.2.1.5.Categorical variable combined: Embarked and Class

# %%
#Gia
# Visualisation for the relationship between class and embark 
sns.factorplot('Pclass', col = 'Embarked', data = train, kind = 'count')

# %% [markdown]
# <font color='pink'>Observation:</font> The hypothesis discussed in section 4.1.2.4 appears to be correct.  Location S has majority of the third class passengers

# %% [markdown]
# ### 4.2.2 Numerical variables

# %% [markdown]
# Gia
# In this dataset, the numerical variables are:
# 1) SibSp
# 2) Parch
# 3) Age
# 4) Fare

# %% [markdown]
# #### 4.2.2.1.Detect outliers in numerical variables

# %% [markdown]
# Gia Outliers are points in the dataset that don't conform with majority of the data (they are extreme values). Outliers need to be addressed as they tend to skew data and can cause inaccurate model predictions. The Tukey method is used to detect these outliers.

# %%
#Gia
#Function to predict outliers
def detect_outliers(df, n, features):
    """"
    This function loops through the list of features and detects outliers in each feature. A data point is considered to be 
    an outlier if it is less than Q1-1.5*IQR or if it is greater than Q3+1.5*IQR. Once the outliers have been determined for 
    a feature, their indices will be stored in a list and then the loop will proceed to the next feature. This process repeats
    until the last feature is complete. Finally, using the list with the indices of the outliers, the frequency of outliers is
    determined and if the frequency is greater than n then the list fill be returned.    
    """
    outlierIndices = [] 
    for col in features: 
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        outlierStep = 1.5 * IQR 
        outlierList = df[(df[col] < Q1 - outlierStep) | (df[col] > Q3 + outlierStep)].index
        outlierIndices.extend(outlierList) 
    outlierIndices = Counter(outlierIndices)
    multipleOutliers = list(key for key, value in outlierIndices.items() if value > n) 
    return multipleOutliers

outliers_to_drop = detect_outliers(train, 2, ['Age', 'SibSp', 'Parch', 'Fare'])
print("The indices where outliers occur are {}: ".format(len(outliers_to_drop)), outliers_to_drop)
# Out:
# The indices where outliers occur are 10:  [27, 88, 159, 180, 201, 324, 341, 792, 846, 863]

# %%
#Gia
# Outliers in numerical variables
#Visualise the 10 rows identified above as rows containing outliers
train.loc[outliers_to_drop, :]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 27            28         0       1     Fortune, Mr. Charles Alexander    male
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 341          342         1       1     Fortune, Miss. Alice Elizabeth  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket    Fare        Cabin Embarked
# 27   19.0      3      2     19950  263.00  C23 C25 C27        S
# 88   23.0      3      2     19950  263.00  C23 C25 C27        S
# 159   NaN      8      2  CA. 2343   69.55          NaN        S
# 180   NaN      8      2  CA. 2343   69.55          NaN        S
# 201   NaN      8      2  CA. 2343   69.55          NaN        S
# 324   NaN      8      2  CA. 2343   69.55          NaN        S
# 341  24.0      3      2     19950  263.00  C23 C25 C27        S
# 792   NaN      8      2  CA. 2343   69.55          NaN        S
# 846   NaN      8      2  CA. 2343   69.55          NaN        S
# 863   NaN      8      2  CA. 2343   69.55          NaN        S

# %% [markdown]
# #### 4.2.2.2.Numerical variables correlation with survival

# %%
#Gia
#Heatmap of numerical variables
df_num = train[['Age','SibSp','Parch','Fare']]
sns.heatmap(df_num.corr(), annot=True,cmap="RdBu")
plt.title("Correlations Among Numeric Features", fontsize = 18);

# %% [markdown]
# Gia<font color='pink'>Observation:</font> The heatmap displayed above shows that Parch and SiSP often travel together.Therefore it will useful to create a isAlone and a family size feature.

# %% [markdown]
# #### 4.2.2.3.Numerical variable: SibSp

# %%
#Gia
# Value counts of the SibSp column 
train['SibSp'].value_counts(dropna = False)
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
#Gia
# Mean of survival by SibSp
train[['SibSp', 'Survived']].groupby('SibSp', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
#Gia
#Visualisation for probability of survival according to SiSP 
sns.barplot(x = 'SibSp', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by SibSp')
# Out:
# Text(0.5, 1.0, 'Survival Probability by SibSp')

# %% [markdown]
# #### 4.2.2.4.Numerical variable: Parch

# %%
#Gia
# Value counts of the Parch column 
train['Parch'].value_counts(dropna = False)
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
#Gia
# Mean of survival by Parch
train[['Parch', 'Survived']].groupby('Parch', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
#Gia
#Visualisation for probability of survival according to Parch
sns.barplot(x = 'Parch', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Parch')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Parch')

# %% [markdown]
# #### 4.2.2.5.Numerical variable: Age

# %%
#Gia
# Passenger age distribution

sns.distplot(train['Age'], label = 'Skewness: %.2f'%(train['Age'].skew()))
plt.legend(loc = 'best')
plt.title('Passenger Age Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Age Distribution')

# %%
#Gia
# Age distribution by survival
sns.FacetGrid(train, col = 'Survived').map(sns.distplot, 'Age')

# %%
sns.kdeplot(train['Age'][train['Survived'] == 0], label = 'Did not survive')
sns.kdeplot(train['Age'][train['Survived'] == 1], label = 'Survived')
plt.xlabel('Age')
plt.legend()
plt.title('Passenger Age Distribution by Survival')
# Out:
# Text(0.5, 1.0, 'Passenger Age Distribution by Survival')

# %% [markdown]
# #### 4.2.2.6.Numerical variable: Fare

# %%
# Passenger fare distribution
sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.ylabel('Passenger Fare Distribution')
# Out:
# Text(0, 0.5, 'Passenger Fare Distribution')

# %% [markdown]
# Gia <font color='pink'>Observation:</font>

# %% [markdown]
# ### 4.2.3 Correlation between categorical and numerical

# %% [markdown]
# #### 4.2.3.1.All variables

# %%
sns.heatmap(train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare','Pclass']].corr(), annot = True, fmt = '.2f', cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Gia <font color='pink'>Observation:</font>  Fare appears to have a high correlation with survival.

# %% [markdown]
# # 5. Data preprocessing
#
# Getting the dataset in a form to be modelled and trained. This includes:
# - Dealing with ouliers
# - Drop and fill missing values
# - Data transformation
# - Feature engineering
# - Feature encoding

# %% [markdown]
# ## 5.1 Remove Outliers

# %%
# Drop outliers 

print("Train Set Before: {} rows".format(len(train)))
#train = train.drop(outliers_to_drop, axis = 0).reset_index(drop = True)
print("Train Set After: {} rows".format(len(train)))
print("Test Set Before: {} rows".format(len(test)))
# test = test.drop(outliers_to_drop_test, axis = 0).reset_index(drop = True)
print("Test Set After: {} rows".format(len(test)))
# Out:
# Train Set Before: 891 rows
# Train Set After: 891 rows
# Test Set Before: 418 rows
# Test Set After: 418 rows

# %% [markdown]
# ## 5.2 Drop and fill missing values

# %%
# Drop ticket and cabin features from training and test set as they are unique or missing many values
train = train.drop(['Ticket', 'Cabin'], axis = 1)
test = test.drop(['Ticket', 'Cabin'], axis = 1)

# %% [markdown]
# I have decided to drop both ticket and cabin for simplicity of this tutorial but if you have the time, I would recommend going through them and see if they can help improve your model.

# %%
train.isnull().sum().sort_values(ascending = False)
# Out:
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
# Fill missing value in Embarked with mode as only 3 values
mode = train['Embarked'].dropna().mode()[0]
train['Embarked'].fillna(mode, inplace = True)

# %%
test.isnull().sum().sort_values(ascending = False)
# Out:
# Age            86
# Fare            1
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# SibSp           0
# Parch           0
# Embarked        0
# dtype: int64

# %%
# Fill missing value for Fare 
median = test['Fare'].dropna().median()
test['Fare'].fillna(median, inplace = True)

# %%
# Check where indeces of missing ages are
age_nan_indices_train = list(train[train['Age'].isnull()].index)
len(age_nan_indices_train)
age_nan_indices_test = list(test[test['Age'].isnull()].index)

# %% [markdown]
# Age is negatively correlated with SibSp, Parch and Pclass as shown in section 4. Loop through each those rows and fill the missing age with their median. Othwerise fill with the Age median.

# %%
for index in age_nan_indices_train:
    median_age = train['Age'].median()
    predict_age = train['Age'][(train['SibSp'] == train.iloc[index]['SibSp']) 
                                 & (train['Parch'] == train.iloc[index]['Parch'])
                                 & (train['Pclass'] == train.iloc[index]["Pclass"])].median()
    if np.isnan(predict_age):
        train['Age'].iloc[index] = median_age
    else:
        train['Age'].iloc[index] = predict_age
combine = pd.concat([train, test], axis = 0).reset_index(drop = True)
median_age = combine['Age'].median()
for index in age_nan_indices_test:
    #use larger sample to fill test data 
    test['Age'].iloc[index] = median_age

# %%
# Make sure there are no more missing ages 
print(train['Age'].isnull().sum())
test['Age'].isnull().sum()
# Out:
# 0
# 0

# %% [markdown]
# ## 5.3 Data transformation
#
# Recall that our passenger fare column has a very high positive skewness. Therefore, we will apply a log transformation to address this issue.

# %%
#  fare distribution

sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.title('Passenger Fare Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Fare Distribution')

# %%
# In order to reduce skewness in fare, apply log transformation 
train['Fare'] = train['Fare'].map(lambda x: np.log(x) if x > 0 else 0)
test['Fare'] = test['Fare'].map(lambda x: np.log(x) if x > 0 else 0)

# %%
# After log transformation

sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.title('Fare Distribution After Log Transformation')
# Out:
# Text(0.5, 1.0, 'Fare Distribution After Log Transformation')

# %% [markdown]
# ## 5.4 Feature engineering
#
# We create new features from existing features to obtain an improved model.

# %% [markdown]
# ### 5.4.1 Title

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch      Fare Embarked
# 0      0  1.981001        S
# 1      0  4.266662        C
# 2      0  2.070022        S
# 3      0  3.972177        S
# 4      0  2.085672        S

# %%
#Title from name column
train['Title'] = [name.split(',')[1].split('.')[0].strip() for name in train['Name']]
train[['Name', 'Title']].head()
test['Title'] = [name.split(',')[1].split('.')[0].strip() for name in test['Name']]
test[['Name', 'Title']].head()
# Out:
#                                            Name Title
# 0                              Kelly, Mr. James    Mr
# 1              Wilkes, Mrs. James (Ellen Needs)   Mrs
# 2                     Myles, Mr. Thomas Francis    Mr
# 3                              Wirz, Mr. Albert    Mr
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   Mrs

# %%
# Value counts of Title
train['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: Title, dtype: int64

# %%
# visualise the testing titles
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: Title, dtype: int64

# %%
# Simplify Title as there are several unique itles that do not necessarily have a trend

train['Title'] = train['Title'].replace(['Dr', 'Rev', 'Col', 'Major', 'Lady', 'Jonkheer', 'Don', 'Capt', 'the Countess',
                                             'Sir'], 'Rare')
train['Title'] = train['Title'].replace(['Mlle', 'Ms'], 'Miss')
train['Title'] = train['Title'].replace('Mme', 'Mrs')

test['Title'] = test['Title'].replace(['Dr', 'Rev', 'Col',  'Capt', 'Dona'], 'Rare')
test['Title'] = test['Title'].replace(['Ms'], 'Miss')

# %%
# Drop name column as title has been extracted


train = train.drop('Name', axis = 1)
train.head()

test = test.drop('Name', axis = 1)
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked Title
# 0          892       3    male  34.5      0      0  2.057860        Q    Mr
# 1          893       3  female  47.0      1      0  1.945910        S   Mrs
# 2          894       2    male  62.0      0      0  2.270836        Q    Mr
# 3          895       3    male  27.0      0      0  2.159003        S    Mr
# 4          896       3  female  22.0      1      1  2.508582        S   Mrs

# %% [markdown]
# ### 5.4.2 IsAlone

# %%
train['FamilySize'] = train['SibSp'] + train['Parch'] + 1
train[['SibSp', 'Parch', 'FamilySize']].head()

test['FamilySize'] = test['SibSp'] + test['Parch'] + 1
test[['SibSp', 'Parch', 'FamilySize']].head()
# Out:
#    SibSp  Parch  FamilySize
# 0      0      0           1
# 1      1      0           2
# 2      0      0           1
# 3      0      0           1
# 4      1      1           3

# %%
# Create IsAlone feature as familySize may have more information than we need, leading to overfitting

train['IsAlone'] = 0
train.loc[train['FamilySize'] == 1, 'IsAlone'] = 1

test['IsAlone'] = 0
test.loc[test['FamilySize'] == 1, 'IsAlone'] = 1

# %%
# Drop SibSp, Parch and FamilySize as this is contained in isAlone

train = train.drop(['SibSp', 'Parch','FamilySize'], axis = 1)
test = test.drop(['SibSp', 'Parch','FamilySize'], axis = 1)
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age      Fare Embarked Title  \
# 0            1         0       3    male  22.0  1.981001        S    Mr
# 1            2         1       1  female  38.0  4.266662        C   Mrs
# 2            3         1       3  female  26.0  2.070022        S  Miss
# 3            4         1       1  female  35.0  3.972177        S   Mrs
# 4            5         0       3    male  35.0  2.085672        S    Mr
#
#    IsAlone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# ### 5.4.3 Age*Class

# %% [markdown]
# First convert Age into an ordinal variable. Group Ages into 5 age bands

# %%
train['AgeBand'] = pd.cut(train['Age'], 4)
test['AgeBand'] = pd.cut(test['Age'], 4)
print(train['AgeBand'].head(10))
# Out:
# 0    (20.315, 40.21]
# 1    (20.315, 40.21]
# 2    (20.315, 40.21]
# 3    (20.315, 40.21]
# 4    (20.315, 40.21]
# 5    (20.315, 40.21]
# 6    (40.21, 60.105]
# 7     (0.34, 20.315]
# 8    (20.315, 40.21]
# 9     (0.34, 20.315]
# Name: AgeBand, dtype: category
# Categories (4, interval[float64, right]): [(0.34, 20.315] < (20.315, 40.21] < (40.21, 60.105] < (60.105, 80.0]]

# %%
# train.loc[train['Age'] <= 16.136, 'Age'] = 0
# train.loc[(train['Age'] > 16.136) & (train['Age'] <= 32.102), 'Age'] = 1
# train.loc[(train['Age'] > 32.102) & (train['Age'] <= 48.068), 'Age'] = 2
# train.loc[(train['Age'] > 48.068) & (train['Age'] <= 64.034), 'Age'] = 3
# train.loc[train['Age'] > 64.034 , 'Age'] = 4

# test.loc[test['Age'] <= 16.136, 'Age'] = 0
# test.loc[(test['Age'] > 16.136) & (test['Age'] <= 32.102), 'Age'] = 1
# test.loc[(test['Age'] > 32.102) & (test['Age'] <= 48.068), 'Age'] = 2
# test.loc[(test['Age'] > 48.068) & (test['Age'] <= 64.034), 'Age'] = 3
# test.loc[test['Age'] > 64.034 , 'Age'] = 4

train.loc[train['Age'] <= 20.315, 'Age'] = 0
train.loc[(train['Age'] > 20.315) & (train['Age'] <= 40.21), 'Age'] = 1
train.loc[(train['Age'] > 40.21) & (train['Age'] <= 60.105), 'Age'] = 2
train.loc[train['Age'] > 60.105,'Age'] = 3

test.loc[test['Age'] <= 20.315, 'Age'] = 0
test.loc[(test['Age'] > 20.315) & (test['Age'] <= 40.21), 'Age'] = 1
test.loc[(test['Age'] > 40.21) & (test['Age'] <= 60.105), 'Age'] = 2
test.loc[test['Age'] > 60.105,'Age'] = 3

# Drop age band feature
train = train.drop('AgeBand', axis = 1)
test = test.drop('AgeBand', axis = 1)

# %%
# Convert ordinal Age into integer
train['Age'] = train['Age'].astype('int')
test['Age'] = test['Age'].astype('int')
train['Age'].dtype
# Out:
# dtype('int64')

# %%
# Create Age*Class

train['Age*Class'] = train['Age'] * train['Pclass']
test['Age*Class'] = test['Age'] * test['Pclass']
train[['Age', 'Pclass', 'Age*Class']].head()
# Out:
#    Age  Pclass  Age*Class
# 0    1       3          3
# 1    1       1          1
# 2    1       3          3
# 3    1       1          1
# 4    1       3          3

# %%
# Bin Fare 
train['FareBand'] = pd.qcut(train['Fare'], 4)
test['FareBand'] = pd.qcut(test['Fare'], 4)
train['FareBand'].head(10)
# Out:
# 0    (-0.001, 2.068]
# 1     (3.434, 6.239]
# 2     (2.068, 2.671]
# 3     (3.434, 6.239]
# 4     (2.068, 2.671]
# 5     (2.068, 2.671]
# 6     (3.434, 6.239]
# 7     (2.671, 3.434]
# 8     (2.068, 2.671]
# 9     (2.671, 3.434]
# Name: FareBand, dtype: category
# Categories (4, interval[float64, right]): [(-0.001, 2.068] < (2.068, 2.671] < (2.671, 3.434] < (3.434, 6.239]]

# %%
#ordinal encoding, simliar to age
train.loc[train['Fare'] <= 2.066, 'Fare'] = 0
train.loc[(train['Fare'] > 2.066) & (train['Fare'] <= 2.671), 'Fare'] = 1
train.loc[(train['Fare'] > 2.671) & (train['Fare'] <= 3.418), 'Fare'] = 2
train.loc[train['Fare'] > 3.418, 'Fare'] = 3

test.loc[test['Fare'] <= 2.066, 'Fare'] = 0
test.loc[(test['Fare'] > 2.066) & (test['Fare'] <= 2.671), 'Fare'] = 1
test.loc[(test['Fare'] > 2.671) & (test['Fare'] <= 3.418), 'Fare'] = 2
test.loc[test['Fare'] > 3.418, 'Fare'] = 3

# %%
train = train.drop(['FareBand'], axis = 1)
test = test.drop(['FareBand'], axis = 1)

# %%
# Convert Fare into integer
train['Fare'] = train['Fare'].astype('int')
test['Fare'] = test['Fare'].astype('int')

# %% [markdown]
# ## 5.5 Feature encoding
#
# Variables must be numeric to use for machine learning. Age and Fare were done when Binning.

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  Fare Embarked Title  IsAlone  \
# 0            1         0       3    male    1     0        S    Mr        0
# 1            2         1       1  female    1     3        C   Mrs        0
# 2            3         1       3  female    1     1        S  Miss        1
# 3            4         1       1  female    1     3        S   Mrs        0
# 4            5         0       3    male    1     1        S    Mr        1
#
#    Age*Class
# 0          3
# 1          1
# 2          3
# 3          1
# 4          3

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
label = LabelEncoder() 
train['Embarked'] = label.fit_transform(train['Embarked'])
test['Embarked'] = label.fit_transform(test['Embarked'])
train['Title'] = label.fit_transform(train['Title'])
test['Title'] = label.fit_transform(test['Title'])
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
test['Sex'] = test['Sex'].map({'male': 0, 'female': 1})

train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  \
# 0            1         0       3    0    1     0         2      2        0
# 1            2         1       1    1    1     3         0      3        0
# 2            3         1       3    1    1     1         2      1        1
# 3            4         1       1    1    1     3         2      3        0
# 4            5         0       3    0    1     1         2      2        1
#
#    Age*Class
# 0          3
# 1          1
# 2          3
# 3          1
# 4          3

# %%
train = train.drop('PassengerId', axis = 1)
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         2      2        0          3
# 1         1       1    1    1     3         0      3        0          1
# 2         1       3    1    1     1         2      1        1          3
# 3         1       1    1    1     3         2      3        0          1
# 4         0       3    0    1     1         2      2        1          3

# %%
train['Survived'] = train['Survived'].astype('int')
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         2      2        0          3
# 1         1       1    1    1     3         0      3        0          1
# 2         1       3    1    1     1         2      1        1          3
# 3         1       1    1    1     3         2      3        0          1
# 4         0       3    0    1     1         2      2        1          3

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    1     0         1      2        1          3
# 1          893       3    1    2     0         2      3        0          6
# 2          894       2    0    3     1         1      2        1          6
# 3          895       3    0    1     1         2      2        1          3
# 4          896       3    1    1     1         2      3        0          3

# %% [markdown]
# # 6. Modelling
#
# For the modelling part of this project we will utilise the Scikit-learn library for machine learning.
#
#  As discussed above, this is a classfication problem, so consequently will use classfication models for our training.  We have chosen to investigate the performance of the following classifiers:
#
# - Logistic regression
# - Multi Layer Perceptron
# - K-nearest neighbours
# - Gaussian naive bayes
# - Perceptron
# - Linear SVC
# - Stochastic gradient descent
# - Decision tree
# - Random forest
# - CatBoost
# - Support vector machines
#
# In this section , we will fit the models to the training data set and evaluate the models' prediction accuracy. Further on we  will implement hyperparameter tuning to further boost the performance of the the following models:
#
# - Logistic regression
# - Multi Layer Perceptron
# - K-nearest neighbours
# - Gaussian naive bayes
#
# We are training our models using the entire training set provided. We then calculate the accuracy of each model for the training set data. In other words we  determine how accurate each model is when it is asked to predict the outcome  (survival)  for the passengers with  which it was trained. High scores might be an inidcation of which algorithms are likely to work well for predicting survival of passenges in the test set(this is the ultimate goal), however high scores could also indicate overfitting which will result in poor accuracy on the test set.

# %% [markdown]
# ## 6.1 Split training data
#
# We need to first split our training data into independent variables or predictor variables, represented by X as well as  dependent variable or response variable, represented by Y.
#
# Y_train is the survived column in our training set and X_train is the other columns in the training set excluding the Survived column. Our models will learn to classify survival, Y_train based on all X_train and make predictions on X_test.

# %%
X_train = train.drop('Survived', axis = 1)
Y_train = train['Survived']
X_test = test.drop('PassengerId', axis = 1).copy()#why only drop now
print("X_train shape: ", X_train.shape)
print("Y_train shape: ", Y_train.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (891, 8)
# Y_train shape:  (891,)
# X_test shape:  (418, 8)

# %% [markdown]
# ## 6.2 Fit model to data and make predictions
#
# This requires 3 simple steps: instantiate the model, fit the model to the training set and predict the data in test set.

# %% [markdown]
# ### 6.2.1 Logistic regression

# %%
#rael
logReg = LogisticRegression()
LGtrained=logReg.fit(X_train, Y_train)
accuracy_log = round(logReg.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.2 Support vector machines

# %%
#rael
svc = SVC()
SVCtrained=svc.fit(X_train, Y_train)
accuracy_svc = round(svc.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.3 K-nearest neighbours (KNN)

# %%
#rael

knn = KNeighborsClassifier(n_neighbors = 5)
KNNtrained=knn.fit(X_train, Y_train)
accuracy_knn = round(knn.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.4 Gaussian naive bayes

# %%
#rael
gaussianNB = GaussianNB()
GNBtrained=gaussianNB.fit(X_train, Y_train)
accuracy_gaussian = round(gaussianNB.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.5 Perceptron

# %%
#rael
perceptron = Perceptron()
peceptronTrained=perceptron.fit(X_train, Y_train)
accuracy_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.6 Linear SVC

# %%
#rael
linearSVC = LinearSVC()
LSVCtrained=linearSVC.fit(X_train, Y_train)
accuracy_linear_svc = round(linearSVC.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.7 Stochastic gradient descent

# %%
#rael
sgd = SGDClassifier()
SGDtrained=sgd.fit(X_train, Y_train)
accuracy_sgd = round(sgd.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.8 Decision tree

# %%
#rael
decision_tree = DecisionTreeClassifier()
DTtrained=decision_tree.fit(X_train, Y_train)
accuracy_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
accuracy_decision_tree
# Out:
# 86.87

# %% [markdown]
# ### 6.2.9 Random forest

# %%
#rael
random_forest = RandomForestClassifier(n_estimators = 100)
Rftrained=random_forest.fit(X_train, Y_train)
accuracy_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.10 CatBoost

# %%
#rael
catBoost = CatBoostClassifier()
CBtrained=catBoost.fit(X_train, Y_train)
accuracy_catboost = round(catBoost.score(X_train, Y_train) * 100, 2)
# Out:
# Learning rate set to 0.009807
# 0:	learn: 0.6869367	total: 1.12ms	remaining: 1.11s
# 1:	learn: 0.6802063	total: 1.8ms	remaining: 897ms
# 2:	learn: 0.6763902	total: 2.41ms	remaining: 800ms
# 3:	learn: 0.6705524	total: 2.79ms	remaining: 693ms
# 4:	learn: 0.6647134	total: 3.31ms	remaining: 659ms
# 5:	learn: 0.6585278	total: 4.2ms	remaining: 695ms
# 6:	learn: 0.6523593	total: 4.74ms	remaining: 672ms
# 7:	learn: 0.6472788	total: 5.3ms	remaining: 658ms
# 8:	learn: 0.6415958	total: 5.89ms	remaining: 648ms
# 9:	learn: 0.6358084	total: 7.44ms	remaining: 737ms
# 10:	learn: 0.6305012	total: 8.28ms	remaining: 744ms
# 11:	learn: 0.6248362	total: 8.91ms	remaining: 733ms
# 12:	learn: 0.6194929	total: 9.56ms	remaining: 726ms
# 13:	learn: 0.6149068	total: 9.88ms	remaining: 696ms
# 14:	learn: 0.6103341	total: 10.4ms	remaining: 681ms
# 15:	learn: 0.6056313	total: 10.8ms	remaining: 662ms
# 16:	learn: 0.6007540	total: 11.3ms	remaining: 653ms
# 17:	learn: 0.5966403	total: 11.9ms	remaining: 651ms
# 18:	learn: 0.5928476	total: 12.4ms	remaining: 642ms
# 19:	learn: 0.5886954	total: 12.9ms	remaining: 634ms
# 20:	learn: 0.5842136	total: 13.5ms	remaining: 628ms
# 21:	learn: 0.5797661	total: 13.9ms	remaining: 620ms
# 22:	learn: 0.5757488	total: 14.5ms	remaining: 614ms
# 23:	learn: 0.5713633	total: 15.2ms	remaining: 617ms
# 24:	learn: 0.5672167	total: 15.6ms	remaining: 610ms
# 25:	learn: 0.5632743	total: 16.4ms	remaining: 614ms
# 26:	learn: 0.5596702	total: 17ms	remaining: 612ms
# 27:	learn: 0.5558808	total: 17.4ms	remaining: 606ms
# 28:	learn: 0.5522932	total: 17.9ms	remaining: 600ms
# 29:	learn: 0.5488750	total: 18.6ms	remaining: 602ms
# 30:	learn: 0.5460025	total: 19.1ms	remaining: 596ms
# 31:	learn: 0.5425912	total: 19.4ms	remaining: 586ms
# 32:	learn: 0.5393361	total: 19.9ms	remaining: 583ms
# 33:	learn: 0.5362857	total: 20.4ms	remaining: 579ms
# 34:	learn: 0.5333014	total: 20.8ms	remaining: 574ms
# 35:	learn: 0.5311089	total: 21.2ms	remaining: 569ms
# 36:	learn: 0.5282205	total: 21.7ms	remaining: 566ms
# 37:	learn: 0.5250413	total: 22.4ms	remaining: 567ms
# 38:	learn: 0.5222665	total: 22.8ms	remaining: 562ms
# 39:	learn: 0.5201982	total: 23.1ms	remaining: 555ms
# 40:	learn: 0.5174225	total: 23.7ms	remaining: 554ms
# 41:	learn: 0.5149646	total: 24.2ms	remaining: 551ms
# 42:	learn: 0.5127689	total: 24.7ms	remaining: 550ms
# 43:	learn: 0.5102136	total: 25.8ms	remaining: 561ms
# 44:	learn: 0.5074517	total: 27.1ms	remaining: 575ms
# 45:	learn: 0.5052863	total: 30.3ms	remaining: 629ms
# 46:	learn: 0.5028941	total: 30.9ms	remaining: 626ms
# 47:	learn: 0.5011386	total: 31.7ms	remaining: 629ms
# 48:	learn: 0.4988674	total: 34.8ms	remaining: 675ms
# 49:	learn: 0.4968862	total: 35.8ms	remaining: 680ms
# 50:	learn: 0.4945562	total: 36.3ms	remaining: 675ms
# 51:	learn: 0.4926094	total: 37ms	remaining: 674ms
# 52:	learn: 0.4912042	total: 37.8ms	remaining: 675ms
# 53:	learn: 0.4889802	total: 38.3ms	remaining: 672ms
# 54:	learn: 0.4867844	total: 38.9ms	remaining: 668ms
# 55:	learn: 0.4847787	total: 39.4ms	remaining: 664ms
# 56:	learn: 0.4827311	total: 40ms	remaining: 661ms
# 57:	learn: 0.4811682	total: 40.6ms	remaining: 659ms
# 58:	learn: 0.4791430	total: 41.3ms	remaining: 659ms
# 59:	learn: 0.4782462	total: 41.9ms	remaining: 656ms
# 60:	learn: 0.4762638	total: 42.7ms	remaining: 657ms
# 61:	learn: 0.4745190	total: 43.8ms	remaining: 663ms
# 62:	learn: 0.4729461	total: 44.5ms	remaining: 662ms
# 63:	learn: 0.4709836	total: 45.2ms	remaining: 661ms
# 64:	learn: 0.4694420	total: 45.8ms	remaining: 659ms
# 65:	learn: 0.4676655	total: 46.4ms	remaining: 656ms
# 66:	learn: 0.4661794	total: 46.9ms	remaining: 653ms
# 67:	learn: 0.4646871	total: 47.5ms	remaining: 652ms
# 68:	learn: 0.4631852	total: 48ms	remaining: 648ms
# 69:	learn: 0.4616488	total: 48.5ms	remaining: 645ms
# 70:	learn: 0.4604525	total: 49.1ms	remaining: 642ms
# 71:	learn: 0.4585981	total: 49.8ms	remaining: 642ms
# 72:	learn: 0.4571592	total: 50.4ms	remaining: 639ms
# 73:	learn: 0.4563581	total: 50.9ms	remaining: 636ms
# 74:	learn: 0.4552482	total: 51.5ms	remaining: 635ms
# 75:	learn: 0.4539460	total: 52ms	remaining: 632ms
# 76:	learn: 0.4526418	total: 52.8ms	remaining: 633ms
# 77:	learn: 0.4516035	total: 53.4ms	remaining: 631ms
# 78:	learn: 0.4506780	total: 54ms	remaining: 630ms
# 79:	learn: 0.4498624	total: 54.6ms	remaining: 628ms
# 80:	learn: 0.4484309	total: 55.6ms	remaining: 631ms
# 81:	learn: 0.4474088	total: 56.6ms	remaining: 634ms
# 82:	learn: 0.4462057	total: 57.2ms	remaining: 632ms
# 83:	learn: 0.4451301	total: 57.8ms	remaining: 630ms
# 84:	learn: 0.4443791	total: 58.2ms	remaining: 626ms
# 85:	learn: 0.4431987	total: 58.7ms	remaining: 624ms
# 86:	learn: 0.4420580	total: 59.2ms	remaining: 621ms
# 87:	learn: 0.4408750	total: 59.7ms	remaining: 619ms
# 88:	learn: 0.4404513	total: 60.1ms	remaining: 615ms
# 89:	learn: 0.4398193	total: 60.6ms	remaining: 612ms
# 90:	learn: 0.4388080	total: 61ms	remaining: 609ms
# 91:	learn: 0.4384103	total: 61.4ms	remaining: 606ms
# 92:	learn: 0.4372531	total: 61.9ms	remaining: 604ms
# 93:	learn: 0.4363489	total: 62.5ms	remaining: 603ms
# 94:	learn: 0.4350819	total: 63.1ms	remaining: 601ms
# 95:	learn: 0.4347065	total: 63.6ms	remaining: 598ms
# 96:	learn: 0.4342171	total: 63.9ms	remaining: 595ms
# 97:	learn: 0.4334116	total: 64.4ms	remaining: 593ms
# 98:	learn: 0.4324293	total: 64.8ms	remaining: 590ms
# 99:	learn: 0.4317612	total: 65.3ms	remaining: 587ms
# 100:	learn: 0.4309562	total: 65.9ms	remaining: 587ms
# 101:	learn: 0.4298967	total: 66.6ms	remaining: 586ms
# 102:	learn: 0.4289195	total: 67.8ms	remaining: 590ms
# 103:	learn: 0.4280995	total: 68.3ms	remaining: 589ms
# 104:	learn: 0.4271924	total: 69ms	remaining: 588ms
# 105:	learn: 0.4266946	total: 69.4ms	remaining: 585ms
# 106:	learn: 0.4258925	total: 70.2ms	remaining: 586ms
# 107:	learn: 0.4251587	total: 70.8ms	remaining: 585ms
# 108:	learn: 0.4248479	total: 71.3ms	remaining: 583ms
# 109:	learn: 0.4240055	total: 71.7ms	remaining: 580ms
# 110:	learn: 0.4235308	total: 72.2ms	remaining: 578ms
# 111:	learn: 0.4227740	total: 72.7ms	remaining: 576ms
# 112:	learn: 0.4219111	total: 73.2ms	remaining: 575ms
# 113:	learn: 0.4210236	total: 73.7ms	remaining: 573ms
# 114:	learn: 0.4203964	total: 74.2ms	remaining: 571ms
# 115:	learn: 0.4203034	total: 74.6ms	remaining: 568ms
# 116:	learn: 0.4200127	total: 75ms	remaining: 566ms
# 117:	learn: 0.4192273	total: 75.5ms	remaining: 564ms
# 118:	learn: 0.4183042	total: 76ms	remaining: 563ms
# 119:	learn: 0.4175200	total: 76.4ms	remaining: 560ms
# 120:	learn: 0.4169033	total: 77ms	remaining: 559ms
# 121:	learn: 0.4161869	total: 77.6ms	remaining: 558ms
# 122:	learn: 0.4154717	total: 78.1ms	remaining: 557ms
# 123:	learn: 0.4145984	total: 79ms	remaining: 558ms
# 124:	learn: 0.4140638	total: 79.6ms	remaining: 557ms
# 125:	learn: 0.4134350	total: 80.3ms	remaining: 557ms
# 126:	learn: 0.4128162	total: 81ms	remaining: 556ms
# 127:	learn: 0.4121368	total: 81.6ms	remaining: 556ms
# 128:	learn: 0.4118899	total: 82.3ms	remaining: 555ms
# 129:	learn: 0.4112843	total: 83.7ms	remaining: 560ms
# 130:	learn: 0.4107075	total: 84.4ms	remaining: 560ms
# 131:	learn: 0.4100449	total: 85.2ms	remaining: 560ms
# 132:	learn: 0.4094469	total: 85.8ms	remaining: 559ms
# 133:	learn: 0.4089366	total: 86.4ms	remaining: 558ms
# 134:	learn: 0.4084792	total: 86.9ms	remaining: 557ms
# 135:	learn: 0.4079321	total: 87.5ms	remaining: 556ms
# 136:	learn: 0.4072366	total: 88.2ms	remaining: 556ms
# 137:	learn: 0.4065198	total: 88.8ms	remaining: 555ms
# 138:	learn: 0.4060023	total: 89.3ms	remaining: 553ms
# 139:	learn: 0.4055060	total: 89.8ms	remaining: 552ms
# 140:	learn: 0.4052668	total: 90.3ms	remaining: 550ms
# 141:	learn: 0.4047932	total: 90.9ms	remaining: 549ms
# 142:	learn: 0.4043335	total: 91.5ms	remaining: 548ms
# 143:	learn: 0.4036350	total: 92.9ms	remaining: 552ms
# 144:	learn: 0.4032236	total: 93.6ms	remaining: 552ms
# 145:	learn: 0.4028588	total: 94.5ms	remaining: 552ms
# 146:	learn: 0.4027297	total: 95.1ms	remaining: 552ms
# 147:	learn: 0.4020191	total: 95.7ms	remaining: 551ms
# 148:	learn: 0.4013803	total: 96.3ms	remaining: 550ms
# 149:	learn: 0.4012722	total: 96.7ms	remaining: 548ms
# 150:	learn: 0.4008516	total: 97.2ms	remaining: 546ms
# 151:	learn: 0.4003298	total: 97.8ms	remaining: 546ms
# 152:	learn: 0.3999998	total: 98.2ms	remaining: 544ms
# 153:	learn: 0.3998927	total: 98.6ms	remaining: 542ms
# 154:	learn: 0.3995177	total: 99.2ms	remaining: 541ms
# 155:	learn: 0.3994406	total: 99.5ms	remaining: 538ms
# 156:	learn: 0.3989952	total: 99.9ms	remaining: 537ms
# 157:	learn: 0.3984464	total: 100ms	remaining: 536ms
# 158:	learn: 0.3982301	total: 101ms	remaining: 533ms
# 159:	learn: 0.3976376	total: 101ms	remaining: 532ms
# 160:	learn: 0.3971882	total: 102ms	remaining: 531ms
# 161:	learn: 0.3967218	total: 102ms	remaining: 529ms
# 162:	learn: 0.3963655	total: 103ms	remaining: 529ms
# 163:	learn: 0.3958226	total: 104ms	remaining: 529ms
# 164:	learn: 0.3955518	total: 105ms	remaining: 532ms
# 165:	learn: 0.3950262	total: 106ms	remaining: 534ms
# 166:	learn: 0.3945389	total: 107ms	remaining: 535ms
# 167:	learn: 0.3942235	total: 108ms	remaining: 534ms
# 168:	learn: 0.3940161	total: 108ms	remaining: 532ms
# 169:	learn: 0.3935943	total: 109ms	remaining: 530ms
# 170:	learn: 0.3932189	total: 109ms	remaining: 529ms
# 171:	learn: 0.3929150	total: 110ms	remaining: 527ms
# 172:	learn: 0.3926918	total: 110ms	remaining: 526ms
# 173:	learn: 0.3923629	total: 110ms	remaining: 524ms
# 174:	learn: 0.3922009	total: 111ms	remaining: 523ms
# 175:	learn: 0.3920736	total: 112ms	remaining: 524ms
# 176:	learn: 0.3916779	total: 112ms	remaining: 523ms
# 177:	learn: 0.3914350	total: 113ms	remaining: 521ms
# 178:	learn: 0.3911885	total: 113ms	remaining: 520ms
# 179:	learn: 0.3908091	total: 114ms	remaining: 518ms
# 180:	learn: 0.3903432	total: 114ms	remaining: 517ms
# 181:	learn: 0.3899910	total: 116ms	remaining: 522ms
# 182:	learn: 0.3896461	total: 117ms	remaining: 524ms
# 183:	learn: 0.3893101	total: 118ms	remaining: 523ms
# 184:	learn: 0.3887317	total: 118ms	remaining: 522ms
# 185:	learn: 0.3885765	total: 119ms	remaining: 520ms
# 186:	learn: 0.3882769	total: 119ms	remaining: 519ms
# 187:	learn: 0.3879092	total: 120ms	remaining: 517ms
# 188:	learn: 0.3876866	total: 120ms	remaining: 515ms
# 189:	learn: 0.3874847	total: 121ms	remaining: 514ms
# 190:	learn: 0.3872400	total: 121ms	remaining: 513ms
# 191:	learn: 0.3868217	total: 121ms	remaining: 511ms
# 192:	learn: 0.3866182	total: 122ms	remaining: 510ms
# 193:	learn: 0.3865879	total: 122ms	remaining: 508ms
# 194:	learn: 0.3862865	total: 123ms	remaining: 507ms
# 195:	learn: 0.3860427	total: 123ms	remaining: 505ms
# 196:	learn: 0.3856470	total: 124ms	remaining: 504ms
# 197:	learn: 0.3852573	total: 124ms	remaining: 502ms
# 198:	learn: 0.3849065	total: 124ms	remaining: 501ms
# 199:	learn: 0.3845554	total: 125ms	remaining: 500ms
# 200:	learn: 0.3842121	total: 125ms	remaining: 498ms
# 201:	learn: 0.3840271	total: 126ms	remaining: 497ms
# 202:	learn: 0.3837663	total: 126ms	remaining: 496ms
# 203:	learn: 0.3833832	total: 127ms	remaining: 495ms
# 204:	learn: 0.3831694	total: 128ms	remaining: 495ms
# 205:	learn: 0.3828575	total: 128ms	remaining: 495ms
# 206:	learn: 0.3825637	total: 129ms	remaining: 495ms
# 207:	learn: 0.3823535	total: 130ms	remaining: 494ms
# 208:	learn: 0.3821663	total: 130ms	remaining: 493ms
# 209:	learn: 0.3818708	total: 131ms	remaining: 492ms
# 210:	learn: 0.3816473	total: 131ms	remaining: 490ms
# 211:	learn: 0.3815777	total: 132ms	remaining: 490ms
# 212:	learn: 0.3815172	total: 132ms	remaining: 489ms
# 213:	learn: 0.3813598	total: 133ms	remaining: 488ms
# 214:	learn: 0.3810644	total: 133ms	remaining: 486ms
# 215:	learn: 0.3807692	total: 134ms	remaining: 485ms
# 216:	learn: 0.3806806	total: 134ms	remaining: 484ms
# 217:	learn: 0.3804998	total: 135ms	remaining: 483ms
# 218:	learn: 0.3801817	total: 135ms	remaining: 481ms
# 219:	learn: 0.3799372	total: 135ms	remaining: 480ms
# 220:	learn: 0.3796446	total: 136ms	remaining: 479ms
# 221:	learn: 0.3794567	total: 136ms	remaining: 478ms
# 222:	learn: 0.3791995	total: 137ms	remaining: 476ms
# 223:	learn: 0.3791528	total: 137ms	remaining: 475ms
# 224:	learn: 0.3790590	total: 138ms	remaining: 474ms
# 225:	learn: 0.3789087	total: 138ms	remaining: 472ms
# 226:	learn: 0.3786226	total: 138ms	remaining: 471ms
# 227:	learn: 0.3784804	total: 139ms	remaining: 470ms
# 228:	learn: 0.3782829	total: 139ms	remaining: 469ms
# 229:	learn: 0.3781074	total: 140ms	remaining: 470ms
# 230:	learn: 0.3780198	total: 141ms	remaining: 471ms
# 231:	learn: 0.3777995	total: 142ms	remaining: 470ms
# 232:	learn: 0.3775920	total: 142ms	remaining: 469ms
# 233:	learn: 0.3773444	total: 143ms	remaining: 467ms
# 234:	learn: 0.3770107	total: 144ms	remaining: 468ms
# 235:	learn: 0.3769828	total: 144ms	remaining: 467ms
# 236:	learn: 0.3768312	total: 145ms	remaining: 466ms
# 237:	learn: 0.3765772	total: 145ms	remaining: 465ms
# 238:	learn: 0.3763535	total: 146ms	remaining: 464ms
# 239:	learn: 0.3761857	total: 146ms	remaining: 463ms
# 240:	learn: 0.3759122	total: 147ms	remaining: 462ms
# 241:	learn: 0.3758858	total: 147ms	remaining: 461ms
# 242:	learn: 0.3758071	total: 148ms	remaining: 461ms
# 243:	learn: 0.3757440	total: 148ms	remaining: 459ms
# 244:	learn: 0.3756091	total: 149ms	remaining: 458ms
# 245:	learn: 0.3754375	total: 149ms	remaining: 457ms
# 246:	learn: 0.3753918	total: 150ms	remaining: 456ms
# 247:	learn: 0.3750912	total: 150ms	remaining: 455ms
# 248:	learn: 0.3748922	total: 150ms	remaining: 454ms
# 249:	learn: 0.3747207	total: 151ms	remaining: 453ms
# 250:	learn: 0.3746763	total: 151ms	remaining: 451ms
# 251:	learn: 0.3743547	total: 152ms	remaining: 450ms
# 252:	learn: 0.3741906	total: 152ms	remaining: 449ms
# 253:	learn: 0.3738509	total: 153ms	remaining: 448ms
# 254:	learn: 0.3735894	total: 153ms	remaining: 448ms
# 255:	learn: 0.3733012	total: 154ms	remaining: 447ms
# 256:	learn: 0.3730155	total: 155ms	remaining: 448ms
# 257:	learn: 0.3727927	total: 155ms	remaining: 446ms
# 258:	learn: 0.3726666	total: 156ms	remaining: 446ms
# 259:	learn: 0.3726010	total: 157ms	remaining: 447ms
# 260:	learn: 0.3723027	total: 157ms	remaining: 446ms
# 261:	learn: 0.3720011	total: 158ms	remaining: 444ms
# 262:	learn: 0.3718457	total: 158ms	remaining: 443ms
# 263:	learn: 0.3717328	total: 158ms	remaining: 441ms
# 264:	learn: 0.3715810	total: 159ms	remaining: 440ms
# 265:	learn: 0.3714113	total: 159ms	remaining: 439ms
# 266:	learn: 0.3710909	total: 160ms	remaining: 438ms
# 267:	learn: 0.3710061	total: 160ms	remaining: 437ms
# 268:	learn: 0.3708509	total: 160ms	remaining: 436ms
# 269:	learn: 0.3707693	total: 161ms	remaining: 435ms
# 270:	learn: 0.3706200	total: 161ms	remaining: 433ms
# 271:	learn: 0.3704139	total: 162ms	remaining: 433ms
# 272:	learn: 0.3702133	total: 162ms	remaining: 431ms
# 273:	learn: 0.3699442	total: 163ms	remaining: 431ms
# 274:	learn: 0.3696665	total: 163ms	remaining: 429ms
# 275:	learn: 0.3694359	total: 163ms	remaining: 429ms
# 276:	learn: 0.3692334	total: 164ms	remaining: 428ms
# 277:	learn: 0.3692312	total: 164ms	remaining: 426ms
# 278:	learn: 0.3690803	total: 165ms	remaining: 426ms
# 279:	learn: 0.3690014	total: 166ms	remaining: 427ms
# 280:	learn: 0.3689386	total: 167ms	remaining: 426ms
# 281:	learn: 0.3687593	total: 167ms	remaining: 425ms
# 282:	learn: 0.3685900	total: 167ms	remaining: 424ms
# 283:	learn: 0.3684455	total: 168ms	remaining: 423ms
# 284:	learn: 0.3682941	total: 168ms	remaining: 422ms
# 285:	learn: 0.3681736	total: 169ms	remaining: 421ms
# 286:	learn: 0.3679727	total: 170ms	remaining: 422ms
# 287:	learn: 0.3677997	total: 171ms	remaining: 423ms
# 288:	learn: 0.3677552	total: 171ms	remaining: 422ms
# 289:	learn: 0.3675807	total: 172ms	remaining: 420ms
# 290:	learn: 0.3674230	total: 172ms	remaining: 419ms
# 291:	learn: 0.3672692	total: 172ms	remaining: 418ms
# 292:	learn: 0.3670796	total: 173ms	remaining: 417ms
# 293:	learn: 0.3669577	total: 173ms	remaining: 416ms
# 294:	learn: 0.3666762	total: 174ms	remaining: 415ms
# 295:	learn: 0.3665953	total: 174ms	remaining: 414ms
# 296:	learn: 0.3665658	total: 174ms	remaining: 413ms
# 297:	learn: 0.3664035	total: 175ms	remaining: 413ms
# 298:	learn: 0.3661565	total: 176ms	remaining: 413ms
# 299:	learn: 0.3659923	total: 177ms	remaining: 413ms
# 300:	learn: 0.3658980	total: 178ms	remaining: 413ms
# 301:	learn: 0.3657657	total: 179ms	remaining: 414ms
# 302:	learn: 0.3656035	total: 180ms	remaining: 413ms
# 303:	learn: 0.3653795	total: 180ms	remaining: 412ms
# 304:	learn: 0.3652759	total: 180ms	remaining: 411ms
# 305:	learn: 0.3651407	total: 181ms	remaining: 410ms
# 306:	learn: 0.3648452	total: 182ms	remaining: 410ms
# 307:	learn: 0.3647433	total: 182ms	remaining: 409ms
# 308:	learn: 0.3647027	total: 183ms	remaining: 408ms
# 309:	learn: 0.3646032	total: 183ms	remaining: 407ms
# 310:	learn: 0.3643894	total: 184ms	remaining: 407ms
# 311:	learn: 0.3643158	total: 184ms	remaining: 406ms
# 312:	learn: 0.3641995	total: 185ms	remaining: 405ms
# 313:	learn: 0.3640365	total: 185ms	remaining: 404ms
# 314:	learn: 0.3638929	total: 185ms	remaining: 403ms
# 315:	learn: 0.3638403	total: 186ms	remaining: 402ms
# 316:	learn: 0.3637239	total: 187ms	remaining: 402ms
# 317:	learn: 0.3636081	total: 187ms	remaining: 401ms
# 318:	learn: 0.3635025	total: 188ms	remaining: 401ms
# 319:	learn: 0.3633612	total: 188ms	remaining: 400ms
# 320:	learn: 0.3633472	total: 189ms	remaining: 399ms
# 321:	learn: 0.3633277	total: 189ms	remaining: 398ms
# 322:	learn: 0.3631678	total: 190ms	remaining: 398ms
# 323:	learn: 0.3630166	total: 190ms	remaining: 397ms
# 324:	learn: 0.3628696	total: 191ms	remaining: 396ms
# 325:	learn: 0.3626512	total: 192ms	remaining: 397ms
# 326:	learn: 0.3625520	total: 193ms	remaining: 397ms
# 327:	learn: 0.3624494	total: 193ms	remaining: 396ms
# 328:	learn: 0.3624292	total: 194ms	remaining: 395ms
# 329:	learn: 0.3623033	total: 194ms	remaining: 394ms
# 330:	learn: 0.3621699	total: 195ms	remaining: 393ms
# 331:	learn: 0.3621129	total: 195ms	remaining: 392ms
# 332:	learn: 0.3620124	total: 196ms	remaining: 392ms
# 333:	learn: 0.3619379	total: 196ms	remaining: 391ms
# 334:	learn: 0.3617723	total: 197ms	remaining: 390ms
# 335:	learn: 0.3616445	total: 197ms	remaining: 389ms
# 336:	learn: 0.3616429	total: 197ms	remaining: 388ms
# 337:	learn: 0.3615513	total: 198ms	remaining: 388ms
# 338:	learn: 0.3614399	total: 198ms	remaining: 387ms
# 339:	learn: 0.3613288	total: 199ms	remaining: 386ms
# 340:	learn: 0.3611055	total: 199ms	remaining: 385ms
# 341:	learn: 0.3610458	total: 200ms	remaining: 384ms
# 342:	learn: 0.3609319	total: 200ms	remaining: 384ms
# 343:	learn: 0.3606793	total: 201ms	remaining: 383ms
# 344:	learn: 0.3604324	total: 201ms	remaining: 382ms
# 345:	learn: 0.3601965	total: 202ms	remaining: 381ms
# 346:	learn: 0.3599434	total: 202ms	remaining: 380ms
# 347:	learn: 0.3599404	total: 202ms	remaining: 379ms
# 348:	learn: 0.3598822	total: 203ms	remaining: 378ms
# 349:	learn: 0.3597532	total: 203ms	remaining: 377ms
# 350:	learn: 0.3597214	total: 204ms	remaining: 377ms
# 351:	learn: 0.3595147	total: 205ms	remaining: 378ms
# 352:	learn: 0.3593634	total: 206ms	remaining: 378ms
# 353:	learn: 0.3592750	total: 206ms	remaining: 377ms
# 354:	learn: 0.3592647	total: 207ms	remaining: 376ms
# 355:	learn: 0.3590915	total: 208ms	remaining: 377ms
# 356:	learn: 0.3590416	total: 209ms	remaining: 376ms
# 357:	learn: 0.3589445	total: 210ms	remaining: 376ms
# 358:	learn: 0.3589443	total: 210ms	remaining: 375ms
# 359:	learn: 0.3588395	total: 211ms	remaining: 374ms
# 360:	learn: 0.3587099	total: 211ms	remaining: 373ms
# 361:	learn: 0.3587002	total: 211ms	remaining: 372ms
# 362:	learn: 0.3586367	total: 212ms	remaining: 372ms
# 363:	learn: 0.3585333	total: 212ms	remaining: 371ms
# 364:	learn: 0.3583804	total: 213ms	remaining: 370ms
# 365:	learn: 0.3582016	total: 213ms	remaining: 370ms
# 366:	learn: 0.3580236	total: 214ms	remaining: 369ms
# 367:	learn: 0.3578552	total: 214ms	remaining: 368ms
# 368:	learn: 0.3576952	total: 214ms	remaining: 366ms
# 369:	learn: 0.3575797	total: 215ms	remaining: 366ms
# 370:	learn: 0.3573966	total: 216ms	remaining: 366ms
# 371:	learn: 0.3573686	total: 217ms	remaining: 367ms
# 372:	learn: 0.3571866	total: 218ms	remaining: 366ms
# 373:	learn: 0.3570248	total: 218ms	remaining: 365ms
# 374:	learn: 0.3569527	total: 219ms	remaining: 364ms
# 375:	learn: 0.3568234	total: 219ms	remaining: 363ms
# 376:	learn: 0.3567055	total: 219ms	remaining: 363ms
# 377:	learn: 0.3566333	total: 220ms	remaining: 362ms
# 378:	learn: 0.3565747	total: 221ms	remaining: 362ms
# 379:	learn: 0.3564849	total: 221ms	remaining: 361ms
# 380:	learn: 0.3564467	total: 222ms	remaining: 360ms
# 381:	learn: 0.3563399	total: 222ms	remaining: 360ms
# 382:	learn: 0.3563175	total: 223ms	remaining: 359ms
# 383:	learn: 0.3561704	total: 223ms	remaining: 358ms
# 384:	learn: 0.3561136	total: 224ms	remaining: 358ms
# 385:	learn: 0.3559574	total: 224ms	remaining: 357ms
# 386:	learn: 0.3559491	total: 225ms	remaining: 356ms
# 387:	learn: 0.3558232	total: 225ms	remaining: 355ms
# 388:	learn: 0.3557401	total: 226ms	remaining: 354ms
# 389:	learn: 0.3555939	total: 226ms	remaining: 354ms
# 390:	learn: 0.3554047	total: 227ms	remaining: 353ms
# 391:	learn: 0.3553728	total: 227ms	remaining: 352ms
# 392:	learn: 0.3553047	total: 228ms	remaining: 351ms
# 393:	learn: 0.3552176	total: 228ms	remaining: 351ms
# 394:	learn: 0.3552129	total: 229ms	remaining: 350ms
# 395:	learn: 0.3550583	total: 230ms	remaining: 350ms
# 396:	learn: 0.3549694	total: 230ms	remaining: 350ms
# 397:	learn: 0.3548070	total: 231ms	remaining: 349ms
# 398:	learn: 0.3546647	total: 231ms	remaining: 348ms
# 399:	learn: 0.3545695	total: 232ms	remaining: 347ms
# 400:	learn: 0.3545127	total: 232ms	remaining: 347ms
# 401:	learn: 0.3544103	total: 232ms	remaining: 346ms
# 402:	learn: 0.3542592	total: 233ms	remaining: 345ms
# 403:	learn: 0.3542433	total: 233ms	remaining: 344ms
# 404:	learn: 0.3541093	total: 234ms	remaining: 343ms
# 405:	learn: 0.3540359	total: 234ms	remaining: 343ms
# 406:	learn: 0.3539365	total: 235ms	remaining: 342ms
# 407:	learn: 0.3538399	total: 235ms	remaining: 341ms
# 408:	learn: 0.3537448	total: 236ms	remaining: 340ms
# 409:	learn: 0.3536289	total: 236ms	remaining: 340ms
# 410:	learn: 0.3535271	total: 236ms	remaining: 339ms
# 411:	learn: 0.3534575	total: 237ms	remaining: 338ms
# 412:	learn: 0.3533616	total: 237ms	remaining: 337ms
# 413:	learn: 0.3532976	total: 238ms	remaining: 337ms
# 414:	learn: 0.3532772	total: 238ms	remaining: 336ms
# 415:	learn: 0.3531297	total: 239ms	remaining: 335ms
# 416:	learn: 0.3530808	total: 239ms	remaining: 334ms
# 417:	learn: 0.3529183	total: 239ms	remaining: 333ms
# 418:	learn: 0.3527253	total: 240ms	remaining: 333ms
# 419:	learn: 0.3526765	total: 240ms	remaining: 332ms
# 420:	learn: 0.3525732	total: 241ms	remaining: 331ms
# 421:	learn: 0.3524944	total: 241ms	remaining: 331ms
# 422:	learn: 0.3524850	total: 242ms	remaining: 331ms
# 423:	learn: 0.3523515	total: 243ms	remaining: 330ms
# 424:	learn: 0.3522624	total: 244ms	remaining: 330ms
# 425:	learn: 0.3520993	total: 244ms	remaining: 329ms
# 426:	learn: 0.3519943	total: 245ms	remaining: 328ms
# 427:	learn: 0.3519908	total: 245ms	remaining: 327ms
# 428:	learn: 0.3518989	total: 246ms	remaining: 327ms
# 429:	learn: 0.3518743	total: 246ms	remaining: 327ms
# 430:	learn: 0.3517932	total: 247ms	remaining: 326ms
# 431:	learn: 0.3517203	total: 248ms	remaining: 326ms
# 432:	learn: 0.3515970	total: 249ms	remaining: 325ms
# 433:	learn: 0.3514794	total: 249ms	remaining: 325ms
# 434:	learn: 0.3513682	total: 250ms	remaining: 325ms
# 435:	learn: 0.3512964	total: 251ms	remaining: 324ms
# 436:	learn: 0.3512200	total: 251ms	remaining: 323ms
# 437:	learn: 0.3510722	total: 251ms	remaining: 323ms
# 438:	learn: 0.3509369	total: 252ms	remaining: 322ms
# 439:	learn: 0.3508289	total: 252ms	remaining: 321ms
# 440:	learn: 0.3507922	total: 253ms	remaining: 320ms
# 441:	learn: 0.3505775	total: 253ms	remaining: 320ms
# 442:	learn: 0.3504606	total: 254ms	remaining: 319ms
# 443:	learn: 0.3503991	total: 254ms	remaining: 318ms
# 444:	learn: 0.3502980	total: 255ms	remaining: 317ms
# 445:	learn: 0.3502628	total: 255ms	remaining: 317ms
# 446:	learn: 0.3501994	total: 256ms	remaining: 317ms
# 447:	learn: 0.3501651	total: 257ms	remaining: 316ms
# 448:	learn: 0.3501156	total: 257ms	remaining: 316ms
# 449:	learn: 0.3500752	total: 258ms	remaining: 315ms
# 450:	learn: 0.3500305	total: 258ms	remaining: 314ms
# 451:	learn: 0.3499140	total: 259ms	remaining: 314ms
# 452:	learn: 0.3497286	total: 259ms	remaining: 313ms
# 453:	learn: 0.3495987	total: 260ms	remaining: 312ms
# 454:	learn: 0.3495546	total: 260ms	remaining: 311ms
# 455:	learn: 0.3494718	total: 260ms	remaining: 311ms
# 456:	learn: 0.3493720	total: 261ms	remaining: 310ms
# 457:	learn: 0.3493199	total: 261ms	remaining: 309ms
# 458:	learn: 0.3491475	total: 262ms	remaining: 309ms
# 459:	learn: 0.3490661	total: 262ms	remaining: 308ms
# 460:	learn: 0.3489372	total: 263ms	remaining: 307ms
# 461:	learn: 0.3489318	total: 263ms	remaining: 306ms
# 462:	learn: 0.3487770	total: 264ms	remaining: 306ms
# 463:	learn: 0.3487201	total: 264ms	remaining: 305ms
# 464:	learn: 0.3485835	total: 264ms	remaining: 304ms
# 465:	learn: 0.3484721	total: 265ms	remaining: 303ms
# 466:	learn: 0.3484604	total: 265ms	remaining: 303ms
# 467:	learn: 0.3484032	total: 266ms	remaining: 302ms
# 468:	learn: 0.3482564	total: 266ms	remaining: 301ms
# 469:	learn: 0.3481681	total: 267ms	remaining: 301ms
# 470:	learn: 0.3481177	total: 267ms	remaining: 300ms
# 471:	learn: 0.3480291	total: 267ms	remaining: 299ms
# 472:	learn: 0.3479659	total: 268ms	remaining: 299ms
# 473:	learn: 0.3479072	total: 269ms	remaining: 299ms
# 474:	learn: 0.3478450	total: 270ms	remaining: 299ms
# 475:	learn: 0.3477756	total: 271ms	remaining: 298ms
# 476:	learn: 0.3476929	total: 271ms	remaining: 297ms
# 477:	learn: 0.3475637	total: 272ms	remaining: 297ms
# 478:	learn: 0.3475631	total: 272ms	remaining: 296ms
# 479:	learn: 0.3474622	total: 272ms	remaining: 295ms
# 480:	learn: 0.3474621	total: 273ms	remaining: 294ms
# 481:	learn: 0.3474038	total: 273ms	remaining: 293ms
# 482:	learn: 0.3473379	total: 273ms	remaining: 293ms
# 483:	learn: 0.3472827	total: 274ms	remaining: 292ms
# 484:	learn: 0.3472000	total: 274ms	remaining: 291ms
# 485:	learn: 0.3471512	total: 275ms	remaining: 291ms
# 486:	learn: 0.3471042	total: 275ms	remaining: 290ms
# 487:	learn: 0.3470620	total: 276ms	remaining: 289ms
# 488:	learn: 0.3470160	total: 276ms	remaining: 289ms
# 489:	learn: 0.3469574	total: 277ms	remaining: 288ms
# 490:	learn: 0.3468836	total: 277ms	remaining: 287ms
# 491:	learn: 0.3467465	total: 278ms	remaining: 287ms
# 492:	learn: 0.3466529	total: 278ms	remaining: 286ms
# 493:	learn: 0.3465543	total: 279ms	remaining: 285ms
# 494:	learn: 0.3464279	total: 279ms	remaining: 285ms
# 495:	learn: 0.3464177	total: 279ms	remaining: 284ms
# 496:	learn: 0.3463475	total: 280ms	remaining: 283ms
# 497:	learn: 0.3462450	total: 280ms	remaining: 283ms
# 498:	learn: 0.3462042	total: 281ms	remaining: 282ms
# 499:	learn: 0.3461561	total: 281ms	remaining: 281ms
# 500:	learn: 0.3461510	total: 282ms	remaining: 281ms
# 501:	learn: 0.3461058	total: 282ms	remaining: 280ms
# 502:	learn: 0.3460344	total: 283ms	remaining: 279ms
# 503:	learn: 0.3459389	total: 284ms	remaining: 279ms
# 504:	learn: 0.3458249	total: 284ms	remaining: 279ms
# 505:	learn: 0.3457906	total: 285ms	remaining: 278ms
# 506:	learn: 0.3457043	total: 285ms	remaining: 277ms
# 507:	learn: 0.3457006	total: 285ms	remaining: 276ms
# 508:	learn: 0.3455832	total: 286ms	remaining: 276ms
# 509:	learn: 0.3455014	total: 286ms	remaining: 275ms
# 510:	learn: 0.3454696	total: 287ms	remaining: 274ms
# 511:	learn: 0.3454688	total: 287ms	remaining: 274ms
# 512:	learn: 0.3454335	total: 288ms	remaining: 273ms
# 513:	learn: 0.3453557	total: 288ms	remaining: 272ms
# 514:	learn: 0.3452415	total: 288ms	remaining: 272ms
# 515:	learn: 0.3451736	total: 289ms	remaining: 271ms
# 516:	learn: 0.3450609	total: 289ms	remaining: 270ms
# 517:	learn: 0.3450282	total: 290ms	remaining: 270ms
# 518:	learn: 0.3449629	total: 290ms	remaining: 269ms
# 519:	learn: 0.3449533	total: 291ms	remaining: 268ms
# 520:	learn: 0.3448569	total: 291ms	remaining: 268ms
# 521:	learn: 0.3448519	total: 291ms	remaining: 267ms
# 522:	learn: 0.3447165	total: 292ms	remaining: 266ms
# 523:	learn: 0.3446527	total: 292ms	remaining: 266ms
# 524:	learn: 0.3446455	total: 293ms	remaining: 265ms
# 525:	learn: 0.3445841	total: 293ms	remaining: 264ms
# 526:	learn: 0.3445142	total: 294ms	remaining: 263ms
# 527:	learn: 0.3444885	total: 294ms	remaining: 263ms
# 528:	learn: 0.3444342	total: 295ms	remaining: 262ms
# 529:	learn: 0.3444312	total: 295ms	remaining: 262ms
# 530:	learn: 0.3443244	total: 296ms	remaining: 261ms
# 531:	learn: 0.3442487	total: 297ms	remaining: 261ms
# 532:	learn: 0.3442044	total: 297ms	remaining: 261ms
# 533:	learn: 0.3442026	total: 298ms	remaining: 260ms
# 534:	learn: 0.3441995	total: 298ms	remaining: 259ms
# 535:	learn: 0.3441823	total: 298ms	remaining: 258ms
# 536:	learn: 0.3440226	total: 299ms	remaining: 258ms
# 537:	learn: 0.3439341	total: 300ms	remaining: 257ms
# 538:	learn: 0.3439297	total: 300ms	remaining: 257ms
# 539:	learn: 0.3438511	total: 301ms	remaining: 256ms
# 540:	learn: 0.3437948	total: 302ms	remaining: 256ms
# 541:	learn: 0.3437430	total: 302ms	remaining: 255ms
# 542:	learn: 0.3436731	total: 303ms	remaining: 255ms
# 543:	learn: 0.3435391	total: 303ms	remaining: 254ms
# 544:	learn: 0.3435012	total: 304ms	remaining: 254ms
# 545:	learn: 0.3434439	total: 304ms	remaining: 253ms
# 546:	learn: 0.3434287	total: 305ms	remaining: 252ms
# 547:	learn: 0.3434283	total: 305ms	remaining: 252ms
# 548:	learn: 0.3433534	total: 305ms	remaining: 251ms
# 549:	learn: 0.3432088	total: 306ms	remaining: 250ms
# 550:	learn: 0.3430881	total: 306ms	remaining: 250ms
# 551:	learn: 0.3430176	total: 307ms	remaining: 249ms
# 552:	learn: 0.3430010	total: 307ms	remaining: 248ms
# 553:	learn: 0.3429400	total: 308ms	remaining: 248ms
# 554:	learn: 0.3429232	total: 308ms	remaining: 247ms
# 555:	learn: 0.3428575	total: 309ms	remaining: 246ms
# 556:	learn: 0.3428476	total: 309ms	remaining: 246ms
# 557:	learn: 0.3427331	total: 310ms	remaining: 245ms
# 558:	learn: 0.3426813	total: 311ms	remaining: 245ms
# 559:	learn: 0.3425316	total: 311ms	remaining: 245ms
# 560:	learn: 0.3424857	total: 312ms	remaining: 244ms
# 561:	learn: 0.3424218	total: 312ms	remaining: 243ms
# 562:	learn: 0.3423701	total: 313ms	remaining: 243ms
# 563:	learn: 0.3422575	total: 313ms	remaining: 242ms
# 564:	learn: 0.3422320	total: 313ms	remaining: 241ms
# 565:	learn: 0.3421624	total: 314ms	remaining: 240ms
# 566:	learn: 0.3421240	total: 314ms	remaining: 240ms
# 567:	learn: 0.3420959	total: 314ms	remaining: 239ms
# 568:	learn: 0.3420925	total: 315ms	remaining: 239ms
# 569:	learn: 0.3419843	total: 315ms	remaining: 238ms
# 570:	learn: 0.3419083	total: 316ms	remaining: 237ms
# 571:	learn: 0.3418453	total: 316ms	remaining: 237ms
# 572:	learn: 0.3418331	total: 316ms	remaining: 236ms
# 573:	learn: 0.3418175	total: 317ms	remaining: 235ms
# 574:	learn: 0.3418057	total: 317ms	remaining: 235ms
# 575:	learn: 0.3417666	total: 318ms	remaining: 234ms
# 576:	learn: 0.3417325	total: 318ms	remaining: 233ms
# 577:	learn: 0.3417137	total: 318ms	remaining: 232ms
# 578:	learn: 0.3416610	total: 319ms	remaining: 232ms
# 579:	learn: 0.3416147	total: 319ms	remaining: 231ms
# 580:	learn: 0.3415466	total: 319ms	remaining: 230ms
# 581:	learn: 0.3414584	total: 320ms	remaining: 230ms
# 582:	learn: 0.3414009	total: 320ms	remaining: 229ms
# 583:	learn: 0.3414000	total: 321ms	remaining: 229ms
# 584:	learn: 0.3413260	total: 322ms	remaining: 229ms
# 585:	learn: 0.3412717	total: 323ms	remaining: 228ms
# 586:	learn: 0.3411968	total: 323ms	remaining: 227ms
# 587:	learn: 0.3411771	total: 323ms	remaining: 227ms
# 588:	learn: 0.3411543	total: 324ms	remaining: 226ms
# 589:	learn: 0.3409815	total: 325ms	remaining: 226ms
# 590:	learn: 0.3409265	total: 325ms	remaining: 225ms
# 591:	learn: 0.3408465	total: 330ms	remaining: 227ms
# 592:	learn: 0.3406780	total: 330ms	remaining: 227ms
# 593:	learn: 0.3406524	total: 330ms	remaining: 226ms
# 594:	learn: 0.3406173	total: 331ms	remaining: 225ms
# 595:	learn: 0.3405309	total: 331ms	remaining: 225ms
# 596:	learn: 0.3404808	total: 332ms	remaining: 224ms
# 597:	learn: 0.3404791	total: 332ms	remaining: 223ms
# 598:	learn: 0.3404482	total: 333ms	remaining: 223ms
# 599:	learn: 0.3403749	total: 334ms	remaining: 223ms
# 600:	learn: 0.3403738	total: 335ms	remaining: 223ms
# 601:	learn: 0.3403351	total: 336ms	remaining: 222ms
# 602:	learn: 0.3402332	total: 337ms	remaining: 222ms
# 603:	learn: 0.3401928	total: 339ms	remaining: 222ms
# 604:	learn: 0.3400983	total: 340ms	remaining: 222ms
# 605:	learn: 0.3400617	total: 341ms	remaining: 221ms
# 606:	learn: 0.3400537	total: 341ms	remaining: 221ms
# 607:	learn: 0.3399344	total: 342ms	remaining: 220ms
# 608:	learn: 0.3398564	total: 342ms	remaining: 220ms
# 609:	learn: 0.3398140	total: 343ms	remaining: 219ms
# 610:	learn: 0.3397667	total: 343ms	remaining: 218ms
# 611:	learn: 0.3397135	total: 344ms	remaining: 218ms
# 612:	learn: 0.3396809	total: 344ms	remaining: 217ms
# 613:	learn: 0.3395635	total: 344ms	remaining: 217ms
# 614:	learn: 0.3394949	total: 345ms	remaining: 216ms
# 615:	learn: 0.3394676	total: 345ms	remaining: 215ms
# 616:	learn: 0.3393882	total: 346ms	remaining: 215ms
# 617:	learn: 0.3393136	total: 346ms	remaining: 214ms
# 618:	learn: 0.3393130	total: 347ms	remaining: 213ms
# 619:	learn: 0.3392170	total: 348ms	remaining: 213ms
# 620:	learn: 0.3391658	total: 350ms	remaining: 213ms
# 621:	learn: 0.3391369	total: 350ms	remaining: 213ms
# 622:	learn: 0.3390873	total: 351ms	remaining: 212ms
# 623:	learn: 0.3390351	total: 352ms	remaining: 212ms
# 624:	learn: 0.3389681	total: 352ms	remaining: 211ms
# 625:	learn: 0.3389088	total: 352ms	remaining: 211ms
# 626:	learn: 0.3388313	total: 353ms	remaining: 210ms
# 627:	learn: 0.3387826	total: 354ms	remaining: 209ms
# 628:	learn: 0.3386896	total: 354ms	remaining: 209ms
# 629:	learn: 0.3386493	total: 354ms	remaining: 208ms
# 630:	learn: 0.3385683	total: 355ms	remaining: 208ms
# 631:	learn: 0.3385279	total: 355ms	remaining: 207ms
# 632:	learn: 0.3385193	total: 356ms	remaining: 206ms
# 633:	learn: 0.3385143	total: 356ms	remaining: 206ms
# 634:	learn: 0.3384876	total: 357ms	remaining: 205ms
# 635:	learn: 0.3384655	total: 357ms	remaining: 204ms
# 636:	learn: 0.3384557	total: 358ms	remaining: 204ms
# 637:	learn: 0.3384427	total: 358ms	remaining: 203ms
# 638:	learn: 0.3383531	total: 359ms	remaining: 203ms
# 639:	learn: 0.3383160	total: 359ms	remaining: 202ms
# 640:	learn: 0.3382609	total: 359ms	remaining: 201ms
# 641:	learn: 0.3381511	total: 360ms	remaining: 201ms
# 642:	learn: 0.3380264	total: 360ms	remaining: 200ms
# 643:	learn: 0.3379811	total: 361ms	remaining: 200ms
# 644:	learn: 0.3379758	total: 362ms	remaining: 199ms
# 645:	learn: 0.3378663	total: 363ms	remaining: 199ms
# 646:	learn: 0.3378030	total: 363ms	remaining: 198ms
# 647:	learn: 0.3377413	total: 364ms	remaining: 198ms
# 648:	learn: 0.3376608	total: 364ms	remaining: 197ms
# 649:	learn: 0.3376609	total: 365ms	remaining: 196ms
# 650:	learn: 0.3375854	total: 365ms	remaining: 196ms
# 651:	learn: 0.3375244	total: 366ms	remaining: 195ms
# 652:	learn: 0.3374968	total: 366ms	remaining: 195ms
# 653:	learn: 0.3374240	total: 367ms	remaining: 194ms
# 654:	learn: 0.3373777	total: 367ms	remaining: 193ms
# 655:	learn: 0.3372846	total: 367ms	remaining: 193ms
# 656:	learn: 0.3372368	total: 368ms	remaining: 192ms
# 657:	learn: 0.3371854	total: 368ms	remaining: 191ms
# 658:	learn: 0.3371249	total: 369ms	remaining: 191ms
# 659:	learn: 0.3371133	total: 369ms	remaining: 190ms
# 660:	learn: 0.3370640	total: 370ms	remaining: 190ms
# 661:	learn: 0.3370572	total: 370ms	remaining: 189ms
# 662:	learn: 0.3370259	total: 371ms	remaining: 188ms
# 663:	learn: 0.3370040	total: 371ms	remaining: 188ms
# 664:	learn: 0.3369310	total: 371ms	remaining: 187ms
# 665:	learn: 0.3369270	total: 372ms	remaining: 186ms
# 666:	learn: 0.3368951	total: 372ms	remaining: 186ms
# 667:	learn: 0.3368046	total: 373ms	remaining: 185ms
# 668:	learn: 0.3367357	total: 373ms	remaining: 185ms
# 669:	learn: 0.3367080	total: 373ms	remaining: 184ms
# 670:	learn: 0.3366000	total: 375ms	remaining: 184ms
# 671:	learn: 0.3365715	total: 376ms	remaining: 183ms
# 672:	learn: 0.3364388	total: 376ms	remaining: 183ms
# 673:	learn: 0.3363400	total: 377ms	remaining: 182ms
# 674:	learn: 0.3362738	total: 377ms	remaining: 182ms
# 675:	learn: 0.3362444	total: 377ms	remaining: 181ms
# 676:	learn: 0.3362211	total: 378ms	remaining: 180ms
# 677:	learn: 0.3361891	total: 378ms	remaining: 180ms
# 678:	learn: 0.3361797	total: 379ms	remaining: 179ms
# 679:	learn: 0.3361145	total: 379ms	remaining: 179ms
# 680:	learn: 0.3360598	total: 380ms	remaining: 178ms
# 681:	learn: 0.3360083	total: 380ms	remaining: 177ms
# 682:	learn: 0.3359883	total: 381ms	remaining: 177ms
# 683:	learn: 0.3359484	total: 381ms	remaining: 176ms
# 684:	learn: 0.3359476	total: 381ms	remaining: 175ms
# 685:	learn: 0.3359037	total: 382ms	remaining: 175ms
# 686:	learn: 0.3358245	total: 383ms	remaining: 174ms
# 687:	learn: 0.3357857	total: 383ms	remaining: 174ms
# 688:	learn: 0.3357295	total: 384ms	remaining: 173ms
# 689:	learn: 0.3356309	total: 384ms	remaining: 173ms
# 690:	learn: 0.3355877	total: 385ms	remaining: 172ms
# 691:	learn: 0.3355180	total: 386ms	remaining: 172ms
# 692:	learn: 0.3354863	total: 387ms	remaining: 171ms
# 693:	learn: 0.3354863	total: 387ms	remaining: 171ms
# 694:	learn: 0.3354134	total: 388ms	remaining: 170ms
# 695:	learn: 0.3353612	total: 389ms	remaining: 170ms
# 696:	learn: 0.3353263	total: 390ms	remaining: 169ms
# 697:	learn: 0.3352921	total: 391ms	remaining: 169ms
# 698:	learn: 0.3352448	total: 391ms	remaining: 168ms
# 699:	learn: 0.3351162	total: 392ms	remaining: 168ms
# 700:	learn: 0.3350385	total: 393ms	remaining: 167ms
# 701:	learn: 0.3349252	total: 393ms	remaining: 167ms
# 702:	learn: 0.3348813	total: 394ms	remaining: 167ms
# 703:	learn: 0.3347800	total: 395ms	remaining: 166ms
# 704:	learn: 0.3347727	total: 396ms	remaining: 166ms
# 705:	learn: 0.3347529	total: 397ms	remaining: 165ms
# 706:	learn: 0.3347231	total: 397ms	remaining: 165ms
# 707:	learn: 0.3346983	total: 398ms	remaining: 164ms
# 708:	learn: 0.3346034	total: 399ms	remaining: 164ms
# 709:	learn: 0.3345525	total: 399ms	remaining: 163ms
# 710:	learn: 0.3345245	total: 400ms	remaining: 162ms
# 711:	learn: 0.3345183	total: 400ms	remaining: 162ms
# 712:	learn: 0.3344662	total: 401ms	remaining: 161ms
# 713:	learn: 0.3344184	total: 401ms	remaining: 161ms
# 714:	learn: 0.3343997	total: 402ms	remaining: 160ms
# 715:	learn: 0.3343992	total: 402ms	remaining: 160ms
# 716:	learn: 0.3343580	total: 403ms	remaining: 159ms
# 717:	learn: 0.3343423	total: 403ms	remaining: 158ms
# 718:	learn: 0.3342927	total: 403ms	remaining: 158ms
# 719:	learn: 0.3341794	total: 404ms	remaining: 157ms
# 720:	learn: 0.3341370	total: 404ms	remaining: 156ms
# 721:	learn: 0.3340935	total: 405ms	remaining: 156ms
# 722:	learn: 0.3340503	total: 406ms	remaining: 155ms
# 723:	learn: 0.3339573	total: 406ms	remaining: 155ms
# 724:	learn: 0.3339095	total: 408ms	remaining: 155ms
# 725:	learn: 0.3338326	total: 409ms	remaining: 154ms
# 726:	learn: 0.3337947	total: 409ms	remaining: 154ms
# 727:	learn: 0.3337458	total: 410ms	remaining: 153ms
# 728:	learn: 0.3336842	total: 410ms	remaining: 152ms
# 729:	learn: 0.3335561	total: 411ms	remaining: 152ms
# 730:	learn: 0.3335411	total: 411ms	remaining: 151ms
# 731:	learn: 0.3334664	total: 412ms	remaining: 151ms
# 732:	learn: 0.3333940	total: 412ms	remaining: 150ms
# 733:	learn: 0.3333682	total: 413ms	remaining: 150ms
# 734:	learn: 0.3332597	total: 413ms	remaining: 149ms
# 735:	learn: 0.3331946	total: 413ms	remaining: 148ms
# 736:	learn: 0.3331938	total: 413ms	remaining: 148ms
# 737:	learn: 0.3331732	total: 414ms	remaining: 147ms
# 738:	learn: 0.3331478	total: 414ms	remaining: 146ms
# 739:	learn: 0.3331219	total: 414ms	remaining: 146ms
# 740:	learn: 0.3331219	total: 415ms	remaining: 145ms
# 741:	learn: 0.3330512	total: 415ms	remaining: 144ms
# 742:	learn: 0.3329803	total: 416ms	remaining: 144ms
# 743:	learn: 0.3329292	total: 416ms	remaining: 143ms
# 744:	learn: 0.3328412	total: 417ms	remaining: 143ms
# 745:	learn: 0.3327688	total: 417ms	remaining: 142ms
# 746:	learn: 0.3327087	total: 418ms	remaining: 142ms
# 747:	learn: 0.3326401	total: 419ms	remaining: 141ms
# 748:	learn: 0.3325715	total: 420ms	remaining: 141ms
# 749:	learn: 0.3325061	total: 420ms	remaining: 140ms
# 750:	learn: 0.3324466	total: 420ms	remaining: 139ms
# 751:	learn: 0.3324292	total: 421ms	remaining: 139ms
# 752:	learn: 0.3324063	total: 421ms	remaining: 138ms
# 753:	learn: 0.3323331	total: 422ms	remaining: 138ms
# 754:	learn: 0.3323015	total: 422ms	remaining: 137ms
# 755:	learn: 0.3322921	total: 422ms	remaining: 136ms
# 756:	learn: 0.3322258	total: 423ms	remaining: 136ms
# 757:	learn: 0.3321746	total: 424ms	remaining: 135ms
# 758:	learn: 0.3321593	total: 424ms	remaining: 135ms
# 759:	learn: 0.3321013	total: 426ms	remaining: 134ms
# 760:	learn: 0.3320647	total: 426ms	remaining: 134ms
# 761:	learn: 0.3320380	total: 427ms	remaining: 133ms
# 762:	learn: 0.3319482	total: 429ms	remaining: 133ms
# 763:	learn: 0.3319108	total: 430ms	remaining: 133ms
# 764:	learn: 0.3319061	total: 430ms	remaining: 132ms
# 765:	learn: 0.3318809	total: 431ms	remaining: 132ms
# 766:	learn: 0.3318275	total: 432ms	remaining: 131ms
# 767:	learn: 0.3317853	total: 433ms	remaining: 131ms
# 768:	learn: 0.3317444	total: 433ms	remaining: 130ms
# 769:	learn: 0.3317124	total: 436ms	remaining: 130ms
# 770:	learn: 0.3316928	total: 437ms	remaining: 130ms
# 771:	learn: 0.3316420	total: 437ms	remaining: 129ms
# 772:	learn: 0.3316133	total: 438ms	remaining: 129ms
# 773:	learn: 0.3315903	total: 439ms	remaining: 128ms
# 774:	learn: 0.3315552	total: 440ms	remaining: 128ms
# 775:	learn: 0.3314966	total: 440ms	remaining: 127ms
# 776:	learn: 0.3314767	total: 441ms	remaining: 127ms
# 777:	learn: 0.3314330	total: 442ms	remaining: 126ms
# 778:	learn: 0.3313949	total: 443ms	remaining: 126ms
# 779:	learn: 0.3313673	total: 443ms	remaining: 125ms
# 780:	learn: 0.3312941	total: 444ms	remaining: 124ms
# 781:	learn: 0.3312478	total: 447ms	remaining: 125ms
# 782:	learn: 0.3311959	total: 448ms	remaining: 124ms
# 783:	learn: 0.3311742	total: 449ms	remaining: 124ms
# 784:	learn: 0.3311445	total: 451ms	remaining: 123ms
# 785:	learn: 0.3310778	total: 451ms	remaining: 123ms
# 786:	learn: 0.3309566	total: 452ms	remaining: 122ms
# 787:	learn: 0.3308806	total: 453ms	remaining: 122ms
# 788:	learn: 0.3308258	total: 454ms	remaining: 121ms
# 789:	learn: 0.3307958	total: 454ms	remaining: 121ms
# 790:	learn: 0.3306863	total: 455ms	remaining: 120ms
# 791:	learn: 0.3306391	total: 461ms	remaining: 121ms
# 792:	learn: 0.3305845	total: 496ms	remaining: 129ms
# 793:	learn: 0.3304966	total: 496ms	remaining: 129ms
# 794:	learn: 0.3304580	total: 497ms	remaining: 128ms
# 795:	learn: 0.3304414	total: 498ms	remaining: 128ms
# 796:	learn: 0.3303741	total: 499ms	remaining: 127ms
# 797:	learn: 0.3303070	total: 500ms	remaining: 126ms
# 798:	learn: 0.3302547	total: 500ms	remaining: 126ms
# 799:	learn: 0.3301904	total: 501ms	remaining: 125ms
# 800:	learn: 0.3301033	total: 501ms	remaining: 125ms
# 801:	learn: 0.3300612	total: 503ms	remaining: 124ms
# 802:	learn: 0.3300191	total: 504ms	remaining: 124ms
# 803:	learn: 0.3299713	total: 505ms	remaining: 123ms
# 804:	learn: 0.3299174	total: 506ms	remaining: 123ms
# 805:	learn: 0.3299012	total: 507ms	remaining: 122ms
# 806:	learn: 0.3298668	total: 508ms	remaining: 121ms
# 807:	learn: 0.3298481	total: 508ms	remaining: 121ms
# 808:	learn: 0.3297675	total: 509ms	remaining: 120ms
# 809:	learn: 0.3296930	total: 509ms	remaining: 119ms
# 810:	learn: 0.3296248	total: 510ms	remaining: 119ms
# 811:	learn: 0.3295818	total: 511ms	remaining: 118ms
# 812:	learn: 0.3294988	total: 513ms	remaining: 118ms
# 813:	learn: 0.3294273	total: 513ms	remaining: 117ms
# 814:	learn: 0.3294248	total: 514ms	remaining: 117ms
# 815:	learn: 0.3293838	total: 515ms	remaining: 116ms
# 816:	learn: 0.3293141	total: 516ms	remaining: 115ms
# 817:	learn: 0.3292781	total: 518ms	remaining: 115ms
# 818:	learn: 0.3292640	total: 520ms	remaining: 115ms
# 819:	learn: 0.3292223	total: 522ms	remaining: 115ms
# 820:	learn: 0.3291256	total: 523ms	remaining: 114ms
# 821:	learn: 0.3290796	total: 524ms	remaining: 114ms
# 822:	learn: 0.3290284	total: 525ms	remaining: 113ms
# 823:	learn: 0.3289675	total: 529ms	remaining: 113ms
# 824:	learn: 0.3289301	total: 530ms	remaining: 112ms
# 825:	learn: 0.3288929	total: 536ms	remaining: 113ms
# 826:	learn: 0.3288202	total: 536ms	remaining: 112ms
# 827:	learn: 0.3287676	total: 537ms	remaining: 112ms
# 828:	learn: 0.3287349	total: 538ms	remaining: 111ms
# 829:	learn: 0.3286685	total: 538ms	remaining: 110ms
# 830:	learn: 0.3286378	total: 539ms	remaining: 110ms
# 831:	learn: 0.3285938	total: 539ms	remaining: 109ms
# 832:	learn: 0.3285450	total: 540ms	remaining: 108ms
# 833:	learn: 0.3284785	total: 541ms	remaining: 108ms
# 834:	learn: 0.3284034	total: 543ms	remaining: 107ms
# 835:	learn: 0.3283558	total: 544ms	remaining: 107ms
# 836:	learn: 0.3283176	total: 545ms	remaining: 106ms
# 837:	learn: 0.3282457	total: 545ms	remaining: 105ms
# 838:	learn: 0.3281802	total: 546ms	remaining: 105ms
# 839:	learn: 0.3281291	total: 547ms	remaining: 104ms
# 840:	learn: 0.3280942	total: 548ms	remaining: 104ms
# 841:	learn: 0.3280394	total: 548ms	remaining: 103ms
# 842:	learn: 0.3279658	total: 549ms	remaining: 102ms
# 843:	learn: 0.3279094	total: 550ms	remaining: 102ms
# 844:	learn: 0.3278036	total: 550ms	remaining: 101ms
# 845:	learn: 0.3277196	total: 551ms	remaining: 100ms
# 846:	learn: 0.3276908	total: 551ms	remaining: 99.6ms
# 847:	learn: 0.3276135	total: 552ms	remaining: 98.9ms
# 848:	learn: 0.3275588	total: 553ms	remaining: 98.3ms
# 849:	learn: 0.3275582	total: 553ms	remaining: 97.6ms
# 850:	learn: 0.3275217	total: 553ms	remaining: 96.9ms
# 851:	learn: 0.3274675	total: 554ms	remaining: 96.2ms
# 852:	learn: 0.3274350	total: 555ms	remaining: 95.6ms
# 853:	learn: 0.3274017	total: 557ms	remaining: 95.2ms
# 854:	learn: 0.3273694	total: 558ms	remaining: 94.6ms
# 855:	learn: 0.3273258	total: 558ms	remaining: 93.9ms
# 856:	learn: 0.3272971	total: 559ms	remaining: 93.3ms
# 857:	learn: 0.3272526	total: 559ms	remaining: 92.6ms
# 858:	learn: 0.3272025	total: 560ms	remaining: 91.9ms
# 859:	learn: 0.3271338	total: 561ms	remaining: 91.3ms
# 860:	learn: 0.3270709	total: 561ms	remaining: 90.6ms
# 861:	learn: 0.3270405	total: 562ms	remaining: 89.9ms
# 862:	learn: 0.3270076	total: 562ms	remaining: 89.2ms
# 863:	learn: 0.3269511	total: 562ms	remaining: 88.5ms
# 864:	learn: 0.3269269	total: 563ms	remaining: 87.8ms
# 865:	learn: 0.3269034	total: 563ms	remaining: 87.2ms
# 866:	learn: 0.3268683	total: 564ms	remaining: 86.5ms
# 867:	learn: 0.3268097	total: 565ms	remaining: 86ms
# 868:	learn: 0.3267876	total: 566ms	remaining: 85.3ms
# 869:	learn: 0.3267155	total: 566ms	remaining: 84.6ms
# 870:	learn: 0.3266671	total: 567ms	remaining: 83.9ms
# 871:	learn: 0.3266512	total: 567ms	remaining: 83.2ms
# 872:	learn: 0.3266288	total: 568ms	remaining: 82.6ms
# 873:	learn: 0.3265904	total: 568ms	remaining: 81.9ms
# 874:	learn: 0.3265687	total: 570ms	remaining: 81.4ms
# 875:	learn: 0.3265128	total: 571ms	remaining: 80.8ms
# 876:	learn: 0.3264359	total: 571ms	remaining: 80.1ms
# 877:	learn: 0.3264112	total: 572ms	remaining: 79.4ms
# 878:	learn: 0.3263622	total: 572ms	remaining: 78.8ms
# 879:	learn: 0.3263125	total: 573ms	remaining: 78.1ms
# 880:	learn: 0.3262454	total: 573ms	remaining: 77.5ms
# 881:	learn: 0.3262031	total: 574ms	remaining: 76.8ms
# 882:	learn: 0.3261654	total: 574ms	remaining: 76.1ms
# 883:	learn: 0.3261147	total: 575ms	remaining: 75.4ms
# 884:	learn: 0.3261138	total: 575ms	remaining: 74.7ms
# 885:	learn: 0.3260511	total: 575ms	remaining: 74ms
# 886:	learn: 0.3260119	total: 575ms	remaining: 73.3ms
# 887:	learn: 0.3259849	total: 577ms	remaining: 72.7ms
# 888:	learn: 0.3259652	total: 577ms	remaining: 72.1ms
# 889:	learn: 0.3259080	total: 578ms	remaining: 71.4ms
# 890:	learn: 0.3258704	total: 578ms	remaining: 70.8ms
# 891:	learn: 0.3258143	total: 579ms	remaining: 70.1ms
# 892:	learn: 0.3258130	total: 579ms	remaining: 69.4ms
# 893:	learn: 0.3257416	total: 579ms	remaining: 68.7ms
# 894:	learn: 0.3257197	total: 580ms	remaining: 68ms
# 895:	learn: 0.3256792	total: 583ms	remaining: 67.6ms
# 896:	learn: 0.3256595	total: 583ms	remaining: 67ms
# 897:	learn: 0.3255985	total: 584ms	remaining: 66.3ms
# 898:	learn: 0.3255615	total: 585ms	remaining: 65.7ms
# 899:	learn: 0.3255430	total: 585ms	remaining: 65ms
# 900:	learn: 0.3255180	total: 586ms	remaining: 64.4ms
# 901:	learn: 0.3254733	total: 587ms	remaining: 63.7ms
# 902:	learn: 0.3254449	total: 587ms	remaining: 63.1ms
# 903:	learn: 0.3254161	total: 588ms	remaining: 62.4ms
# 904:	learn: 0.3253958	total: 588ms	remaining: 61.8ms
# 905:	learn: 0.3253604	total: 589ms	remaining: 61.1ms
# 906:	learn: 0.3253335	total: 590ms	remaining: 60.5ms
# 907:	learn: 0.3253006	total: 591ms	remaining: 59.9ms
# 908:	learn: 0.3252377	total: 591ms	remaining: 59.2ms
# 909:	learn: 0.3251815	total: 592ms	remaining: 58.6ms
# 910:	learn: 0.3251198	total: 593ms	remaining: 57.9ms
# 911:	learn: 0.3250571	total: 594ms	remaining: 57.3ms
# 912:	learn: 0.3249953	total: 597ms	remaining: 56.9ms
# 913:	learn: 0.3249957	total: 597ms	remaining: 56.2ms
# 914:	learn: 0.3249499	total: 598ms	remaining: 55.5ms
# 915:	learn: 0.3249496	total: 598ms	remaining: 54.8ms
# 916:	learn: 0.3248979	total: 599ms	remaining: 54.2ms
# 917:	learn: 0.3248693	total: 599ms	remaining: 53.5ms
# 918:	learn: 0.3248050	total: 600ms	remaining: 52.9ms
# 919:	learn: 0.3247818	total: 601ms	remaining: 52.3ms
# 920:	learn: 0.3247345	total: 602ms	remaining: 51.7ms
# 921:	learn: 0.3247096	total: 605ms	remaining: 51.2ms
# 922:	learn: 0.3246910	total: 605ms	remaining: 50.5ms
# 923:	learn: 0.3246896	total: 606ms	remaining: 49.8ms
# 924:	learn: 0.3246895	total: 606ms	remaining: 49.2ms
# 925:	learn: 0.3246382	total: 607ms	remaining: 48.5ms
# 926:	learn: 0.3245913	total: 607ms	remaining: 47.8ms
# 927:	learn: 0.3245124	total: 608ms	remaining: 47.1ms
# 928:	learn: 0.3244663	total: 609ms	remaining: 46.5ms
# 929:	learn: 0.3244211	total: 610ms	remaining: 45.9ms
# 930:	learn: 0.3243597	total: 610ms	remaining: 45.2ms
# 931:	learn: 0.3243096	total: 611ms	remaining: 44.6ms
# 932:	learn: 0.3242798	total: 611ms	remaining: 43.9ms
# 933:	learn: 0.3242571	total: 612ms	remaining: 43.2ms
# 934:	learn: 0.3241716	total: 612ms	remaining: 42.6ms
# 935:	learn: 0.3241593	total: 612ms	remaining: 41.9ms
# 936:	learn: 0.3241154	total: 613ms	remaining: 41.2ms
# 937:	learn: 0.3240922	total: 613ms	remaining: 40.5ms
# 938:	learn: 0.3240710	total: 614ms	remaining: 39.9ms
# 939:	learn: 0.3240225	total: 614ms	remaining: 39.2ms
# 940:	learn: 0.3239832	total: 615ms	remaining: 38.5ms
# 941:	learn: 0.3239437	total: 615ms	remaining: 37.9ms
# 942:	learn: 0.3239177	total: 615ms	remaining: 37.2ms
# 943:	learn: 0.3238808	total: 616ms	remaining: 36.5ms
# 944:	learn: 0.3238479	total: 616ms	remaining: 35.9ms
# 945:	learn: 0.3237930	total: 617ms	remaining: 35.2ms
# 946:	learn: 0.3237612	total: 617ms	remaining: 34.5ms
# 947:	learn: 0.3237466	total: 618ms	remaining: 33.9ms
# 948:	learn: 0.3237282	total: 618ms	remaining: 33.2ms
# 949:	learn: 0.3236581	total: 619ms	remaining: 32.6ms
# 950:	learn: 0.3236139	total: 619ms	remaining: 31.9ms
# 951:	learn: 0.3235704	total: 621ms	remaining: 31.3ms
# 952:	learn: 0.3235538	total: 622ms	remaining: 30.7ms
# 953:	learn: 0.3235113	total: 622ms	remaining: 30ms
# 954:	learn: 0.3234723	total: 623ms	remaining: 29.3ms
# 955:	learn: 0.3234424	total: 623ms	remaining: 28.7ms
# 956:	learn: 0.3233941	total: 624ms	remaining: 28ms
# 957:	learn: 0.3233550	total: 624ms	remaining: 27.4ms
# 958:	learn: 0.3233353	total: 624ms	remaining: 26.7ms
# 959:	learn: 0.3232556	total: 625ms	remaining: 26ms
# 960:	learn: 0.3232239	total: 625ms	remaining: 25.4ms
# 961:	learn: 0.3231846	total: 626ms	remaining: 24.7ms
# 962:	learn: 0.3231467	total: 626ms	remaining: 24.1ms
# 963:	learn: 0.3231179	total: 627ms	remaining: 23.4ms
# 964:	learn: 0.3230897	total: 627ms	remaining: 22.7ms
# 965:	learn: 0.3230616	total: 627ms	remaining: 22.1ms
# 966:	learn: 0.3230217	total: 628ms	remaining: 21.4ms
# 967:	learn: 0.3229915	total: 629ms	remaining: 20.8ms
# 968:	learn: 0.3229110	total: 629ms	remaining: 20.1ms
# 969:	learn: 0.3228899	total: 630ms	remaining: 19.5ms
# 970:	learn: 0.3228511	total: 631ms	remaining: 18.9ms
# 971:	learn: 0.3228271	total: 632ms	remaining: 18.2ms
# 972:	learn: 0.3227944	total: 633ms	remaining: 17.6ms
# 973:	learn: 0.3227763	total: 636ms	remaining: 17ms
# 974:	learn: 0.3227382	total: 636ms	remaining: 16.3ms
# 975:	learn: 0.3227038	total: 637ms	remaining: 15.7ms
# 976:	learn: 0.3226576	total: 638ms	remaining: 15ms
# 977:	learn: 0.3226034	total: 638ms	remaining: 14.4ms
# 978:	learn: 0.3225714	total: 639ms	remaining: 13.7ms
# 979:	learn: 0.3225607	total: 639ms	remaining: 13ms
# 980:	learn: 0.3225112	total: 640ms	remaining: 12.4ms
# 981:	learn: 0.3224768	total: 640ms	remaining: 11.7ms
# 982:	learn: 0.3224406	total: 641ms	remaining: 11.1ms
# 983:	learn: 0.3223913	total: 641ms	remaining: 10.4ms
# 984:	learn: 0.3223679	total: 642ms	remaining: 9.77ms
# 985:	learn: 0.3223415	total: 642ms	remaining: 9.12ms
# 986:	learn: 0.3223178	total: 643ms	remaining: 8.46ms
# 987:	learn: 0.3222593	total: 643ms	remaining: 7.81ms
# 988:	learn: 0.3222332	total: 644ms	remaining: 7.16ms
# 989:	learn: 0.3222218	total: 644ms	remaining: 6.5ms
# 990:	learn: 0.3222104	total: 644ms	remaining: 5.85ms
# 991:	learn: 0.3221588	total: 645ms	remaining: 5.2ms
# 992:	learn: 0.3221304	total: 645ms	remaining: 4.55ms
# 993:	learn: 0.3221047	total: 646ms	remaining: 3.9ms
# 994:	learn: 0.3220843	total: 646ms	remaining: 3.25ms
# 995:	learn: 0.3220697	total: 647ms	remaining: 2.6ms
# 996:	learn: 0.3220588	total: 647ms	remaining: 1.95ms
# 997:	learn: 0.3220355	total: 648ms	remaining: 1.3ms
# 998:	learn: 0.3219998	total: 648ms	remaining: 649us
# 999:	learn: 0.3219471	total: 649ms	remaining: 0us

# %% [markdown]
# ### 6.2.11 multilayer perceptron

# %%
#rael
#MLP
mlp = MLPClassifier()
MLPtrained=mlp.fit(X_train, Y_train)
accuracy_mlp = round(mlp.score(X_train, Y_train) * 100, 2)#made a change here

# %% [markdown]
# ## 6.3 Model evaluation and hyperparameter tuning
#
# Once all our models have been trained, the next step is to assess the performance of these models and select the one which has the highest prediction accuracy.

# %% [markdown]
# ### 6.3.1 Training accuracy
#
# Training accuracy shows how well our model has learned from the training set.

# %% [markdown]
# Internal comment: Viewing and summarising the scores calcualted above for each algorithm. These models have have not yet been tuned

# %%
#rael 
#creating a dataframe to store the score of each model based on the training data 
# This will allows us to find early identifiers indicating which  models that are likely to have 
# a high prediction sucess rate with the test data and which ones might be overfitted.
models = pd.DataFrame({'Model': ['Multilayer perceptron','Logistic Regression','Naive Bayes', 'K Nearest Neighbours', 
                                  'Support Vector Machines', 'Stochastic Gradient Decent', 
                                 'Linear SVC','Perceptron', 'Random Forest', 'Cat Boost','Decision Tree'],
                       'Score': [accuracy_mlp, accuracy_log ,accuracy_gaussian,  accuracy_knn, accuracy_svc, 
                                 accuracy_sgd, accuracy_linear_svc,accuracy_perceptron,accuracy_random_forest,accuracy_catboost, accuracy_decision_tree]})

models.sort_values(by = 'Score', ascending = False, ignore_index = True)
# Out:
#                          Model  Score
# 0                Random Forest  86.87
# 1                Decision Tree  86.87
# 2                    Cat Boost  86.76
# 3         K Nearest Neighbours  83.73
# 4        Multilayer perceptron  83.05
# 5      Support Vector Machines  82.94
# 6                   Linear SVC  79.12
# 7          Logistic Regression  78.90
# 8                  Naive Bayes  76.77
# 9                   Perceptron  76.77
# 10  Stochastic Gradient Decent  75.31

# %% [markdown]
# ### 6.3.2 K-fold cross validation
#
# It is important to not get too carried away with models with impressive training accuracy as what we should focus on instead is the model's ability to predict out-of-samples data, in other words, data our model has not seen before.
#
# This is where k-fold cross validation comes in. K-fold cross validation is a technique whereby a subset of our training set is kept aside and will act as holdout set for testing purposes. Here is a great [video](https://www.youtube.com/watch?v=fSytzGwwBVw) explaining the concept in more detail.

# %%
# Create a list which contains classifiers 
# Rael
classifiers = [ MLPClassifier(),
                LogisticRegression(), 
                GaussianNB(),
                KNeighborsClassifier(n_neighbors = 5), 
                SVC(),  
                SGDClassifier(), 
                LinearSVC(),
                Perceptron(),
                RandomForestClassifier(),
                CatBoostClassifier(),
                DecisionTreeClassifier()
               ]


if len(classifiers) is not 11: # assuming we intend to use 11 classifiers
    print("error")

cross_val_results = []
for classifier in classifiers:#each result has k subcomponents.Cv=k 
    cross_val_results.append(cross_val_score(classifier, X_train, Y_train, scoring = 'accuracy', cv = 5))
    # we need to try other cv's if this affects other parts of the code
    # potentially mifht be a place for tuning using grid search
# Out:
# Learning rate set to 0.008911
# 0:	learn: 0.6867102	total: 1.18ms	remaining: 1.18s
# 1:	learn: 0.6816314	total: 1.62ms	remaining: 807ms
# 2:	learn: 0.6760633	total: 2.25ms	remaining: 747ms
# 3:	learn: 0.6711699	total: 2.67ms	remaining: 665ms
# 4:	learn: 0.6670504	total: 3.07ms	remaining: 610ms
# 5:	learn: 0.6615089	total: 3.5ms	remaining: 581ms
# 6:	learn: 0.6560690	total: 3.98ms	remaining: 565ms
# 7:	learn: 0.6506229	total: 4.43ms	remaining: 550ms
# 8:	learn: 0.6451099	total: 4.95ms	remaining: 545ms
# 9:	learn: 0.6397200	total: 5.49ms	remaining: 543ms
# 10:	learn: 0.6351848	total: 6.47ms	remaining: 582ms
# 11:	learn: 0.6304318	total: 7.23ms	remaining: 595ms
# 12:	learn: 0.6254140	total: 7.86ms	remaining: 596ms
# 13:	learn: 0.6207909	total: 8.38ms	remaining: 590ms
# 14:	learn: 0.6163616	total: 8.84ms	remaining: 581ms
# 15:	learn: 0.6113830	total: 9.3ms	remaining: 572ms
# 16:	learn: 0.6078094	total: 9.66ms	remaining: 559ms
# 17:	learn: 0.6032256	total: 10.1ms	remaining: 553ms
# 18:	learn: 0.5998448	total: 10.6ms	remaining: 545ms
# 19:	learn: 0.5952990	total: 11ms	remaining: 541ms
# 20:	learn: 0.5915194	total: 11.5ms	remaining: 534ms
# 21:	learn: 0.5873219	total: 11.9ms	remaining: 530ms
# 22:	learn: 0.5833369	total: 12.3ms	remaining: 524ms
# 23:	learn: 0.5792053	total: 12.8ms	remaining: 520ms
# 24:	learn: 0.5757754	total: 13.2ms	remaining: 513ms
# 25:	learn: 0.5717743	total: 13.6ms	remaining: 510ms
# 26:	learn: 0.5679733	total: 14ms	remaining: 504ms
# 27:	learn: 0.5662419	total: 14.3ms	remaining: 497ms
# 28:	learn: 0.5635653	total: 14.8ms	remaining: 496ms
# 29:	learn: 0.5598189	total: 15.2ms	remaining: 493ms
# 30:	learn: 0.5565204	total: 15.6ms	remaining: 489ms
# 31:	learn: 0.5535072	total: 16.1ms	remaining: 488ms
# 32:	learn: 0.5508077	total: 16.7ms	remaining: 488ms
# 33:	learn: 0.5474767	total: 17ms	remaining: 484ms
# 34:	learn: 0.5444288	total: 17.4ms	remaining: 481ms
# 35:	learn: 0.5415945	total: 17.9ms	remaining: 478ms
# 36:	learn: 0.5384028	total: 18.3ms	remaining: 477ms
# 37:	learn: 0.5357534	total: 18.8ms	remaining: 475ms
# 38:	learn: 0.5330600	total: 19.3ms	remaining: 476ms
# 39:	learn: 0.5300123	total: 20.4ms	remaining: 488ms
# 40:	learn: 0.5268692	total: 21.1ms	remaining: 494ms
# 41:	learn: 0.5246333	total: 21.6ms	remaining: 493ms
# 42:	learn: 0.5216964	total: 22.1ms	remaining: 491ms
# 43:	learn: 0.5193541	total: 22.4ms	remaining: 488ms
# 44:	learn: 0.5178585	total: 22.8ms	remaining: 483ms
# 45:	learn: 0.5152513	total: 23.2ms	remaining: 481ms
# 46:	learn: 0.5123468	total: 23.6ms	remaining: 479ms
# 47:	learn: 0.5102604	total: 24.1ms	remaining: 478ms
# 48:	learn: 0.5079508	total: 24.5ms	remaining: 476ms
# 49:	learn: 0.5061736	total: 24.9ms	remaining: 472ms
# 50:	learn: 0.5035430	total: 25.3ms	remaining: 471ms
# 51:	learn: 0.5014504	total: 25.7ms	remaining: 469ms
# 52:	learn: 0.4996914	total: 26.1ms	remaining: 466ms
# 53:	learn: 0.4977658	total: 26.5ms	remaining: 465ms
# 54:	learn: 0.4955123	total: 27ms	remaining: 464ms
# 55:	learn: 0.4937326	total: 27.4ms	remaining: 462ms
# 56:	learn: 0.4922645	total: 27.9ms	remaining: 462ms
# 57:	learn: 0.4905311	total: 28.3ms	remaining: 460ms
# 58:	learn: 0.4882322	total: 28.8ms	remaining: 459ms
# 59:	learn: 0.4864240	total: 29.2ms	remaining: 457ms
# 60:	learn: 0.4844941	total: 29.6ms	remaining: 456ms
# 61:	learn: 0.4830678	total: 30.1ms	remaining: 455ms
# 62:	learn: 0.4810966	total: 30.5ms	remaining: 454ms
# 63:	learn: 0.4791807	total: 31ms	remaining: 453ms
# 64:	learn: 0.4772260	total: 31.5ms	remaining: 453ms
# 65:	learn: 0.4756979	total: 32ms	remaining: 453ms
# 66:	learn: 0.4739499	total: 32.6ms	remaining: 454ms
# 67:	learn: 0.4723326	total: 33.3ms	remaining: 456ms
# 68:	learn: 0.4706699	total: 34ms	remaining: 459ms
# 69:	learn: 0.4692256	total: 34.8ms	remaining: 462ms
# 70:	learn: 0.4675315	total: 35.3ms	remaining: 462ms
# 71:	learn: 0.4659870	total: 35.8ms	remaining: 462ms
# 72:	learn: 0.4651037	total: 36.2ms	remaining: 460ms
# 73:	learn: 0.4637127	total: 36.6ms	remaining: 458ms
# 74:	learn: 0.4625651	total: 37ms	remaining: 457ms
# 75:	learn: 0.4608057	total: 37.5ms	remaining: 455ms
# 76:	learn: 0.4593333	total: 37.9ms	remaining: 454ms
# 77:	learn: 0.4578019	total: 38.3ms	remaining: 453ms
# 78:	learn: 0.4566922	total: 38.8ms	remaining: 452ms
# 79:	learn: 0.4552667	total: 39.2ms	remaining: 451ms
# 80:	learn: 0.4538072	total: 39.7ms	remaining: 450ms
# 81:	learn: 0.4531127	total: 40.1ms	remaining: 449ms
# 82:	learn: 0.4518726	total: 40.6ms	remaining: 448ms
# 83:	learn: 0.4504010	total: 41ms	remaining: 447ms
# 84:	learn: 0.4491965	total: 41.5ms	remaining: 447ms
# 85:	learn: 0.4479263	total: 42ms	remaining: 446ms
# 86:	learn: 0.4464941	total: 42.4ms	remaining: 445ms
# 87:	learn: 0.4454386	total: 42.8ms	remaining: 444ms
# 88:	learn: 0.4447685	total: 43.3ms	remaining: 443ms
# 89:	learn: 0.4435603	total: 43.7ms	remaining: 442ms
# 90:	learn: 0.4422785	total: 44.2ms	remaining: 441ms
# 91:	learn: 0.4411737	total: 44.7ms	remaining: 441ms
# 92:	learn: 0.4400652	total: 45.2ms	remaining: 440ms
# 93:	learn: 0.4386566	total: 45.8ms	remaining: 442ms
# 94:	learn: 0.4377232	total: 47.2ms	remaining: 449ms
# 95:	learn: 0.4365696	total: 47.7ms	remaining: 449ms
# 96:	learn: 0.4355627	total: 48.1ms	remaining: 448ms
# 97:	learn: 0.4352889	total: 48.5ms	remaining: 446ms
# 98:	learn: 0.4343284	total: 48.9ms	remaining: 445ms
# 99:	learn: 0.4334184	total: 49.3ms	remaining: 444ms
# 100:	learn: 0.4329549	total: 49.7ms	remaining: 442ms
# 101:	learn: 0.4318095	total: 50.2ms	remaining: 442ms
# 102:	learn: 0.4304741	total: 50.6ms	remaining: 441ms
# 103:	learn: 0.4296093	total: 51ms	remaining: 440ms
# 104:	learn: 0.4289377	total: 51.5ms	remaining: 439ms
# 105:	learn: 0.4278528	total: 51.9ms	remaining: 438ms
# 106:	learn: 0.4270270	total: 52.3ms	remaining: 437ms
# 107:	learn: 0.4263220	total: 52.8ms	remaining: 436ms
# 108:	learn: 0.4252820	total: 53.3ms	remaining: 435ms
# 109:	learn: 0.4245498	total: 53.7ms	remaining: 434ms
# 110:	learn: 0.4240315	total: 54ms	remaining: 433ms
# 111:	learn: 0.4233515	total: 54.5ms	remaining: 432ms
# 112:	learn: 0.4227285	total: 54.9ms	remaining: 431ms
# 113:	learn: 0.4222224	total: 55.3ms	remaining: 430ms
# 114:	learn: 0.4214127	total: 55.7ms	remaining: 429ms
# 115:	learn: 0.4205957	total: 56.2ms	remaining: 428ms
# 116:	learn: 0.4196383	total: 56.6ms	remaining: 427ms
# 117:	learn: 0.4187892	total: 57ms	remaining: 426ms
# 118:	learn: 0.4179136	total: 57.4ms	remaining: 425ms
# 119:	learn: 0.4171590	total: 57.9ms	remaining: 425ms
# 120:	learn: 0.4162042	total: 58.4ms	remaining: 424ms
# 121:	learn: 0.4154582	total: 58.8ms	remaining: 423ms
# 122:	learn: 0.4147194	total: 59.3ms	remaining: 423ms
# 123:	learn: 0.4141817	total: 59.9ms	remaining: 423ms
# 124:	learn: 0.4133987	total: 60.5ms	remaining: 423ms
# 125:	learn: 0.4131026	total: 60.8ms	remaining: 422ms
# 126:	learn: 0.4126067	total: 61.3ms	remaining: 421ms
# 127:	learn: 0.4118264	total: 61.8ms	remaining: 421ms
# 128:	learn: 0.4109064	total: 62.2ms	remaining: 420ms
# 129:	learn: 0.4102890	total: 62.7ms	remaining: 419ms
# 130:	learn: 0.4096812	total: 63.1ms	remaining: 419ms
# 131:	learn: 0.4088191	total: 63.6ms	remaining: 419ms
# 132:	learn: 0.4083535	total: 64ms	remaining: 417ms
# 133:	learn: 0.4076932	total: 64.5ms	remaining: 417ms
# 134:	learn: 0.4070405	total: 64.9ms	remaining: 416ms
# 135:	learn: 0.4065466	total: 65.3ms	remaining: 415ms
# 136:	learn: 0.4057520	total: 65.8ms	remaining: 415ms
# 137:	learn: 0.4053763	total: 66.2ms	remaining: 414ms
# 138:	learn: 0.4046634	total: 66.7ms	remaining: 413ms
# 139:	learn: 0.4041523	total: 67.1ms	remaining: 412ms
# 140:	learn: 0.4039274	total: 67.5ms	remaining: 411ms
# 141:	learn: 0.4032230	total: 67.9ms	remaining: 410ms
# 142:	learn: 0.4028061	total: 68.4ms	remaining: 410ms
# 143:	learn: 0.4024999	total: 68.8ms	remaining: 409ms
# 144:	learn: 0.4020858	total: 69.2ms	remaining: 408ms
# 145:	learn: 0.4016715	total: 69.6ms	remaining: 407ms
# 146:	learn: 0.4011335	total: 70.2ms	remaining: 407ms
# 147:	learn: 0.4007647	total: 70.7ms	remaining: 407ms
# 148:	learn: 0.4002432	total: 71.3ms	remaining: 407ms
# 149:	learn: 0.4001208	total: 71.9ms	remaining: 407ms
# 150:	learn: 0.3998758	total: 72.5ms	remaining: 408ms
# 151:	learn: 0.3994028	total: 73.1ms	remaining: 408ms
# 152:	learn: 0.3987446	total: 73.5ms	remaining: 407ms
# 153:	learn: 0.3986717	total: 73.8ms	remaining: 406ms
# 154:	learn: 0.3983525	total: 74.2ms	remaining: 405ms
# 155:	learn: 0.3980944	total: 74.6ms	remaining: 404ms
# 156:	learn: 0.3976257	total: 75.1ms	remaining: 403ms
# 157:	learn: 0.3971621	total: 75.6ms	remaining: 403ms
# 158:	learn: 0.3966281	total: 76.3ms	remaining: 404ms
# 159:	learn: 0.3964019	total: 76.7ms	remaining: 403ms
# 160:	learn: 0.3960590	total: 77.2ms	remaining: 402ms
# 161:	learn: 0.3954560	total: 77.6ms	remaining: 401ms
# 162:	learn: 0.3953587	total: 78ms	remaining: 401ms
# 163:	learn: 0.3949691	total: 78.4ms	remaining: 400ms
# 164:	learn: 0.3943613	total: 78.9ms	remaining: 399ms
# 165:	learn: 0.3939655	total: 79.4ms	remaining: 399ms
# 166:	learn: 0.3938901	total: 79.7ms	remaining: 398ms
# 167:	learn: 0.3937447	total: 80.1ms	remaining: 397ms
# 168:	learn: 0.3931236	total: 80.5ms	remaining: 396ms
# 169:	learn: 0.3926595	total: 80.9ms	remaining: 395ms
# 170:	learn: 0.3922502	total: 81.5ms	remaining: 395ms
# 171:	learn: 0.3919260	total: 81.9ms	remaining: 394ms
# 172:	learn: 0.3916415	total: 82.3ms	remaining: 394ms
# 173:	learn: 0.3910110	total: 82.8ms	remaining: 393ms
# 174:	learn: 0.3905022	total: 83.3ms	remaining: 393ms
# 175:	learn: 0.3902605	total: 84ms	remaining: 393ms
# 176:	learn: 0.3899289	total: 85.7ms	remaining: 399ms
# 177:	learn: 0.3898543	total: 86.1ms	remaining: 397ms
# 178:	learn: 0.3897605	total: 86.4ms	remaining: 396ms
# 179:	learn: 0.3891689	total: 86.9ms	remaining: 396ms
# 180:	learn: 0.3885005	total: 87.4ms	remaining: 396ms
# 181:	learn: 0.3881902	total: 87.9ms	remaining: 395ms
# 182:	learn: 0.3878350	total: 88.4ms	remaining: 394ms
# 183:	learn: 0.3871560	total: 88.8ms	remaining: 394ms
# 184:	learn: 0.3867099	total: 89.2ms	remaining: 393ms
# 185:	learn: 0.3866109	total: 89.6ms	remaining: 392ms
# 186:	learn: 0.3860206	total: 90ms	remaining: 391ms
# 187:	learn: 0.3856911	total: 90.5ms	remaining: 391ms
# 188:	learn: 0.3853980	total: 90.9ms	remaining: 390ms
# 189:	learn: 0.3849687	total: 91.3ms	remaining: 389ms
# 190:	learn: 0.3846425	total: 91.7ms	remaining: 389ms
# 191:	learn: 0.3844305	total: 92.2ms	remaining: 388ms
# 192:	learn: 0.3841466	total: 92.6ms	remaining: 387ms
# 193:	learn: 0.3840460	total: 93ms	remaining: 386ms
# 194:	learn: 0.3840118	total: 93.3ms	remaining: 385ms
# 195:	learn: 0.3837849	total: 93.9ms	remaining: 385ms
# 196:	learn: 0.3832849	total: 94.4ms	remaining: 385ms
# 197:	learn: 0.3828668	total: 94.8ms	remaining: 384ms
# 198:	learn: 0.3827495	total: 95.2ms	remaining: 383ms
# 199:	learn: 0.3825508	total: 95.6ms	remaining: 382ms
# 200:	learn: 0.3823729	total: 96.1ms	remaining: 382ms
# 201:	learn: 0.3822533	total: 96.6ms	remaining: 382ms
# 202:	learn: 0.3820590	total: 97.2ms	remaining: 382ms
# 203:	learn: 0.3819279	total: 98ms	remaining: 382ms
# 204:	learn: 0.3816353	total: 98.8ms	remaining: 383ms
# 205:	learn: 0.3813452	total: 99.2ms	remaining: 382ms
# 206:	learn: 0.3811673	total: 99.7ms	remaining: 382ms
# 207:	learn: 0.3806839	total: 100ms	remaining: 382ms
# 208:	learn: 0.3804510	total: 101ms	remaining: 382ms
# 209:	learn: 0.3803522	total: 101ms	remaining: 381ms
# 210:	learn: 0.3801136	total: 102ms	remaining: 381ms
# 211:	learn: 0.3798667	total: 102ms	remaining: 380ms
# 212:	learn: 0.3798114	total: 103ms	remaining: 379ms
# 213:	learn: 0.3795455	total: 103ms	remaining: 378ms
# 214:	learn: 0.3792948	total: 103ms	remaining: 378ms
# 215:	learn: 0.3790532	total: 104ms	remaining: 377ms
# 216:	learn: 0.3790206	total: 104ms	remaining: 376ms
# 217:	learn: 0.3787877	total: 105ms	remaining: 375ms
# 218:	learn: 0.3786011	total: 105ms	remaining: 375ms
# 219:	learn: 0.3782595	total: 106ms	remaining: 374ms
# 220:	learn: 0.3778429	total: 106ms	remaining: 373ms
# 221:	learn: 0.3774548	total: 106ms	remaining: 373ms
# 222:	learn: 0.3772416	total: 107ms	remaining: 372ms
# 223:	learn: 0.3768978	total: 107ms	remaining: 372ms
# 224:	learn: 0.3766148	total: 108ms	remaining: 371ms
# 225:	learn: 0.3763870	total: 108ms	remaining: 371ms
# 226:	learn: 0.3761053	total: 109ms	remaining: 370ms
# 227:	learn: 0.3758189	total: 109ms	remaining: 370ms
# 228:	learn: 0.3755894	total: 110ms	remaining: 369ms
# 229:	learn: 0.3753030	total: 110ms	remaining: 369ms
# 230:	learn: 0.3749716	total: 111ms	remaining: 370ms
# 231:	learn: 0.3748195	total: 112ms	remaining: 371ms
# 232:	learn: 0.3744007	total: 113ms	remaining: 370ms
# 233:	learn: 0.3740973	total: 113ms	remaining: 370ms
# 234:	learn: 0.3740642	total: 113ms	remaining: 369ms
# 235:	learn: 0.3738129	total: 114ms	remaining: 368ms
# 236:	learn: 0.3734811	total: 114ms	remaining: 368ms
# 237:	learn: 0.3734179	total: 115ms	remaining: 367ms
# 238:	learn: 0.3730930	total: 115ms	remaining: 366ms
# 239:	learn: 0.3727914	total: 115ms	remaining: 366ms
# 240:	learn: 0.3725917	total: 116ms	remaining: 365ms
# 241:	learn: 0.3723145	total: 116ms	remaining: 365ms
# 242:	learn: 0.3721926	total: 117ms	remaining: 364ms
# 243:	learn: 0.3719128	total: 117ms	remaining: 363ms
# 244:	learn: 0.3716042	total: 118ms	remaining: 363ms
# 245:	learn: 0.3714973	total: 118ms	remaining: 362ms
# 246:	learn: 0.3713109	total: 119ms	remaining: 361ms
# 247:	learn: 0.3710742	total: 119ms	remaining: 361ms
# 248:	learn: 0.3708293	total: 119ms	remaining: 360ms
# 249:	learn: 0.3706338	total: 120ms	remaining: 360ms
# 250:	learn: 0.3704314	total: 120ms	remaining: 359ms
# 251:	learn: 0.3700219	total: 121ms	remaining: 359ms
# 252:	learn: 0.3697580	total: 121ms	remaining: 358ms
# 253:	learn: 0.3695806	total: 122ms	remaining: 357ms
# 254:	learn: 0.3694105	total: 122ms	remaining: 357ms
# 255:	learn: 0.3693852	total: 123ms	remaining: 356ms
# 256:	learn: 0.3692421	total: 123ms	remaining: 356ms
# 257:	learn: 0.3690618	total: 124ms	remaining: 356ms
# 258:	learn: 0.3687349	total: 125ms	remaining: 358ms
# 259:	learn: 0.3685982	total: 126ms	remaining: 357ms
# 260:	learn: 0.3684048	total: 126ms	remaining: 357ms
# 261:	learn: 0.3682302	total: 126ms	remaining: 356ms
# 262:	learn: 0.3679982	total: 127ms	remaining: 356ms
# 263:	learn: 0.3678409	total: 128ms	remaining: 356ms
# 264:	learn: 0.3674714	total: 128ms	remaining: 355ms
# 265:	learn: 0.3670936	total: 129ms	remaining: 355ms
# 266:	learn: 0.3670753	total: 129ms	remaining: 355ms
# 267:	learn: 0.3669611	total: 130ms	remaining: 355ms
# 268:	learn: 0.3667454	total: 130ms	remaining: 355ms
# 269:	learn: 0.3665387	total: 131ms	remaining: 354ms
# 270:	learn: 0.3663954	total: 132ms	remaining: 354ms
# 271:	learn: 0.3662083	total: 132ms	remaining: 354ms
# 272:	learn: 0.3658721	total: 133ms	remaining: 354ms
# 273:	learn: 0.3656823	total: 134ms	remaining: 354ms
# 274:	learn: 0.3652958	total: 134ms	remaining: 354ms
# 275:	learn: 0.3651836	total: 135ms	remaining: 354ms
# 276:	learn: 0.3650904	total: 136ms	remaining: 354ms
# 277:	learn: 0.3648800	total: 138ms	remaining: 358ms
# 278:	learn: 0.3646628	total: 139ms	remaining: 358ms
# 279:	learn: 0.3643218	total: 139ms	remaining: 358ms
# 280:	learn: 0.3641030	total: 140ms	remaining: 359ms
# 281:	learn: 0.3639994	total: 141ms	remaining: 359ms
# 282:	learn: 0.3638517	total: 142ms	remaining: 359ms
# 283:	learn: 0.3636782	total: 142ms	remaining: 359ms
# 284:	learn: 0.3635170	total: 143ms	remaining: 358ms
# 285:	learn: 0.3634063	total: 144ms	remaining: 358ms
# 286:	learn: 0.3631703	total: 144ms	remaining: 359ms
# 287:	learn: 0.3628050	total: 145ms	remaining: 359ms
# 288:	learn: 0.3627540	total: 146ms	remaining: 358ms
# 289:	learn: 0.3625393	total: 146ms	remaining: 358ms
# 290:	learn: 0.3622725	total: 147ms	remaining: 358ms
# 291:	learn: 0.3620212	total: 148ms	remaining: 358ms
# 292:	learn: 0.3619628	total: 148ms	remaining: 358ms
# 293:	learn: 0.3616020	total: 150ms	remaining: 360ms
# 294:	learn: 0.3612506	total: 151ms	remaining: 362ms
# 295:	learn: 0.3611322	total: 152ms	remaining: 362ms
# 296:	learn: 0.3607899	total: 153ms	remaining: 362ms
# 297:	learn: 0.3607816	total: 153ms	remaining: 362ms
# 298:	learn: 0.3606965	total: 155ms	remaining: 362ms
# 299:	learn: 0.3606657	total: 156ms	remaining: 364ms
# 300:	learn: 0.3605021	total: 157ms	remaining: 364ms
# 301:	learn: 0.3603925	total: 158ms	remaining: 365ms
# 302:	learn: 0.3602963	total: 159ms	remaining: 365ms
# 303:	learn: 0.3601336	total: 159ms	remaining: 365ms
# 304:	learn: 0.3598743	total: 160ms	remaining: 364ms
# 305:	learn: 0.3596903	total: 160ms	remaining: 364ms
# 306:	learn: 0.3596127	total: 161ms	remaining: 364ms
# 307:	learn: 0.3594364	total: 164ms	remaining: 369ms
# 308:	learn: 0.3592763	total: 165ms	remaining: 368ms
# 309:	learn: 0.3590041	total: 165ms	remaining: 368ms
# 310:	learn: 0.3588721	total: 166ms	remaining: 368ms
# 311:	learn: 0.3586291	total: 166ms	remaining: 367ms
# 312:	learn: 0.3584767	total: 167ms	remaining: 366ms
# 313:	learn: 0.3582529	total: 168ms	remaining: 366ms
# 314:	learn: 0.3580211	total: 168ms	remaining: 366ms
# 315:	learn: 0.3579164	total: 169ms	remaining: 365ms
# 316:	learn: 0.3577637	total: 169ms	remaining: 365ms
# 317:	learn: 0.3575998	total: 170ms	remaining: 365ms
# 318:	learn: 0.3574722	total: 171ms	remaining: 365ms
# 319:	learn: 0.3572698	total: 172ms	remaining: 365ms
# 320:	learn: 0.3571292	total: 172ms	remaining: 365ms
# 321:	learn: 0.3569916	total: 173ms	remaining: 364ms
# 322:	learn: 0.3568624	total: 173ms	remaining: 363ms
# 323:	learn: 0.3566050	total: 174ms	remaining: 363ms
# 324:	learn: 0.3564479	total: 175ms	remaining: 363ms
# 325:	learn: 0.3563026	total: 175ms	remaining: 362ms
# 326:	learn: 0.3561629	total: 176ms	remaining: 362ms
# 327:	learn: 0.3561145	total: 176ms	remaining: 361ms
# 328:	learn: 0.3559212	total: 177ms	remaining: 361ms
# 329:	learn: 0.3559177	total: 177ms	remaining: 360ms
# 330:	learn: 0.3558165	total: 178ms	remaining: 360ms
# 331:	learn: 0.3557851	total: 179ms	remaining: 359ms
# 332:	learn: 0.3556701	total: 179ms	remaining: 359ms
# 333:	learn: 0.3555437	total: 181ms	remaining: 361ms
# 334:	learn: 0.3554162	total: 183ms	remaining: 363ms
# 335:	learn: 0.3552915	total: 183ms	remaining: 362ms
# 336:	learn: 0.3551426	total: 184ms	remaining: 362ms
# 337:	learn: 0.3548616	total: 185ms	remaining: 363ms
# 338:	learn: 0.3547185	total: 186ms	remaining: 362ms
# 339:	learn: 0.3545255	total: 187ms	remaining: 363ms
# 340:	learn: 0.3544075	total: 188ms	remaining: 363ms
# 341:	learn: 0.3542536	total: 188ms	remaining: 363ms
# 342:	learn: 0.3541128	total: 189ms	remaining: 362ms
# 343:	learn: 0.3540124	total: 190ms	remaining: 363ms
# 344:	learn: 0.3536671	total: 191ms	remaining: 362ms
# 345:	learn: 0.3534533	total: 191ms	remaining: 362ms
# 346:	learn: 0.3532146	total: 192ms	remaining: 361ms
# 347:	learn: 0.3529831	total: 193ms	remaining: 361ms
# 348:	learn: 0.3528865	total: 193ms	remaining: 360ms
# 349:	learn: 0.3526986	total: 194ms	remaining: 360ms
# 350:	learn: 0.3526900	total: 194ms	remaining: 359ms
# 351:	learn: 0.3525868	total: 195ms	remaining: 359ms
# 352:	learn: 0.3524675	total: 196ms	remaining: 359ms
# 353:	learn: 0.3523100	total: 197ms	remaining: 359ms
# 354:	learn: 0.3522119	total: 197ms	remaining: 359ms
# 355:	learn: 0.3519791	total: 198ms	remaining: 358ms
# 356:	learn: 0.3519634	total: 199ms	remaining: 358ms
# 357:	learn: 0.3519409	total: 199ms	remaining: 357ms
# 358:	learn: 0.3517878	total: 200ms	remaining: 357ms
# 359:	learn: 0.3517699	total: 201ms	remaining: 356ms
# 360:	learn: 0.3516866	total: 201ms	remaining: 356ms
# 361:	learn: 0.3515444	total: 202ms	remaining: 356ms
# 362:	learn: 0.3514210	total: 203ms	remaining: 356ms
# 363:	learn: 0.3514003	total: 204ms	remaining: 356ms
# 364:	learn: 0.3511946	total: 205ms	remaining: 356ms
# 365:	learn: 0.3510985	total: 205ms	remaining: 356ms
# 366:	learn: 0.3508289	total: 206ms	remaining: 355ms
# 367:	learn: 0.3506240	total: 207ms	remaining: 355ms
# 368:	learn: 0.3505396	total: 207ms	remaining: 354ms
# 369:	learn: 0.3505218	total: 208ms	remaining: 354ms
# 370:	learn: 0.3504942	total: 208ms	remaining: 353ms
# 371:	learn: 0.3503163	total: 209ms	remaining: 353ms
# 372:	learn: 0.3501661	total: 210ms	remaining: 352ms
# 373:	learn: 0.3499722	total: 210ms	remaining: 352ms
# 374:	learn: 0.3498380	total: 211ms	remaining: 351ms
# 375:	learn: 0.3497606	total: 211ms	remaining: 350ms
# 376:	learn: 0.3495238	total: 212ms	remaining: 350ms
# 377:	learn: 0.3493004	total: 212ms	remaining: 349ms
# 378:	learn: 0.3491696	total: 213ms	remaining: 349ms
# 379:	learn: 0.3488793	total: 213ms	remaining: 348ms
# 380:	learn: 0.3487495	total: 214ms	remaining: 348ms
# 381:	learn: 0.3486486	total: 215ms	remaining: 348ms
# 382:	learn: 0.3486257	total: 216ms	remaining: 348ms
# 383:	learn: 0.3483861	total: 217ms	remaining: 348ms
# 384:	learn: 0.3482454	total: 218ms	remaining: 348ms
# 385:	learn: 0.3480755	total: 219ms	remaining: 348ms
# 386:	learn: 0.3478949	total: 219ms	remaining: 347ms
# 387:	learn: 0.3478780	total: 220ms	remaining: 347ms
# 388:	learn: 0.3478448	total: 220ms	remaining: 346ms
# 389:	learn: 0.3477715	total: 221ms	remaining: 345ms
# 390:	learn: 0.3476748	total: 221ms	remaining: 345ms
# 391:	learn: 0.3475611	total: 222ms	remaining: 344ms
# 392:	learn: 0.3474854	total: 222ms	remaining: 344ms
# 393:	learn: 0.3473378	total: 223ms	remaining: 343ms
# 394:	learn: 0.3471700	total: 224ms	remaining: 343ms
# 395:	learn: 0.3470358	total: 224ms	remaining: 342ms
# 396:	learn: 0.3468614	total: 225ms	remaining: 341ms
# 397:	learn: 0.3467572	total: 225ms	remaining: 341ms
# 398:	learn: 0.3467161	total: 226ms	remaining: 340ms
# 399:	learn: 0.3465959	total: 226ms	remaining: 339ms
# 400:	learn: 0.3464791	total: 227ms	remaining: 338ms
# 401:	learn: 0.3464212	total: 227ms	remaining: 338ms
# 402:	learn: 0.3462492	total: 230ms	remaining: 341ms
# 403:	learn: 0.3461472	total: 231ms	remaining: 341ms
# 404:	learn: 0.3460303	total: 231ms	remaining: 340ms
# 405:	learn: 0.3458911	total: 236ms	remaining: 345ms
# 406:	learn: 0.3458762	total: 237ms	remaining: 345ms
# 407:	learn: 0.3456468	total: 237ms	remaining: 344ms
# 408:	learn: 0.3455962	total: 237ms	remaining: 343ms
# 409:	learn: 0.3455245	total: 238ms	remaining: 342ms
# 410:	learn: 0.3454572	total: 238ms	remaining: 341ms
# 411:	learn: 0.3453486	total: 239ms	remaining: 341ms
# 412:	learn: 0.3451365	total: 240ms	remaining: 341ms
# 413:	learn: 0.3450274	total: 241ms	remaining: 341ms
# 414:	learn: 0.3448857	total: 243ms	remaining: 342ms
# 415:	learn: 0.3447123	total: 244ms	remaining: 342ms
# 416:	learn: 0.3445204	total: 245ms	remaining: 342ms
# 417:	learn: 0.3442898	total: 245ms	remaining: 341ms
# 418:	learn: 0.3441484	total: 246ms	remaining: 341ms
# 419:	learn: 0.3441046	total: 247ms	remaining: 341ms
# 420:	learn: 0.3440324	total: 248ms	remaining: 341ms
# 421:	learn: 0.3439300	total: 248ms	remaining: 340ms
# 422:	learn: 0.3438282	total: 249ms	remaining: 340ms
# 423:	learn: 0.3436538	total: 250ms	remaining: 340ms
# 424:	learn: 0.3435102	total: 251ms	remaining: 340ms
# 425:	learn: 0.3434113	total: 252ms	remaining: 339ms
# 426:	learn: 0.3432962	total: 253ms	remaining: 339ms
# 427:	learn: 0.3432933	total: 253ms	remaining: 338ms
# 428:	learn: 0.3432916	total: 254ms	remaining: 338ms
# 429:	learn: 0.3431367	total: 256ms	remaining: 340ms
# 430:	learn: 0.3431130	total: 257ms	remaining: 339ms
# 431:	learn: 0.3430362	total: 257ms	remaining: 339ms
# 432:	learn: 0.3429113	total: 258ms	remaining: 338ms
# 433:	learn: 0.3427698	total: 259ms	remaining: 338ms
# 434:	learn: 0.3425883	total: 260ms	remaining: 337ms
# 435:	learn: 0.3424391	total: 260ms	remaining: 336ms
# 436:	learn: 0.3423670	total: 261ms	remaining: 336ms
# 437:	learn: 0.3423104	total: 261ms	remaining: 335ms
# 438:	learn: 0.3421635	total: 262ms	remaining: 335ms
# 439:	learn: 0.3419961	total: 262ms	remaining: 334ms
# 440:	learn: 0.3419725	total: 263ms	remaining: 333ms
# 441:	learn: 0.3418646	total: 264ms	remaining: 333ms
# 442:	learn: 0.3418565	total: 264ms	remaining: 332ms
# 443:	learn: 0.3417410	total: 265ms	remaining: 332ms
# 444:	learn: 0.3414696	total: 266ms	remaining: 331ms
# 445:	learn: 0.3413740	total: 266ms	remaining: 330ms
# 446:	learn: 0.3412765	total: 269ms	remaining: 332ms
# 447:	learn: 0.3412748	total: 269ms	remaining: 332ms
# 448:	learn: 0.3411595	total: 270ms	remaining: 331ms
# 449:	learn: 0.3409487	total: 270ms	remaining: 330ms
# 450:	learn: 0.3408749	total: 271ms	remaining: 329ms
# 451:	learn: 0.3407686	total: 271ms	remaining: 328ms
# 452:	learn: 0.3407624	total: 271ms	remaining: 328ms
# 453:	learn: 0.3406147	total: 272ms	remaining: 327ms
# 454:	learn: 0.3404694	total: 272ms	remaining: 326ms
# 455:	learn: 0.3404670	total: 273ms	remaining: 326ms
# 456:	learn: 0.3402852	total: 273ms	remaining: 325ms
# 457:	learn: 0.3401524	total: 274ms	remaining: 324ms
# 458:	learn: 0.3401073	total: 274ms	remaining: 324ms
# 459:	learn: 0.3400339	total: 275ms	remaining: 323ms
# 460:	learn: 0.3399387	total: 275ms	remaining: 322ms
# 461:	learn: 0.3398690	total: 275ms	remaining: 321ms
# 462:	learn: 0.3398245	total: 276ms	remaining: 320ms
# 463:	learn: 0.3397612	total: 276ms	remaining: 319ms
# 464:	learn: 0.3397349	total: 277ms	remaining: 319ms
# 465:	learn: 0.3396487	total: 277ms	remaining: 318ms
# 466:	learn: 0.3395265	total: 278ms	remaining: 317ms
# 467:	learn: 0.3394149	total: 278ms	remaining: 316ms
# 468:	learn: 0.3391928	total: 282ms	remaining: 319ms
# 469:	learn: 0.3391410	total: 282ms	remaining: 319ms
# 470:	learn: 0.3390327	total: 283ms	remaining: 318ms
# 471:	learn: 0.3389171	total: 284ms	remaining: 318ms
# 472:	learn: 0.3388433	total: 285ms	remaining: 317ms
# 473:	learn: 0.3387796	total: 285ms	remaining: 317ms
# 474:	learn: 0.3386771	total: 286ms	remaining: 316ms
# 475:	learn: 0.3385294	total: 287ms	remaining: 316ms
# 476:	learn: 0.3384567	total: 288ms	remaining: 315ms
# 477:	learn: 0.3383665	total: 289ms	remaining: 315ms
# 478:	learn: 0.3383277	total: 289ms	remaining: 315ms
# 479:	learn: 0.3382450	total: 290ms	remaining: 314ms
# 480:	learn: 0.3380308	total: 291ms	remaining: 314ms
# 481:	learn: 0.3379227	total: 291ms	remaining: 313ms
# 482:	learn: 0.3377934	total: 292ms	remaining: 312ms
# 483:	learn: 0.3375926	total: 292ms	remaining: 312ms
# 484:	learn: 0.3374434	total: 293ms	remaining: 311ms
# 485:	learn: 0.3373778	total: 293ms	remaining: 310ms
# 486:	learn: 0.3373304	total: 294ms	remaining: 310ms
# 487:	learn: 0.3373297	total: 295ms	remaining: 310ms
# 488:	learn: 0.3372513	total: 296ms	remaining: 309ms
# 489:	learn: 0.3371716	total: 296ms	remaining: 308ms
# 490:	learn: 0.3370347	total: 296ms	remaining: 307ms
# 491:	learn: 0.3369794	total: 297ms	remaining: 306ms
# 492:	learn: 0.3369175	total: 297ms	remaining: 306ms
# 493:	learn: 0.3367586	total: 298ms	remaining: 305ms
# 494:	learn: 0.3367044	total: 298ms	remaining: 304ms
# 495:	learn: 0.3366258	total: 299ms	remaining: 304ms
# 496:	learn: 0.3365778	total: 299ms	remaining: 303ms
# 497:	learn: 0.3365362	total: 300ms	remaining: 302ms
# 498:	learn: 0.3364800	total: 300ms	remaining: 301ms
# 499:	learn: 0.3363921	total: 300ms	remaining: 300ms
# 500:	learn: 0.3363567	total: 300ms	remaining: 299ms
# 501:	learn: 0.3362929	total: 301ms	remaining: 298ms
# 502:	learn: 0.3361717	total: 301ms	remaining: 297ms
# 503:	learn: 0.3361015	total: 302ms	remaining: 297ms
# 504:	learn: 0.3360250	total: 302ms	remaining: 296ms
# 505:	learn: 0.3358958	total: 303ms	remaining: 295ms
# 506:	learn: 0.3357812	total: 303ms	remaining: 295ms
# 507:	learn: 0.3357667	total: 303ms	remaining: 294ms
# 508:	learn: 0.3357089	total: 304ms	remaining: 294ms
# 509:	learn: 0.3357067	total: 305ms	remaining: 293ms
# 510:	learn: 0.3356267	total: 305ms	remaining: 292ms
# 511:	learn: 0.3356207	total: 306ms	remaining: 292ms
# 512:	learn: 0.3356120	total: 307ms	remaining: 291ms
# 513:	learn: 0.3354725	total: 307ms	remaining: 290ms
# 514:	learn: 0.3353847	total: 307ms	remaining: 289ms
# 515:	learn: 0.3353590	total: 308ms	remaining: 289ms
# 516:	learn: 0.3352919	total: 308ms	remaining: 288ms
# 517:	learn: 0.3351953	total: 308ms	remaining: 287ms
# 518:	learn: 0.3351018	total: 310ms	remaining: 287ms
# 519:	learn: 0.3350055	total: 310ms	remaining: 286ms
# 520:	learn: 0.3349288	total: 311ms	remaining: 286ms
# 521:	learn: 0.3348818	total: 311ms	remaining: 285ms
# 522:	learn: 0.3348096	total: 312ms	remaining: 285ms
# 523:	learn: 0.3347546	total: 313ms	remaining: 284ms
# 524:	learn: 0.3347371	total: 313ms	remaining: 284ms
# 525:	learn: 0.3346714	total: 314ms	remaining: 283ms
# 526:	learn: 0.3345674	total: 315ms	remaining: 283ms
# 527:	learn: 0.3344061	total: 316ms	remaining: 282ms
# 528:	learn: 0.3343958	total: 319ms	remaining: 284ms
# 529:	learn: 0.3343431	total: 319ms	remaining: 283ms
# 530:	learn: 0.3343095	total: 319ms	remaining: 282ms
# 531:	learn: 0.3342331	total: 319ms	remaining: 281ms
# 532:	learn: 0.3341087	total: 320ms	remaining: 280ms
# 533:	learn: 0.3340677	total: 320ms	remaining: 279ms
# 534:	learn: 0.3340090	total: 321ms	remaining: 279ms
# 535:	learn: 0.3338644	total: 321ms	remaining: 278ms
# 536:	learn: 0.3337608	total: 322ms	remaining: 277ms
# 537:	learn: 0.3337037	total: 322ms	remaining: 277ms
# 538:	learn: 0.3336244	total: 323ms	remaining: 276ms
# 539:	learn: 0.3335810	total: 324ms	remaining: 276ms
# 540:	learn: 0.3335642	total: 324ms	remaining: 275ms
# 541:	learn: 0.3334839	total: 324ms	remaining: 274ms
# 542:	learn: 0.3334591	total: 325ms	remaining: 274ms
# 543:	learn: 0.3334254	total: 327ms	remaining: 274ms
# 544:	learn: 0.3333036	total: 328ms	remaining: 274ms
# 545:	learn: 0.3332582	total: 328ms	remaining: 273ms
# 546:	learn: 0.3331831	total: 329ms	remaining: 272ms
# 547:	learn: 0.3331309	total: 329ms	remaining: 272ms
# 548:	learn: 0.3330116	total: 330ms	remaining: 271ms
# 549:	learn: 0.3329028	total: 330ms	remaining: 270ms
# 550:	learn: 0.3328985	total: 331ms	remaining: 269ms
# 551:	learn: 0.3328409	total: 331ms	remaining: 269ms
# 552:	learn: 0.3327770	total: 331ms	remaining: 268ms
# 553:	learn: 0.3326963	total: 332ms	remaining: 267ms
# 554:	learn: 0.3326293	total: 332ms	remaining: 266ms
# 555:	learn: 0.3325837	total: 333ms	remaining: 266ms
# 556:	learn: 0.3325245	total: 333ms	remaining: 265ms
# 557:	learn: 0.3324089	total: 334ms	remaining: 264ms
# 558:	learn: 0.3323833	total: 334ms	remaining: 264ms
# 559:	learn: 0.3322232	total: 335ms	remaining: 263ms
# 560:	learn: 0.3321090	total: 335ms	remaining: 262ms
# 561:	learn: 0.3319887	total: 336ms	remaining: 261ms
# 562:	learn: 0.3319758	total: 336ms	remaining: 261ms
# 563:	learn: 0.3319319	total: 336ms	remaining: 260ms
# 564:	learn: 0.3318650	total: 337ms	remaining: 259ms
# 565:	learn: 0.3317851	total: 337ms	remaining: 259ms
# 566:	learn: 0.3317339	total: 338ms	remaining: 258ms
# 567:	learn: 0.3317290	total: 338ms	remaining: 257ms
# 568:	learn: 0.3316783	total: 339ms	remaining: 256ms
# 569:	learn: 0.3316023	total: 339ms	remaining: 256ms
# 570:	learn: 0.3315071	total: 340ms	remaining: 256ms
# 571:	learn: 0.3314495	total: 342ms	remaining: 256ms
# 572:	learn: 0.3313565	total: 343ms	remaining: 256ms
# 573:	learn: 0.3313489	total: 344ms	remaining: 255ms
# 574:	learn: 0.3312379	total: 344ms	remaining: 254ms
# 575:	learn: 0.3312371	total: 345ms	remaining: 254ms
# 576:	learn: 0.3310634	total: 345ms	remaining: 253ms
# 577:	learn: 0.3310515	total: 346ms	remaining: 252ms
# 578:	learn: 0.3309869	total: 346ms	remaining: 252ms
# 579:	learn: 0.3309036	total: 346ms	remaining: 251ms
# 580:	learn: 0.3308580	total: 347ms	remaining: 250ms
# 581:	learn: 0.3308221	total: 347ms	remaining: 249ms
# 582:	learn: 0.3307636	total: 348ms	remaining: 249ms
# 583:	learn: 0.3306903	total: 348ms	remaining: 248ms
# 584:	learn: 0.3306237	total: 348ms	remaining: 247ms
# 585:	learn: 0.3305732	total: 349ms	remaining: 247ms
# 586:	learn: 0.3305073	total: 349ms	remaining: 246ms
# 587:	learn: 0.3304390	total: 350ms	remaining: 245ms
# 588:	learn: 0.3303898	total: 350ms	remaining: 244ms
# 589:	learn: 0.3303372	total: 351ms	remaining: 244ms
# 590:	learn: 0.3303215	total: 351ms	remaining: 243ms
# 591:	learn: 0.3302737	total: 352ms	remaining: 242ms
# 592:	learn: 0.3302212	total: 353ms	remaining: 242ms
# 593:	learn: 0.3301593	total: 354ms	remaining: 242ms
# 594:	learn: 0.3301235	total: 354ms	remaining: 241ms
# 595:	learn: 0.3301169	total: 355ms	remaining: 240ms
# 596:	learn: 0.3301113	total: 355ms	remaining: 240ms
# 597:	learn: 0.3300969	total: 355ms	remaining: 239ms
# 598:	learn: 0.3300504	total: 356ms	remaining: 238ms
# 599:	learn: 0.3299887	total: 356ms	remaining: 237ms
# 600:	learn: 0.3298889	total: 357ms	remaining: 237ms
# 601:	learn: 0.3298660	total: 357ms	remaining: 236ms
# 602:	learn: 0.3298659	total: 357ms	remaining: 235ms
# 603:	learn: 0.3297962	total: 358ms	remaining: 234ms
# 604:	learn: 0.3297940	total: 358ms	remaining: 234ms
# 605:	learn: 0.3297032	total: 358ms	remaining: 233ms
# 606:	learn: 0.3296978	total: 359ms	remaining: 232ms
# 607:	learn: 0.3296205	total: 359ms	remaining: 232ms
# 608:	learn: 0.3295787	total: 360ms	remaining: 231ms
# 609:	learn: 0.3294739	total: 360ms	remaining: 230ms
# 610:	learn: 0.3294025	total: 361ms	remaining: 230ms
# 611:	learn: 0.3293405	total: 361ms	remaining: 229ms
# 612:	learn: 0.3292204	total: 361ms	remaining: 228ms
# 613:	learn: 0.3291501	total: 362ms	remaining: 227ms
# 614:	learn: 0.3290527	total: 362ms	remaining: 227ms
# 615:	learn: 0.3289728	total: 363ms	remaining: 226ms
# 616:	learn: 0.3288235	total: 363ms	remaining: 225ms
# 617:	learn: 0.3287357	total: 364ms	remaining: 225ms
# 618:	learn: 0.3287260	total: 364ms	remaining: 224ms
# 619:	learn: 0.3286635	total: 364ms	remaining: 223ms
# 620:	learn: 0.3286584	total: 365ms	remaining: 223ms
# 621:	learn: 0.3286009	total: 365ms	remaining: 222ms
# 622:	learn: 0.3285582	total: 366ms	remaining: 222ms
# 623:	learn: 0.3285369	total: 367ms	remaining: 221ms
# 624:	learn: 0.3284426	total: 368ms	remaining: 221ms
# 625:	learn: 0.3283362	total: 368ms	remaining: 220ms
# 626:	learn: 0.3283177	total: 368ms	remaining: 219ms
# 627:	learn: 0.3282898	total: 369ms	remaining: 218ms
# 628:	learn: 0.3281715	total: 369ms	remaining: 218ms
# 629:	learn: 0.3280943	total: 370ms	remaining: 217ms
# 630:	learn: 0.3280467	total: 370ms	remaining: 216ms
# 631:	learn: 0.3279572	total: 371ms	remaining: 216ms
# 632:	learn: 0.3279080	total: 371ms	remaining: 215ms
# 633:	learn: 0.3279079	total: 371ms	remaining: 214ms
# 634:	learn: 0.3278427	total: 372ms	remaining: 214ms
# 635:	learn: 0.3277931	total: 372ms	remaining: 213ms
# 636:	learn: 0.3277761	total: 372ms	remaining: 212ms
# 637:	learn: 0.3276952	total: 373ms	remaining: 212ms
# 638:	learn: 0.3276011	total: 373ms	remaining: 211ms
# 639:	learn: 0.3275723	total: 374ms	remaining: 210ms
# 640:	learn: 0.3275389	total: 374ms	remaining: 210ms
# 641:	learn: 0.3274133	total: 374ms	remaining: 209ms
# 642:	learn: 0.3274010	total: 375ms	remaining: 208ms
# 643:	learn: 0.3273574	total: 375ms	remaining: 207ms
# 644:	learn: 0.3272940	total: 376ms	remaining: 207ms
# 645:	learn: 0.3272525	total: 376ms	remaining: 206ms
# 646:	learn: 0.3271726	total: 377ms	remaining: 205ms
# 647:	learn: 0.3270703	total: 377ms	remaining: 205ms
# 648:	learn: 0.3269958	total: 378ms	remaining: 204ms
# 649:	learn: 0.3269538	total: 378ms	remaining: 204ms
# 650:	learn: 0.3268705	total: 379ms	remaining: 203ms
# 651:	learn: 0.3268210	total: 379ms	remaining: 202ms
# 652:	learn: 0.3267834	total: 380ms	remaining: 202ms
# 653:	learn: 0.3266971	total: 380ms	remaining: 201ms
# 654:	learn: 0.3266816	total: 381ms	remaining: 201ms
# 655:	learn: 0.3266022	total: 381ms	remaining: 200ms
# 656:	learn: 0.3265554	total: 381ms	remaining: 199ms
# 657:	learn: 0.3265105	total: 382ms	remaining: 198ms
# 658:	learn: 0.3264929	total: 382ms	remaining: 198ms
# 659:	learn: 0.3264212	total: 383ms	remaining: 197ms
# 660:	learn: 0.3263895	total: 383ms	remaining: 196ms
# 661:	learn: 0.3263126	total: 383ms	remaining: 196ms
# 662:	learn: 0.3262405	total: 384ms	remaining: 195ms
# 663:	learn: 0.3261600	total: 384ms	remaining: 195ms
# 664:	learn: 0.3261372	total: 385ms	remaining: 194ms
# 665:	learn: 0.3260688	total: 385ms	remaining: 193ms
# 666:	learn: 0.3259892	total: 386ms	remaining: 193ms
# 667:	learn: 0.3258997	total: 386ms	remaining: 192ms
# 668:	learn: 0.3258196	total: 386ms	remaining: 191ms
# 669:	learn: 0.3258180	total: 387ms	remaining: 190ms
# 670:	learn: 0.3257442	total: 387ms	remaining: 190ms
# 671:	learn: 0.3256242	total: 388ms	remaining: 189ms
# 672:	learn: 0.3255636	total: 388ms	remaining: 189ms
# 673:	learn: 0.3254851	total: 388ms	remaining: 188ms
# 674:	learn: 0.3254807	total: 389ms	remaining: 187ms
# 675:	learn: 0.3254046	total: 389ms	remaining: 187ms
# 676:	learn: 0.3253617	total: 390ms	remaining: 186ms
# 677:	learn: 0.3252943	total: 390ms	remaining: 185ms
# 678:	learn: 0.3252339	total: 390ms	remaining: 185ms
# 679:	learn: 0.3252159	total: 391ms	remaining: 184ms
# 680:	learn: 0.3251918	total: 391ms	remaining: 183ms
# 681:	learn: 0.3250430	total: 392ms	remaining: 183ms
# 682:	learn: 0.3249801	total: 392ms	remaining: 182ms
# 683:	learn: 0.3249493	total: 393ms	remaining: 181ms
# 684:	learn: 0.3248750	total: 393ms	remaining: 181ms
# 685:	learn: 0.3248413	total: 393ms	remaining: 180ms
# 686:	learn: 0.3247770	total: 394ms	remaining: 179ms
# 687:	learn: 0.3247288	total: 394ms	remaining: 179ms
# 688:	learn: 0.3246620	total: 395ms	remaining: 178ms
# 689:	learn: 0.3246553	total: 395ms	remaining: 177ms
# 690:	learn: 0.3246335	total: 395ms	remaining: 177ms
# 691:	learn: 0.3246250	total: 396ms	remaining: 176ms
# 692:	learn: 0.3245185	total: 396ms	remaining: 175ms
# 693:	learn: 0.3244379	total: 397ms	remaining: 175ms
# 694:	learn: 0.3244261	total: 397ms	remaining: 174ms
# 695:	learn: 0.3243226	total: 397ms	remaining: 174ms
# 696:	learn: 0.3242661	total: 398ms	remaining: 173ms
# 697:	learn: 0.3242121	total: 398ms	remaining: 172ms
# 698:	learn: 0.3241569	total: 399ms	remaining: 172ms
# 699:	learn: 0.3241056	total: 399ms	remaining: 171ms
# 700:	learn: 0.3240550	total: 399ms	remaining: 170ms
# 701:	learn: 0.3240482	total: 400ms	remaining: 170ms
# 702:	learn: 0.3240334	total: 400ms	remaining: 169ms
# 703:	learn: 0.3239685	total: 400ms	remaining: 168ms
# 704:	learn: 0.3239666	total: 401ms	remaining: 168ms
# 705:	learn: 0.3239330	total: 401ms	remaining: 167ms
# 706:	learn: 0.3238576	total: 402ms	remaining: 166ms
# 707:	learn: 0.3238359	total: 402ms	remaining: 166ms
# 708:	learn: 0.3238292	total: 402ms	remaining: 165ms
# 709:	learn: 0.3238172	total: 403ms	remaining: 164ms
# 710:	learn: 0.3237842	total: 403ms	remaining: 164ms
# 711:	learn: 0.3237273	total: 403ms	remaining: 163ms
# 712:	learn: 0.3236764	total: 404ms	remaining: 163ms
# 713:	learn: 0.3236705	total: 405ms	remaining: 162ms
# 714:	learn: 0.3235382	total: 405ms	remaining: 162ms
# 715:	learn: 0.3234414	total: 406ms	remaining: 161ms
# 716:	learn: 0.3233636	total: 406ms	remaining: 160ms
# 717:	learn: 0.3232920	total: 407ms	remaining: 160ms
# 718:	learn: 0.3232110	total: 407ms	remaining: 159ms
# 719:	learn: 0.3231824	total: 408ms	remaining: 158ms
# 720:	learn: 0.3231101	total: 408ms	remaining: 158ms
# 721:	learn: 0.3230658	total: 408ms	remaining: 157ms
# 722:	learn: 0.3229649	total: 409ms	remaining: 157ms
# 723:	learn: 0.3228783	total: 409ms	remaining: 156ms
# 724:	learn: 0.3228151	total: 410ms	remaining: 155ms
# 725:	learn: 0.3227842	total: 410ms	remaining: 155ms
# 726:	learn: 0.3227152	total: 410ms	remaining: 154ms
# 727:	learn: 0.3226879	total: 411ms	remaining: 154ms
# 728:	learn: 0.3225773	total: 411ms	remaining: 153ms
# 729:	learn: 0.3224877	total: 412ms	remaining: 152ms
# 730:	learn: 0.3224170	total: 412ms	remaining: 152ms
# 731:	learn: 0.3223347	total: 413ms	remaining: 151ms
# 732:	learn: 0.3223345	total: 413ms	remaining: 150ms
# 733:	learn: 0.3222861	total: 413ms	remaining: 150ms
# 734:	learn: 0.3222034	total: 414ms	remaining: 149ms
# 735:	learn: 0.3221859	total: 414ms	remaining: 148ms
# 736:	learn: 0.3221142	total: 414ms	remaining: 148ms
# 737:	learn: 0.3220418	total: 415ms	remaining: 147ms
# 738:	learn: 0.3219923	total: 415ms	remaining: 147ms
# 739:	learn: 0.3219646	total: 416ms	remaining: 146ms
# 740:	learn: 0.3219424	total: 416ms	remaining: 145ms
# 741:	learn: 0.3219252	total: 417ms	remaining: 145ms
# 742:	learn: 0.3218311	total: 418ms	remaining: 144ms
# 743:	learn: 0.3217279	total: 418ms	remaining: 144ms
# 744:	learn: 0.3217250	total: 418ms	remaining: 143ms
# 745:	learn: 0.3216887	total: 419ms	remaining: 143ms
# 746:	learn: 0.3216532	total: 420ms	remaining: 142ms
# 747:	learn: 0.3215866	total: 420ms	remaining: 142ms
# 748:	learn: 0.3214804	total: 421ms	remaining: 141ms
# 749:	learn: 0.3214657	total: 421ms	remaining: 140ms
# 750:	learn: 0.3213815	total: 422ms	remaining: 140ms
# 751:	learn: 0.3213424	total: 422ms	remaining: 139ms
# 752:	learn: 0.3212434	total: 423ms	remaining: 139ms
# 753:	learn: 0.3211939	total: 423ms	remaining: 138ms
# 754:	learn: 0.3211401	total: 424ms	remaining: 138ms
# 755:	learn: 0.3210700	total: 424ms	remaining: 137ms
# 756:	learn: 0.3209683	total: 425ms	remaining: 136ms
# 757:	learn: 0.3208796	total: 425ms	remaining: 136ms
# 758:	learn: 0.3208357	total: 425ms	remaining: 135ms
# 759:	learn: 0.3207175	total: 426ms	remaining: 135ms
# 760:	learn: 0.3206437	total: 426ms	remaining: 134ms
# 761:	learn: 0.3205756	total: 427ms	remaining: 133ms
# 762:	learn: 0.3205384	total: 427ms	remaining: 133ms
# 763:	learn: 0.3204601	total: 428ms	remaining: 132ms
# 764:	learn: 0.3203897	total: 430ms	remaining: 132ms
# 765:	learn: 0.3203430	total: 430ms	remaining: 132ms
# 766:	learn: 0.3202809	total: 431ms	remaining: 131ms
# 767:	learn: 0.3202344	total: 431ms	remaining: 130ms
# 768:	learn: 0.3201484	total: 432ms	remaining: 130ms
# 769:	learn: 0.3200668	total: 432ms	remaining: 129ms
# 770:	learn: 0.3200102	total: 433ms	remaining: 128ms
# 771:	learn: 0.3199416	total: 434ms	remaining: 128ms
# 772:	learn: 0.3198921	total: 435ms	remaining: 128ms
# 773:	learn: 0.3197740	total: 435ms	remaining: 127ms
# 774:	learn: 0.3197213	total: 436ms	remaining: 127ms
# 775:	learn: 0.3196226	total: 436ms	remaining: 126ms
# 776:	learn: 0.3195834	total: 437ms	remaining: 125ms
# 777:	learn: 0.3194726	total: 437ms	remaining: 125ms
# 778:	learn: 0.3193751	total: 438ms	remaining: 124ms
# 779:	learn: 0.3193558	total: 439ms	remaining: 124ms
# 780:	learn: 0.3192991	total: 439ms	remaining: 123ms
# 781:	learn: 0.3192337	total: 440ms	remaining: 123ms
# 782:	learn: 0.3191618	total: 441ms	remaining: 122ms
# 783:	learn: 0.3190924	total: 441ms	remaining: 122ms
# 784:	learn: 0.3190568	total: 442ms	remaining: 121ms
# 785:	learn: 0.3190242	total: 442ms	remaining: 120ms
# 786:	learn: 0.3189209	total: 443ms	remaining: 120ms
# 787:	learn: 0.3188293	total: 443ms	remaining: 119ms
# 788:	learn: 0.3187964	total: 444ms	remaining: 119ms
# 789:	learn: 0.3187466	total: 444ms	remaining: 118ms
# 790:	learn: 0.3186794	total: 445ms	remaining: 117ms
# 791:	learn: 0.3186205	total: 445ms	remaining: 117ms
# 792:	learn: 0.3185239	total: 446ms	remaining: 116ms
# 793:	learn: 0.3184741	total: 446ms	remaining: 116ms
# 794:	learn: 0.3184704	total: 446ms	remaining: 115ms
# 795:	learn: 0.3184250	total: 447ms	remaining: 115ms
# 796:	learn: 0.3183812	total: 447ms	remaining: 114ms
# 797:	learn: 0.3183175	total: 448ms	remaining: 113ms
# 798:	learn: 0.3182780	total: 449ms	remaining: 113ms
# 799:	learn: 0.3181283	total: 449ms	remaining: 112ms
# 800:	learn: 0.3180980	total: 449ms	remaining: 112ms
# 801:	learn: 0.3180468	total: 450ms	remaining: 111ms
# 802:	learn: 0.3179674	total: 450ms	remaining: 111ms
# 803:	learn: 0.3179373	total: 451ms	remaining: 110ms
# 804:	learn: 0.3178726	total: 452ms	remaining: 109ms
# 805:	learn: 0.3178257	total: 452ms	remaining: 109ms
# 806:	learn: 0.3177829	total: 453ms	remaining: 108ms
# 807:	learn: 0.3177041	total: 453ms	remaining: 108ms
# 808:	learn: 0.3175779	total: 454ms	remaining: 107ms
# 809:	learn: 0.3175623	total: 455ms	remaining: 107ms
# 810:	learn: 0.3175526	total: 456ms	remaining: 106ms
# 811:	learn: 0.3174854	total: 457ms	remaining: 106ms
# 812:	learn: 0.3174476	total: 457ms	remaining: 105ms
# 813:	learn: 0.3173855	total: 458ms	remaining: 105ms
# 814:	learn: 0.3173156	total: 458ms	remaining: 104ms
# 815:	learn: 0.3172516	total: 458ms	remaining: 103ms
# 816:	learn: 0.3171816	total: 459ms	remaining: 103ms
# 817:	learn: 0.3170956	total: 459ms	remaining: 102ms
# 818:	learn: 0.3170167	total: 460ms	remaining: 102ms
# 819:	learn: 0.3169445	total: 460ms	remaining: 101ms
# 820:	learn: 0.3169075	total: 461ms	remaining: 100ms
# 821:	learn: 0.3168685	total: 461ms	remaining: 99.9ms
# 822:	learn: 0.3168295	total: 462ms	remaining: 99.4ms
# 823:	learn: 0.3167919	total: 463ms	remaining: 98.8ms
# 824:	learn: 0.3167353	total: 463ms	remaining: 98.3ms
# 825:	learn: 0.3166879	total: 464ms	remaining: 97.7ms
# 826:	learn: 0.3166643	total: 464ms	remaining: 97.1ms
# 827:	learn: 0.3166065	total: 465ms	remaining: 96.7ms
# 828:	learn: 0.3165747	total: 468ms	remaining: 96.5ms
# 829:	learn: 0.3165060	total: 468ms	remaining: 95.9ms
# 830:	learn: 0.3164098	total: 469ms	remaining: 95.4ms
# 831:	learn: 0.3163407	total: 470ms	remaining: 94.9ms
# 832:	learn: 0.3163012	total: 470ms	remaining: 94.3ms
# 833:	learn: 0.3162261	total: 471ms	remaining: 93.7ms
# 834:	learn: 0.3161671	total: 471ms	remaining: 93.2ms
# 835:	learn: 0.3160795	total: 472ms	remaining: 92.6ms
# 836:	learn: 0.3160520	total: 473ms	remaining: 92.1ms
# 837:	learn: 0.3158965	total: 473ms	remaining: 91.5ms
# 838:	learn: 0.3158737	total: 474ms	remaining: 90.9ms
# 839:	learn: 0.3158525	total: 474ms	remaining: 90.3ms
# 840:	learn: 0.3157724	total: 475ms	remaining: 89.8ms
# 841:	learn: 0.3157343	total: 476ms	remaining: 89.2ms
# 842:	learn: 0.3157340	total: 476ms	remaining: 88.7ms
# 843:	learn: 0.3156923	total: 477ms	remaining: 88.1ms
# 844:	learn: 0.3156068	total: 477ms	remaining: 87.5ms
# 845:	learn: 0.3155601	total: 478ms	remaining: 87ms
# 846:	learn: 0.3154814	total: 479ms	remaining: 86.4ms
# 847:	learn: 0.3154225	total: 480ms	remaining: 86ms
# 848:	learn: 0.3153708	total: 481ms	remaining: 85.5ms
# 849:	learn: 0.3152843	total: 481ms	remaining: 84.9ms
# 850:	learn: 0.3152233	total: 482ms	remaining: 84.3ms
# 851:	learn: 0.3151538	total: 482ms	remaining: 83.8ms
# 852:	learn: 0.3150959	total: 483ms	remaining: 83.3ms
# 853:	learn: 0.3150955	total: 484ms	remaining: 82.7ms
# 854:	learn: 0.3149800	total: 484ms	remaining: 82.1ms
# 855:	learn: 0.3149191	total: 484ms	remaining: 81.5ms
# 856:	learn: 0.3148685	total: 485ms	remaining: 80.9ms
# 857:	learn: 0.3148205	total: 485ms	remaining: 80.3ms
# 858:	learn: 0.3147849	total: 486ms	remaining: 79.7ms
# 859:	learn: 0.3147356	total: 486ms	remaining: 79.2ms
# 860:	learn: 0.3146998	total: 487ms	remaining: 78.6ms
# 861:	learn: 0.3146425	total: 487ms	remaining: 78ms
# 862:	learn: 0.3145702	total: 488ms	remaining: 77.4ms
# 863:	learn: 0.3144892	total: 488ms	remaining: 76.9ms
# 864:	learn: 0.3144511	total: 489ms	remaining: 76.3ms
# 865:	learn: 0.3143821	total: 490ms	remaining: 75.9ms
# 866:	learn: 0.3143641	total: 492ms	remaining: 75.4ms
# 867:	learn: 0.3142859	total: 492ms	remaining: 74.9ms
# 868:	learn: 0.3142651	total: 493ms	remaining: 74.3ms
# 869:	learn: 0.3142153	total: 493ms	remaining: 73.7ms
# 870:	learn: 0.3141654	total: 494ms	remaining: 73.1ms
# 871:	learn: 0.3140874	total: 494ms	remaining: 72.6ms
# 872:	learn: 0.3140273	total: 495ms	remaining: 72ms
# 873:	learn: 0.3140022	total: 495ms	remaining: 71.4ms
# 874:	learn: 0.3139734	total: 496ms	remaining: 70.8ms
# 875:	learn: 0.3139275	total: 496ms	remaining: 70.2ms
# 876:	learn: 0.3138520	total: 497ms	remaining: 69.7ms
# 877:	learn: 0.3138171	total: 498ms	remaining: 69.1ms
# 878:	learn: 0.3137810	total: 498ms	remaining: 68.6ms
# 879:	learn: 0.3136933	total: 499ms	remaining: 68.1ms
# 880:	learn: 0.3136316	total: 500ms	remaining: 67.5ms
# 881:	learn: 0.3135932	total: 500ms	remaining: 66.9ms
# 882:	learn: 0.3135598	total: 501ms	remaining: 66.3ms
# 883:	learn: 0.3134903	total: 501ms	remaining: 65.7ms
# 884:	learn: 0.3133509	total: 502ms	remaining: 65.2ms
# 885:	learn: 0.3132912	total: 502ms	remaining: 64.6ms
# 886:	learn: 0.3132355	total: 503ms	remaining: 64ms
# 887:	learn: 0.3131811	total: 503ms	remaining: 63.5ms
# 888:	learn: 0.3130854	total: 504ms	remaining: 62.9ms
# 889:	learn: 0.3129787	total: 505ms	remaining: 62.4ms
# 890:	learn: 0.3129509	total: 505ms	remaining: 61.8ms
# 891:	learn: 0.3128965	total: 506ms	remaining: 61.2ms
# 892:	learn: 0.3128577	total: 506ms	remaining: 60.6ms
# 893:	learn: 0.3128012	total: 506ms	remaining: 60.1ms
# 894:	learn: 0.3127957	total: 507ms	remaining: 59.5ms
# 895:	learn: 0.3127592	total: 507ms	remaining: 58.9ms
# 896:	learn: 0.3126541	total: 508ms	remaining: 58.3ms
# 897:	learn: 0.3125683	total: 508ms	remaining: 57.7ms
# 898:	learn: 0.3125036	total: 509ms	remaining: 57.2ms
# 899:	learn: 0.3124781	total: 509ms	remaining: 56.6ms
# 900:	learn: 0.3124351	total: 510ms	remaining: 56ms
# 901:	learn: 0.3124048	total: 511ms	remaining: 55.5ms
# 902:	learn: 0.3123310	total: 511ms	remaining: 54.9ms
# 903:	learn: 0.3123017	total: 512ms	remaining: 54.4ms
# 904:	learn: 0.3122430	total: 512ms	remaining: 53.8ms
# 905:	learn: 0.3122012	total: 513ms	remaining: 53.2ms
# 906:	learn: 0.3121737	total: 514ms	remaining: 52.7ms
# 907:	learn: 0.3121385	total: 514ms	remaining: 52.1ms
# 908:	learn: 0.3121004	total: 515ms	remaining: 51.5ms
# 909:	learn: 0.3120447	total: 515ms	remaining: 50.9ms
# 910:	learn: 0.3119874	total: 516ms	remaining: 50.4ms
# 911:	learn: 0.3119531	total: 517ms	remaining: 49.9ms
# 912:	learn: 0.3118892	total: 517ms	remaining: 49.3ms
# 913:	learn: 0.3118470	total: 518ms	remaining: 48.7ms
# 914:	learn: 0.3118317	total: 518ms	remaining: 48.1ms
# 915:	learn: 0.3117585	total: 519ms	remaining: 47.5ms
# 916:	learn: 0.3116914	total: 519ms	remaining: 47ms
# 917:	learn: 0.3116573	total: 519ms	remaining: 46.4ms
# 918:	learn: 0.3116163	total: 520ms	remaining: 45.8ms
# ...
# 693:	learn: 0.3476474	total: 859ms	remaining: 379ms
# 694:	learn: 0.3475274	total: 860ms	remaining: 377ms
# 695:	learn: 0.3474050	total: 863ms	remaining: 377ms
# 696:	learn: 0.3473984	total: 863ms	remaining: 375ms
# 697:	learn: 0.3473926	total: 863ms	remaining: 374ms
# 698:	learn: 0.3473523	total: 864ms	remaining: 372ms
# 699:	learn: 0.3472519	total: 864ms	remaining: 370ms
# 700:	learn: 0.3472206	total: 864ms	remaining: 369ms
# 701:	learn: 0.3471535	total: 864ms	remaining: 367ms
# 702:	learn: 0.3470956	total: 865ms	remaining: 365ms
# 703:	learn: 0.3469857	total: 865ms	remaining: 364ms
# 704:	learn: 0.3468666	total: 870ms	remaining: 364ms
# 705:	learn: 0.3467781	total: 873ms	remaining: 364ms
# 706:	learn: 0.3466831	total: 876ms	remaining: 363ms
# 707:	learn: 0.3466287	total: 877ms	remaining: 362ms
# 708:	learn: 0.3465841	total: 879ms	remaining: 361ms
# 709:	learn: 0.3465100	total: 879ms	remaining: 359ms
# 710:	learn: 0.3464435	total: 881ms	remaining: 358ms
# 711:	learn: 0.3464287	total: 886ms	remaining: 358ms
# 712:	learn: 0.3463287	total: 886ms	remaining: 357ms
# 713:	learn: 0.3463166	total: 887ms	remaining: 355ms
# 714:	learn: 0.3462699	total: 887ms	remaining: 354ms
# 715:	learn: 0.3462184	total: 887ms	remaining: 352ms
# 716:	learn: 0.3461180	total: 888ms	remaining: 350ms
# 717:	learn: 0.3459652	total: 889ms	remaining: 349ms
# 718:	learn: 0.3459291	total: 892ms	remaining: 348ms
# 719:	learn: 0.3458514	total: 892ms	remaining: 347ms
# 720:	learn: 0.3458357	total: 892ms	remaining: 345ms
# 721:	learn: 0.3456707	total: 893ms	remaining: 344ms
# 722:	learn: 0.3456191	total: 894ms	remaining: 342ms
# 723:	learn: 0.3455246	total: 894ms	remaining: 341ms
# 724:	learn: 0.3454551	total: 894ms	remaining: 339ms
# 725:	learn: 0.3453862	total: 895ms	remaining: 338ms
# 726:	learn: 0.3453558	total: 896ms	remaining: 336ms
# 727:	learn: 0.3453114	total: 897ms	remaining: 335ms
# 728:	learn: 0.3452165	total: 899ms	remaining: 334ms
# 729:	learn: 0.3451081	total: 902ms	remaining: 334ms
# 730:	learn: 0.3450435	total: 902ms	remaining: 332ms
# 731:	learn: 0.3450132	total: 902ms	remaining: 330ms
# 732:	learn: 0.3449566	total: 903ms	remaining: 329ms
# 733:	learn: 0.3449565	total: 907ms	remaining: 329ms
# 734:	learn: 0.3448997	total: 911ms	remaining: 328ms
# 735:	learn: 0.3448661	total: 912ms	remaining: 327ms
# 736:	learn: 0.3448440	total: 913ms	remaining: 326ms
# 737:	learn: 0.3447829	total: 914ms	remaining: 324ms
# 738:	learn: 0.3446706	total: 915ms	remaining: 323ms
# 739:	learn: 0.3446361	total: 916ms	remaining: 322ms
# 740:	learn: 0.3445512	total: 918ms	remaining: 321ms
# 741:	learn: 0.3444456	total: 923ms	remaining: 321ms
# 742:	learn: 0.3443659	total: 924ms	remaining: 320ms
# 743:	learn: 0.3443309	total: 924ms	remaining: 318ms
# 744:	learn: 0.3442581	total: 925ms	remaining: 317ms
# 745:	learn: 0.3441690	total: 926ms	remaining: 315ms
# 746:	learn: 0.3440827	total: 926ms	remaining: 314ms
# 747:	learn: 0.3440745	total: 927ms	remaining: 312ms
# 748:	learn: 0.3439838	total: 933ms	remaining: 313ms
# 749:	learn: 0.3439351	total: 934ms	remaining: 311ms
# 750:	learn: 0.3438599	total: 936ms	remaining: 310ms
# 751:	learn: 0.3438141	total: 936ms	remaining: 309ms
# 752:	learn: 0.3437635	total: 937ms	remaining: 307ms
# 753:	learn: 0.3437325	total: 938ms	remaining: 306ms
# 754:	learn: 0.3436346	total: 940ms	remaining: 305ms
# 755:	learn: 0.3435617	total: 941ms	remaining: 304ms
# 756:	learn: 0.3434848	total: 942ms	remaining: 302ms
# 757:	learn: 0.3434520	total: 943ms	remaining: 301ms
# 758:	learn: 0.3433742	total: 943ms	remaining: 299ms
# 759:	learn: 0.3433090	total: 944ms	remaining: 298ms
# 760:	learn: 0.3432578	total: 946ms	remaining: 297ms
# 761:	learn: 0.3431772	total: 946ms	remaining: 295ms
# 762:	learn: 0.3431554	total: 947ms	remaining: 294ms
# 763:	learn: 0.3430737	total: 947ms	remaining: 293ms
# 764:	learn: 0.3430498	total: 947ms	remaining: 291ms
# 765:	learn: 0.3430354	total: 948ms	remaining: 290ms
# 766:	learn: 0.3429473	total: 949ms	remaining: 288ms
# 767:	learn: 0.3428455	total: 950ms	remaining: 287ms
# 768:	learn: 0.3427809	total: 950ms	remaining: 286ms
# 769:	learn: 0.3427346	total: 951ms	remaining: 284ms
# 770:	learn: 0.3426654	total: 951ms	remaining: 283ms
# 771:	learn: 0.3425609	total: 952ms	remaining: 281ms
# 772:	learn: 0.3424823	total: 952ms	remaining: 280ms
# 773:	learn: 0.3424781	total: 957ms	remaining: 279ms
# 774:	learn: 0.3423380	total: 958ms	remaining: 278ms
# 775:	learn: 0.3423088	total: 960ms	remaining: 277ms
# 776:	learn: 0.3422756	total: 964ms	remaining: 277ms
# 777:	learn: 0.3422149	total: 967ms	remaining: 276ms
# 778:	learn: 0.3421250	total: 968ms	remaining: 275ms
# 779:	learn: 0.3421220	total: 970ms	remaining: 274ms
# 780:	learn: 0.3420702	total: 971ms	remaining: 272ms
# 781:	learn: 0.3420360	total: 971ms	remaining: 271ms
# 782:	learn: 0.3420202	total: 973ms	remaining: 270ms
# 783:	learn: 0.3419848	total: 974ms	remaining: 268ms
# 784:	learn: 0.3419055	total: 974ms	remaining: 267ms
# 785:	learn: 0.3418460	total: 975ms	remaining: 266ms
# 786:	learn: 0.3418404	total: 976ms	remaining: 264ms
# 787:	learn: 0.3418189	total: 978ms	remaining: 263ms
# 788:	learn: 0.3416900	total: 979ms	remaining: 262ms
# 789:	learn: 0.3416605	total: 979ms	remaining: 260ms
# 790:	learn: 0.3416589	total: 980ms	remaining: 259ms
# 791:	learn: 0.3415297	total: 980ms	remaining: 257ms
# 792:	learn: 0.3415109	total: 981ms	remaining: 256ms
# 793:	learn: 0.3414641	total: 983ms	remaining: 255ms
# 794:	learn: 0.3414430	total: 984ms	remaining: 254ms
# 795:	learn: 0.3414167	total: 984ms	remaining: 252ms
# 796:	learn: 0.3413335	total: 985ms	remaining: 251ms
# 797:	learn: 0.3412857	total: 989ms	remaining: 250ms
# 798:	learn: 0.3412814	total: 989ms	remaining: 249ms
# 799:	learn: 0.3412359	total: 989ms	remaining: 247ms
# 800:	learn: 0.3411940	total: 989ms	remaining: 246ms
# 801:	learn: 0.3411570	total: 992ms	remaining: 245ms
# 802:	learn: 0.3411232	total: 995ms	remaining: 244ms
# 803:	learn: 0.3411201	total: 996ms	remaining: 243ms
# 804:	learn: 0.3410746	total: 997ms	remaining: 242ms
# 805:	learn: 0.3409906	total: 998ms	remaining: 240ms
# 806:	learn: 0.3409812	total: 1s	remaining: 239ms
# 807:	learn: 0.3409275	total: 1s	remaining: 238ms
# 808:	learn: 0.3408657	total: 1s	remaining: 236ms
# 809:	learn: 0.3408001	total: 1s	remaining: 235ms
# 810:	learn: 0.3407329	total: 1s	remaining: 234ms
# 811:	learn: 0.3406567	total: 1s	remaining: 232ms
# 812:	learn: 0.3406237	total: 1s	remaining: 231ms
# 813:	learn: 0.3405779	total: 1s	remaining: 229ms
# 814:	learn: 0.3405460	total: 1s	remaining: 228ms
# 815:	learn: 0.3404794	total: 1s	remaining: 227ms
# 816:	learn: 0.3403836	total: 1.01s	remaining: 225ms
# 817:	learn: 0.3403641	total: 1.01s	remaining: 224ms
# 818:	learn: 0.3403312	total: 1.01s	remaining: 223ms
# 819:	learn: 0.3403288	total: 1.01s	remaining: 221ms
# 820:	learn: 0.3402435	total: 1.01s	remaining: 220ms
# 821:	learn: 0.3401416	total: 1.01s	remaining: 219ms
# 822:	learn: 0.3400764	total: 1.01s	remaining: 218ms
# 823:	learn: 0.3399856	total: 1.01s	remaining: 216ms
# 824:	learn: 0.3399161	total: 1.01s	remaining: 215ms
# 825:	learn: 0.3399027	total: 1.01s	remaining: 214ms
# 826:	learn: 0.3398384	total: 1.02s	remaining: 213ms
# 827:	learn: 0.3397827	total: 1.02s	remaining: 211ms
# 828:	learn: 0.3397487	total: 1.02s	remaining: 211ms
# 829:	learn: 0.3396887	total: 1.02s	remaining: 209ms
# 830:	learn: 0.3395892	total: 1.02s	remaining: 208ms
# 831:	learn: 0.3395184	total: 1.03s	remaining: 208ms
# 832:	learn: 0.3394842	total: 1.03s	remaining: 207ms
# 833:	learn: 0.3394836	total: 1.03s	remaining: 205ms
# 834:	learn: 0.3394472	total: 1.03s	remaining: 204ms
# 835:	learn: 0.3393758	total: 1.04s	remaining: 204ms
# 836:	learn: 0.3393390	total: 1.04s	remaining: 202ms
# 837:	learn: 0.3393073	total: 1.04s	remaining: 201ms
# 838:	learn: 0.3392376	total: 1.04s	remaining: 199ms
# 839:	learn: 0.3391910	total: 1.04s	remaining: 198ms
# 840:	learn: 0.3391561	total: 1.04s	remaining: 197ms
# 841:	learn: 0.3391355	total: 1.04s	remaining: 196ms
# 842:	learn: 0.3390860	total: 1.04s	remaining: 194ms
# 843:	learn: 0.3390287	total: 1.04s	remaining: 193ms
# 844:	learn: 0.3389411	total: 1.05s	remaining: 193ms
# 845:	learn: 0.3388050	total: 1.05s	remaining: 192ms
# 846:	learn: 0.3387248	total: 1.05s	remaining: 191ms
# 847:	learn: 0.3386609	total: 1.05s	remaining: 189ms
# 848:	learn: 0.3385932	total: 1.05s	remaining: 188ms
# 849:	learn: 0.3384992	total: 1.06s	remaining: 187ms
# 850:	learn: 0.3384703	total: 1.06s	remaining: 186ms
# 851:	learn: 0.3383679	total: 1.06s	remaining: 184ms
# 852:	learn: 0.3383630	total: 1.06s	remaining: 183ms
# 853:	learn: 0.3383237	total: 1.06s	remaining: 182ms
# 854:	learn: 0.3382578	total: 1.07s	remaining: 181ms
# 855:	learn: 0.3381901	total: 1.07s	remaining: 180ms
# 856:	learn: 0.3381659	total: 1.07s	remaining: 178ms
# 857:	learn: 0.3381368	total: 1.07s	remaining: 177ms
# 858:	learn: 0.3380567	total: 1.07s	remaining: 176ms
# 859:	learn: 0.3379769	total: 1.07s	remaining: 175ms
# 860:	learn: 0.3379428	total: 1.07s	remaining: 173ms
# 861:	learn: 0.3378673	total: 1.08s	remaining: 172ms
# 862:	learn: 0.3378315	total: 1.08s	remaining: 171ms
# 863:	learn: 0.3377941	total: 1.08s	remaining: 170ms
# 864:	learn: 0.3377236	total: 1.08s	remaining: 168ms
# 865:	learn: 0.3376563	total: 1.08s	remaining: 167ms
# 866:	learn: 0.3375293	total: 1.08s	remaining: 166ms
# 867:	learn: 0.3375296	total: 1.08s	remaining: 164ms
# 868:	learn: 0.3374949	total: 1.08s	remaining: 163ms
# 869:	learn: 0.3374274	total: 1.08s	remaining: 161ms
# 870:	learn: 0.3373878	total: 1.08s	remaining: 160ms
# 871:	learn: 0.3373486	total: 1.08s	remaining: 159ms
# 872:	learn: 0.3373119	total: 1.08s	remaining: 158ms
# 873:	learn: 0.3372257	total: 1.08s	remaining: 156ms
# 874:	learn: 0.3371878	total: 1.08s	remaining: 155ms
# 875:	learn: 0.3371085	total: 1.08s	remaining: 154ms
# 876:	learn: 0.3370810	total: 1.08s	remaining: 152ms
# 877:	learn: 0.3370120	total: 1.09s	remaining: 151ms
# 878:	learn: 0.3369838	total: 1.09s	remaining: 150ms
# 879:	learn: 0.3369409	total: 1.09s	remaining: 149ms
# 880:	learn: 0.3368899	total: 1.09s	remaining: 147ms
# 881:	learn: 0.3368432	total: 1.09s	remaining: 146ms
# 882:	learn: 0.3367661	total: 1.09s	remaining: 145ms
# 883:	learn: 0.3366666	total: 1.09s	remaining: 143ms
# 884:	learn: 0.3366213	total: 1.09s	remaining: 142ms
# 885:	learn: 0.3365471	total: 1.09s	remaining: 141ms
# 886:	learn: 0.3365018	total: 1.09s	remaining: 139ms
# 887:	learn: 0.3364140	total: 1.09s	remaining: 138ms
# 888:	learn: 0.3363109	total: 1.09s	remaining: 137ms
# 889:	learn: 0.3361950	total: 1.09s	remaining: 135ms
# 890:	learn: 0.3360922	total: 1.1s	remaining: 134ms
# 891:	learn: 0.3360641	total: 1.1s	remaining: 133ms
# 892:	learn: 0.3360253	total: 1.1s	remaining: 131ms
# 893:	learn: 0.3359577	total: 1.1s	remaining: 130ms
# 894:	learn: 0.3359569	total: 1.1s	remaining: 129ms
# 895:	learn: 0.3359351	total: 1.1s	remaining: 128ms
# 896:	learn: 0.3358741	total: 1.1s	remaining: 126ms
# 897:	learn: 0.3358674	total: 1.1s	remaining: 125ms
# 898:	learn: 0.3358673	total: 1.1s	remaining: 124ms
# 899:	learn: 0.3358674	total: 1.1s	remaining: 122ms
# 900:	learn: 0.3357855	total: 1.1s	remaining: 121ms
# 901:	learn: 0.3357339	total: 1.1s	remaining: 120ms
# 902:	learn: 0.3356665	total: 1.1s	remaining: 118ms
# 903:	learn: 0.3356401	total: 1.1s	remaining: 117ms
# 904:	learn: 0.3356096	total: 1.1s	remaining: 116ms
# 905:	learn: 0.3355568	total: 1.1s	remaining: 115ms
# 906:	learn: 0.3354875	total: 1.1s	remaining: 113ms
# 907:	learn: 0.3354526	total: 1.1s	remaining: 112ms
# 908:	learn: 0.3354212	total: 1.11s	remaining: 111ms
# 909:	learn: 0.3353744	total: 1.11s	remaining: 110ms
# 910:	learn: 0.3353351	total: 1.11s	remaining: 108ms
# 911:	learn: 0.3352609	total: 1.11s	remaining: 107ms
# 912:	learn: 0.3351476	total: 1.11s	remaining: 106ms
# 913:	learn: 0.3351204	total: 1.11s	remaining: 105ms
# 914:	learn: 0.3350637	total: 1.11s	remaining: 103ms
# 915:	learn: 0.3350335	total: 1.11s	remaining: 102ms
# 916:	learn: 0.3349864	total: 1.11s	remaining: 101ms
# 917:	learn: 0.3349583	total: 1.11s	remaining: 99.6ms
# 918:	learn: 0.3349024	total: 1.11s	remaining: 98.3ms
# 919:	learn: 0.3348366	total: 1.12s	remaining: 97.1ms
# 920:	learn: 0.3348010	total: 1.12s	remaining: 95.8ms
# 921:	learn: 0.3347415	total: 1.12s	remaining: 94.5ms
# 922:	learn: 0.3346640	total: 1.12s	remaining: 93.2ms
# 923:	learn: 0.3346230	total: 1.12s	remaining: 92ms
# 924:	learn: 0.3345787	total: 1.12s	remaining: 90.7ms
# 925:	learn: 0.3345370	total: 1.12s	remaining: 89.4ms
# 926:	learn: 0.3344825	total: 1.12s	remaining: 88.2ms
# 927:	learn: 0.3344396	total: 1.12s	remaining: 86.9ms
# 928:	learn: 0.3343924	total: 1.12s	remaining: 85.6ms
# 929:	learn: 0.3343131	total: 1.12s	remaining: 84.4ms
# 930:	learn: 0.3342189	total: 1.12s	remaining: 83.1ms
# 931:	learn: 0.3341610	total: 1.12s	remaining: 81.9ms
# 932:	learn: 0.3341238	total: 1.12s	remaining: 80.6ms
# 933:	learn: 0.3341072	total: 1.12s	remaining: 79.4ms
# 934:	learn: 0.3340637	total: 1.12s	remaining: 78.1ms
# 935:	learn: 0.3340288	total: 1.12s	remaining: 76.9ms
# 936:	learn: 0.3339805	total: 1.12s	remaining: 75.6ms
# 937:	learn: 0.3339531	total: 1.13s	remaining: 74.4ms
# 938:	learn: 0.3338634	total: 1.13s	remaining: 73.1ms
# 939:	learn: 0.3338419	total: 1.13s	remaining: 71.9ms
# 940:	learn: 0.3338008	total: 1.13s	remaining: 70.6ms
# 941:	learn: 0.3337822	total: 1.13s	remaining: 69.4ms
# 942:	learn: 0.3337814	total: 1.13s	remaining: 68.2ms
# 943:	learn: 0.3337589	total: 1.13s	remaining: 66.9ms
# 944:	learn: 0.3336806	total: 1.13s	remaining: 65.7ms
# 945:	learn: 0.3336570	total: 1.13s	remaining: 64.5ms
# 946:	learn: 0.3336211	total: 1.13s	remaining: 63.2ms
# 947:	learn: 0.3335749	total: 1.13s	remaining: 62ms
# 948:	learn: 0.3335101	total: 1.13s	remaining: 60.8ms
# 949:	learn: 0.3334746	total: 1.13s	remaining: 59.5ms
# 950:	learn: 0.3334413	total: 1.13s	remaining: 58.3ms
# 951:	learn: 0.3334201	total: 1.13s	remaining: 57.1ms
# 952:	learn: 0.3333852	total: 1.13s	remaining: 55.8ms
# 953:	learn: 0.3333305	total: 1.13s	remaining: 54.6ms
# 954:	learn: 0.3332798	total: 1.13s	remaining: 53.4ms
# 955:	learn: 0.3332522	total: 1.13s	remaining: 52.2ms
# 956:	learn: 0.3331607	total: 1.13s	remaining: 51ms
# 957:	learn: 0.3331219	total: 1.13s	remaining: 49.7ms
# 958:	learn: 0.3330721	total: 1.14s	remaining: 48.5ms
# 959:	learn: 0.3330259	total: 1.14s	remaining: 47.3ms
# 960:	learn: 0.3330003	total: 1.14s	remaining: 46.1ms
# 961:	learn: 0.3329245	total: 1.14s	remaining: 44.9ms
# 962:	learn: 0.3328874	total: 1.14s	remaining: 43.7ms
# 963:	learn: 0.3328671	total: 1.14s	remaining: 42.5ms
# 964:	learn: 0.3328174	total: 1.14s	remaining: 41.3ms
# 965:	learn: 0.3328174	total: 1.14s	remaining: 40.1ms
# 966:	learn: 0.3327863	total: 1.14s	remaining: 38.9ms
# 967:	learn: 0.3327350	total: 1.14s	remaining: 37.7ms
# 968:	learn: 0.3326924	total: 1.14s	remaining: 36.5ms
# 969:	learn: 0.3326706	total: 1.14s	remaining: 35.3ms
# 970:	learn: 0.3326062	total: 1.14s	remaining: 34.1ms
# 971:	learn: 0.3325743	total: 1.14s	remaining: 32.9ms
# 972:	learn: 0.3325642	total: 1.14s	remaining: 31.7ms
# 973:	learn: 0.3325326	total: 1.14s	remaining: 30.5ms
# 974:	learn: 0.3324824	total: 1.14s	remaining: 29.3ms
# 975:	learn: 0.3324342	total: 1.15s	remaining: 28.3ms
# 976:	learn: 0.3323948	total: 1.15s	remaining: 27.1ms
# 977:	learn: 0.3323698	total: 1.15s	remaining: 25.9ms
# 978:	learn: 0.3323279	total: 1.15s	remaining: 24.8ms
# 979:	learn: 0.3322833	total: 1.15s	remaining: 23.6ms
# 980:	learn: 0.3322206	total: 1.16s	remaining: 22.4ms
# 981:	learn: 0.3321526	total: 1.16s	remaining: 21.2ms
# 982:	learn: 0.3320888	total: 1.16s	remaining: 20ms
# 983:	learn: 0.3320442	total: 1.16s	remaining: 18.8ms
# 984:	learn: 0.3319990	total: 1.16s	remaining: 17.6ms
# 985:	learn: 0.3319684	total: 1.16s	remaining: 16.4ms
# 986:	learn: 0.3319488	total: 1.16s	remaining: 15.2ms
# 987:	learn: 0.3319088	total: 1.16s	remaining: 14.1ms
# 988:	learn: 0.3318689	total: 1.16s	remaining: 12.9ms
# 989:	learn: 0.3318229	total: 1.16s	remaining: 11.7ms
# 990:	learn: 0.3318076	total: 1.16s	remaining: 10.5ms
# 991:	learn: 0.3317819	total: 1.16s	remaining: 9.35ms
# 992:	learn: 0.3317280	total: 1.16s	remaining: 8.17ms
# 993:	learn: 0.3317276	total: 1.16s	remaining: 7ms
# 994:	learn: 0.3316624	total: 1.16s	remaining: 5.83ms
# 995:	learn: 0.3316079	total: 1.16s	remaining: 4.66ms
# 996:	learn: 0.3315280	total: 1.16s	remaining: 3.49ms
# 997:	learn: 0.3315050	total: 1.16s	remaining: 2.33ms
# 998:	learn: 0.3314631	total: 1.16s	remaining: 1.17ms
# 999:	learn: 0.3314381	total: 1.17s	remaining: 0us

# %%
# Mean and standard deviation of cross validation results for each classifier  

cross_val_mean = []
cross_val_std = []
for cross_val_result in cross_val_results:
    cross_val_mean.append(cross_val_result.mean())
    cross_val_std.append(cross_val_result.std())

    
    
#putting our cross val mean and standard deviation for each algorithm into a data frame
cross_val_res = pd.DataFrame({'Cross Validation Mean': cross_val_mean, 'Cross Validation Std': cross_val_std, 'Algorithm': [ 'Multilayer perceptron','Logistic Regression','Naive Bayes', 'K Nearest Neighbours', 'Support Vector Machines', 'Stochastic Gradient Decent', 'Linear SVC','Perceptron', 'Random Forest', 'Cat Boost','Decision Tree']})
cross_val_res.sort_values(by = 'Cross Validation Mean', ascending = False, ignore_index = True)
# Out:
#     Cross Validation Mean  Cross Validation Std                   Algorithm
# 0                0.823765              0.019224     Support Vector Machines
# 1                0.820438              0.019013                   Cat Boost
# 2                0.818222              0.024663               Random Forest
# 3                0.818185              0.016476       Multilayer perceptron
# 4                0.811481              0.022030               Decision Tree
# 5                0.793491              0.007433        K Nearest Neighbours
# 6                0.786780              0.012852         Logistic Regression
# 7                0.785626              0.009837                  Linear SVC
# 8                0.760938              0.023772  Stochastic Gradient Decent
# 9                0.757661              0.039413                 Naive Bayes
# 10               0.679342              0.154759                  Perceptron

# %%
sns.barplot('Cross Validation Mean', 'Algorithm', data = cross_val_res, order = cross_val_res.sort_values(by = 'Cross Validation Mean', ascending = False)['Algorithm'], palette = 'Set3', **{'xerr': cross_val_std})
plt.ylabel('Algorithm')
plt.title('Cross Validation Scores')
# Out:
# Text(0.5, 1.0, 'Cross Validation Scores')

# %% [markdown]
# ## 6.3.3 Hyper Paramter tuning

# %% [markdown]
# As we can see, support vector machines has the highest cross validation mean and thus we will proceed with this model.

# %% [markdown]
# ### 6.3.3.1 Hyperparameter tuning for MLP
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Aiden will tune the parameters of support vector classifier using GridSearchCV.

# %%
mlp = MLPClassifier(max_iter=2000)
param_grid = {'alpha': [1e-5],  
              'hidden_layer_sizes': [(50,50,50),(3,), (50,190,3), (64,64,64) ],
              'activation': ['tanh','relu','logistic'],  
              'solver': ['sgd','adam'],
              'learning_rate': ['constant','adaptive']
}
grid = GridSearchCV(mlp, param_grid,n_jobs=-1, cv=5) 

MLPtrained=grid.fit(X_train, Y_train)
# Out:
# /Applications/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=5, estimator=MLPClassifier(max_iter=2000), n_jobs=-1,
#              param_grid={'activation': ['tanh', 'relu', 'logistic'],
#                          'alpha': [1e-05],
#                          'hidden_layer_sizes': [(50, 50, 50), (3,),
#                                                 (50, 190, 3), (64, 64, 64)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']})

# %%
# Best paramete set
print('Best parameters found:\n', grid.best_params_)

# All results
means = grid.cv_results_['mean_test_score']
stds = grid.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, grid.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.790 (+/-0.009) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.817 (+/-0.039) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.785 (+/-0.027) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.813 (+/-0.051) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.734 (+/-0.144) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.779 (+/-0.066) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.737 (+/-0.125) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.785 (+/-0.022) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.780 (+/-0.048) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.814 (+/-0.033) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.782 (+/-0.032) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.802 (+/-0.041) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.781 (+/-0.018) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.801 (+/-0.061) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.776 (+/-0.016) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.805 (+/-0.059) for {'activation': 'tanh', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.796 (+/-0.019) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.826 (+/-0.052) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.795 (+/-0.023) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.822 (+/-0.054) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.758 (+/-0.136) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.785 (+/-0.025) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.786 (+/-0.062) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.741 (+/-0.117) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.804 (+/-0.029) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.056) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.804 (+/-0.026) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.771 (+/-0.160) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.796 (+/-0.030) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.823 (+/-0.053) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.804 (+/-0.019) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.820 (+/-0.062) for {'activation': 'relu', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.785 (+/-0.038) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.776 (+/-0.052) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.644 (+/-0.120) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.780 (+/-0.023) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.609 (+/-0.029) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.773 (+/-0.038) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (3,), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.690 (+/-0.180) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.718 (+/-0.167) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (50, 190, 3), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.783 (+/-0.042) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.616 (+/-0.005) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.787 (+/-0.050) for {'activation': 'logistic', 'alpha': 1e-05, 'hidden_layer_sizes': (64, 64, 64), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
MLP_cross_val_result=cross_val_score(mlp, X_train, Y_train, scoring = 'accuracy', cv = 5)

print(MLP_cross_val_result.mean())
print(MLP_cross_val_result.std())
# Out:
# 0.8114430983616849
# 0.01693769805888391

# %%
Y_pred = grid.predict(X_test).astype(int)

# %% [markdown]
# ### 6.3.3.2 Hyperparameter tuning for KNN
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Rael will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# ### 6.3.3.3 Hyperparameter tuning for GNB
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Ben will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# ### 6.3.3.4 Hyperparameter tuning for LogReg
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Gia will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# Our mean cross validation score improved slightly.

# %% [markdown]
# ### 6.3.4 Ensembles

# %%
best_trained_MLP = MLPtrained #the rhs  will be replaced with the tuned models, right now 
best_trained_knn = KNNtrained
best_trained_lg = LGtrained
best_trained_GNB= GNBtrained



voting_classifier_hard = VotingClassifier(estimators = [('mlp',best_trained_MLP),('knn',best_trained_knn),('lg',best_trained_lg),('gnb',best_trained_GNB)], voting = 'hard') 
voting_classifier_hard_trained=voting_classifier_hard.fit(X_train, Y_train)
survival_predications=voting_classifier_hard_trained.predict(X_test)

print('voting classifier cross validation score :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5))
print('voting classifier cross validation score mean :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5).mean())
print('voting classifier cross validation score standard deviation :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5).std())
# Out:
# voting classifier cross validation score : [0.79888268 0.82022472 0.80898876 0.79213483 0.83146067]
# voting classifier cross validation score mean : 0.8047203565375682
# voting classifier cross validation score standard deviation : 0.013841145437031297

# %% [markdown]
# # 7. Preparing data for submission

# %%
#ss.head()

# %%
#ss.shape

# %% [markdown]
# We want our submission dataframe to have 418 rows and 2 columns, PassengerId and Survived.

# %%
# Create submission dataframe

submit = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': Y_pred})
submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
submit.shape
# Out:
# (418, 2)

# %% [markdown]
# Our dataframe is ready for submission!

# %%
# Create and save csv file 

submit.to_csv("submission.csv", index = False)

# %% [markdown]
# # 8. Possible extensions to improve model accuracy
#
# 1. Analyse ticket and cabin features
#     - Do these features help predict passenger survival?
#     - If yes, consider including them in the training set instead of dropping
# 2. Come up with alternative features in feature engineering
#     - Is there any other features you can potentially create from existing features in the dataset
# 3. Remove features that are less important
#     - Does removing features help reduce overfitting in the model?
# 4. Ensemble modelling
#     - This is a more advanced technique whereby you combine prediction results from multiple machine learning models

# %% [markdown]
# # 9. Conclusion
#
# You should achieve a submission score of 0.77511 if you follow exactly what I have done in this notebook. In other words, I have correctly predicted 77.5% of the test set. I highly encourage you to work through this project again and see if you can improve on this result.
#
# If you found any mistakes in the notebook or places where I can potentially improve on, feel free to reach out to me. Let's help each other get better - happy learning!
#
# My platforms:
# - [Facebook](https://www.facebook.com/chongjason914)
# - [Instagram](https://www.instagram.com/chongjason914)
# - [Twitter](https://www.twitter.com/chongjason914)
# - [LinkedIn](https://www.linkedin.com/in/chongjason914)
# - [YouTube](https://www.youtube.com/channel/UCQXiCnjatxiAKgWjoUlM-Xg?view_as=subscriber)
# - [Medium](https://www.medium.com/@chongjason)

# %% [markdown]
# ## References
# https://github.com/chongjason914/kaggle-titanic
#
# https://www.kaggle.com/code/ldfreeman3/a-data-science-framework-to-achieve-99-accuracy
#
# https://github.com/murilogustineli/Titanic-Classification
#
# https://www.kaggle.com/code/kenjee/titanic-project-example/notebook
