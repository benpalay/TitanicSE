# %% [markdown]
# # 1. Import libraries

# %%
import pandas as pd
import numpy as np
import missingno
from collections import Counter

# Data visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# Data preprocessing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder


# Machine learning models
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from numpy import array
import matplotlib.pyplot as pl
from sklearn.ensemble import VotingClassifier

# Model evaluation
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import learning_curve
# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Remove warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 2. Import and read data
#
# Now import and read the 3 datasets as outlined in the introduction.

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# # 3. Data description

# %% [markdown]
# The data provided is split into two groups:
# 1) The training set (train.csv)
# 2) The testing set (test.csv)
#
# The training set includes a survival column which indicates whether or not the passenger survived. This data set is used to create the machine learning model.
# The testing set is used to determine how well the model (generated from the training data set) performs on new unseen data. The testing data set does not provide the passengers' survival status. The model generated predicts the passengers' survival status.
#
# The table below provides all the relevant information about the columns in the data sets:
#
# | Column Name          | Description                                                | Key                    |
# | ---------------------| ---------------------------------------------------------- | ---------------------- |
# | __PassengerId__      | Passenger Identity                                         |                        |
# | __Survived__         | Passenger survival status                                  | 0 = No, 1 = Yes        |
# | __Pclass__           | Ticket class, a representation of socio-economic status (SES)| 1 = 1st class, 2 = 2nd class, 3 = 3rd class |
# | __Name__             | Passenger's name                                           |                        |
# | __Sex__              | Passenger's sex                                            |                        |
# | __Age__              | Passengers age (in years)                                  |                        |
# | __SibSp__            | Number of sibling and/or spouse travelling with passenger  |                        |
# | __Parch__            | Number of parent and/or children travelling with passenger |                        |
# | __Ticket__           | Ticket number                                              |                        |
# | __Fare__             | Price of the ticket                                        |                        |
# | __Cabin__            | Cabin number                                               |                        |
# | __Embarked__         | Point of embarkation                                       | C = Cherbourg, Q = Queenstown, S = Southampton |
#
# More information can be found under the [data](https://www.kaggle.com/c/titanic/)

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# Exploratory data analysis is used to gain insight on the data provided. This is achieved by using visualisation tools such as graphs and tables. It will allow us to understand the data and derive preliminary conclusions. Furthermore, it will summerise important trends, characteristics, and abnormalities in the dataset which will ultimately aid in training the model.
#
# The following is explored and analysed:
# - Data Types
# - The shape of the data
# - Missing values in the data
# - Statistics derived from the data

# %% [markdown]
# ## 4.1 Data types,data shapes, missing data and summary statistics

# %% [markdown]
# ### 4.1.1.Data Types

# %%
# Non-null count and data types of the training
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
#  <font color='pink'>Observation:</font>  The training-set has 891 rows and 11 features including the __target variable (survived).__ 2 of the features are floats, 5 are integers and 5 are objects. When training, the model requires the data to all be in the form of numbers, therefore these columns will be converted later on.

# %% [markdown]
# ### 4.1.2.Data Shape

# %%
print("The shape of the training data set: ", train.shape)
print("The shape of the testing data set: ", test.shape)
# Out:
# The shape of the training data set:  (891, 12)
# The shape of the testing data set:  (418, 11)

# %% [markdown]
# <font color='pink'>Observation:</font> The testing data set has one column less column than the training data set (the Survived column). As discussed above in section 3, survived is our response/target variable and will therefore be determined from the model derived from the training data.

# %% [markdown]
# ### 4.1.3.Missing Values

# %%
#Determine what percentage of data is missing values in each column of the training dataset
totalNumberOfDataPoints = train.isnull().sum().sort_values(ascending=False)
percentMissing = train.isnull().sum()/train.isnull().count()*100
percentMissingRounded = (round(percentMissing, 1)).sort_values(ascending=False)
missingData = pd.concat([totalNumberOfDataPoints, percentMissingRounded], axis=1, keys=['Total missing', '%'])
missingData.head(13)
# Out:
#              Total missing     %
# Cabin                  687  77.1
# Age                    177  19.9
# Embarked                 2   0.2
# PassengerId              0   0.0
# Survived                 0   0.0
# Pclass                   0   0.0
# Name                     0   0.0
# Sex                      0   0.0
# SibSp                    0   0.0
# Parch                    0   0.0
# Ticket                   0   0.0
# Fare                     0   0.0

# %%
#Determine what percentage of data is missing values in each column of the testing dataset
totalNumberOfDataPoints = test.isnull().sum().sort_values(ascending=False)
percentMissing = test.isnull().sum()/test.isnull().count()*100
percentMissingRounded = (round(percentMissing, 1)).sort_values(ascending=False)
missingData = pd.concat([totalNumberOfDataPoints, percentMissingRounded], axis=1, keys=['Total missing', '%'])
missingData.head(13)
# Out:
#              Total missing     %
# Cabin                  327  78.2
# Age                     86  20.6
# Fare                     1   0.2
# PassengerId              0   0.0
# Pclass                   0   0.0
# Name                     0   0.0
# Sex                      0   0.0
# SibSp                    0   0.0
# Parch                    0   0.0
# Ticket                   0   0.0
# Embarked                 0   0.0

# %% [markdown]
# <font color='pink'>Observation:</font> From the two tables above it can be seen that the training set has missing values in the Cabin, Age and Embarked columns. The testing dataset has missing values in the Cabin, Age and Fare columns.
# For the training dataset, the Embarked column only contains two missing values which can be easily dropped or filled. The Age column on the other hand has 177 missing values. We therefore, cannot drop the rows which have missing values in the age column as this will eliminate 20% of the training data. Therefore, these values need to be filled in. The approach taken to fill in the missing values is discussed below in section 5.2. Since the Cabin column is missing 77% of data points, we have decided to drop this column.

# %% [markdown]
# ### 4.1.4.Statistics

# %%
# Summary of the statistics for the training data set 
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# The table above gives an overview of the central tendencies of the numeric data in the testing dataset. <br /> <font color='pink'>Observations:</font>
# - 38% of people in the training dataset survived the Titanic
# - The passenger age ranges from 0.4 to 80 years old.
# - There is an outlier in the Fare column because of the differences between the 75th percentile, standard deviation, and the max value (512). We will thus determine how to deal with this outlier by either dropping its corresponding row or filling the outlier with an appropriate value.

# %% [markdown]
# ## 4.2 Feature analysis

# %% [markdown]
# For feature analysis the training dataset will be split into two categories:
# 1) Categorical variables
# 2) Numerical variables
#
# Categorical variables have values belonging to one of two or more categories. Numerical variables have a continuous distribution.
# Identifying which variables are categorical and which variables are numerical will hel structure the data analysis properly. For example it makes no sense to determine the average of a categorical variable such as sex or class. Furthermore, sex, class and embarked have no intrinsic ordering to its value.

# %% [markdown]
# ### 4.2.1 Categorical variables

# %% [markdown]
# In this data set the categorical variables are:
# 1) Sex
# 2) Pclass
# 3) Embarked.

# %% [markdown]
# #### 4.2.1.1.Categorical variable: Sex

# %%
#Gia
# Value counts of the sex column
train['Sex'].value_counts(dropna = False)
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# <font color='pink'>Observation:</font> There are 263 more male passengers than female passengers in the training dataset. Therefore there it is assumend that the test dataset will have a similiar distribution of sex.

# %%
# Mean of survival according to sex
train[['Sex', 'Survived']].groupby('Sex', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
# visualisation for the probability of survival according to sex
sns.barplot(x = 'Sex', y ='Survived', data = train)
plt.ylabel('Probability of survival')
plt.title('Survival Probability by Sex')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Sex')

# %% [markdown]
# <font color='pink'>Observation:</font> Female passengers are more likely to survive.

# %% [markdown]
# #### 4.2.1.2.Categorical variable: Pclass

# %%
# Value counts of the Pclass column in the training dataset

train['Pclass'].value_counts(dropna = False)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# Mean of survival by passenger class in the training dataset

train[['Pclass', 'Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
 
#Pclass distributions for survived and not survived
ax=sns.kdeplot(train.loc[(train['Survived'] == 0),'Pclass'],shade=True,color='r',label='Not Survived')
ax.legend()
ax=sns.kdeplot(train.loc[(train['Survived'] == 1),'Pclass'],shade=True,color='b',label='Survived')
ax.legend()

plt.title("Passenger Class Distribution - Survived vs Non-Survived", fontsize = 25)
labels = ['First', 'Second', 'Third']
plt.xticks(sorted(train.Pclass.unique()),labels);

# %%
sns.barplot(x = 'Pclass', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Passenger Class')

# %% [markdown]
# <font color='pink'>Observation:</font> The probability of survival decreases with a decrease in passenger class. It can therefore be assumed that first class passengers were prioritised during the evacuation. Evidently, from the two graphs above, Pclass plays an important role in determining whether a passenger did or did not survive. According to the training dataset, 63% of the 1st class passengers survived, 48% of the 2nd class passengers survived and only 24% of the 3rd class passengers survived.

# %% [markdown]
# #### 4.2.1.3.Categorical variables combined: Sex and Plass

# %%
# Survival by gender and passenger class
sns.factorplot(x = 'Pclass', y = 'Survived', hue = 'Sex', data = train, kind = 'bar').despine(left = True)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Sex and Passenger Class')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Sex and Passenger Class')

# %% [markdown]
# <font color='pink'>Observation:</font>The graph above indicates that in every class, females where always more likely to survive. It can also be seen that males in the first class were more likely to survive than in any other class.

# %% [markdown]
# #### 4.2.1.4.Categorical variable: Embarked

# %%
# Value counts of the Embarked column 
#NAN is the missing values in Embarked
train['Embarked'].value_counts(dropna = False)
# Out:
# S      644
# C      168
# Q       77
# NaN      2
# Name: Embarked, dtype: int64

# %%
# Mean of survival by point of embarkation
train[['Embarked', 'Survived']].groupby(['Embarked'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.336957

# %%
#Visualisation for the probability of survival according to point of embarkation
sns.barplot(x = 'Embarked', y ='Survived', data = train)
plt.ylabel('Probability of Survival')
plt.title('Survival Probability by Point of Embarkation')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Point of Embarkation')

# %% [markdown]
# <font color='pink'>Observation:</font> The probability of survival is highest for location C and lowest for location S.
# Perhaps first class passengers embarked from location C and therefore because first class passengers had a higher chance of survival, location c also has the highest chance of survival. As an alternative perhaps third class passengers embarked from location S and because third class passengers had the lowest chance of survival , location S also has the lowest survival probability. This hypothesis is tested in section 4.2.1.5 below.

# %% [markdown]
# #### 4.2.1.5.Categorical variable combined: Embarked and Class

# %%
#Gia
# Visualisation for the relationship between class and embark 
sns.factorplot('Pclass', col = 'Embarked', data = train, kind = 'count')

# %% [markdown]
# <font color='pink'>Observation:</font> The hypothesis discussed in section 4.1.2.4 appears to be correct.  Location S has majority of the third class passengers and the majority of passengers embarking from location C are first class.

# %% [markdown]
# ### 4.2.2 Numerical variables

# %% [markdown]
# Gia
# In this dataset, the numerical variables are:
# 1) SibSp
# 2) Parch
# 3) Age
# 4) Fare

# %% [markdown]
# #### 4.2.2.1.Detect outliers in numerical variables

# %% [markdown]
# Outliers are points in the dataset that don't conform with majority of the data (they are extreme values). Outliers need to be addressed as they tend to skew data and can cause inaccurate model predictions. The Tukey method is used to detect these outliers. Outliers can only be determined for numeric data.

# %%
#Function to predict outliers
def detect_outliers(df, n, features):
    """"
    This function loops through the list of features and detects outliers in each feature. A data point is considered to be 
    an outlier if it is less than Q1-1.5*IQR or if it is greater than Q3+1.5*IQR. Once the outliers have been determined for 
    a feature, their indices will be stored in a list and then the loop will proceed to the next feature. This process repeats
    until the last feature is complete. Finally, using the list with the indices of the outliers, the frequency of outliers is
    determined and if the frequency is greater than n then the list fill be returned.    
    """
    outlierIndices = [] 
    for col in features: 
        Q1 = np.percentile(df[col], 25)
        Q3 = np.percentile(df[col], 75)
        IQR = Q3 - Q1
        outlierStep = 1.5 * IQR 
        outlierList = df[(df[col] < Q1 - outlierStep) | (df[col] > Q3 + outlierStep)].index
        outlierIndices.extend(outlierList) 
    outlierIndices = Counter(outlierIndices)
    multipleOutliers = list(key for key, value in outlierIndices.items() if value > n) 
    return multipleOutliers
outliers_to_drop_test = detect_outliers(test, 2, ['Age', 'SibSp', 'Parch', 'Fare'])
outliers_to_drop = detect_outliers(train, 2, ['Age', 'SibSp', 'Parch', 'Fare'])
print("The indices where outliers occur are {}: ".format(len(outliers_to_drop)), outliers_to_drop)
# Out:
# The indices where outliers occur are 10:  [27, 88, 159, 180, 201, 324, 341, 792, 846, 863]

# %%
# Outliers in numerical variables
#Visualise the 10 rows identified above as rows containing outliers
train.loc[outliers_to_drop, :]
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 27            28         0       1     Fortune, Mr. Charles Alexander    male
# 88            89         1       1         Fortune, Miss. Mabel Helen  female
# 159          160         0       3         Sage, Master. Thomas Henry    male
# 180          181         0       3       Sage, Miss. Constance Gladys  female
# 201          202         0       3                Sage, Mr. Frederick    male
# 324          325         0       3           Sage, Mr. George John Jr    male
# 341          342         1       1     Fortune, Miss. Alice Elizabeth  female
# 792          793         0       3            Sage, Miss. Stella Anna  female
# 846          847         0       3           Sage, Mr. Douglas Bullen    male
# 863          864         0       3  Sage, Miss. Dorothy Edith "Dolly"  female
#
#       Age  SibSp  Parch    Ticket    Fare        Cabin Embarked
# 27   19.0      3      2     19950  263.00  C23 C25 C27        S
# 88   23.0      3      2     19950  263.00  C23 C25 C27        S
# 159   NaN      8      2  CA. 2343   69.55          NaN        S
# 180   NaN      8      2  CA. 2343   69.55          NaN        S
# 201   NaN      8      2  CA. 2343   69.55          NaN        S
# 324   NaN      8      2  CA. 2343   69.55          NaN        S
# 341  24.0      3      2     19950  263.00  C23 C25 C27        S
# 792   NaN      8      2  CA. 2343   69.55          NaN        S
# 846   NaN      8      2  CA. 2343   69.55          NaN        S
# 863   NaN      8      2  CA. 2343   69.55          NaN        S

# %% [markdown]
# #### 4.2.2.2.Numerical variables correlation with survival

# %%
#Gia
#Heatmap of numerical variables
df_num = train[['Survived','Age','SibSp','Parch','Fare']]
sns.heatmap(df_num.corr(), annot=True,cmap="RdBu")
plt.title("Correlations Among Numeric Features", fontsize = 18);

# %% [markdown]
# <font color='pink'>Observation:</font> The heatmap displayed above shows that Parch and SiSp often travel together.Therefore it will useful to create a isAlone and a family size feature.
# we also see that Fare has a pretty large positive correlation to survival, thus it may be an important metric in training the model.

# %% [markdown]
# #### 4.2.2.3.Numerical variable: SibSp

# %%
# Value counts of the SibSp column 
train['SibSp'].value_counts(dropna = False)
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
# Mean of survival by SibSp
train[['SibSp', 'Survived']].groupby('SibSp', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
#Visualisation for probability of survival according to SiSP 
sns.barplot(x = 'SibSp', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by SibSp')
# Out:
# Text(0.5, 1.0, 'Survival Probability by SibSp')

# %% [markdown]
# #### 4.2.2.4.Numerical variable: Parch

# %%
# Value counts of the Parch column 
train['Parch'].value_counts(dropna = False)
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
# Mean of survival by Parch
train[['Parch', 'Survived']].groupby('Parch', as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#    Parch  Survived
# 3      3  0.600000
# 1      1  0.550847
# 2      2  0.500000
# 0      0  0.343658
# 5      5  0.200000
# 4      4  0.000000
# 6      6  0.000000

# %%
#Visualisation for probability of survival according to Parch
sns.barplot(x = 'Parch', y ='Survived', data = train)
plt.ylabel('Survival Probability')
plt.title('Survival Probability by Parch')
# Out:
# Text(0.5, 1.0, 'Survival Probability by Parch')

# %% [markdown]
# #### 4.2.2.5.Numerical variable: Age

# %%
# Passenger age distribution
sns.distplot(train['Age'], label = 'Skewness: %.2f'%(train['Age'].skew()))
plt.legend(loc = 'best')
plt.title('Passenger Age Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Age Distribution')

# %%
# Age distribution by survival
sns.FacetGrid(train, col = 'Survived').map(sns.distplot, 'Age')

# %%
sns.kdeplot(train['Age'][train['Survived'] == 0], label = 'Did not survive')
sns.kdeplot(train['Age'][train['Survived'] == 1], label = 'Survived')
plt.xlabel('Age')
plt.legend()
plt.title('Passenger Age Distribution by Survival')
# Out:
# Text(0.5, 1.0, 'Passenger Age Distribution by Survival')

# %% [markdown]
# <font color='red'>AidenPotentially add explanation</font>

# %% [markdown]
# #### 4.2.2.6.Numerical variable: Fare

# %%
# Passenger fare distribution
sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.ylabel('Passenger Fare Distribution')
# Out:
# Text(0, 0.5, 'Passenger Fare Distribution')

# %% [markdown]
# <font color='pink'>Observation:</font> The majority of passengers paid low fares where there are few people who paid very large fares.

# %% [markdown]
# ### 4.2.3 Correlation between categorical and numerical

# %% [markdown]
# #### 4.2.3.1.All variables

# %%
sns.heatmap(train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare','Pclass']].corr(), annot = True, fmt = '.2f', cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# <font color='pink'>Observation:</font>  Fare appears to have a high correlation with survival and Pclass has a high ngeative correlation with survival.

# %% [markdown]
# # 5. Data preprocessing
#
# Now that we knwo what features are correlated and some other important factors, we can getthe dataset in a form to be modelled and trained. This includes:
# - Dealing with ouliers
# - Drop and fill missing values
# - Data transformation
# - Feature engineering
# - Feature encoding

# %% [markdown]
# ## 5.1 Remove Outliers

# %%
# Drop outliers 

print("Train Set Before: {} rows".format(len(train)))
#train = train.drop(outliers_to_drop, axis = 0).reset_index(drop = True)
print("Train Set After: {} rows".format(len(train)))
print("Test Set Before: {} rows".format(len(test)))
# test = test.drop(outliers_to_drop_test, axis = 0).reset_index(drop = True)
print("Test Set After: {} rows".format(len(test)))
# Out:
# Train Set Before: 891 rows
# Train Set After: 891 rows
# Test Set Before: 418 rows
# Test Set After: 418 rows

# %% [markdown]
# ## 5.2 Drop and fill missing values

# %%
# Drop ticket and cabin features from training and test set as they are unique or missing many values
train = train.drop(['Ticket', 'Cabin'], axis = 1)
test = test.drop(['Ticket', 'Cabin'], axis = 1)

# %% [markdown]
# I have decided to drop both ticket and cabin for simplicity of this tutorial but if you have the time, I would recommend going through them and see if they can help improve your model.

# %%
train.isnull().sum().sort_values(ascending = False)
# Out:
# Age            177
# Embarked         2
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Fare             0
# dtype: int64

# %%
# Fill missing value in Embarked with mode as only 3 values
mode = train['Embarked'].dropna().mode()[0]
train['Embarked'].fillna(mode, inplace = True)

# %%
test.isnull().sum().sort_values(ascending = False)
# Out:
# Age            86
# Fare            1
# PassengerId     0
# Pclass          0
# Name            0
# Sex             0
# SibSp           0
# Parch           0
# Embarked        0
# dtype: int64

# %%
# Fill missing value for Fare 
median = test['Fare'].dropna().median()
test['Fare'].fillna(median, inplace = True)

# %%
# Check where indeces of missing ages are
age_nan_indices_train = list(train[train['Age'].isnull()].index)
len(age_nan_indices_train)
age_nan_indices_test = list(test[test['Age'].isnull()].index)

# %% [markdown]
# Age is negatively correlated with SibSp, Parch and Pclass as shown in section 4. Loop through each of the rows which have the same corresponding values and fill the missing age with their median. Othwerise fill with the Age median.

# %%
for index in age_nan_indices_train:
    median_age = train['Age'].median()
    predict_age = train['Age'][(train['SibSp'] == train.iloc[index]['SibSp']) 
                                 & (train['Parch'] == train.iloc[index]['Parch'])
                                 & (train['Pclass'] == train.iloc[index]["Pclass"])].median()
    if np.isnan(predict_age):
        train['Age'].iloc[index] = median_age
    else:
        train['Age'].iloc[index] = predict_age
combine = pd.concat([train, test], axis = 0).reset_index(drop = True)
median_age = combine['Age'].median()
for index in age_nan_indices_test:
    #use larger sample to fill test data 
    test['Age'].iloc[index] = median_age

# %%
# Make sure there are no more missing ages 
print(train['Age'].isnull().sum())
test['Age'].isnull().sum()
# Out:
# 0
# 0

# %% [markdown]
# ## 5.3 Data transformation
#
# Recall that our passenger fare column has a very high positive skewness. Therefore, we will apply a log transformation to address this issue.

# %%
#  fare distribution

sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.title('Passenger Fare Distribution')
# Out:
# Text(0.5, 1.0, 'Passenger Fare Distribution')

# %%
# In order to reduce skewness in fare, apply log transformation 
train['Fare'] = train['Fare'].map(lambda x: np.log(x) if x > 0 else 0)
test['Fare'] = test['Fare'].map(lambda x: np.log(x) if x > 0 else 0)

# %%
# After log transformation

sns.distplot(train['Fare'], label = 'Skewness: %.2f'%(train['Fare'].skew()))
plt.legend(loc = 'best')
plt.title('Fare Distribution After Log Transformation')
# Out:
# Text(0.5, 1.0, 'Fare Distribution After Log Transformation')

# %% [markdown]
# ## 5.4 Feature engineering
#
# We create new features from existing features to obtain an improved model.

# %% [markdown]
# ### 5.4.1 Title

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch      Fare Embarked
# 0      0  1.981001        S
# 1      0  4.266662        C
# 2      0  2.070022        S
# 3      0  3.972177        S
# 4      0  2.085672        S

# %%
#Title from name column
train['Title'] = [name.split(',')[1].split('.')[0].strip() for name in train['Name']]
train[['Name', 'Title']].head()
test['Title'] = [name.split(',')[1].split('.')[0].strip() for name in test['Name']]
test[['Name', 'Title']].head()
# Out:
#                                            Name Title
# 0                              Kelly, Mr. James    Mr
# 1              Wilkes, Mrs. James (Ellen Needs)   Mrs
# 2                     Myles, Mr. Thomas Francis    Mr
# 3                              Wirz, Mr. Albert    Mr
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   Mrs

# %%
# Value counts of Title
train['Title'].value_counts()
# Out:
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Mlle              2
# Major             2
# Col               2
# the Countess      1
# Capt              1
# Ms                1
# Sir               1
# Lady              1
# Mme               1
# Don               1
# Jonkheer          1
# Name: Title, dtype: int64

# %%
# visualise the testing titles
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Col         2
# Rev         2
# Ms          1
# Dr          1
# Dona        1
# Name: Title, dtype: int64

# %%
# Simplify Title as there are several unique itles that do not necessarily have a trend

train['Title'] = train['Title'].replace(['Dr', 'Rev', 'Col', 'Major', 'Lady', 'Jonkheer', 'Don', 'Capt', 'the Countess',
                                             'Sir'], 'Rare')
train['Title'] = train['Title'].replace(['Mlle', 'Ms'], 'Miss')
train['Title'] = train['Title'].replace('Mme', 'Mrs')

test['Title'] = test['Title'].replace(['Dr', 'Rev', 'Col',  'Capt', 'Dona'], 'Rare')
test['Title'] = test['Title'].replace(['Ms'], 'Miss')

# %%
# Drop name column as title has been extracted


train = train.drop('Name', axis = 1)
train.head()

test = test.drop('Name', axis = 1)
test.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch      Fare Embarked Title
# 0          892       3    male  34.5      0      0  2.057860        Q    Mr
# 1          893       3  female  47.0      1      0  1.945910        S   Mrs
# 2          894       2    male  62.0      0      0  2.270836        Q    Mr
# 3          895       3    male  27.0      0      0  2.159003        S    Mr
# 4          896       3  female  22.0      1      1  2.508582        S   Mrs

# %%
train[['Title', 'Survived']].groupby(['Title'], as_index = False).mean().sort_values(by = 'Survived', ascending = False)
# Out:
#     Title  Survived
# 3     Mrs  0.793651
# 1    Miss  0.702703
# 0  Master  0.575000
# 4    Rare  0.347826
# 2      Mr  0.156673

# %% [markdown]
# <font color='pink'>Observation:</font> Woman and young males had a high chance of survival.

# %% [markdown]
# ### 5.4.2 IsAlone

# %%
train['FamilySize'] = train['SibSp'] + train['Parch'] + 1
train[['SibSp', 'Parch', 'FamilySize']].head()

test['FamilySize'] = test['SibSp'] + test['Parch'] + 1
test[['SibSp', 'Parch', 'FamilySize']].head()
# Out:
#    SibSp  Parch  FamilySize
# 0      0      0           1
# 1      1      0           2
# 2      0      0           1
# 3      0      0           1
# 4      1      1           3

# %%
# Create IsAlone feature as familySize may have more information than we need, leading to overfitting

train['IsAlone'] = 0
train.loc[train['FamilySize'] == 1, 'IsAlone'] = 1

test['IsAlone'] = 0
test.loc[test['FamilySize'] == 1, 'IsAlone'] = 1

# %%
# Drop SibSp, Parch and FamilySize as this is contained in isAlone

train = train.drop(['SibSp', 'Parch','FamilySize'], axis = 1)
test = test.drop(['SibSp', 'Parch','FamilySize'], axis = 1)
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age      Fare Embarked Title  \
# 0            1         0       3    male  22.0  1.981001        S    Mr
# 1            2         1       1  female  38.0  4.266662        C   Mrs
# 2            3         1       3  female  26.0  2.070022        S  Miss
# 3            4         1       1  female  35.0  3.972177        S   Mrs
# 4            5         0       3    male  35.0  2.085672        S    Mr
#
#    IsAlone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %% [markdown]
# ### 5.4.3 Age*Class

# %% [markdown]
# First convert Age into an ordinal variable. Group Ages into 5 age bands

# %%
# train['AgeBand'] = pd.cut(train['Age'], 5)
# test['AgeBand'] = pd.cut(test['Age'], 5)

train['AgeBand'] = pd.cut(train['Age'], 4)
test['AgeBand'] = pd.cut(test['Age'], 4)
print(train['AgeBand'].head(10))
# Out:
# 0    (20.315, 40.21]
# 1    (20.315, 40.21]
# 2    (20.315, 40.21]
# 3    (20.315, 40.21]
# 4    (20.315, 40.21]
# 5    (20.315, 40.21]
# 6    (40.21, 60.105]
# 7     (0.34, 20.315]
# 8    (20.315, 40.21]
# 9     (0.34, 20.315]
# Name: AgeBand, dtype: category
# Categories (4, interval[float64, right]): [(0.34, 20.315] < (20.315, 40.21] < (40.21, 60.105] < (60.105, 80.0]]

# %%
# train.loc[train['Age'] <= 16.136, 'Age'] = 0
# train.loc[(train['Age'] > 16.136) & (train['Age'] <= 32.102), 'Age'] = 1
# train.loc[(train['Age'] > 32.102) & (train['Age'] <= 48.068), 'Age'] = 2
# train.loc[(train['Age'] > 48.068) & (train['Age'] <= 64.034), 'Age'] = 3
# train.loc[train['Age'] > 64.034 , 'Age'] = 4

# test.loc[test['Age'] <= 16.136, 'Age'] = 0
# test.loc[(test['Age'] > 16.136) & (test['Age'] <= 32.102), 'Age'] = 1
# test.loc[(test['Age'] > 32.102) & (test['Age'] <= 48.068), 'Age'] = 2
# test.loc[(test['Age'] > 48.068) & (test['Age'] <= 64.034), 'Age'] = 3
# test.loc[test['Age'] > 64.034 , 'Age'] = 4

train.loc[train['Age'] <= 20.315, 'Age'] = 0
train.loc[(train['Age'] > 20.315) & (train['Age'] <= 40.21), 'Age'] = 1
train.loc[(train['Age'] > 40.21) & (train['Age'] <= 60.105), 'Age'] = 2
train.loc[train['Age'] > 60.105,'Age'] = 3

test.loc[test['Age'] <= 20.315, 'Age'] = 0
test.loc[(test['Age'] > 20.315) & (test['Age'] <= 40.21), 'Age'] = 1
test.loc[(test['Age'] > 40.21) & (test['Age'] <= 60.105), 'Age'] = 2
test.loc[test['Age'] > 60.105,'Age'] = 3

# Drop age band feature
train = train.drop('AgeBand', axis = 1)
test = test.drop('AgeBand', axis = 1)

# %%
# Convert ordinal Age into integer
train['Age'] = train['Age'].astype('int')
test['Age'] = test['Age'].astype('int')
train['Age'].dtype
# Out:
# dtype('int32')

# %%
# Create Age*Class

train['Age*Class'] = train['Age'] * train['Pclass']
test['Age*Class'] = test['Age'] * test['Pclass']
train[['Age', 'Pclass', 'Age*Class']].head()
# Out:
#    Age  Pclass  Age*Class
# 0    1       3          3
# 1    1       1          1
# 2    1       3          3
# 3    1       1          1
# 4    1       3          3

# %%
# Bin Fare 
train['FareBand'] = pd.qcut(train['Fare'], 4)
test['FareBand'] = pd.qcut(test['Fare'], 4)
train['FareBand'].head(10)
# Out:
# 0    (-0.001, 2.068]
# 1     (3.434, 6.239]
# 2     (2.068, 2.671]
# 3     (3.434, 6.239]
# 4     (2.068, 2.671]
# 5     (2.068, 2.671]
# 6     (3.434, 6.239]
# 7     (2.671, 3.434]
# 8     (2.068, 2.671]
# 9     (2.671, 3.434]
# Name: FareBand, dtype: category
# Categories (4, interval[float64, right]): [(-0.001, 2.068] < (2.068, 2.671] < (2.671, 3.434] < (3.434, 6.239]]

# %%
#ordinal encoding, simliar to age
train.loc[train['Fare'] <= 2.066, 'Fare'] = 0
train.loc[(train['Fare'] > 2.066) & (train['Fare'] <= 2.671), 'Fare'] = 1
train.loc[(train['Fare'] > 2.671) & (train['Fare'] <= 3.418), 'Fare'] = 2
train.loc[train['Fare'] > 3.418, 'Fare'] = 3

test.loc[test['Fare'] <= 2.066, 'Fare'] = 0
test.loc[(test['Fare'] > 2.066) & (test['Fare'] <= 2.671), 'Fare'] = 1
test.loc[(test['Fare'] > 2.671) & (test['Fare'] <= 3.418), 'Fare'] = 2
test.loc[test['Fare'] > 3.418, 'Fare'] = 3

# %%
train = train.drop([ 'FareBand'], axis = 1)
test = test.drop(['FareBand'], axis = 1)

# %%
# Convert Fare into integer
train['Fare'] = train['Fare'].astype('int')
test['Fare'] = test['Fare'].astype('int')

# %% [markdown]
# ## 5.5 Feature encoding
#
# Variables must be numeric to use for machine learning. Age and Fare were done when Binning.

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass     Sex  Age  Fare Embarked Title  IsAlone  \
# 0            1         0       3    male    1     0        S    Mr        0
# 1            2         1       1  female    1     3        C   Mrs        0
# 2            3         1       3  female    1     1        S  Miss        1
# 3            4         1       1  female    1     3        S   Mrs        0
# 4            5         0       3    male    1     1        S    Mr        1
#
#    Age*Class
# 0          3
# 1          1
# 2          3
# 3          1
# 4          3

# %%
label = LabelEncoder() 
train['Embarked'] = label.fit_transform(train['Embarked'])
test['Embarked'] = label.fit_transform(test['Embarked'])
train['Title'] = label.fit_transform(train['Title'])
test['Title'] = label.fit_transform(test['Title'])
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})
test['Sex'] = test['Sex'].map({'male': 0, 'female': 1})

train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  \
# 0            1         0       3    0    1     0         2      2        0
# 1            2         1       1    1    1     3         0      3        0
# 2            3         1       3    1    1     1         2      1        1
# 3            4         1       1    1    1     3         2      3        0
# 4            5         0       3    0    1     1         2      2        1
#
#    Age*Class
# 0          3
# 1          1
# 2          3
# 3          1
# 4          3

# %%
train = train.drop('PassengerId', axis = 1)
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         2      2        0          3
# 1         1       1    1    1     3         0      3        0          1
# 2         1       3    1    1     1         2      1        1          3
# 3         1       1    1    1     3         2      3        0          1
# 4         0       3    0    1     1         2      2        1          3

# %%
train['Survived'] = train['Survived'].astype('int')
train.head()
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0         0       3    0    1     0         2      2        0          3
# 1         1       1    1    1     3         0      3        0          1
# 2         1       3    1    1     1         2      1        1          3
# 3         1       1    1    1     3         2      3        0          1
# 4         0       3    0    1     1         2      2        1          3

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0          892       3    0    1     0         1      2        1          3
# 1          893       3    1    2     0         2      3        0          6
# 2          894       2    0    3     1         1      2        1          6
# 3          895       3    0    1     1         2      2        1          3
# 4          896       3    1    1     1         2      3        0          3

# %%
sns.heatmap(train[['Survived', 'Pclass', 'Sex', 'Age', 'Fare','Embarked','Title','IsAlone','Age*Class']].corr(), annot = True, fmt = '.2f', cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 6. Modelling
#
# For the modelling part of this project we will utilise the Scikit-learn library for machine learning.
#
#  As discussed above, this is a classfication problem, so consequently will use classfication models for our training.  We have chosen to investigate the performance of the following classifiers:
#
# - Logistic regression
# - Multi Layer Perceptron
# - K-nearest neighbours
# - Gaussian naive bayes
# - Perceptron
# - Linear SVC
# - Stochastic gradient descent
# - Decision tree
# - Random forest
# - CatBoost
# - Support vector machines
#
# In this section , we will fit the models to the training data set and evaluate the models' prediction accuracy. Further on we  will implement hyperparameter tuning to further boost the performance of the the following models:
#
# - Logistic regression
# - Multi Layer Perceptron
# - K-nearest neighbours
# - Gaussian naive bayes
#
# We are training our models using the entire training set provided. We then calculate the accuracy of each model for the training set data. In other words we  determine how accurate each model is when it is asked to predict the outcome  (survival)  for the passengers with  which it was trained. High scores might be an inidcation of which algorithms are likely to work well for predicting survival of passenges in the test set(this is the ultimate goal), however high scores could also indicate overfitting which will result in poor accuracy on the test set.

# %% [markdown]
# ## 6.1 Split training data
#
#
# Split the training data into a smaller training set as well as a validation set. This split will be done for different validation set sizes, to find the optimal split. The training and validation loss can be found using MSE, and then the accuracy scores can be compared to then hyperparameterise and cross-validate.

# %%
target = train['Survived']
data = train.drop('Survived', axis = 1)
X_train = [None]*5 #initiliaising arrays for different split ratios
X_test = [None]*5
t_train = [None]*5
t_test = [None]*5


logreg = [None]*5
score_test_lr = [None]*5
score_train_lr = [None]*5
train_predict_lr= [None]*5
test_predict_lr = [None]*5
mse_train_lr = [None]*5
mse_test_lr = [None]*5

knn = [None]*5
score_test_knn = [None]*5
score_train_knn = [None]*5
train_predict_knn= [None]*5
test_predict_knn = [None]*5
mse_train_knn = [None]*5
mse_test_knn = [None]*5

gnb = [None]*5
score_test_gnb = [None]*5
score_train_gnb = [None]*5
train_predict_gnb= [None]*5
test_predict_gnb = [None]*5
mse_train_gnb = [None]*5
mse_test_gnb = [None]*5

mlp = [None]*5
score_test_mlp = [None]*5
score_train_mlp = [None]*5
train_predict_mlp= [None]*5
test_predict_mlp = [None]*5
mse_train_mlp = [None]*5
mse_test_mlp = [None]*5

#for each MLA, try different test sizes, train on the training set, find predictions and errors
for i in range(1,5):
    X_train[i], X_test[i], t_train[i], t_test[i] = train_test_split(data, target, test_size = (0.1*i))
    logreg[i] = LogisticRegression().fit(X_train[i], t_train[i])
    score_train_lr[i] = logreg[i].score(X_train[i],t_train[i])
    score_test_lr[i] = logreg[i].score(X_test[i],t_test[i])
    train_predict_lr[i] = logreg[i].predict(X_train[i])
    test_predict_lr[i] = logreg[i].predict(X_test[i])
    mse_train_lr[i] = mean_squared_error(t_train[i],train_predict_lr[i])
    mse_test_lr[i] = mean_squared_error(t_test[i],test_predict_lr[i])

    knn[i] = KNeighborsClassifier().fit(X_train[i], t_train[i])
    score_train_knn[i] = knn[i].score(X_train[i],t_train[i])
    score_test_knn[i] = knn[i].score(X_test[i],t_test[i])
    train_predict_knn[i] = knn[i].predict(X_train[i])
    test_predict_knn[i] = knn[i].predict(X_test[i])
    mse_train_knn[i] = mean_squared_error(t_train[i],train_predict_knn[i])
    mse_test_knn[i] = mean_squared_error(t_test[i],test_predict_knn[i])

    gnb[i] = GaussianNB().fit(X_train[i], t_train[i])
    score_train_knn[i] = gnb[i].score(X_train[i],t_train[i])
    score_test_gnb[i] = gnb[i].score(X_test[i],t_test[i])
    train_predict_gnb[i] = gnb[i].predict(X_train[i])
    test_predict_gnb[i] = gnb[i].predict(X_test[i])
    mse_train_gnb[i] = mean_squared_error(t_train[i],train_predict_gnb[i])
    mse_test_gnb[i] = mean_squared_error(t_test[i],test_predict_gnb[i])

    mlp[i] = MLPClassifier().fit(X_train[i], t_train[i])
    score_train_knn[i] = mlp[i].score(X_train[i],t_train[i])
    score_test_mlp[i] = mlp[i].score(X_test[i],t_test[i])
    train_predict_mlp[i] = mlp[i].predict(X_train[i])
    test_predict_mlp[i] = mlp[i].predict(X_test[i])
    mse_train_mlp[i] = mean_squared_error(t_train[i],train_predict_mlp[i])
    mse_test_mlp[i] = mean_squared_error(t_test[i],test_predict_mlp[i])

# %%
#plotting scores and MSEs

from numpy import array
import matplotlib.pyplot as pl

i1 = [0,10,20,30,40]

pl.figure()
pl.scatter(i1,mse_train_lr,
          c = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
pl.scatter(i1,mse_test_lr,
          c = 'blue', marker = 'x', s = 35, alpha = 0.5,
          label = 'Test data')
pl.xlabel('Percent test_size')
pl.ylabel('Mean Squared Error Logistic Regression')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,score_test_lr, c= 'green', label = 'test')
pl.scatter(i1,score_train_lr, c= 'orange', label = ' train')
pl.xlabel('Percent test_size')
pl.ylabel('Logistic Regression Score')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,mse_train_knn,
          c = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
pl.scatter(i1,mse_test_knn,
          c = 'blue', marker = 'x', s = 35, alpha = 0.5,
          label = 'Test data')
pl.xlabel('Percent test_size')
pl.ylabel('Mean Squared Error KNN')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,score_test_knn, c= 'green', label = 'test')
pl.scatter(i1,score_train_knn, c= 'orange', label = ' train')
pl.xlabel('Percent test_size')
pl.ylabel('KNN Score')
pl.legend(loc = 'upper left')
pl.show() 
pl.legend(loc = 'upper left')
pl.show()

pl.figure()
pl.scatter(i1,mse_train_gnb,
          c = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
pl.scatter(i1,mse_test_gnb,
          c = 'blue', marker = 'x', s = 35, alpha = 0.5,
          label = 'Test data')
pl.xlabel('Percent test_size')
pl.ylabel('Mean Squared Error G Naive Bayes')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,score_test_gnb, c= 'green', label = 'test')
pl.scatter(i1,score_train_gnb, c= 'orange', label = ' train')
pl.xlabel('Percent test_size')
pl.ylabel('GNB Score')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,mse_train_mlp,
          c = 'red', marker = 'o', s = 35, alpha = 0.5,
          label = 'Train data')
pl.scatter(i1,mse_test_mlp,
          c = 'blue', marker = 'x', s = 35, alpha = 0.5,
          label = 'Test data')
pl.xlabel('Percent test_size')
pl.ylabel('Mean Squared Error MLP')
pl.legend(loc = 'upper left')
pl.show() 

pl.figure()
pl.scatter(i1,score_test_mlp, c= 'green', label = 'test')
pl.scatter(i1,score_train_mlp, c= 'orange', label = ' train')
pl.xlabel('Percent test_size')
pl.ylabel('MLP Score')
pl.legend(loc = 'upper left')
pl.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# From the different split ratios above, we can see the MSE for training and validation sets. If MSE for train model is lower than for test model => overfitting. If it is higher => underfitting. We can then train the above models using the optimal split, i.e. when the  smallest difference between test and training loss occurs for each machine learning algorithm.

# %%
#try KNN with split at 10% for validation as was the smallest difference between test and training loss

X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size = (0.1))
acc_knn = cross_val_score(KNeighborsClassifier(), X_train, Y_train, scoring = 'accuracy', cv = 10).mean()

#try logistic regression with split at 20% 

X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size = (0.2))
acc_log = cross_val_score(LogisticRegression(), X_train, Y_train, scoring = 'accuracy', cv =5).mean()

#try mlp with split at 30% 

X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size = (0.3))
acc_mlp = cross_val_score(MLPClassifier(), X_train, Y_train, scoring = 'accuracy', cv =3).mean()

#try gnb with split at 35% 

X_train, X_test, Y_train, Y_test = train_test_split(data, target, test_size = (0.35))
acc_gnb = cross_val_score(GaussianNB(), X_train, Y_train, scoring = 'accuracy', cv =3).mean()

# %%
models = pd.DataFrame({'Model': [ 'KNN', 'MLP', 'Gaussian NB', 'Logistic Regression', 
                              ],
                       'Score': [acc_knn,acc_mlp, acc_gnb, acc_log]})

models.sort_values(by = 'Score', ascending = False, ignore_index = True)
# Out:
#                  Model     Score
# 0                  KNN  0.791543
# 1  Logistic Regression  0.783778
# 2                  MLP  0.783305
# 3          Gaussian NB  0.756477

# %% [markdown]
# We can now see how these models behave in a rudimentary way with specific splitting ratios of train and validation sets. We can train on the full dataset for these models, tune them and provide other methods and see if the accuracy improves. In this way we can improve the models.
#
#
# We need to first split our training data into independent variables or predictor variables, represented by X as well as  dependent variable or response variable, represented by Y.
#
# Y_train is the survived column in our training set and X_train is the other columns in the training set excluding the Survived column. Our models will learn to classify survival, Y_train based on all X_train and make predictions on X_test.

# %%
X_train = train.drop('Survived', axis = 1)
Y_train = train['Survived']
X_test = test.drop('PassengerId', axis = 1).copy()#why only drop now
print("X_train shape: ", X_train.shape)
print("Y_train shape: ", Y_train.shape)
print("X_test shape: ", X_test.shape)
# Out:
# X_train shape:  (891, 8)
# Y_train shape:  (891,)
# X_test shape:  (418, 8)

# %% [markdown]
# ## 6.2 Fit model to data and make predictions
#
# This requires 3 simple steps: instantiate the model, fit the model to the training set and predict the data in test set.

# %% [markdown]
# ### 6.2.1 Logistic regression

# %%
#rael
logReg = LogisticRegression()
LGtrained=logReg.fit(X_train, Y_train)
accuracy_log = round(logReg.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.2 Support vector machines

# %%
#rael
svc = SVC()
SVCtrained=svc.fit(X_train, Y_train)
accuracy_svc = round(svc.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.3 K-nearest neighbours (KNN)

# %%
#rael

knn = KNeighborsClassifier(n_neighbors = 5)
KNNtrained=knn.fit(X_train, Y_train)
accuracy_knn = round(knn.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.4 Gaussian naive bayes

# %%
#rael
gaussianNB = GaussianNB()
GNBtrained=gaussianNB.fit(X_train, Y_train)
accuracy_gaussian = round(gaussianNB.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.5 Perceptron

# %%
#rael
perceptron = Perceptron()
peceptronTrained=perceptron.fit(X_train, Y_train)
accuracy_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.6 Linear SVC

# %%
#rael
linearSVC = LinearSVC()
LSVCtrained=linearSVC.fit(X_train, Y_train)
accuracy_linear_svc = round(linearSVC.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.7 Stochastic gradient descent

# %%
#rael
sgd = SGDClassifier()
SGDtrained=sgd.fit(X_train, Y_train)
accuracy_sgd = round(sgd.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.8 Decision tree

# %%
#rael
decision_tree = DecisionTreeClassifier()
DTtrained=decision_tree.fit(X_train, Y_train)
accuracy_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)
accuracy_decision_tree
# Out:
# 86.87

# %% [markdown]
# ### 6.2.9 Random forest

# %%
#rael
random_forest = RandomForestClassifier(n_estimators = 100)
Rftrained=random_forest.fit(X_train, Y_train)
accuracy_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### 6.2.10 CatBoost

# %%
#rael
catBoost = CatBoostClassifier()
CBtrained=catBoost.fit(X_train, Y_train)
accuracy_catboost = round(catBoost.score(X_train, Y_train) * 100, 2)
# Out:
# Learning rate set to 0.009807
# 0:	learn: 0.6869367	total: 142ms	remaining: 2m 21s
# 1:	learn: 0.6802063	total: 143ms	remaining: 1m 11s
# 2:	learn: 0.6763902	total: 144ms	remaining: 47.9s
# 3:	learn: 0.6705524	total: 145ms	remaining: 36s
# 4:	learn: 0.6647134	total: 146ms	remaining: 29s
# 5:	learn: 0.6585278	total: 147ms	remaining: 24.3s
# 6:	learn: 0.6523593	total: 148ms	remaining: 20.9s
# 7:	learn: 0.6472788	total: 148ms	remaining: 18.4s
# 8:	learn: 0.6415958	total: 149ms	remaining: 16.4s
# 9:	learn: 0.6358084	total: 150ms	remaining: 14.9s
# 10:	learn: 0.6305012	total: 151ms	remaining: 13.6s
# 11:	learn: 0.6248362	total: 152ms	remaining: 12.5s
# 12:	learn: 0.6194929	total: 153ms	remaining: 11.6s
# 13:	learn: 0.6149068	total: 153ms	remaining: 10.8s
# 14:	learn: 0.6103341	total: 154ms	remaining: 10.1s
# 15:	learn: 0.6056313	total: 155ms	remaining: 9.53s
# 16:	learn: 0.6007540	total: 156ms	remaining: 9.01s
# 17:	learn: 0.5966403	total: 157ms	remaining: 8.55s
# 18:	learn: 0.5928476	total: 157ms	remaining: 8.13s
# 19:	learn: 0.5886954	total: 158ms	remaining: 7.75s
# 20:	learn: 0.5842136	total: 159ms	remaining: 7.42s
# 21:	learn: 0.5797661	total: 160ms	remaining: 7.11s
# 22:	learn: 0.5757488	total: 161ms	remaining: 6.83s
# 23:	learn: 0.5713633	total: 162ms	remaining: 6.58s
# 24:	learn: 0.5672167	total: 163ms	remaining: 6.36s
# 25:	learn: 0.5632743	total: 164ms	remaining: 6.16s
# 26:	learn: 0.5596702	total: 165ms	remaining: 5.95s
# 27:	learn: 0.5558808	total: 166ms	remaining: 5.77s
# 28:	learn: 0.5522932	total: 167ms	remaining: 5.6s
# 29:	learn: 0.5488750	total: 168ms	remaining: 5.43s
# 30:	learn: 0.5460025	total: 169ms	remaining: 5.27s
# 31:	learn: 0.5425912	total: 170ms	remaining: 5.13s
# 32:	learn: 0.5393361	total: 171ms	remaining: 5s
# 33:	learn: 0.5362857	total: 171ms	remaining: 4.87s
# 34:	learn: 0.5333014	total: 172ms	remaining: 4.74s
# 35:	learn: 0.5311089	total: 173ms	remaining: 4.62s
# 36:	learn: 0.5282205	total: 173ms	remaining: 4.51s
# 37:	learn: 0.5250413	total: 174ms	remaining: 4.41s
# 38:	learn: 0.5222665	total: 175ms	remaining: 4.31s
# 39:	learn: 0.5201982	total: 175ms	remaining: 4.21s
# 40:	learn: 0.5174225	total: 176ms	remaining: 4.12s
# 41:	learn: 0.5149646	total: 177ms	remaining: 4.04s
# 42:	learn: 0.5127689	total: 178ms	remaining: 3.96s
# 43:	learn: 0.5102136	total: 178ms	remaining: 3.88s
# 44:	learn: 0.5074517	total: 179ms	remaining: 3.8s
# 45:	learn: 0.5052863	total: 180ms	remaining: 3.73s
# 46:	learn: 0.5028941	total: 180ms	remaining: 3.66s
# 47:	learn: 0.5011386	total: 181ms	remaining: 3.59s
# 48:	learn: 0.4988674	total: 182ms	remaining: 3.53s
# 49:	learn: 0.4968862	total: 182ms	remaining: 3.46s
# 50:	learn: 0.4945562	total: 183ms	remaining: 3.41s
# 51:	learn: 0.4926094	total: 184ms	remaining: 3.35s
# 52:	learn: 0.4912042	total: 185ms	remaining: 3.3s
# 53:	learn: 0.4889802	total: 185ms	remaining: 3.25s
# 54:	learn: 0.4867844	total: 186ms	remaining: 3.19s
# 55:	learn: 0.4847787	total: 187ms	remaining: 3.15s
# 56:	learn: 0.4827311	total: 187ms	remaining: 3.1s
# 57:	learn: 0.4811682	total: 188ms	remaining: 3.06s
# 58:	learn: 0.4791430	total: 189ms	remaining: 3.01s
# 59:	learn: 0.4782462	total: 189ms	remaining: 2.96s
# 60:	learn: 0.4762638	total: 190ms	remaining: 2.92s
# 61:	learn: 0.4745190	total: 191ms	remaining: 2.89s
# 62:	learn: 0.4729461	total: 192ms	remaining: 2.85s
# 63:	learn: 0.4709836	total: 192ms	remaining: 2.81s
# 64:	learn: 0.4694420	total: 193ms	remaining: 2.78s
# 65:	learn: 0.4676655	total: 194ms	remaining: 2.74s
# 66:	learn: 0.4661794	total: 195ms	remaining: 2.71s
# 67:	learn: 0.4646871	total: 195ms	remaining: 2.68s
# 68:	learn: 0.4631852	total: 196ms	remaining: 2.64s
# 69:	learn: 0.4616488	total: 197ms	remaining: 2.61s
# 70:	learn: 0.4604525	total: 197ms	remaining: 2.58s
# 71:	learn: 0.4585981	total: 198ms	remaining: 2.55s
# 72:	learn: 0.4571592	total: 199ms	remaining: 2.52s
# 73:	learn: 0.4563581	total: 199ms	remaining: 2.49s
# 74:	learn: 0.4552482	total: 200ms	remaining: 2.47s
# 75:	learn: 0.4539460	total: 201ms	remaining: 2.44s
# 76:	learn: 0.4526418	total: 202ms	remaining: 2.42s
# 77:	learn: 0.4516035	total: 202ms	remaining: 2.39s
# 78:	learn: 0.4506780	total: 203ms	remaining: 2.37s
# 79:	learn: 0.4498624	total: 204ms	remaining: 2.34s
# 80:	learn: 0.4484309	total: 205ms	remaining: 2.32s
# 81:	learn: 0.4474088	total: 205ms	remaining: 2.3s
# 82:	learn: 0.4462057	total: 206ms	remaining: 2.28s
# 83:	learn: 0.4451301	total: 207ms	remaining: 2.26s
# 84:	learn: 0.4443791	total: 208ms	remaining: 2.23s
# 85:	learn: 0.4431987	total: 208ms	remaining: 2.21s
# 86:	learn: 0.4420580	total: 209ms	remaining: 2.19s
# 87:	learn: 0.4408750	total: 210ms	remaining: 2.17s
# 88:	learn: 0.4404513	total: 210ms	remaining: 2.15s
# 89:	learn: 0.4398193	total: 211ms	remaining: 2.13s
# 90:	learn: 0.4388080	total: 212ms	remaining: 2.11s
# 91:	learn: 0.4384103	total: 212ms	remaining: 2.09s
# 92:	learn: 0.4372531	total: 213ms	remaining: 2.07s
# 93:	learn: 0.4363489	total: 214ms	remaining: 2.06s
# 94:	learn: 0.4350819	total: 214ms	remaining: 2.04s
# 95:	learn: 0.4347065	total: 215ms	remaining: 2.02s
# 96:	learn: 0.4342171	total: 215ms	remaining: 2s
# 97:	learn: 0.4334116	total: 216ms	remaining: 1.99s
# 98:	learn: 0.4324293	total: 217ms	remaining: 1.97s
# 99:	learn: 0.4317612	total: 218ms	remaining: 1.96s
# 100:	learn: 0.4309562	total: 218ms	remaining: 1.94s
# 101:	learn: 0.4298967	total: 219ms	remaining: 1.93s
# 102:	learn: 0.4289195	total: 220ms	remaining: 1.92s
# 103:	learn: 0.4280995	total: 221ms	remaining: 1.9s
# 104:	learn: 0.4271924	total: 222ms	remaining: 1.89s
# 105:	learn: 0.4266946	total: 222ms	remaining: 1.87s
# 106:	learn: 0.4258925	total: 223ms	remaining: 1.86s
# 107:	learn: 0.4251587	total: 224ms	remaining: 1.85s
# 108:	learn: 0.4248479	total: 224ms	remaining: 1.83s
# 109:	learn: 0.4240055	total: 225ms	remaining: 1.82s
# 110:	learn: 0.4235308	total: 226ms	remaining: 1.81s
# 111:	learn: 0.4227740	total: 226ms	remaining: 1.79s
# 112:	learn: 0.4219111	total: 227ms	remaining: 1.78s
# 113:	learn: 0.4210236	total: 228ms	remaining: 1.77s
# 114:	learn: 0.4203964	total: 229ms	remaining: 1.76s
# 115:	learn: 0.4203034	total: 229ms	remaining: 1.75s
# 116:	learn: 0.4200127	total: 230ms	remaining: 1.73s
# 117:	learn: 0.4192273	total: 230ms	remaining: 1.72s
# 118:	learn: 0.4183042	total: 231ms	remaining: 1.71s
# 119:	learn: 0.4175200	total: 232ms	remaining: 1.7s
# 120:	learn: 0.4169033	total: 232ms	remaining: 1.69s
# 121:	learn: 0.4161869	total: 233ms	remaining: 1.68s
# 122:	learn: 0.4154717	total: 234ms	remaining: 1.67s
# 123:	learn: 0.4145984	total: 235ms	remaining: 1.66s
# 124:	learn: 0.4140638	total: 235ms	remaining: 1.65s
# 125:	learn: 0.4134350	total: 236ms	remaining: 1.64s
# 126:	learn: 0.4128162	total: 237ms	remaining: 1.63s
# 127:	learn: 0.4121368	total: 237ms	remaining: 1.62s
# 128:	learn: 0.4118899	total: 238ms	remaining: 1.61s
# 129:	learn: 0.4112843	total: 239ms	remaining: 1.6s
# 130:	learn: 0.4107075	total: 239ms	remaining: 1.59s
# 131:	learn: 0.4100449	total: 240ms	remaining: 1.58s
# 132:	learn: 0.4094469	total: 241ms	remaining: 1.57s
# 133:	learn: 0.4089366	total: 242ms	remaining: 1.56s
# 134:	learn: 0.4084792	total: 243ms	remaining: 1.55s
# 135:	learn: 0.4079321	total: 243ms	remaining: 1.54s
# 136:	learn: 0.4072366	total: 244ms	remaining: 1.54s
# 137:	learn: 0.4065198	total: 245ms	remaining: 1.53s
# 138:	learn: 0.4060023	total: 245ms	remaining: 1.52s
# 139:	learn: 0.4055060	total: 246ms	remaining: 1.51s
# 140:	learn: 0.4052668	total: 246ms	remaining: 1.5s
# 141:	learn: 0.4047932	total: 247ms	remaining: 1.49s
# 142:	learn: 0.4043335	total: 248ms	remaining: 1.48s
# 143:	learn: 0.4036350	total: 249ms	remaining: 1.48s
# 144:	learn: 0.4032236	total: 249ms	remaining: 1.47s
# 145:	learn: 0.4028588	total: 250ms	remaining: 1.46s
# 146:	learn: 0.4027297	total: 251ms	remaining: 1.45s
# 147:	learn: 0.4020191	total: 251ms	remaining: 1.45s
# 148:	learn: 0.4013803	total: 252ms	remaining: 1.44s
# 149:	learn: 0.4012722	total: 252ms	remaining: 1.43s
# 150:	learn: 0.4008516	total: 253ms	remaining: 1.42s
# 151:	learn: 0.4003298	total: 254ms	remaining: 1.42s
# 152:	learn: 0.3999998	total: 255ms	remaining: 1.41s
# 153:	learn: 0.3998927	total: 255ms	remaining: 1.4s
# 154:	learn: 0.3995177	total: 256ms	remaining: 1.4s
# 155:	learn: 0.3994406	total: 256ms	remaining: 1.39s
# 156:	learn: 0.3989952	total: 257ms	remaining: 1.38s
# 157:	learn: 0.3984464	total: 258ms	remaining: 1.37s
# 158:	learn: 0.3982301	total: 258ms	remaining: 1.37s
# 159:	learn: 0.3976376	total: 259ms	remaining: 1.36s
# 160:	learn: 0.3971882	total: 260ms	remaining: 1.35s
# 161:	learn: 0.3967218	total: 261ms	remaining: 1.35s
# 162:	learn: 0.3963655	total: 261ms	remaining: 1.34s
# 163:	learn: 0.3958226	total: 262ms	remaining: 1.33s
# 164:	learn: 0.3955518	total: 262ms	remaining: 1.33s
# 165:	learn: 0.3950262	total: 263ms	remaining: 1.32s
# 166:	learn: 0.3945389	total: 264ms	remaining: 1.32s
# 167:	learn: 0.3942235	total: 265ms	remaining: 1.31s
# 168:	learn: 0.3940161	total: 265ms	remaining: 1.3s
# 169:	learn: 0.3935943	total: 266ms	remaining: 1.3s
# 170:	learn: 0.3932189	total: 267ms	remaining: 1.29s
# 171:	learn: 0.3929150	total: 268ms	remaining: 1.29s
# 172:	learn: 0.3926918	total: 268ms	remaining: 1.28s
# 173:	learn: 0.3923629	total: 269ms	remaining: 1.28s
# 174:	learn: 0.3922009	total: 270ms	remaining: 1.27s
# 175:	learn: 0.3920736	total: 270ms	remaining: 1.26s
# 176:	learn: 0.3916779	total: 271ms	remaining: 1.26s
# 177:	learn: 0.3914350	total: 272ms	remaining: 1.25s
# 178:	learn: 0.3911885	total: 273ms	remaining: 1.25s
# 179:	learn: 0.3908091	total: 273ms	remaining: 1.25s
# 180:	learn: 0.3903432	total: 274ms	remaining: 1.24s
# 181:	learn: 0.3899910	total: 275ms	remaining: 1.24s
# 182:	learn: 0.3896461	total: 276ms	remaining: 1.23s
# 183:	learn: 0.3893101	total: 276ms	remaining: 1.23s
# 184:	learn: 0.3887317	total: 277ms	remaining: 1.22s
# 185:	learn: 0.3885765	total: 278ms	remaining: 1.22s
# 186:	learn: 0.3882769	total: 279ms	remaining: 1.21s
# 187:	learn: 0.3879092	total: 280ms	remaining: 1.21s
# 188:	learn: 0.3876866	total: 281ms	remaining: 1.2s
# 189:	learn: 0.3874847	total: 281ms	remaining: 1.2s
# 190:	learn: 0.3872400	total: 282ms	remaining: 1.2s
# 191:	learn: 0.3868217	total: 283ms	remaining: 1.19s
# 192:	learn: 0.3866182	total: 284ms	remaining: 1.19s
# 193:	learn: 0.3865879	total: 284ms	remaining: 1.18s
# 194:	learn: 0.3862865	total: 285ms	remaining: 1.18s
# 195:	learn: 0.3860427	total: 286ms	remaining: 1.17s
# 196:	learn: 0.3856470	total: 287ms	remaining: 1.17s
# 197:	learn: 0.3852573	total: 288ms	remaining: 1.17s
# 198:	learn: 0.3849065	total: 288ms	remaining: 1.16s
# 199:	learn: 0.3845554	total: 289ms	remaining: 1.16s
# 200:	learn: 0.3842121	total: 290ms	remaining: 1.15s
# 201:	learn: 0.3840271	total: 291ms	remaining: 1.15s
# 202:	learn: 0.3837663	total: 291ms	remaining: 1.14s
# 203:	learn: 0.3833832	total: 292ms	remaining: 1.14s
# 204:	learn: 0.3831694	total: 293ms	remaining: 1.14s
# 205:	learn: 0.3828575	total: 294ms	remaining: 1.13s
# 206:	learn: 0.3825637	total: 295ms	remaining: 1.13s
# 207:	learn: 0.3823535	total: 296ms	remaining: 1.13s
# 208:	learn: 0.3821663	total: 297ms	remaining: 1.12s
# 209:	learn: 0.3818708	total: 298ms	remaining: 1.12s
# 210:	learn: 0.3816473	total: 299ms	remaining: 1.12s
# 211:	learn: 0.3815777	total: 299ms	remaining: 1.11s
# 212:	learn: 0.3815172	total: 300ms	remaining: 1.11s
# 213:	learn: 0.3813598	total: 301ms	remaining: 1.1s
# 214:	learn: 0.3810644	total: 302ms	remaining: 1.1s
# 215:	learn: 0.3807692	total: 303ms	remaining: 1.1s
# 216:	learn: 0.3806806	total: 303ms	remaining: 1.09s
# 217:	learn: 0.3804998	total: 304ms	remaining: 1.09s
# 218:	learn: 0.3801817	total: 305ms	remaining: 1.09s
# 219:	learn: 0.3799372	total: 306ms	remaining: 1.08s
# 220:	learn: 0.3796446	total: 307ms	remaining: 1.08s
# 221:	learn: 0.3794567	total: 308ms	remaining: 1.08s
# 222:	learn: 0.3791995	total: 309ms	remaining: 1.07s
# 223:	learn: 0.3791528	total: 309ms	remaining: 1.07s
# 224:	learn: 0.3790590	total: 310ms	remaining: 1.07s
# 225:	learn: 0.3789087	total: 311ms	remaining: 1.06s
# 226:	learn: 0.3786226	total: 312ms	remaining: 1.06s
# 227:	learn: 0.3784804	total: 313ms	remaining: 1.06s
# 228:	learn: 0.3782829	total: 314ms	remaining: 1.06s
# 229:	learn: 0.3781074	total: 315ms	remaining: 1.05s
# 230:	learn: 0.3780198	total: 315ms	remaining: 1.05s
# 231:	learn: 0.3777995	total: 316ms	remaining: 1.05s
# 232:	learn: 0.3775920	total: 317ms	remaining: 1.04s
# 233:	learn: 0.3773444	total: 318ms	remaining: 1.04s
# 234:	learn: 0.3770107	total: 319ms	remaining: 1.04s
# 235:	learn: 0.3769828	total: 319ms	remaining: 1.03s
# 236:	learn: 0.3768312	total: 320ms	remaining: 1.03s
# 237:	learn: 0.3765772	total: 321ms	remaining: 1.03s
# 238:	learn: 0.3763535	total: 322ms	remaining: 1.02s
# 239:	learn: 0.3761857	total: 323ms	remaining: 1.02s
# 240:	learn: 0.3759122	total: 324ms	remaining: 1.02s
# 241:	learn: 0.3758858	total: 325ms	remaining: 1.02s
# 242:	learn: 0.3758071	total: 325ms	remaining: 1.01s
# 243:	learn: 0.3757440	total: 326ms	remaining: 1.01s
# 244:	learn: 0.3756091	total: 327ms	remaining: 1.01s
# 245:	learn: 0.3754375	total: 328ms	remaining: 1s
# 246:	learn: 0.3753918	total: 328ms	remaining: 1s
# 247:	learn: 0.3750912	total: 329ms	remaining: 998ms
# 248:	learn: 0.3748922	total: 330ms	remaining: 996ms
# 249:	learn: 0.3747207	total: 331ms	remaining: 993ms
# 250:	learn: 0.3746763	total: 332ms	remaining: 990ms
# 251:	learn: 0.3743547	total: 333ms	remaining: 988ms
# 252:	learn: 0.3741906	total: 334ms	remaining: 986ms
# 253:	learn: 0.3738509	total: 335ms	remaining: 983ms
# 254:	learn: 0.3735894	total: 336ms	remaining: 981ms
# 255:	learn: 0.3733012	total: 337ms	remaining: 979ms
# 256:	learn: 0.3730155	total: 338ms	remaining: 976ms
# 257:	learn: 0.3727927	total: 338ms	remaining: 973ms
# 258:	learn: 0.3726666	total: 339ms	remaining: 971ms
# 259:	learn: 0.3726010	total: 340ms	remaining: 969ms
# 260:	learn: 0.3723027	total: 341ms	remaining: 966ms
# 261:	learn: 0.3720011	total: 342ms	remaining: 964ms
# 262:	learn: 0.3718457	total: 343ms	remaining: 962ms
# 263:	learn: 0.3717328	total: 344ms	remaining: 959ms
# 264:	learn: 0.3715810	total: 351ms	remaining: 973ms
# 265:	learn: 0.3714113	total: 352ms	remaining: 971ms
# 266:	learn: 0.3710909	total: 353ms	remaining: 968ms
# 267:	learn: 0.3710061	total: 354ms	remaining: 966ms
# 268:	learn: 0.3708509	total: 354ms	remaining: 963ms
# 269:	learn: 0.3707693	total: 355ms	remaining: 960ms
# 270:	learn: 0.3706200	total: 356ms	remaining: 958ms
# 271:	learn: 0.3704139	total: 357ms	remaining: 956ms
# 272:	learn: 0.3702133	total: 358ms	remaining: 953ms
# 273:	learn: 0.3699442	total: 359ms	remaining: 951ms
# 274:	learn: 0.3696665	total: 360ms	remaining: 948ms
# 275:	learn: 0.3694359	total: 361ms	remaining: 946ms
# 276:	learn: 0.3692334	total: 361ms	remaining: 943ms
# 277:	learn: 0.3692312	total: 362ms	remaining: 940ms
# 278:	learn: 0.3690803	total: 363ms	remaining: 937ms
# 279:	learn: 0.3690014	total: 363ms	remaining: 935ms
# 280:	learn: 0.3689386	total: 364ms	remaining: 932ms
# 281:	learn: 0.3687593	total: 365ms	remaining: 930ms
# 282:	learn: 0.3685900	total: 366ms	remaining: 928ms
# 283:	learn: 0.3684455	total: 367ms	remaining: 925ms
# 284:	learn: 0.3682941	total: 368ms	remaining: 923ms
# 285:	learn: 0.3681736	total: 369ms	remaining: 921ms
# 286:	learn: 0.3679727	total: 370ms	remaining: 919ms
# 287:	learn: 0.3677997	total: 371ms	remaining: 916ms
# 288:	learn: 0.3677552	total: 371ms	remaining: 914ms
# 289:	learn: 0.3675807	total: 372ms	remaining: 912ms
# 290:	learn: 0.3674230	total: 373ms	remaining: 909ms
# 291:	learn: 0.3672692	total: 374ms	remaining: 907ms
# 292:	learn: 0.3670796	total: 375ms	remaining: 905ms
# 293:	learn: 0.3669577	total: 376ms	remaining: 902ms
# 294:	learn: 0.3666762	total: 377ms	remaining: 900ms
# 295:	learn: 0.3665953	total: 377ms	remaining: 897ms
# 296:	learn: 0.3665658	total: 378ms	remaining: 895ms
# 297:	learn: 0.3664035	total: 379ms	remaining: 893ms
# 298:	learn: 0.3661565	total: 380ms	remaining: 891ms
# 299:	learn: 0.3659923	total: 381ms	remaining: 889ms
# 300:	learn: 0.3658980	total: 382ms	remaining: 887ms
# 301:	learn: 0.3657657	total: 383ms	remaining: 885ms
# 302:	learn: 0.3656035	total: 384ms	remaining: 883ms
# 303:	learn: 0.3653795	total: 385ms	remaining: 880ms
# 304:	learn: 0.3652759	total: 385ms	remaining: 878ms
# 305:	learn: 0.3651407	total: 386ms	remaining: 876ms
# 306:	learn: 0.3648452	total: 387ms	remaining: 874ms
# 307:	learn: 0.3647433	total: 388ms	remaining: 872ms
# 308:	learn: 0.3647027	total: 389ms	remaining: 869ms
# 309:	learn: 0.3646032	total: 390ms	remaining: 867ms
# 310:	learn: 0.3643894	total: 390ms	remaining: 865ms
# 311:	learn: 0.3643158	total: 391ms	remaining: 863ms
# 312:	learn: 0.3641995	total: 392ms	remaining: 861ms
# 313:	learn: 0.3640365	total: 393ms	remaining: 858ms
# 314:	learn: 0.3638929	total: 394ms	remaining: 856ms
# 315:	learn: 0.3638403	total: 395ms	remaining: 854ms
# 316:	learn: 0.3637239	total: 396ms	remaining: 853ms
# 317:	learn: 0.3636081	total: 397ms	remaining: 851ms
# 318:	learn: 0.3635025	total: 398ms	remaining: 849ms
# 319:	learn: 0.3633612	total: 398ms	remaining: 847ms
# 320:	learn: 0.3633472	total: 399ms	remaining: 844ms
# 321:	learn: 0.3633277	total: 400ms	remaining: 841ms
# 322:	learn: 0.3631678	total: 401ms	remaining: 840ms
# 323:	learn: 0.3630166	total: 401ms	remaining: 838ms
# 324:	learn: 0.3628696	total: 402ms	remaining: 836ms
# 325:	learn: 0.3626512	total: 403ms	remaining: 833ms
# 326:	learn: 0.3625520	total: 404ms	remaining: 831ms
# 327:	learn: 0.3624494	total: 405ms	remaining: 829ms
# 328:	learn: 0.3624292	total: 406ms	remaining: 827ms
# 329:	learn: 0.3623033	total: 407ms	remaining: 825ms
# 330:	learn: 0.3621699	total: 407ms	remaining: 823ms
# 331:	learn: 0.3621129	total: 408ms	remaining: 821ms
# 332:	learn: 0.3620124	total: 409ms	remaining: 819ms
# 333:	learn: 0.3619379	total: 410ms	remaining: 817ms
# 334:	learn: 0.3617723	total: 411ms	remaining: 815ms
# 335:	learn: 0.3616445	total: 412ms	remaining: 814ms
# 336:	learn: 0.3616429	total: 412ms	remaining: 811ms
# 337:	learn: 0.3615513	total: 413ms	remaining: 809ms
# 338:	learn: 0.3614399	total: 414ms	remaining: 807ms
# 339:	learn: 0.3613288	total: 415ms	remaining: 805ms
# 340:	learn: 0.3611055	total: 416ms	remaining: 803ms
# 341:	learn: 0.3610458	total: 416ms	remaining: 801ms
# 342:	learn: 0.3609319	total: 417ms	remaining: 799ms
# 343:	learn: 0.3606793	total: 418ms	remaining: 797ms
# 344:	learn: 0.3604324	total: 419ms	remaining: 795ms
# 345:	learn: 0.3601965	total: 420ms	remaining: 794ms
# 346:	learn: 0.3599434	total: 421ms	remaining: 792ms
# 347:	learn: 0.3599404	total: 422ms	remaining: 790ms
# 348:	learn: 0.3598822	total: 423ms	remaining: 788ms
# 349:	learn: 0.3597532	total: 423ms	remaining: 786ms
# 350:	learn: 0.3597214	total: 424ms	remaining: 785ms
# 351:	learn: 0.3595147	total: 425ms	remaining: 783ms
# 352:	learn: 0.3593634	total: 426ms	remaining: 781ms
# 353:	learn: 0.3592750	total: 427ms	remaining: 779ms
# 354:	learn: 0.3592647	total: 428ms	remaining: 777ms
# 355:	learn: 0.3590915	total: 428ms	remaining: 775ms
# 356:	learn: 0.3590416	total: 429ms	remaining: 773ms
# 357:	learn: 0.3589445	total: 430ms	remaining: 771ms
# 358:	learn: 0.3589443	total: 431ms	remaining: 769ms
# 359:	learn: 0.3588395	total: 431ms	remaining: 767ms
# 360:	learn: 0.3587099	total: 432ms	remaining: 765ms
# 361:	learn: 0.3587002	total: 433ms	remaining: 763ms
# 362:	learn: 0.3586367	total: 434ms	remaining: 761ms
# 363:	learn: 0.3585333	total: 435ms	remaining: 759ms
# 364:	learn: 0.3583804	total: 435ms	remaining: 758ms
# 365:	learn: 0.3582016	total: 436ms	remaining: 756ms
# 366:	learn: 0.3580236	total: 437ms	remaining: 754ms
# 367:	learn: 0.3578552	total: 438ms	remaining: 752ms
# 368:	learn: 0.3576952	total: 439ms	remaining: 751ms
# 369:	learn: 0.3575797	total: 440ms	remaining: 749ms
# 370:	learn: 0.3573966	total: 441ms	remaining: 747ms
# 371:	learn: 0.3573686	total: 441ms	remaining: 745ms
# 372:	learn: 0.3571866	total: 442ms	remaining: 744ms
# 373:	learn: 0.3570248	total: 443ms	remaining: 742ms
# 374:	learn: 0.3569527	total: 444ms	remaining: 740ms
# 375:	learn: 0.3568234	total: 445ms	remaining: 738ms
# 376:	learn: 0.3567055	total: 445ms	remaining: 736ms
# 377:	learn: 0.3566333	total: 446ms	remaining: 734ms
# 378:	learn: 0.3565747	total: 447ms	remaining: 733ms
# 379:	learn: 0.3564849	total: 448ms	remaining: 731ms
# 380:	learn: 0.3564467	total: 449ms	remaining: 729ms
# 381:	learn: 0.3563399	total: 449ms	remaining: 727ms
# 382:	learn: 0.3563175	total: 450ms	remaining: 725ms
# 383:	learn: 0.3561704	total: 451ms	remaining: 723ms
# 384:	learn: 0.3561136	total: 452ms	remaining: 722ms
# 385:	learn: 0.3559574	total: 453ms	remaining: 720ms
# 386:	learn: 0.3559491	total: 454ms	remaining: 718ms
# 387:	learn: 0.3558232	total: 454ms	remaining: 717ms
# 388:	learn: 0.3557401	total: 455ms	remaining: 715ms
# 389:	learn: 0.3555939	total: 456ms	remaining: 714ms
# 390:	learn: 0.3554047	total: 457ms	remaining: 712ms
# 391:	learn: 0.3553728	total: 458ms	remaining: 710ms
# 392:	learn: 0.3553047	total: 458ms	remaining: 708ms
# 393:	learn: 0.3552176	total: 459ms	remaining: 706ms
# 394:	learn: 0.3552129	total: 460ms	remaining: 704ms
# 395:	learn: 0.3550583	total: 461ms	remaining: 703ms
# 396:	learn: 0.3549694	total: 461ms	remaining: 701ms
# 397:	learn: 0.3548070	total: 462ms	remaining: 699ms
# 398:	learn: 0.3546647	total: 463ms	remaining: 697ms
# 399:	learn: 0.3545695	total: 464ms	remaining: 696ms
# 400:	learn: 0.3545127	total: 465ms	remaining: 694ms
# 401:	learn: 0.3544103	total: 466ms	remaining: 693ms
# 402:	learn: 0.3542592	total: 466ms	remaining: 691ms
# 403:	learn: 0.3542433	total: 467ms	remaining: 689ms
# 404:	learn: 0.3541093	total: 468ms	remaining: 688ms
# 405:	learn: 0.3540359	total: 469ms	remaining: 686ms
# 406:	learn: 0.3539365	total: 470ms	remaining: 685ms
# 407:	learn: 0.3538399	total: 471ms	remaining: 683ms
# 408:	learn: 0.3537448	total: 472ms	remaining: 682ms
# 409:	learn: 0.3536289	total: 473ms	remaining: 680ms
# 410:	learn: 0.3535271	total: 473ms	remaining: 678ms
# 411:	learn: 0.3534575	total: 474ms	remaining: 677ms
# 412:	learn: 0.3533616	total: 475ms	remaining: 675ms
# 413:	learn: 0.3532976	total: 476ms	remaining: 674ms
# 414:	learn: 0.3532772	total: 477ms	remaining: 672ms
# 415:	learn: 0.3531297	total: 478ms	remaining: 670ms
# 416:	learn: 0.3530808	total: 478ms	remaining: 669ms
# 417:	learn: 0.3529183	total: 479ms	remaining: 667ms
# 418:	learn: 0.3527253	total: 480ms	remaining: 666ms
# 419:	learn: 0.3526765	total: 481ms	remaining: 664ms
# 420:	learn: 0.3525732	total: 482ms	remaining: 663ms
# 421:	learn: 0.3524944	total: 483ms	remaining: 661ms
# 422:	learn: 0.3524850	total: 484ms	remaining: 660ms
# 423:	learn: 0.3523515	total: 485ms	remaining: 658ms
# 424:	learn: 0.3522624	total: 485ms	remaining: 657ms
# 425:	learn: 0.3520993	total: 486ms	remaining: 655ms
# 426:	learn: 0.3519943	total: 487ms	remaining: 654ms
# 427:	learn: 0.3519908	total: 488ms	remaining: 652ms
# 428:	learn: 0.3518989	total: 489ms	remaining: 651ms
# 429:	learn: 0.3518743	total: 490ms	remaining: 649ms
# 430:	learn: 0.3517932	total: 491ms	remaining: 648ms
# 431:	learn: 0.3517203	total: 492ms	remaining: 646ms
# 432:	learn: 0.3515970	total: 492ms	remaining: 645ms
# 433:	learn: 0.3514794	total: 493ms	remaining: 643ms
# 434:	learn: 0.3513682	total: 494ms	remaining: 642ms
# 435:	learn: 0.3512964	total: 495ms	remaining: 640ms
# 436:	learn: 0.3512200	total: 496ms	remaining: 639ms
# 437:	learn: 0.3510722	total: 497ms	remaining: 638ms
# 438:	learn: 0.3509369	total: 498ms	remaining: 636ms
# 439:	learn: 0.3508289	total: 499ms	remaining: 634ms
# 440:	learn: 0.3507922	total: 499ms	remaining: 633ms
# 441:	learn: 0.3505775	total: 500ms	remaining: 631ms
# 442:	learn: 0.3504606	total: 501ms	remaining: 630ms
# 443:	learn: 0.3503991	total: 501ms	remaining: 628ms
# 444:	learn: 0.3502980	total: 502ms	remaining: 626ms
# 445:	learn: 0.3502628	total: 503ms	remaining: 625ms
# 446:	learn: 0.3501994	total: 504ms	remaining: 623ms
# 447:	learn: 0.3501651	total: 504ms	remaining: 622ms
# 448:	learn: 0.3501156	total: 505ms	remaining: 620ms
# 449:	learn: 0.3500752	total: 506ms	remaining: 618ms
# 450:	learn: 0.3500305	total: 507ms	remaining: 617ms
# 451:	learn: 0.3499140	total: 507ms	remaining: 615ms
# 452:	learn: 0.3497286	total: 508ms	remaining: 613ms
# 453:	learn: 0.3495987	total: 509ms	remaining: 612ms
# 454:	learn: 0.3495546	total: 509ms	remaining: 610ms
# 455:	learn: 0.3494718	total: 510ms	remaining: 609ms
# 456:	learn: 0.3493720	total: 511ms	remaining: 607ms
# 457:	learn: 0.3493199	total: 512ms	remaining: 606ms
# 458:	learn: 0.3491475	total: 513ms	remaining: 604ms
# 459:	learn: 0.3490661	total: 513ms	remaining: 603ms
# 460:	learn: 0.3489372	total: 514ms	remaining: 601ms
# 461:	learn: 0.3489318	total: 515ms	remaining: 599ms
# 462:	learn: 0.3487770	total: 515ms	remaining: 598ms
# 463:	learn: 0.3487201	total: 516ms	remaining: 596ms
# 464:	learn: 0.3485835	total: 517ms	remaining: 595ms
# 465:	learn: 0.3484721	total: 518ms	remaining: 593ms
# 466:	learn: 0.3484604	total: 518ms	remaining: 592ms
# 467:	learn: 0.3484032	total: 519ms	remaining: 590ms
# 468:	learn: 0.3482564	total: 520ms	remaining: 589ms
# 469:	learn: 0.3481681	total: 521ms	remaining: 587ms
# 470:	learn: 0.3481177	total: 521ms	remaining: 586ms
# 471:	learn: 0.3480291	total: 522ms	remaining: 584ms
# 472:	learn: 0.3479659	total: 523ms	remaining: 582ms
# 473:	learn: 0.3479072	total: 524ms	remaining: 581ms
# 474:	learn: 0.3478450	total: 524ms	remaining: 579ms
# 475:	learn: 0.3477756	total: 525ms	remaining: 578ms
# 476:	learn: 0.3476929	total: 526ms	remaining: 577ms
# 477:	learn: 0.3475637	total: 527ms	remaining: 575ms
# 478:	learn: 0.3475631	total: 527ms	remaining: 573ms
# 479:	learn: 0.3474622	total: 528ms	remaining: 572ms
# 480:	learn: 0.3474621	total: 528ms	remaining: 570ms
# 481:	learn: 0.3474038	total: 529ms	remaining: 569ms
# 482:	learn: 0.3473379	total: 530ms	remaining: 567ms
# 483:	learn: 0.3472827	total: 531ms	remaining: 566ms
# 484:	learn: 0.3472000	total: 532ms	remaining: 565ms
# 485:	learn: 0.3471512	total: 532ms	remaining: 563ms
# 486:	learn: 0.3471042	total: 533ms	remaining: 562ms
# 487:	learn: 0.3470620	total: 534ms	remaining: 560ms
# 488:	learn: 0.3470160	total: 535ms	remaining: 559ms
# 489:	learn: 0.3469574	total: 535ms	remaining: 557ms
# 490:	learn: 0.3468836	total: 536ms	remaining: 556ms
# 491:	learn: 0.3467465	total: 537ms	remaining: 554ms
# 492:	learn: 0.3466529	total: 538ms	remaining: 553ms
# 493:	learn: 0.3465543	total: 538ms	remaining: 551ms
# 494:	learn: 0.3464279	total: 539ms	remaining: 550ms
# 495:	learn: 0.3464177	total: 540ms	remaining: 549ms
# 496:	learn: 0.3463475	total: 541ms	remaining: 547ms
# 497:	learn: 0.3462450	total: 541ms	remaining: 546ms
# 498:	learn: 0.3462042	total: 542ms	remaining: 544ms
# 499:	learn: 0.3461561	total: 543ms	remaining: 543ms
# 500:	learn: 0.3461510	total: 544ms	remaining: 541ms
# 501:	learn: 0.3461058	total: 544ms	remaining: 540ms
# 502:	learn: 0.3460344	total: 545ms	remaining: 539ms
# 503:	learn: 0.3459389	total: 546ms	remaining: 537ms
# 504:	learn: 0.3458249	total: 547ms	remaining: 536ms
# 505:	learn: 0.3457906	total: 547ms	remaining: 534ms
# 506:	learn: 0.3457043	total: 548ms	remaining: 533ms
# 507:	learn: 0.3457006	total: 549ms	remaining: 531ms
# 508:	learn: 0.3455832	total: 549ms	remaining: 530ms
# 509:	learn: 0.3455014	total: 550ms	remaining: 529ms
# 510:	learn: 0.3454696	total: 551ms	remaining: 527ms
# 511:	learn: 0.3454688	total: 551ms	remaining: 526ms
# 512:	learn: 0.3454335	total: 552ms	remaining: 524ms
# 513:	learn: 0.3453557	total: 553ms	remaining: 523ms
# 514:	learn: 0.3452415	total: 554ms	remaining: 521ms
# 515:	learn: 0.3451736	total: 555ms	remaining: 520ms
# 516:	learn: 0.3450609	total: 555ms	remaining: 519ms
# 517:	learn: 0.3450282	total: 556ms	remaining: 518ms
# 518:	learn: 0.3449629	total: 557ms	remaining: 516ms
# 519:	learn: 0.3449533	total: 558ms	remaining: 515ms
# 520:	learn: 0.3448569	total: 558ms	remaining: 513ms
# 521:	learn: 0.3448519	total: 559ms	remaining: 512ms
# 522:	learn: 0.3447165	total: 560ms	remaining: 510ms
# 523:	learn: 0.3446527	total: 560ms	remaining: 509ms
# 524:	learn: 0.3446455	total: 561ms	remaining: 508ms
# 525:	learn: 0.3445841	total: 562ms	remaining: 506ms
# 526:	learn: 0.3445142	total: 562ms	remaining: 505ms
# 527:	learn: 0.3444885	total: 563ms	remaining: 503ms
# 528:	learn: 0.3444342	total: 564ms	remaining: 502ms
# 529:	learn: 0.3444312	total: 564ms	remaining: 500ms
# 530:	learn: 0.3443244	total: 565ms	remaining: 499ms
# 531:	learn: 0.3442487	total: 566ms	remaining: 498ms
# 532:	learn: 0.3442044	total: 566ms	remaining: 496ms
# 533:	learn: 0.3442026	total: 567ms	remaining: 495ms
# 534:	learn: 0.3441995	total: 568ms	remaining: 493ms
# 535:	learn: 0.3441823	total: 568ms	remaining: 492ms
# 536:	learn: 0.3440226	total: 569ms	remaining: 490ms
# 537:	learn: 0.3439341	total: 570ms	remaining: 489ms
# 538:	learn: 0.3439297	total: 570ms	remaining: 488ms
# 539:	learn: 0.3438511	total: 571ms	remaining: 486ms
# 540:	learn: 0.3437948	total: 572ms	remaining: 485ms
# 541:	learn: 0.3437430	total: 573ms	remaining: 484ms
# 542:	learn: 0.3436731	total: 573ms	remaining: 482ms
# 543:	learn: 0.3435391	total: 574ms	remaining: 481ms
# 544:	learn: 0.3435012	total: 575ms	remaining: 480ms
# 545:	learn: 0.3434439	total: 575ms	remaining: 478ms
# 546:	learn: 0.3434287	total: 576ms	remaining: 477ms
# 547:	learn: 0.3434283	total: 576ms	remaining: 475ms
# 548:	learn: 0.3433534	total: 577ms	remaining: 474ms
# 549:	learn: 0.3432088	total: 578ms	remaining: 473ms
# 550:	learn: 0.3430881	total: 579ms	remaining: 471ms
# 551:	learn: 0.3430176	total: 579ms	remaining: 470ms
# 552:	learn: 0.3430010	total: 580ms	remaining: 469ms
# 553:	learn: 0.3429400	total: 581ms	remaining: 467ms
# 554:	learn: 0.3429232	total: 581ms	remaining: 466ms
# 555:	learn: 0.3428575	total: 582ms	remaining: 465ms
# 556:	learn: 0.3428476	total: 583ms	remaining: 463ms
# 557:	learn: 0.3427331	total: 583ms	remaining: 462ms
# 558:	learn: 0.3426813	total: 584ms	remaining: 461ms
# 559:	learn: 0.3425316	total: 585ms	remaining: 460ms
# 560:	learn: 0.3424857	total: 586ms	remaining: 458ms
# 561:	learn: 0.3424218	total: 587ms	remaining: 457ms
# 562:	learn: 0.3423701	total: 587ms	remaining: 456ms
# 563:	learn: 0.3422575	total: 588ms	remaining: 455ms
# 564:	learn: 0.3422320	total: 589ms	remaining: 454ms
# 565:	learn: 0.3421624	total: 590ms	remaining: 452ms
# 566:	learn: 0.3421240	total: 591ms	remaining: 451ms
# 567:	learn: 0.3420959	total: 591ms	remaining: 450ms
# 568:	learn: 0.3420925	total: 592ms	remaining: 448ms
# 569:	learn: 0.3419843	total: 592ms	remaining: 447ms
# 570:	learn: 0.3419083	total: 593ms	remaining: 446ms
# 571:	learn: 0.3418453	total: 594ms	remaining: 444ms
# 572:	learn: 0.3418331	total: 595ms	remaining: 443ms
# 573:	learn: 0.3418175	total: 595ms	remaining: 442ms
# 574:	learn: 0.3418057	total: 596ms	remaining: 440ms
# 575:	learn: 0.3417666	total: 596ms	remaining: 439ms
# 576:	learn: 0.3417325	total: 597ms	remaining: 438ms
# 577:	learn: 0.3417137	total: 598ms	remaining: 436ms
# 578:	learn: 0.3416610	total: 599ms	remaining: 435ms
# 579:	learn: 0.3416147	total: 599ms	remaining: 434ms
# 580:	learn: 0.3415466	total: 600ms	remaining: 433ms
# 581:	learn: 0.3414584	total: 601ms	remaining: 432ms
# 582:	learn: 0.3414009	total: 602ms	remaining: 430ms
# 583:	learn: 0.3414000	total: 602ms	remaining: 429ms
# 584:	learn: 0.3413260	total: 603ms	remaining: 428ms
# 585:	learn: 0.3412717	total: 604ms	remaining: 426ms
# 586:	learn: 0.3411968	total: 604ms	remaining: 425ms
# 587:	learn: 0.3411771	total: 605ms	remaining: 424ms
# 588:	learn: 0.3411543	total: 606ms	remaining: 423ms
# 589:	learn: 0.3409815	total: 606ms	remaining: 421ms
# 590:	learn: 0.3409265	total: 607ms	remaining: 420ms
# 591:	learn: 0.3408465	total: 608ms	remaining: 419ms
# 592:	learn: 0.3406780	total: 609ms	remaining: 418ms
# 593:	learn: 0.3406524	total: 609ms	remaining: 416ms
# 594:	learn: 0.3406173	total: 610ms	remaining: 415ms
# 595:	learn: 0.3405309	total: 611ms	remaining: 414ms
# 596:	learn: 0.3404808	total: 611ms	remaining: 413ms
# 597:	learn: 0.3404791	total: 612ms	remaining: 411ms
# 598:	learn: 0.3404482	total: 613ms	remaining: 410ms
# 599:	learn: 0.3403749	total: 613ms	remaining: 409ms
# 600:	learn: 0.3403738	total: 614ms	remaining: 408ms
# 601:	learn: 0.3403351	total: 615ms	remaining: 406ms
# 602:	learn: 0.3402332	total: 616ms	remaining: 405ms
# 603:	learn: 0.3401928	total: 616ms	remaining: 404ms
# 604:	learn: 0.3400983	total: 617ms	remaining: 403ms
# 605:	learn: 0.3400617	total: 618ms	remaining: 402ms
# 606:	learn: 0.3400537	total: 618ms	remaining: 400ms
# 607:	learn: 0.3399344	total: 619ms	remaining: 399ms
# 608:	learn: 0.3398564	total: 620ms	remaining: 398ms
# 609:	learn: 0.3398140	total: 620ms	remaining: 397ms
# 610:	learn: 0.3397667	total: 621ms	remaining: 395ms
# 611:	learn: 0.3397135	total: 622ms	remaining: 394ms
# 612:	learn: 0.3396809	total: 623ms	remaining: 393ms
# 613:	learn: 0.3395635	total: 623ms	remaining: 392ms
# 614:	learn: 0.3394949	total: 624ms	remaining: 391ms
# 615:	learn: 0.3394676	total: 625ms	remaining: 389ms
# 616:	learn: 0.3393882	total: 625ms	remaining: 388ms
# 617:	learn: 0.3393136	total: 626ms	remaining: 387ms
# 618:	learn: 0.3393130	total: 627ms	remaining: 386ms
# 619:	learn: 0.3392170	total: 627ms	remaining: 385ms
# 620:	learn: 0.3391658	total: 628ms	remaining: 383ms
# 621:	learn: 0.3391369	total: 629ms	remaining: 382ms
# 622:	learn: 0.3390873	total: 629ms	remaining: 381ms
# 623:	learn: 0.3390351	total: 630ms	remaining: 380ms
# 624:	learn: 0.3389681	total: 631ms	remaining: 379ms
# 625:	learn: 0.3389088	total: 632ms	remaining: 377ms
# 626:	learn: 0.3388313	total: 632ms	remaining: 376ms
# 627:	learn: 0.3387826	total: 633ms	remaining: 375ms
# 628:	learn: 0.3386896	total: 634ms	remaining: 374ms
# 629:	learn: 0.3386493	total: 634ms	remaining: 373ms
# 630:	learn: 0.3385683	total: 635ms	remaining: 371ms
# 631:	learn: 0.3385279	total: 636ms	remaining: 370ms
# 632:	learn: 0.3385193	total: 636ms	remaining: 369ms
# 633:	learn: 0.3385143	total: 637ms	remaining: 368ms
# 634:	learn: 0.3384876	total: 638ms	remaining: 367ms
# 635:	learn: 0.3384655	total: 639ms	remaining: 365ms
# 636:	learn: 0.3384557	total: 639ms	remaining: 364ms
# 637:	learn: 0.3384427	total: 640ms	remaining: 363ms
# 638:	learn: 0.3383531	total: 641ms	remaining: 362ms
# 639:	learn: 0.3383160	total: 641ms	remaining: 361ms
# 640:	learn: 0.3382609	total: 642ms	remaining: 360ms
# 641:	learn: 0.3381511	total: 643ms	remaining: 359ms
# 642:	learn: 0.3380264	total: 644ms	remaining: 357ms
# 643:	learn: 0.3379811	total: 644ms	remaining: 356ms
# 644:	learn: 0.3379758	total: 645ms	remaining: 355ms
# 645:	learn: 0.3378663	total: 646ms	remaining: 354ms
# 646:	learn: 0.3378030	total: 646ms	remaining: 353ms
# 647:	learn: 0.3377413	total: 647ms	remaining: 351ms
# 648:	learn: 0.3376608	total: 648ms	remaining: 350ms
# 649:	learn: 0.3376609	total: 648ms	remaining: 349ms
# 650:	learn: 0.3375854	total: 649ms	remaining: 348ms
# 651:	learn: 0.3375244	total: 650ms	remaining: 347ms
# 652:	learn: 0.3374968	total: 650ms	remaining: 346ms
# 653:	learn: 0.3374240	total: 651ms	remaining: 344ms
# 654:	learn: 0.3373777	total: 652ms	remaining: 343ms
# 655:	learn: 0.3372846	total: 652ms	remaining: 342ms
# 656:	learn: 0.3372368	total: 653ms	remaining: 341ms
# 657:	learn: 0.3371854	total: 654ms	remaining: 340ms
# 658:	learn: 0.3371249	total: 655ms	remaining: 339ms
# 659:	learn: 0.3371133	total: 655ms	remaining: 338ms
# 660:	learn: 0.3370640	total: 656ms	remaining: 337ms
# 661:	learn: 0.3370572	total: 657ms	remaining: 335ms
# 662:	learn: 0.3370259	total: 657ms	remaining: 334ms
# 663:	learn: 0.3370040	total: 658ms	remaining: 333ms
# 664:	learn: 0.3369310	total: 659ms	remaining: 332ms
# 665:	learn: 0.3369270	total: 659ms	remaining: 331ms
# 666:	learn: 0.3368951	total: 660ms	remaining: 330ms
# 667:	learn: 0.3368046	total: 661ms	remaining: 329ms
# 668:	learn: 0.3367357	total: 662ms	remaining: 328ms
# 669:	learn: 0.3367080	total: 663ms	remaining: 326ms
# 670:	learn: 0.3366000	total: 663ms	remaining: 325ms
# 671:	learn: 0.3365715	total: 664ms	remaining: 324ms
# 672:	learn: 0.3364388	total: 665ms	remaining: 323ms
# 673:	learn: 0.3363400	total: 665ms	remaining: 322ms
# 674:	learn: 0.3362738	total: 666ms	remaining: 321ms
# 675:	learn: 0.3362444	total: 667ms	remaining: 320ms
# 676:	learn: 0.3362211	total: 668ms	remaining: 318ms
# 677:	learn: 0.3361891	total: 668ms	remaining: 317ms
# 678:	learn: 0.3361797	total: 669ms	remaining: 316ms
# 679:	learn: 0.3361145	total: 670ms	remaining: 315ms
# 680:	learn: 0.3360598	total: 670ms	remaining: 314ms
# 681:	learn: 0.3360083	total: 671ms	remaining: 313ms
# 682:	learn: 0.3359883	total: 672ms	remaining: 312ms
# 683:	learn: 0.3359484	total: 672ms	remaining: 311ms
# 684:	learn: 0.3359476	total: 673ms	remaining: 309ms
# 685:	learn: 0.3359037	total: 674ms	remaining: 308ms
# 686:	learn: 0.3358245	total: 674ms	remaining: 307ms
# 687:	learn: 0.3357857	total: 675ms	remaining: 306ms
# 688:	learn: 0.3357295	total: 676ms	remaining: 305ms
# 689:	learn: 0.3356309	total: 676ms	remaining: 304ms
# 690:	learn: 0.3355877	total: 677ms	remaining: 303ms
# 691:	learn: 0.3355180	total: 678ms	remaining: 302ms
# 692:	learn: 0.3354863	total: 678ms	remaining: 301ms
# 693:	learn: 0.3354863	total: 679ms	remaining: 299ms
# 694:	learn: 0.3354134	total: 680ms	remaining: 298ms
# 695:	learn: 0.3353612	total: 680ms	remaining: 297ms
# 696:	learn: 0.3353263	total: 681ms	remaining: 296ms
# 697:	learn: 0.3352921	total: 682ms	remaining: 295ms
# 698:	learn: 0.3352448	total: 682ms	remaining: 294ms
# 699:	learn: 0.3351162	total: 683ms	remaining: 293ms
# 700:	learn: 0.3350385	total: 684ms	remaining: 292ms
# 701:	learn: 0.3349252	total: 684ms	remaining: 291ms
# 702:	learn: 0.3348813	total: 685ms	remaining: 289ms
# 703:	learn: 0.3347800	total: 686ms	remaining: 288ms
# 704:	learn: 0.3347727	total: 687ms	remaining: 287ms
# 705:	learn: 0.3347529	total: 687ms	remaining: 286ms
# 706:	learn: 0.3347231	total: 688ms	remaining: 285ms
# 707:	learn: 0.3346983	total: 689ms	remaining: 284ms
# 708:	learn: 0.3346034	total: 689ms	remaining: 283ms
# 709:	learn: 0.3345525	total: 690ms	remaining: 282ms
# 710:	learn: 0.3345245	total: 691ms	remaining: 281ms
# 711:	learn: 0.3345183	total: 691ms	remaining: 280ms
# 712:	learn: 0.3344662	total: 692ms	remaining: 279ms
# 713:	learn: 0.3344184	total: 693ms	remaining: 277ms
# 714:	learn: 0.3343997	total: 693ms	remaining: 276ms
# 715:	learn: 0.3343992	total: 694ms	remaining: 275ms
# 716:	learn: 0.3343580	total: 694ms	remaining: 274ms
# 717:	learn: 0.3343423	total: 695ms	remaining: 273ms
# 718:	learn: 0.3342927	total: 696ms	remaining: 272ms
# 719:	learn: 0.3341794	total: 696ms	remaining: 271ms
# 720:	learn: 0.3341370	total: 697ms	remaining: 270ms
# 721:	learn: 0.3340935	total: 698ms	remaining: 269ms
# 722:	learn: 0.3340503	total: 699ms	remaining: 268ms
# 723:	learn: 0.3339573	total: 699ms	remaining: 267ms
# 724:	learn: 0.3339095	total: 700ms	remaining: 266ms
# 725:	learn: 0.3338326	total: 701ms	remaining: 264ms
# 726:	learn: 0.3337947	total: 702ms	remaining: 263ms
# 727:	learn: 0.3337458	total: 702ms	remaining: 262ms
# 728:	learn: 0.3336842	total: 703ms	remaining: 261ms
# 729:	learn: 0.3335561	total: 704ms	remaining: 260ms
# 730:	learn: 0.3335411	total: 704ms	remaining: 259ms
# 731:	learn: 0.3334664	total: 705ms	remaining: 258ms
# 732:	learn: 0.3333940	total: 706ms	remaining: 257ms
# 733:	learn: 0.3333682	total: 706ms	remaining: 256ms
# 734:	learn: 0.3332597	total: 707ms	remaining: 255ms
# 735:	learn: 0.3331946	total: 708ms	remaining: 254ms
# 736:	learn: 0.3331938	total: 708ms	remaining: 253ms
# 737:	learn: 0.3331732	total: 709ms	remaining: 252ms
# 738:	learn: 0.3331478	total: 710ms	remaining: 251ms
# 739:	learn: 0.3331219	total: 710ms	remaining: 250ms
# 740:	learn: 0.3331219	total: 711ms	remaining: 248ms
# 741:	learn: 0.3330512	total: 712ms	remaining: 247ms
# 742:	learn: 0.3329803	total: 712ms	remaining: 246ms
# 743:	learn: 0.3329292	total: 713ms	remaining: 245ms
# 744:	learn: 0.3328412	total: 714ms	remaining: 244ms
# 745:	learn: 0.3327688	total: 714ms	remaining: 243ms
# 746:	learn: 0.3327087	total: 715ms	remaining: 242ms
# 747:	learn: 0.3326401	total: 716ms	remaining: 241ms
# 748:	learn: 0.3325715	total: 717ms	remaining: 240ms
# 749:	learn: 0.3325061	total: 718ms	remaining: 239ms
# 750:	learn: 0.3324466	total: 718ms	remaining: 238ms
# 751:	learn: 0.3324292	total: 719ms	remaining: 237ms
# 752:	learn: 0.3324063	total: 720ms	remaining: 236ms
# 753:	learn: 0.3323331	total: 720ms	remaining: 235ms
# 754:	learn: 0.3323015	total: 721ms	remaining: 234ms
# 755:	learn: 0.3322921	total: 722ms	remaining: 233ms
# 756:	learn: 0.3322258	total: 723ms	remaining: 232ms
# 757:	learn: 0.3321746	total: 723ms	remaining: 231ms
# 758:	learn: 0.3321593	total: 724ms	remaining: 230ms
# 759:	learn: 0.3321013	total: 725ms	remaining: 229ms
# 760:	learn: 0.3320647	total: 725ms	remaining: 228ms
# 761:	learn: 0.3320380	total: 726ms	remaining: 227ms
# 762:	learn: 0.3319482	total: 727ms	remaining: 226ms
# 763:	learn: 0.3319108	total: 727ms	remaining: 225ms
# 764:	learn: 0.3319061	total: 728ms	remaining: 224ms
# 765:	learn: 0.3318809	total: 729ms	remaining: 223ms
# 766:	learn: 0.3318275	total: 729ms	remaining: 222ms
# 767:	learn: 0.3317853	total: 730ms	remaining: 221ms
# 768:	learn: 0.3317444	total: 731ms	remaining: 220ms
# 769:	learn: 0.3317124	total: 732ms	remaining: 219ms
# 770:	learn: 0.3316928	total: 732ms	remaining: 218ms
# 771:	learn: 0.3316420	total: 733ms	remaining: 216ms
# 772:	learn: 0.3316133	total: 734ms	remaining: 215ms
# 773:	learn: 0.3315903	total: 734ms	remaining: 214ms
# 774:	learn: 0.3315552	total: 735ms	remaining: 213ms
# 775:	learn: 0.3314966	total: 736ms	remaining: 212ms
# 776:	learn: 0.3314767	total: 737ms	remaining: 211ms
# 777:	learn: 0.3314330	total: 737ms	remaining: 210ms
# 778:	learn: 0.3313949	total: 738ms	remaining: 209ms
# 779:	learn: 0.3313673	total: 739ms	remaining: 208ms
# 780:	learn: 0.3312941	total: 739ms	remaining: 207ms
# 781:	learn: 0.3312478	total: 740ms	remaining: 206ms
# 782:	learn: 0.3311959	total: 741ms	remaining: 205ms
# 783:	learn: 0.3311742	total: 742ms	remaining: 204ms
# 784:	learn: 0.3311445	total: 742ms	remaining: 203ms
# 785:	learn: 0.3310778	total: 743ms	remaining: 202ms
# 786:	learn: 0.3309566	total: 744ms	remaining: 201ms
# 787:	learn: 0.3308806	total: 744ms	remaining: 200ms
# 788:	learn: 0.3308258	total: 745ms	remaining: 199ms
# 789:	learn: 0.3307958	total: 746ms	remaining: 198ms
# 790:	learn: 0.3306863	total: 746ms	remaining: 197ms
# 791:	learn: 0.3306391	total: 747ms	remaining: 196ms
# 792:	learn: 0.3305845	total: 748ms	remaining: 195ms
# 793:	learn: 0.3304966	total: 749ms	remaining: 194ms
# 794:	learn: 0.3304580	total: 749ms	remaining: 193ms
# 795:	learn: 0.3304414	total: 750ms	remaining: 192ms
# 796:	learn: 0.3303741	total: 751ms	remaining: 191ms
# 797:	learn: 0.3303070	total: 751ms	remaining: 190ms
# 798:	learn: 0.3302547	total: 752ms	remaining: 189ms
# 799:	learn: 0.3301904	total: 753ms	remaining: 188ms
# 800:	learn: 0.3301033	total: 753ms	remaining: 187ms
# 801:	learn: 0.3300612	total: 754ms	remaining: 186ms
# 802:	learn: 0.3300191	total: 755ms	remaining: 185ms
# 803:	learn: 0.3299713	total: 755ms	remaining: 184ms
# 804:	learn: 0.3299174	total: 756ms	remaining: 183ms
# 805:	learn: 0.3299012	total: 757ms	remaining: 182ms
# 806:	learn: 0.3298668	total: 757ms	remaining: 181ms
# 807:	learn: 0.3298481	total: 758ms	remaining: 180ms
# 808:	learn: 0.3297675	total: 759ms	remaining: 179ms
# 809:	learn: 0.3296930	total: 760ms	remaining: 178ms
# 810:	learn: 0.3296248	total: 760ms	remaining: 177ms
# 811:	learn: 0.3295818	total: 761ms	remaining: 176ms
# 812:	learn: 0.3294988	total: 762ms	remaining: 175ms
# 813:	learn: 0.3294273	total: 762ms	remaining: 174ms
# 814:	learn: 0.3294248	total: 763ms	remaining: 173ms
# 815:	learn: 0.3293838	total: 764ms	remaining: 172ms
# 816:	learn: 0.3293141	total: 764ms	remaining: 171ms
# 817:	learn: 0.3292781	total: 765ms	remaining: 170ms
# 818:	learn: 0.3292640	total: 766ms	remaining: 169ms
# 819:	learn: 0.3292223	total: 767ms	remaining: 168ms
# 820:	learn: 0.3291256	total: 767ms	remaining: 167ms
# 821:	learn: 0.3290796	total: 768ms	remaining: 166ms
# 822:	learn: 0.3290284	total: 769ms	remaining: 165ms
# 823:	learn: 0.3289675	total: 769ms	remaining: 164ms
# 824:	learn: 0.3289301	total: 770ms	remaining: 163ms
# 825:	learn: 0.3288929	total: 771ms	remaining: 162ms
# 826:	learn: 0.3288202	total: 771ms	remaining: 161ms
# 827:	learn: 0.3287676	total: 772ms	remaining: 160ms
# 828:	learn: 0.3287349	total: 773ms	remaining: 159ms
# 829:	learn: 0.3286685	total: 773ms	remaining: 158ms
# 830:	learn: 0.3286378	total: 774ms	remaining: 157ms
# 831:	learn: 0.3285938	total: 775ms	remaining: 156ms
# 832:	learn: 0.3285450	total: 776ms	remaining: 156ms
# 833:	learn: 0.3284785	total: 776ms	remaining: 155ms
# 834:	learn: 0.3284034	total: 777ms	remaining: 154ms
# 835:	learn: 0.3283558	total: 778ms	remaining: 153ms
# 836:	learn: 0.3283176	total: 779ms	remaining: 152ms
# 837:	learn: 0.3282457	total: 779ms	remaining: 151ms
# 838:	learn: 0.3281802	total: 780ms	remaining: 150ms
# 839:	learn: 0.3281291	total: 781ms	remaining: 149ms
# 840:	learn: 0.3280942	total: 782ms	remaining: 148ms
# 841:	learn: 0.3280394	total: 782ms	remaining: 147ms
# 842:	learn: 0.3279658	total: 783ms	remaining: 146ms
# 843:	learn: 0.3279094	total: 784ms	remaining: 145ms
# 844:	learn: 0.3278036	total: 784ms	remaining: 144ms
# 845:	learn: 0.3277196	total: 785ms	remaining: 143ms
# 846:	learn: 0.3276908	total: 786ms	remaining: 142ms
# 847:	learn: 0.3276135	total: 787ms	remaining: 141ms
# 848:	learn: 0.3275588	total: 787ms	remaining: 140ms
# 849:	learn: 0.3275582	total: 788ms	remaining: 139ms
# 850:	learn: 0.3275217	total: 789ms	remaining: 138ms
# 851:	learn: 0.3274675	total: 789ms	remaining: 137ms
# 852:	learn: 0.3274350	total: 790ms	remaining: 136ms
# 853:	learn: 0.3274017	total: 791ms	remaining: 135ms
# 854:	learn: 0.3273694	total: 792ms	remaining: 134ms
# 855:	learn: 0.3273258	total: 793ms	remaining: 133ms
# 856:	learn: 0.3272971	total: 793ms	remaining: 132ms
# 857:	learn: 0.3272526	total: 794ms	remaining: 131ms
# 858:	learn: 0.3272025	total: 795ms	remaining: 130ms
# 859:	learn: 0.3271338	total: 795ms	remaining: 129ms
# 860:	learn: 0.3270709	total: 796ms	remaining: 129ms
# 861:	learn: 0.3270405	total: 797ms	remaining: 128ms
# 862:	learn: 0.3270076	total: 797ms	remaining: 127ms
# 863:	learn: 0.3269511	total: 798ms	remaining: 126ms
# 864:	learn: 0.3269269	total: 799ms	remaining: 125ms
# 865:	learn: 0.3269034	total: 800ms	remaining: 124ms
# 866:	learn: 0.3268683	total: 800ms	remaining: 123ms
# 867:	learn: 0.3268097	total: 801ms	remaining: 122ms
# 868:	learn: 0.3267876	total: 802ms	remaining: 121ms
# 869:	learn: 0.3267155	total: 802ms	remaining: 120ms
# 870:	learn: 0.3266671	total: 803ms	remaining: 119ms
# 871:	learn: 0.3266512	total: 804ms	remaining: 118ms
# 872:	learn: 0.3266288	total: 805ms	remaining: 117ms
# 873:	learn: 0.3265904	total: 805ms	remaining: 116ms
# 874:	learn: 0.3265687	total: 806ms	remaining: 115ms
# 875:	learn: 0.3265128	total: 807ms	remaining: 114ms
# 876:	learn: 0.3264359	total: 808ms	remaining: 113ms
# 877:	learn: 0.3264112	total: 808ms	remaining: 112ms
# 878:	learn: 0.3263622	total: 809ms	remaining: 111ms
# 879:	learn: 0.3263125	total: 810ms	remaining: 110ms
# 880:	learn: 0.3262454	total: 810ms	remaining: 109ms
# 881:	learn: 0.3262031	total: 811ms	remaining: 109ms
# 882:	learn: 0.3261654	total: 812ms	remaining: 108ms
# 883:	learn: 0.3261147	total: 812ms	remaining: 107ms
# 884:	learn: 0.3261138	total: 813ms	remaining: 106ms
# 885:	learn: 0.3260511	total: 814ms	remaining: 105ms
# 886:	learn: 0.3260119	total: 814ms	remaining: 104ms
# 887:	learn: 0.3259849	total: 815ms	remaining: 103ms
# 888:	learn: 0.3259652	total: 816ms	remaining: 102ms
# 889:	learn: 0.3259080	total: 816ms	remaining: 101ms
# 890:	learn: 0.3258704	total: 817ms	remaining: 100ms
# 891:	learn: 0.3258143	total: 818ms	remaining: 99.1ms
# 892:	learn: 0.3258130	total: 819ms	remaining: 98.1ms
# 893:	learn: 0.3257416	total: 819ms	remaining: 97.2ms
# 894:	learn: 0.3257197	total: 820ms	remaining: 96.2ms
# 895:	learn: 0.3256792	total: 821ms	remaining: 95.3ms
# 896:	learn: 0.3256595	total: 822ms	remaining: 94.3ms
# 897:	learn: 0.3255985	total: 822ms	remaining: 93.4ms
# 898:	learn: 0.3255615	total: 823ms	remaining: 92.5ms
# 899:	learn: 0.3255430	total: 824ms	remaining: 91.5ms
# 900:	learn: 0.3255180	total: 824ms	remaining: 90.6ms
# 901:	learn: 0.3254733	total: 825ms	remaining: 89.7ms
# 902:	learn: 0.3254449	total: 826ms	remaining: 88.7ms
# 903:	learn: 0.3254161	total: 827ms	remaining: 87.8ms
# 904:	learn: 0.3253958	total: 827ms	remaining: 86.9ms
# 905:	learn: 0.3253604	total: 828ms	remaining: 85.9ms
# 906:	learn: 0.3253335	total: 829ms	remaining: 85ms
# 907:	learn: 0.3253006	total: 829ms	remaining: 84ms
# 908:	learn: 0.3252377	total: 830ms	remaining: 83.1ms
# 909:	learn: 0.3251815	total: 831ms	remaining: 82.2ms
# 910:	learn: 0.3251198	total: 832ms	remaining: 81.2ms
# 911:	learn: 0.3250571	total: 832ms	remaining: 80.3ms
# 912:	learn: 0.3249953	total: 833ms	remaining: 79.4ms
# 913:	learn: 0.3249957	total: 834ms	remaining: 78.4ms
# 914:	learn: 0.3249499	total: 834ms	remaining: 77.5ms
# 915:	learn: 0.3249496	total: 835ms	remaining: 76.6ms
# 916:	learn: 0.3248979	total: 836ms	remaining: 75.6ms
# 917:	learn: 0.3248693	total: 836ms	remaining: 74.7ms
# 918:	learn: 0.3248050	total: 837ms	remaining: 73.8ms
# 919:	learn: 0.3247818	total: 838ms	remaining: 72.9ms
# 920:	learn: 0.3247345	total: 839ms	remaining: 71.9ms
# 921:	learn: 0.3247096	total: 839ms	remaining: 71ms
# 922:	learn: 0.3246910	total: 840ms	remaining: 70.1ms
# 923:	learn: 0.3246896	total: 840ms	remaining: 69.1ms
# 924:	learn: 0.3246895	total: 841ms	remaining: 68.2ms
# 925:	learn: 0.3246382	total: 842ms	remaining: 67.3ms
# 926:	learn: 0.3245913	total: 842ms	remaining: 66.3ms
# 927:	learn: 0.3245124	total: 843ms	remaining: 65.4ms
# 928:	learn: 0.3244663	total: 844ms	remaining: 64.5ms
# 929:	learn: 0.3244211	total: 844ms	remaining: 63.5ms
# 930:	learn: 0.3243597	total: 845ms	remaining: 62.6ms
# 931:	learn: 0.3243096	total: 846ms	remaining: 61.7ms
# 932:	learn: 0.3242798	total: 847ms	remaining: 60.8ms
# 933:	learn: 0.3242571	total: 848ms	remaining: 59.9ms
# 934:	learn: 0.3241716	total: 848ms	remaining: 59ms
# 935:	learn: 0.3241593	total: 849ms	remaining: 58ms
# 936:	learn: 0.3241154	total: 850ms	remaining: 57.1ms
# 937:	learn: 0.3240922	total: 850ms	remaining: 56.2ms
# 938:	learn: 0.3240710	total: 851ms	remaining: 55.3ms
# 939:	learn: 0.3240225	total: 852ms	remaining: 54.4ms
# 940:	learn: 0.3239832	total: 853ms	remaining: 53.5ms
# 941:	learn: 0.3239437	total: 853ms	remaining: 52.5ms
# 942:	learn: 0.3239177	total: 854ms	remaining: 51.6ms
# 943:	learn: 0.3238808	total: 855ms	remaining: 50.7ms
# 944:	learn: 0.3238479	total: 856ms	remaining: 49.8ms
# 945:	learn: 0.3237930	total: 856ms	remaining: 48.9ms
# 946:	learn: 0.3237612	total: 857ms	remaining: 48ms
# 947:	learn: 0.3237466	total: 858ms	remaining: 47ms
# 948:	learn: 0.3237282	total: 858ms	remaining: 46.1ms
# 949:	learn: 0.3236581	total: 859ms	remaining: 45.2ms
# 950:	learn: 0.3236139	total: 860ms	remaining: 44.3ms
# 951:	learn: 0.3235704	total: 861ms	remaining: 43.4ms
# 952:	learn: 0.3235538	total: 862ms	remaining: 42.5ms
# 953:	learn: 0.3235113	total: 862ms	remaining: 41.6ms
# 954:	learn: 0.3234723	total: 863ms	remaining: 40.7ms
# 955:	learn: 0.3234424	total: 864ms	remaining: 39.8ms
# 956:	learn: 0.3233941	total: 865ms	remaining: 38.9ms
# 957:	learn: 0.3233550	total: 866ms	remaining: 37.9ms
# 958:	learn: 0.3233353	total: 866ms	remaining: 37ms
# 959:	learn: 0.3232556	total: 867ms	remaining: 36.1ms
# 960:	learn: 0.3232239	total: 868ms	remaining: 35.2ms
# 961:	learn: 0.3231846	total: 869ms	remaining: 34.3ms
# 962:	learn: 0.3231467	total: 869ms	remaining: 33.4ms
# 963:	learn: 0.3231179	total: 870ms	remaining: 32.5ms
# 964:	learn: 0.3230897	total: 871ms	remaining: 31.6ms
# 965:	learn: 0.3230616	total: 871ms	remaining: 30.7ms
# 966:	learn: 0.3230217	total: 872ms	remaining: 29.8ms
# 967:	learn: 0.3229915	total: 873ms	remaining: 28.8ms
# 968:	learn: 0.3229110	total: 873ms	remaining: 27.9ms
# 969:	learn: 0.3228899	total: 874ms	remaining: 27ms
# 970:	learn: 0.3228511	total: 875ms	remaining: 26.1ms
# 971:	learn: 0.3228271	total: 876ms	remaining: 25.2ms
# 972:	learn: 0.3227944	total: 877ms	remaining: 24.3ms
# 973:	learn: 0.3227763	total: 877ms	remaining: 23.4ms
# 974:	learn: 0.3227382	total: 878ms	remaining: 22.5ms
# 975:	learn: 0.3227038	total: 879ms	remaining: 21.6ms
# 976:	learn: 0.3226576	total: 879ms	remaining: 20.7ms
# 977:	learn: 0.3226034	total: 880ms	remaining: 19.8ms
# 978:	learn: 0.3225714	total: 881ms	remaining: 18.9ms
# 979:	learn: 0.3225607	total: 881ms	remaining: 18ms
# 980:	learn: 0.3225112	total: 882ms	remaining: 17.1ms
# 981:	learn: 0.3224768	total: 883ms	remaining: 16.2ms
# 982:	learn: 0.3224406	total: 884ms	remaining: 15.3ms
# 983:	learn: 0.3223913	total: 884ms	remaining: 14.4ms
# 984:	learn: 0.3223679	total: 885ms	remaining: 13.5ms
# 985:	learn: 0.3223415	total: 886ms	remaining: 12.6ms
# 986:	learn: 0.3223178	total: 886ms	remaining: 11.7ms
# 987:	learn: 0.3222593	total: 887ms	remaining: 10.8ms
# 988:	learn: 0.3222332	total: 888ms	remaining: 9.87ms
# 989:	learn: 0.3222218	total: 889ms	remaining: 8.97ms
# 990:	learn: 0.3222104	total: 889ms	remaining: 8.07ms
# 991:	learn: 0.3221588	total: 890ms	remaining: 7.18ms
# 992:	learn: 0.3221304	total: 891ms	remaining: 6.28ms
# 993:	learn: 0.3221047	total: 891ms	remaining: 5.38ms
# 994:	learn: 0.3220843	total: 892ms	remaining: 4.48ms
# 995:	learn: 0.3220697	total: 893ms	remaining: 3.58ms
# 996:	learn: 0.3220588	total: 893ms	remaining: 2.69ms
# 997:	learn: 0.3220355	total: 894ms	remaining: 1.79ms
# 998:	learn: 0.3219998	total: 895ms	remaining: 895us
# 999:	learn: 0.3219471	total: 895ms	remaining: 0us

# %% [markdown]
# ### 6.2.11 multilayer perceptron

# %%
#rael
#MLP
mlp = MLPClassifier()
MLPtrained=mlp.fit(X_train, Y_train)
accuracy_mlp = round(mlp.score(X_train, Y_train) * 100, 2)#made a change here

# %% [markdown]
# ## 6.3 Model evaluation and hyperparameter tuning
#
# Once all our models have been trained, the next step is to assess the performance of these models and select the one which has the highest prediction accuracy.

# %% [markdown]
# ### 6.3.1 Training accuracy
#
# Training accuracy shows how well our model has learned from the training set.

# %% [markdown]
# Internal comment: Viewing and summarising the scores calcualted above for each algorithm. These models have have not yet been tuned

# %%
#rael 
#creating a dataframe to store the score of each model based on the training data 
# This will allows us to find early identifiers indicating which  models that are likely to have 
# a high prediction sucess rate with the test data and which ones might be overfitted.
models = pd.DataFrame({'Model': ['Multilayer perceptron','Logistic Regression','Naive Bayes', 'K Nearest Neighbours', 
                                  'Support Vector Machines', 'Stochastic Gradient Decent', 
                                 'Linear SVC','Perceptron', 'Random Forest', 'Cat Boost','Decision Tree'],
                       'Score': [accuracy_mlp, accuracy_log ,accuracy_gaussian,  accuracy_knn, accuracy_svc, 
                                 accuracy_sgd, accuracy_linear_svc,accuracy_perceptron,accuracy_random_forest,accuracy_catboost, accuracy_decision_tree]})

models.sort_values(by = 'Score', ascending = False, ignore_index = True)
# Out:
#                          Model  Score
# 0                Random Forest  86.87
# 1                Decision Tree  86.87
# 2                    Cat Boost  86.76
# 3         K Nearest Neighbours  83.73
# 4        Multilayer perceptron  82.94
# 5      Support Vector Machines  82.94
# 6                   Linear SVC  79.12
# 7          Logistic Regression  78.90
# 8                  Naive Bayes  76.77
# 9                   Perceptron  76.77
# 10  Stochastic Gradient Decent  73.51

# %% [markdown]
# ### 6.3.2 K-fold cross validation
#
# It is important to not get too carried away with models with impressive training accuracy as what we should focus on instead is the model's ability to predict out-of-samples data, in other words, data our model has not seen before.
#
# This is where k-fold cross validation comes in. K-fold cross validation is a technique whereby a subset of our training set is kept aside and will act as holdout set for testing purposes. Here is a great [video](https://www.youtube.com/watch?v=fSytzGwwBVw) explaining the concept in more detail.

# %%
# Create a list which contains classifiers 
# Rael
classifiers = [ MLPClassifier(),
                LogisticRegression(), 
                GaussianNB(),
                KNeighborsClassifier(n_neighbors = 5), 
                SVC(),  
                SGDClassifier(), 
                LinearSVC(),
                Perceptron(),
                RandomForestClassifier(),
                CatBoostClassifier(),
                DecisionTreeClassifier()
               ]


if len(classifiers) is not 11: # assuming we intend to use 11 classifiers
    print("error")

cross_val_results = []
for classifier in classifiers:#each result has k subcomponents.Cv=k 
    cross_val_results.append(cross_val_score(classifier, X_train, Y_train, scoring = 'accuracy', cv = 5))
    # we need to try other cv's if this affects other parts of the code
    # potentially mifht be a place for tuning using grid search
# Out:
# Learning rate set to 0.008911
# 0:	learn: 0.6867102	total: 708us	remaining: 708ms
# 1:	learn: 0.6816314	total: 1.33ms	remaining: 662ms
# 2:	learn: 0.6760633	total: 2.02ms	remaining: 670ms
# 3:	learn: 0.6711699	total: 2.7ms	remaining: 672ms
# 4:	learn: 0.6670504	total: 3.39ms	remaining: 674ms
# 5:	learn: 0.6615089	total: 4.14ms	remaining: 686ms
# 6:	learn: 0.6560690	total: 4.95ms	remaining: 702ms
# 7:	learn: 0.6506229	total: 5.64ms	remaining: 699ms
# 8:	learn: 0.6451099	total: 6.33ms	remaining: 697ms
# 9:	learn: 0.6397200	total: 7.13ms	remaining: 706ms
# 10:	learn: 0.6351848	total: 7.87ms	remaining: 708ms
# 11:	learn: 0.6304318	total: 8.57ms	remaining: 706ms
# 12:	learn: 0.6254140	total: 9.32ms	remaining: 707ms
# 13:	learn: 0.6207909	total: 10ms	remaining: 707ms
# 14:	learn: 0.6163616	total: 10.8ms	remaining: 712ms
# 15:	learn: 0.6113830	total: 11.6ms	remaining: 711ms
# 16:	learn: 0.6078094	total: 12.2ms	remaining: 706ms
# 17:	learn: 0.6032256	total: 12.9ms	remaining: 703ms
# 18:	learn: 0.5998448	total: 13.6ms	remaining: 700ms
# 19:	learn: 0.5952990	total: 14.2ms	remaining: 698ms
# 20:	learn: 0.5915194	total: 15ms	remaining: 699ms
# 21:	learn: 0.5873219	total: 15.7ms	remaining: 697ms
# 22:	learn: 0.5833369	total: 16.3ms	remaining: 694ms
# 23:	learn: 0.5792053	total: 17.1ms	remaining: 694ms
# 24:	learn: 0.5757754	total: 17.8ms	remaining: 693ms
# 25:	learn: 0.5717743	total: 18.6ms	remaining: 697ms
# 26:	learn: 0.5679733	total: 19.4ms	remaining: 698ms
# 27:	learn: 0.5662419	total: 19.9ms	remaining: 690ms
# 28:	learn: 0.5635653	total: 20.6ms	remaining: 691ms
# 29:	learn: 0.5598189	total: 21.4ms	remaining: 691ms
# 30:	learn: 0.5565204	total: 22ms	remaining: 689ms
# 31:	learn: 0.5535072	total: 22.9ms	remaining: 693ms
# 32:	learn: 0.5508077	total: 23.6ms	remaining: 692ms
# 33:	learn: 0.5474767	total: 24.4ms	remaining: 692ms
# 34:	learn: 0.5444288	total: 25ms	remaining: 690ms
# 35:	learn: 0.5415945	total: 25.8ms	remaining: 691ms
# 36:	learn: 0.5384028	total: 26.6ms	remaining: 692ms
# 37:	learn: 0.5357534	total: 27.2ms	remaining: 690ms
# 38:	learn: 0.5330600	total: 28ms	remaining: 690ms
# 39:	learn: 0.5300123	total: 28.8ms	remaining: 690ms
# 40:	learn: 0.5268692	total: 29.5ms	remaining: 690ms
# 41:	learn: 0.5246333	total: 30.2ms	remaining: 689ms
# 42:	learn: 0.5216964	total: 31ms	remaining: 691ms
# 43:	learn: 0.5193541	total: 31.9ms	remaining: 692ms
# 44:	learn: 0.5178585	total: 32.5ms	remaining: 690ms
# 45:	learn: 0.5152513	total: 33.5ms	remaining: 694ms
# 46:	learn: 0.5123468	total: 34.3ms	remaining: 696ms
# 47:	learn: 0.5102604	total: 35.1ms	remaining: 696ms
# 48:	learn: 0.5079508	total: 36ms	remaining: 698ms
# 49:	learn: 0.5061736	total: 36.6ms	remaining: 695ms
# 50:	learn: 0.5035430	total: 37.3ms	remaining: 694ms
# 51:	learn: 0.5014504	total: 37.9ms	remaining: 691ms
# 52:	learn: 0.4996914	total: 38.5ms	remaining: 687ms
# 53:	learn: 0.4977658	total: 39ms	remaining: 683ms
# 54:	learn: 0.4955123	total: 39.7ms	remaining: 682ms
# 55:	learn: 0.4937326	total: 40.4ms	remaining: 681ms
# 56:	learn: 0.4922645	total: 41.1ms	remaining: 680ms
# 57:	learn: 0.4905311	total: 41.8ms	remaining: 680ms
# 58:	learn: 0.4882322	total: 42.5ms	remaining: 679ms
# 59:	learn: 0.4864240	total: 43.3ms	remaining: 678ms
# 60:	learn: 0.4844941	total: 44ms	remaining: 677ms
# 61:	learn: 0.4830678	total: 44.6ms	remaining: 675ms
# 62:	learn: 0.4810966	total: 45.3ms	remaining: 674ms
# 63:	learn: 0.4791807	total: 46ms	remaining: 673ms
# 64:	learn: 0.4772260	total: 46.8ms	remaining: 673ms
# 65:	learn: 0.4756979	total: 47.5ms	remaining: 672ms
# 66:	learn: 0.4739499	total: 48.3ms	remaining: 672ms
# 67:	learn: 0.4723326	total: 49ms	remaining: 671ms
# 68:	learn: 0.4706699	total: 49.7ms	remaining: 671ms
# 69:	learn: 0.4692256	total: 50.4ms	remaining: 669ms
# 70:	learn: 0.4675315	total: 51.1ms	remaining: 669ms
# 71:	learn: 0.4659870	total: 51.8ms	remaining: 668ms
# 72:	learn: 0.4651037	total: 52.4ms	remaining: 665ms
# 73:	learn: 0.4637127	total: 53.1ms	remaining: 664ms
# 74:	learn: 0.4625651	total: 53.7ms	remaining: 662ms
# 75:	learn: 0.4608057	total: 54.4ms	remaining: 662ms
# 76:	learn: 0.4593333	total: 55.2ms	remaining: 662ms
# 77:	learn: 0.4578019	total: 55.9ms	remaining: 660ms
# 78:	learn: 0.4566922	total: 56.6ms	remaining: 660ms
# 79:	learn: 0.4552667	total: 57.4ms	remaining: 660ms
# 80:	learn: 0.4538072	total: 58.1ms	remaining: 660ms
# 81:	learn: 0.4531127	total: 58.7ms	remaining: 658ms
# 82:	learn: 0.4518726	total: 59.5ms	remaining: 657ms
# 83:	learn: 0.4504010	total: 60.4ms	remaining: 658ms
# 84:	learn: 0.4491965	total: 61.1ms	remaining: 658ms
# 85:	learn: 0.4479263	total: 62.1ms	remaining: 660ms
# 86:	learn: 0.4464941	total: 62.9ms	remaining: 660ms
# 87:	learn: 0.4454386	total: 63.7ms	remaining: 660ms
# 88:	learn: 0.4447685	total: 64.3ms	remaining: 658ms
# 89:	learn: 0.4435603	total: 65.2ms	remaining: 659ms
# 90:	learn: 0.4422785	total: 65.9ms	remaining: 658ms
# 91:	learn: 0.4411737	total: 66.6ms	remaining: 657ms
# 92:	learn: 0.4400652	total: 67.3ms	remaining: 656ms
# 93:	learn: 0.4386566	total: 68.1ms	remaining: 656ms
# 94:	learn: 0.4377232	total: 68.9ms	remaining: 657ms
# 95:	learn: 0.4365696	total: 69.7ms	remaining: 657ms
# 96:	learn: 0.4355627	total: 70.5ms	remaining: 656ms
# 97:	learn: 0.4352889	total: 71.1ms	remaining: 654ms
# 98:	learn: 0.4343284	total: 71.9ms	remaining: 654ms
# 99:	learn: 0.4334184	total: 72.6ms	remaining: 654ms
# 100:	learn: 0.4329549	total: 73.2ms	remaining: 652ms
# 101:	learn: 0.4318095	total: 74ms	remaining: 652ms
# 102:	learn: 0.4304741	total: 74.8ms	remaining: 651ms
# 103:	learn: 0.4296093	total: 75.5ms	remaining: 651ms
# 104:	learn: 0.4289377	total: 76.4ms	remaining: 652ms
# 105:	learn: 0.4278528	total: 77.2ms	remaining: 651ms
# 106:	learn: 0.4270270	total: 77.9ms	remaining: 650ms
# 107:	learn: 0.4263220	total: 78.6ms	remaining: 649ms
# 108:	learn: 0.4252820	total: 79.4ms	remaining: 649ms
# 109:	learn: 0.4245498	total: 80.1ms	remaining: 648ms
# 110:	learn: 0.4240315	total: 80.7ms	remaining: 646ms
# 111:	learn: 0.4233515	total: 81.4ms	remaining: 645ms
# 112:	learn: 0.4227285	total: 82ms	remaining: 644ms
# 113:	learn: 0.4222224	total: 82.8ms	remaining: 643ms
# 114:	learn: 0.4214127	total: 83.5ms	remaining: 643ms
# 115:	learn: 0.4205957	total: 84.4ms	remaining: 644ms
# 116:	learn: 0.4196383	total: 85.2ms	remaining: 643ms
# 117:	learn: 0.4187892	total: 85.9ms	remaining: 642ms
# 118:	learn: 0.4179136	total: 86.6ms	remaining: 641ms
# 119:	learn: 0.4171590	total: 87.3ms	remaining: 640ms
# 120:	learn: 0.4162042	total: 88.1ms	remaining: 640ms
# 121:	learn: 0.4154582	total: 88.8ms	remaining: 639ms
# 122:	learn: 0.4147194	total: 89.5ms	remaining: 638ms
# 123:	learn: 0.4141817	total: 90.6ms	remaining: 640ms
# 124:	learn: 0.4133987	total: 91.4ms	remaining: 640ms
# 125:	learn: 0.4131026	total: 92ms	remaining: 638ms
# 126:	learn: 0.4126067	total: 92.6ms	remaining: 637ms
# 127:	learn: 0.4118264	total: 93.3ms	remaining: 636ms
# 128:	learn: 0.4109064	total: 94.1ms	remaining: 636ms
# 129:	learn: 0.4102890	total: 94.9ms	remaining: 635ms
# 130:	learn: 0.4096812	total: 95.7ms	remaining: 635ms
# 131:	learn: 0.4088191	total: 96.4ms	remaining: 634ms
# 132:	learn: 0.4083535	total: 97ms	remaining: 632ms
# 133:	learn: 0.4076932	total: 97.7ms	remaining: 631ms
# 134:	learn: 0.4070405	total: 98.5ms	remaining: 631ms
# 135:	learn: 0.4065466	total: 99.2ms	remaining: 630ms
# 136:	learn: 0.4057520	total: 99.9ms	remaining: 629ms
# 137:	learn: 0.4053763	total: 101ms	remaining: 628ms
# 138:	learn: 0.4046634	total: 101ms	remaining: 628ms
# 139:	learn: 0.4041523	total: 102ms	remaining: 628ms
# 140:	learn: 0.4039274	total: 103ms	remaining: 626ms
# 141:	learn: 0.4032230	total: 104ms	remaining: 626ms
# 142:	learn: 0.4028061	total: 104ms	remaining: 625ms
# 143:	learn: 0.4024999	total: 105ms	remaining: 625ms
# 144:	learn: 0.4020858	total: 106ms	remaining: 624ms
# 145:	learn: 0.4016715	total: 107ms	remaining: 624ms
# 146:	learn: 0.4011335	total: 107ms	remaining: 623ms
# 147:	learn: 0.4007647	total: 108ms	remaining: 622ms
# 148:	learn: 0.4002432	total: 109ms	remaining: 622ms
# 149:	learn: 0.4001208	total: 109ms	remaining: 620ms
# 150:	learn: 0.3998758	total: 110ms	remaining: 618ms
# 151:	learn: 0.3994028	total: 111ms	remaining: 617ms
# 152:	learn: 0.3987446	total: 111ms	remaining: 617ms
# 153:	learn: 0.3986717	total: 112ms	remaining: 614ms
# 154:	learn: 0.3983525	total: 112ms	remaining: 613ms
# 155:	learn: 0.3980944	total: 113ms	remaining: 612ms
# 156:	learn: 0.3976257	total: 114ms	remaining: 611ms
# 157:	learn: 0.3971621	total: 115ms	remaining: 610ms
# 158:	learn: 0.3966281	total: 115ms	remaining: 610ms
# 159:	learn: 0.3964019	total: 116ms	remaining: 608ms
# 160:	learn: 0.3960590	total: 116ms	remaining: 607ms
# 161:	learn: 0.3954560	total: 117ms	remaining: 606ms
# 162:	learn: 0.3953587	total: 118ms	remaining: 604ms
# 163:	learn: 0.3949691	total: 118ms	remaining: 604ms
# 164:	learn: 0.3943613	total: 119ms	remaining: 603ms
# 165:	learn: 0.3939655	total: 120ms	remaining: 603ms
# 166:	learn: 0.3938901	total: 121ms	remaining: 601ms
# 167:	learn: 0.3937447	total: 121ms	remaining: 600ms
# 168:	learn: 0.3931236	total: 122ms	remaining: 599ms
# 169:	learn: 0.3926595	total: 123ms	remaining: 598ms
# 170:	learn: 0.3922502	total: 123ms	remaining: 598ms
# 171:	learn: 0.3919260	total: 124ms	remaining: 597ms
# 172:	learn: 0.3916415	total: 125ms	remaining: 596ms
# 173:	learn: 0.3910110	total: 125ms	remaining: 595ms
# 174:	learn: 0.3905022	total: 126ms	remaining: 595ms
# 175:	learn: 0.3902605	total: 127ms	remaining: 594ms
# 176:	learn: 0.3899289	total: 127ms	remaining: 593ms
# 177:	learn: 0.3898543	total: 128ms	remaining: 591ms
# 178:	learn: 0.3897605	total: 128ms	remaining: 589ms
# 179:	learn: 0.3891689	total: 129ms	remaining: 588ms
# 180:	learn: 0.3885005	total: 130ms	remaining: 587ms
# 181:	learn: 0.3881902	total: 130ms	remaining: 586ms
# 182:	learn: 0.3878350	total: 131ms	remaining: 586ms
# 183:	learn: 0.3871560	total: 132ms	remaining: 585ms
# 184:	learn: 0.3867099	total: 133ms	remaining: 584ms
# 185:	learn: 0.3866109	total: 133ms	remaining: 582ms
# 186:	learn: 0.3860206	total: 134ms	remaining: 582ms
# 187:	learn: 0.3856911	total: 135ms	remaining: 582ms
# 188:	learn: 0.3853980	total: 135ms	remaining: 581ms
# 189:	learn: 0.3849687	total: 136ms	remaining: 580ms
# 190:	learn: 0.3846425	total: 137ms	remaining: 580ms
# 191:	learn: 0.3844305	total: 138ms	remaining: 579ms
# 192:	learn: 0.3841466	total: 138ms	remaining: 578ms
# 193:	learn: 0.3840460	total: 139ms	remaining: 577ms
# 194:	learn: 0.3840118	total: 139ms	remaining: 575ms
# 195:	learn: 0.3837849	total: 140ms	remaining: 574ms
# 196:	learn: 0.3832849	total: 141ms	remaining: 574ms
# 197:	learn: 0.3828668	total: 141ms	remaining: 573ms
# 198:	learn: 0.3827495	total: 142ms	remaining: 572ms
# 199:	learn: 0.3825508	total: 143ms	remaining: 570ms
# 200:	learn: 0.3823729	total: 143ms	remaining: 570ms
# 201:	learn: 0.3822533	total: 144ms	remaining: 569ms
# 202:	learn: 0.3820590	total: 145ms	remaining: 568ms
# 203:	learn: 0.3819279	total: 145ms	remaining: 567ms
# 204:	learn: 0.3816353	total: 146ms	remaining: 566ms
# 205:	learn: 0.3813452	total: 147ms	remaining: 565ms
# 206:	learn: 0.3811673	total: 147ms	remaining: 565ms
# 207:	learn: 0.3806839	total: 148ms	remaining: 564ms
# 208:	learn: 0.3804510	total: 149ms	remaining: 564ms
# 209:	learn: 0.3803522	total: 150ms	remaining: 564ms
# 210:	learn: 0.3801136	total: 151ms	remaining: 564ms
# 211:	learn: 0.3798667	total: 152ms	remaining: 563ms
# 212:	learn: 0.3798114	total: 152ms	remaining: 562ms
# 213:	learn: 0.3795455	total: 153ms	remaining: 561ms
# 214:	learn: 0.3792948	total: 153ms	remaining: 560ms
# 215:	learn: 0.3790532	total: 154ms	remaining: 560ms
# 216:	learn: 0.3790206	total: 155ms	remaining: 558ms
# 217:	learn: 0.3787877	total: 156ms	remaining: 558ms
# 218:	learn: 0.3786011	total: 156ms	remaining: 557ms
# 219:	learn: 0.3782595	total: 157ms	remaining: 556ms
# 220:	learn: 0.3778429	total: 158ms	remaining: 555ms
# 221:	learn: 0.3774548	total: 158ms	remaining: 555ms
# 222:	learn: 0.3772416	total: 159ms	remaining: 554ms
# 223:	learn: 0.3768978	total: 160ms	remaining: 554ms
# 224:	learn: 0.3766148	total: 160ms	remaining: 553ms
# 225:	learn: 0.3763870	total: 161ms	remaining: 552ms
# 226:	learn: 0.3761053	total: 162ms	remaining: 551ms
# 227:	learn: 0.3758189	total: 163ms	remaining: 552ms
# 228:	learn: 0.3755894	total: 164ms	remaining: 551ms
# 229:	learn: 0.3753030	total: 165ms	remaining: 551ms
# 230:	learn: 0.3749716	total: 165ms	remaining: 550ms
# 231:	learn: 0.3748195	total: 166ms	remaining: 550ms
# 232:	learn: 0.3744007	total: 167ms	remaining: 549ms
# 233:	learn: 0.3740973	total: 167ms	remaining: 548ms
# 234:	learn: 0.3740642	total: 168ms	remaining: 547ms
# 235:	learn: 0.3738129	total: 169ms	remaining: 546ms
# 236:	learn: 0.3734811	total: 169ms	remaining: 545ms
# 237:	learn: 0.3734179	total: 170ms	remaining: 544ms
# 238:	learn: 0.3730930	total: 171ms	remaining: 543ms
# 239:	learn: 0.3727914	total: 171ms	remaining: 543ms
# 240:	learn: 0.3725917	total: 172ms	remaining: 542ms
# 241:	learn: 0.3723145	total: 173ms	remaining: 541ms
# 242:	learn: 0.3721926	total: 173ms	remaining: 540ms
# 243:	learn: 0.3719128	total: 174ms	remaining: 540ms
# 244:	learn: 0.3716042	total: 175ms	remaining: 539ms
# 245:	learn: 0.3714973	total: 176ms	remaining: 539ms
# 246:	learn: 0.3713109	total: 177ms	remaining: 538ms
# 247:	learn: 0.3710742	total: 177ms	remaining: 538ms
# 248:	learn: 0.3708293	total: 178ms	remaining: 537ms
# 249:	learn: 0.3706338	total: 179ms	remaining: 537ms
# 250:	learn: 0.3704314	total: 180ms	remaining: 536ms
# 251:	learn: 0.3700219	total: 180ms	remaining: 535ms
# 252:	learn: 0.3697580	total: 181ms	remaining: 535ms
# 253:	learn: 0.3695806	total: 182ms	remaining: 535ms
# 254:	learn: 0.3694105	total: 183ms	remaining: 535ms
# 255:	learn: 0.3693852	total: 183ms	remaining: 533ms
# 256:	learn: 0.3692421	total: 184ms	remaining: 532ms
# 257:	learn: 0.3690618	total: 185ms	remaining: 532ms
# 258:	learn: 0.3687349	total: 186ms	remaining: 531ms
# 259:	learn: 0.3685982	total: 186ms	remaining: 531ms
# 260:	learn: 0.3684048	total: 187ms	remaining: 530ms
# 261:	learn: 0.3682302	total: 188ms	remaining: 530ms
# 262:	learn: 0.3679982	total: 189ms	remaining: 529ms
# 263:	learn: 0.3678409	total: 190ms	remaining: 529ms
# 264:	learn: 0.3674714	total: 190ms	remaining: 528ms
# 265:	learn: 0.3670936	total: 191ms	remaining: 528ms
# 266:	learn: 0.3670753	total: 192ms	remaining: 527ms
# 267:	learn: 0.3669611	total: 193ms	remaining: 526ms
# 268:	learn: 0.3667454	total: 193ms	remaining: 525ms
# 269:	learn: 0.3665387	total: 194ms	remaining: 525ms
# 270:	learn: 0.3663954	total: 195ms	remaining: 524ms
# 271:	learn: 0.3662083	total: 196ms	remaining: 523ms
# 272:	learn: 0.3658721	total: 196ms	remaining: 523ms
# 273:	learn: 0.3656823	total: 197ms	remaining: 522ms
# 274:	learn: 0.3652958	total: 198ms	remaining: 522ms
# 275:	learn: 0.3651836	total: 199ms	remaining: 521ms
# 276:	learn: 0.3650904	total: 199ms	remaining: 521ms
# 277:	learn: 0.3648800	total: 200ms	remaining: 520ms
# 278:	learn: 0.3646628	total: 201ms	remaining: 520ms
# 279:	learn: 0.3643218	total: 202ms	remaining: 519ms
# 280:	learn: 0.3641030	total: 203ms	remaining: 519ms
# 281:	learn: 0.3639994	total: 204ms	remaining: 518ms
# 282:	learn: 0.3638517	total: 204ms	remaining: 518ms
# 283:	learn: 0.3636782	total: 205ms	remaining: 518ms
# 284:	learn: 0.3635170	total: 206ms	remaining: 517ms
# 285:	learn: 0.3634063	total: 207ms	remaining: 517ms
# 286:	learn: 0.3631703	total: 208ms	remaining: 517ms
# 287:	learn: 0.3628050	total: 209ms	remaining: 516ms
# 288:	learn: 0.3627540	total: 209ms	remaining: 515ms
# 289:	learn: 0.3625393	total: 210ms	remaining: 515ms
# 290:	learn: 0.3622725	total: 211ms	remaining: 514ms
# 291:	learn: 0.3620212	total: 212ms	remaining: 514ms
# 292:	learn: 0.3619628	total: 213ms	remaining: 513ms
# 293:	learn: 0.3616020	total: 213ms	remaining: 512ms
# 294:	learn: 0.3612506	total: 214ms	remaining: 512ms
# 295:	learn: 0.3611322	total: 215ms	remaining: 511ms
# 296:	learn: 0.3607899	total: 216ms	remaining: 510ms
# 297:	learn: 0.3607816	total: 216ms	remaining: 509ms
# 298:	learn: 0.3606965	total: 217ms	remaining: 508ms
# 299:	learn: 0.3606657	total: 217ms	remaining: 507ms
# 300:	learn: 0.3605021	total: 218ms	remaining: 506ms
# 301:	learn: 0.3603925	total: 219ms	remaining: 506ms
# 302:	learn: 0.3602963	total: 220ms	remaining: 505ms
# 303:	learn: 0.3601336	total: 220ms	remaining: 504ms
# 304:	learn: 0.3598743	total: 221ms	remaining: 504ms
# 305:	learn: 0.3596903	total: 222ms	remaining: 504ms
# 306:	learn: 0.3596127	total: 223ms	remaining: 503ms
# 307:	learn: 0.3594364	total: 224ms	remaining: 503ms
# 308:	learn: 0.3592763	total: 225ms	remaining: 502ms
# 309:	learn: 0.3590041	total: 225ms	remaining: 502ms
# 310:	learn: 0.3588721	total: 226ms	remaining: 501ms
# 311:	learn: 0.3586291	total: 227ms	remaining: 501ms
# 312:	learn: 0.3584767	total: 228ms	remaining: 500ms
# 313:	learn: 0.3582529	total: 228ms	remaining: 499ms
# 314:	learn: 0.3580211	total: 229ms	remaining: 498ms
# 315:	learn: 0.3579164	total: 230ms	remaining: 498ms
# 316:	learn: 0.3577637	total: 231ms	remaining: 497ms
# 317:	learn: 0.3575998	total: 231ms	remaining: 496ms
# 318:	learn: 0.3574722	total: 232ms	remaining: 495ms
# 319:	learn: 0.3572698	total: 233ms	remaining: 495ms
# 320:	learn: 0.3571292	total: 234ms	remaining: 494ms
# 321:	learn: 0.3569916	total: 234ms	remaining: 493ms
# 322:	learn: 0.3568624	total: 235ms	remaining: 493ms
# 323:	learn: 0.3566050	total: 236ms	remaining: 492ms
# 324:	learn: 0.3564479	total: 237ms	remaining: 491ms
# 325:	learn: 0.3563026	total: 237ms	remaining: 491ms
# 326:	learn: 0.3561629	total: 238ms	remaining: 490ms
# 327:	learn: 0.3561145	total: 239ms	remaining: 489ms
# 328:	learn: 0.3559212	total: 239ms	remaining: 488ms
# 329:	learn: 0.3559177	total: 240ms	remaining: 487ms
# 330:	learn: 0.3558165	total: 241ms	remaining: 486ms
# 331:	learn: 0.3557851	total: 241ms	remaining: 485ms
# 332:	learn: 0.3556701	total: 242ms	remaining: 485ms
# 333:	learn: 0.3555437	total: 243ms	remaining: 484ms
# 334:	learn: 0.3554162	total: 243ms	remaining: 483ms
# 335:	learn: 0.3552915	total: 244ms	remaining: 483ms
# 336:	learn: 0.3551426	total: 245ms	remaining: 482ms
# 337:	learn: 0.3548616	total: 246ms	remaining: 481ms
# 338:	learn: 0.3547185	total: 247ms	remaining: 481ms
# 339:	learn: 0.3545255	total: 247ms	remaining: 480ms
# 340:	learn: 0.3544075	total: 248ms	remaining: 480ms
# 341:	learn: 0.3542536	total: 249ms	remaining: 479ms
# 342:	learn: 0.3541128	total: 250ms	remaining: 478ms
# 343:	learn: 0.3540124	total: 250ms	remaining: 478ms
# 344:	learn: 0.3536671	total: 251ms	remaining: 477ms
# 345:	learn: 0.3534533	total: 252ms	remaining: 476ms
# 346:	learn: 0.3532146	total: 253ms	remaining: 476ms
# 347:	learn: 0.3529831	total: 253ms	remaining: 475ms
# 348:	learn: 0.3528865	total: 254ms	remaining: 474ms
# 349:	learn: 0.3526986	total: 255ms	remaining: 473ms
# 350:	learn: 0.3526900	total: 255ms	remaining: 472ms
# 351:	learn: 0.3525868	total: 256ms	remaining: 471ms
# 352:	learn: 0.3524675	total: 257ms	remaining: 471ms
# 353:	learn: 0.3523100	total: 258ms	remaining: 470ms
# 354:	learn: 0.3522119	total: 258ms	remaining: 469ms
# 355:	learn: 0.3519791	total: 259ms	remaining: 469ms
# 356:	learn: 0.3519634	total: 260ms	remaining: 468ms
# 357:	learn: 0.3519409	total: 260ms	remaining: 467ms
# 358:	learn: 0.3517878	total: 261ms	remaining: 466ms
# 359:	learn: 0.3517699	total: 262ms	remaining: 465ms
# 360:	learn: 0.3516866	total: 262ms	remaining: 464ms
# 361:	learn: 0.3515444	total: 263ms	remaining: 464ms
# 362:	learn: 0.3514210	total: 264ms	remaining: 463ms
# 363:	learn: 0.3514003	total: 265ms	remaining: 462ms
# 364:	learn: 0.3511946	total: 265ms	remaining: 462ms
# 365:	learn: 0.3510985	total: 266ms	remaining: 461ms
# 366:	learn: 0.3508289	total: 267ms	remaining: 460ms
# 367:	learn: 0.3506240	total: 268ms	remaining: 460ms
# 368:	learn: 0.3505396	total: 268ms	remaining: 459ms
# 369:	learn: 0.3505218	total: 269ms	remaining: 458ms
# 370:	learn: 0.3504942	total: 270ms	remaining: 457ms
# 371:	learn: 0.3503163	total: 270ms	remaining: 457ms
# 372:	learn: 0.3501661	total: 271ms	remaining: 456ms
# 373:	learn: 0.3499722	total: 272ms	remaining: 455ms
# 374:	learn: 0.3498380	total: 273ms	remaining: 454ms
# 375:	learn: 0.3497606	total: 273ms	remaining: 454ms
# 376:	learn: 0.3495238	total: 274ms	remaining: 453ms
# 377:	learn: 0.3493004	total: 275ms	remaining: 452ms
# 378:	learn: 0.3491696	total: 276ms	remaining: 451ms
# 379:	learn: 0.3488793	total: 276ms	remaining: 451ms
# 380:	learn: 0.3487495	total: 277ms	remaining: 450ms
# 381:	learn: 0.3486486	total: 278ms	remaining: 449ms
# 382:	learn: 0.3486257	total: 279ms	remaining: 449ms
# 383:	learn: 0.3483861	total: 279ms	remaining: 448ms
# 384:	learn: 0.3482454	total: 280ms	remaining: 447ms
# 385:	learn: 0.3480755	total: 281ms	remaining: 447ms
# 386:	learn: 0.3478949	total: 282ms	remaining: 446ms
# 387:	learn: 0.3478780	total: 282ms	remaining: 445ms
# 388:	learn: 0.3478448	total: 283ms	remaining: 444ms
# 389:	learn: 0.3477715	total: 284ms	remaining: 443ms
# 390:	learn: 0.3476748	total: 284ms	remaining: 443ms
# 391:	learn: 0.3475611	total: 285ms	remaining: 442ms
# 392:	learn: 0.3474854	total: 286ms	remaining: 441ms
# 393:	learn: 0.3473378	total: 286ms	remaining: 440ms
# 394:	learn: 0.3471700	total: 287ms	remaining: 440ms
# 395:	learn: 0.3470358	total: 288ms	remaining: 439ms
# 396:	learn: 0.3468614	total: 289ms	remaining: 438ms
# 397:	learn: 0.3467572	total: 289ms	remaining: 438ms
# 398:	learn: 0.3467161	total: 290ms	remaining: 437ms
# 399:	learn: 0.3465959	total: 291ms	remaining: 436ms
# 400:	learn: 0.3464791	total: 292ms	remaining: 436ms
# 401:	learn: 0.3464212	total: 292ms	remaining: 435ms
# 402:	learn: 0.3462492	total: 293ms	remaining: 434ms
# 403:	learn: 0.3461472	total: 294ms	remaining: 434ms
# 404:	learn: 0.3460303	total: 295ms	remaining: 433ms
# 405:	learn: 0.3458911	total: 296ms	remaining: 433ms
# 406:	learn: 0.3458762	total: 296ms	remaining: 432ms
# 407:	learn: 0.3456468	total: 297ms	remaining: 431ms
# 408:	learn: 0.3455962	total: 298ms	remaining: 430ms
# 409:	learn: 0.3455245	total: 298ms	remaining: 429ms
# 410:	learn: 0.3454572	total: 299ms	remaining: 428ms
# 411:	learn: 0.3453486	total: 300ms	remaining: 428ms
# 412:	learn: 0.3451365	total: 300ms	remaining: 427ms
# 413:	learn: 0.3450274	total: 301ms	remaining: 426ms
# 414:	learn: 0.3448857	total: 302ms	remaining: 425ms
# 415:	learn: 0.3447123	total: 303ms	remaining: 425ms
# 416:	learn: 0.3445204	total: 303ms	remaining: 424ms
# 417:	learn: 0.3442898	total: 304ms	remaining: 424ms
# 418:	learn: 0.3441484	total: 305ms	remaining: 423ms
# 419:	learn: 0.3441046	total: 306ms	remaining: 422ms
# 420:	learn: 0.3440324	total: 306ms	remaining: 421ms
# 421:	learn: 0.3439300	total: 307ms	remaining: 421ms
# 422:	learn: 0.3438282	total: 308ms	remaining: 420ms
# 423:	learn: 0.3436538	total: 309ms	remaining: 419ms
# 424:	learn: 0.3435102	total: 309ms	remaining: 418ms
# 425:	learn: 0.3434113	total: 310ms	remaining: 418ms
# 426:	learn: 0.3432962	total: 311ms	remaining: 417ms
# 427:	learn: 0.3432933	total: 311ms	remaining: 416ms
# 428:	learn: 0.3432916	total: 312ms	remaining: 415ms
# 429:	learn: 0.3431367	total: 313ms	remaining: 415ms
# 430:	learn: 0.3431130	total: 314ms	remaining: 414ms
# 431:	learn: 0.3430362	total: 314ms	remaining: 413ms
# 432:	learn: 0.3429113	total: 315ms	remaining: 413ms
# 433:	learn: 0.3427698	total: 316ms	remaining: 412ms
# 434:	learn: 0.3425883	total: 317ms	remaining: 411ms
# 435:	learn: 0.3424391	total: 318ms	remaining: 411ms
# 436:	learn: 0.3423670	total: 318ms	remaining: 410ms
# 437:	learn: 0.3423104	total: 319ms	remaining: 409ms
# 438:	learn: 0.3421635	total: 320ms	remaining: 409ms
# 439:	learn: 0.3419961	total: 320ms	remaining: 408ms
# 440:	learn: 0.3419725	total: 321ms	remaining: 407ms
# 441:	learn: 0.3418646	total: 322ms	remaining: 407ms
# 442:	learn: 0.3418565	total: 323ms	remaining: 406ms
# 443:	learn: 0.3417410	total: 324ms	remaining: 405ms
# 444:	learn: 0.3414696	total: 324ms	remaining: 405ms
# 445:	learn: 0.3413740	total: 325ms	remaining: 404ms
# 446:	learn: 0.3412765	total: 326ms	remaining: 403ms
# 447:	learn: 0.3412748	total: 326ms	remaining: 402ms
# 448:	learn: 0.3411595	total: 327ms	remaining: 401ms
# 449:	learn: 0.3409487	total: 328ms	remaining: 401ms
# 450:	learn: 0.3408749	total: 329ms	remaining: 400ms
# 451:	learn: 0.3407686	total: 329ms	remaining: 399ms
# 452:	learn: 0.3407624	total: 330ms	remaining: 398ms
# 453:	learn: 0.3406147	total: 331ms	remaining: 398ms
# 454:	learn: 0.3404694	total: 331ms	remaining: 397ms
# 455:	learn: 0.3404670	total: 332ms	remaining: 396ms
# 456:	learn: 0.3402852	total: 333ms	remaining: 395ms
# 457:	learn: 0.3401524	total: 333ms	remaining: 394ms
# 458:	learn: 0.3401073	total: 334ms	remaining: 394ms
# 459:	learn: 0.3400339	total: 335ms	remaining: 393ms
# 460:	learn: 0.3399387	total: 335ms	remaining: 392ms
# 461:	learn: 0.3398690	total: 336ms	remaining: 392ms
# 462:	learn: 0.3398245	total: 337ms	remaining: 391ms
# 463:	learn: 0.3397612	total: 338ms	remaining: 390ms
# 464:	learn: 0.3397349	total: 339ms	remaining: 390ms
# 465:	learn: 0.3396487	total: 339ms	remaining: 389ms
# 466:	learn: 0.3395265	total: 340ms	remaining: 388ms
# 467:	learn: 0.3394149	total: 341ms	remaining: 387ms
# 468:	learn: 0.3391928	total: 342ms	remaining: 387ms
# 469:	learn: 0.3391410	total: 342ms	remaining: 386ms
# 470:	learn: 0.3390327	total: 343ms	remaining: 385ms
# 471:	learn: 0.3389171	total: 344ms	remaining: 385ms
# 472:	learn: 0.3388433	total: 345ms	remaining: 384ms
# 473:	learn: 0.3387796	total: 345ms	remaining: 383ms
# 474:	learn: 0.3386771	total: 346ms	remaining: 383ms
# 475:	learn: 0.3385294	total: 347ms	remaining: 382ms
# 476:	learn: 0.3384567	total: 348ms	remaining: 381ms
# 477:	learn: 0.3383665	total: 348ms	remaining: 380ms
# 478:	learn: 0.3383277	total: 349ms	remaining: 380ms
# 479:	learn: 0.3382450	total: 350ms	remaining: 379ms
# 480:	learn: 0.3380308	total: 351ms	remaining: 378ms
# 481:	learn: 0.3379227	total: 351ms	remaining: 378ms
# 482:	learn: 0.3377934	total: 352ms	remaining: 377ms
# 483:	learn: 0.3375926	total: 353ms	remaining: 377ms
# 484:	learn: 0.3374434	total: 354ms	remaining: 376ms
# 485:	learn: 0.3373778	total: 355ms	remaining: 375ms
# 486:	learn: 0.3373304	total: 355ms	remaining: 374ms
# 487:	learn: 0.3373297	total: 356ms	remaining: 373ms
# 488:	learn: 0.3372513	total: 357ms	remaining: 373ms
# 489:	learn: 0.3371716	total: 357ms	remaining: 372ms
# 490:	learn: 0.3370347	total: 358ms	remaining: 371ms
# 491:	learn: 0.3369794	total: 359ms	remaining: 371ms
# 492:	learn: 0.3369175	total: 360ms	remaining: 370ms
# 493:	learn: 0.3367586	total: 360ms	remaining: 369ms
# 494:	learn: 0.3367044	total: 361ms	remaining: 369ms
# 495:	learn: 0.3366258	total: 362ms	remaining: 368ms
# 496:	learn: 0.3365778	total: 363ms	remaining: 367ms
# 497:	learn: 0.3365362	total: 364ms	remaining: 367ms
# 498:	learn: 0.3364800	total: 364ms	remaining: 366ms
# 499:	learn: 0.3363921	total: 365ms	remaining: 365ms
# 500:	learn: 0.3363567	total: 366ms	remaining: 365ms
# 501:	learn: 0.3362929	total: 367ms	remaining: 364ms
# 502:	learn: 0.3361717	total: 368ms	remaining: 364ms
# 503:	learn: 0.3361015	total: 369ms	remaining: 363ms
# 504:	learn: 0.3360250	total: 370ms	remaining: 362ms
# 505:	learn: 0.3358958	total: 370ms	remaining: 362ms
# 506:	learn: 0.3357812	total: 371ms	remaining: 361ms
# 507:	learn: 0.3357667	total: 372ms	remaining: 360ms
# 508:	learn: 0.3357089	total: 373ms	remaining: 360ms
# 509:	learn: 0.3357067	total: 373ms	remaining: 359ms
# 510:	learn: 0.3356267	total: 374ms	remaining: 358ms
# 511:	learn: 0.3356207	total: 374ms	remaining: 357ms
# 512:	learn: 0.3356120	total: 375ms	remaining: 356ms
# 513:	learn: 0.3354725	total: 376ms	remaining: 355ms
# 514:	learn: 0.3353847	total: 377ms	remaining: 355ms
# 515:	learn: 0.3353590	total: 377ms	remaining: 354ms
# 516:	learn: 0.3352919	total: 378ms	remaining: 353ms
# 517:	learn: 0.3351953	total: 379ms	remaining: 353ms
# 518:	learn: 0.3351018	total: 380ms	remaining: 352ms
# 519:	learn: 0.3350055	total: 381ms	remaining: 351ms
# 520:	learn: 0.3349288	total: 381ms	remaining: 351ms
# 521:	learn: 0.3348818	total: 382ms	remaining: 350ms
# 522:	learn: 0.3348096	total: 383ms	remaining: 349ms
# 523:	learn: 0.3347546	total: 384ms	remaining: 349ms
# 524:	learn: 0.3347371	total: 384ms	remaining: 348ms
# 525:	learn: 0.3346714	total: 385ms	remaining: 347ms
# 526:	learn: 0.3345674	total: 386ms	remaining: 346ms
# 527:	learn: 0.3344061	total: 387ms	remaining: 346ms
# 528:	learn: 0.3343958	total: 387ms	remaining: 345ms
# 529:	learn: 0.3343431	total: 388ms	remaining: 344ms
# 530:	learn: 0.3343095	total: 389ms	remaining: 343ms
# 531:	learn: 0.3342331	total: 389ms	remaining: 342ms
# 532:	learn: 0.3341087	total: 390ms	remaining: 342ms
# 533:	learn: 0.3340677	total: 391ms	remaining: 341ms
# 534:	learn: 0.3340090	total: 391ms	remaining: 340ms
# 535:	learn: 0.3338644	total: 392ms	remaining: 339ms
# 536:	learn: 0.3337608	total: 393ms	remaining: 339ms
# 537:	learn: 0.3337037	total: 394ms	remaining: 338ms
# 538:	learn: 0.3336244	total: 394ms	remaining: 337ms
# 539:	learn: 0.3335810	total: 395ms	remaining: 337ms
# 540:	learn: 0.3335642	total: 396ms	remaining: 336ms
# 541:	learn: 0.3334839	total: 397ms	remaining: 335ms
# 542:	learn: 0.3334591	total: 397ms	remaining: 334ms
# 543:	learn: 0.3334254	total: 398ms	remaining: 334ms
# 544:	learn: 0.3333036	total: 399ms	remaining: 333ms
# 545:	learn: 0.3332582	total: 400ms	remaining: 332ms
# 546:	learn: 0.3331831	total: 400ms	remaining: 332ms
# 547:	learn: 0.3331309	total: 401ms	remaining: 331ms
# 548:	learn: 0.3330116	total: 402ms	remaining: 330ms
# 549:	learn: 0.3329028	total: 402ms	remaining: 329ms
# 550:	learn: 0.3328985	total: 403ms	remaining: 328ms
# 551:	learn: 0.3328409	total: 404ms	remaining: 328ms
# 552:	learn: 0.3327770	total: 404ms	remaining: 327ms
# 553:	learn: 0.3326963	total: 405ms	remaining: 326ms
# 554:	learn: 0.3326293	total: 406ms	remaining: 325ms
# 555:	learn: 0.3325837	total: 406ms	remaining: 325ms
# 556:	learn: 0.3325245	total: 407ms	remaining: 324ms
# 557:	learn: 0.3324089	total: 408ms	remaining: 323ms
# 558:	learn: 0.3323833	total: 409ms	remaining: 322ms
# 559:	learn: 0.3322232	total: 409ms	remaining: 322ms
# 560:	learn: 0.3321090	total: 410ms	remaining: 321ms
# 561:	learn: 0.3319887	total: 411ms	remaining: 320ms
# 562:	learn: 0.3319758	total: 411ms	remaining: 319ms
# 563:	learn: 0.3319319	total: 412ms	remaining: 319ms
# 564:	learn: 0.3318650	total: 413ms	remaining: 318ms
# 565:	learn: 0.3317851	total: 414ms	remaining: 317ms
# 566:	learn: 0.3317339	total: 414ms	remaining: 316ms
# 567:	learn: 0.3317290	total: 415ms	remaining: 316ms
# 568:	learn: 0.3316783	total: 416ms	remaining: 315ms
# 569:	learn: 0.3316023	total: 416ms	remaining: 314ms
# 570:	learn: 0.3315071	total: 417ms	remaining: 313ms
# 571:	learn: 0.3314495	total: 418ms	remaining: 313ms
# 572:	learn: 0.3313565	total: 419ms	remaining: 312ms
# 573:	learn: 0.3313489	total: 419ms	remaining: 311ms
# 574:	learn: 0.3312379	total: 420ms	remaining: 310ms
# 575:	learn: 0.3312371	total: 421ms	remaining: 310ms
# 576:	learn: 0.3310634	total: 421ms	remaining: 309ms
# 577:	learn: 0.3310515	total: 422ms	remaining: 308ms
# 578:	learn: 0.3309869	total: 423ms	remaining: 307ms
# 579:	learn: 0.3309036	total: 424ms	remaining: 307ms
# 580:	learn: 0.3308580	total: 425ms	remaining: 306ms
# 581:	learn: 0.3308221	total: 426ms	remaining: 306ms
# 582:	learn: 0.3307636	total: 426ms	remaining: 305ms
# 583:	learn: 0.3306903	total: 427ms	remaining: 304ms
# 584:	learn: 0.3306237	total: 428ms	remaining: 304ms
# 585:	learn: 0.3305732	total: 429ms	remaining: 303ms
# 586:	learn: 0.3305073	total: 429ms	remaining: 302ms
# 587:	learn: 0.3304390	total: 430ms	remaining: 301ms
# 588:	learn: 0.3303898	total: 431ms	remaining: 301ms
# 589:	learn: 0.3303372	total: 432ms	remaining: 300ms
# 590:	learn: 0.3303215	total: 432ms	remaining: 299ms
# 591:	learn: 0.3302737	total: 433ms	remaining: 298ms
# 592:	learn: 0.3302212	total: 434ms	remaining: 298ms
# 593:	learn: 0.3301593	total: 434ms	remaining: 297ms
# 594:	learn: 0.3301235	total: 435ms	remaining: 296ms
# 595:	learn: 0.3301169	total: 436ms	remaining: 295ms
# 596:	learn: 0.3301113	total: 436ms	remaining: 295ms
# 597:	learn: 0.3300969	total: 437ms	remaining: 294ms
# 598:	learn: 0.3300504	total: 438ms	remaining: 293ms
# 599:	learn: 0.3299887	total: 438ms	remaining: 292ms
# 600:	learn: 0.3298889	total: 439ms	remaining: 292ms
# 601:	learn: 0.3298660	total: 440ms	remaining: 291ms
# 602:	learn: 0.3298659	total: 440ms	remaining: 290ms
# 603:	learn: 0.3297962	total: 441ms	remaining: 289ms
# 604:	learn: 0.3297940	total: 441ms	remaining: 288ms
# 605:	learn: 0.3297032	total: 442ms	remaining: 288ms
# 606:	learn: 0.3296978	total: 443ms	remaining: 287ms
# 607:	learn: 0.3296205	total: 444ms	remaining: 286ms
# 608:	learn: 0.3295787	total: 444ms	remaining: 285ms
# 609:	learn: 0.3294739	total: 445ms	remaining: 285ms
# 610:	learn: 0.3294025	total: 446ms	remaining: 284ms
# 611:	learn: 0.3293405	total: 446ms	remaining: 283ms
# 612:	learn: 0.3292204	total: 447ms	remaining: 282ms
# 613:	learn: 0.3291501	total: 448ms	remaining: 282ms
# 614:	learn: 0.3290527	total: 449ms	remaining: 281ms
# 615:	learn: 0.3289728	total: 450ms	remaining: 280ms
# 616:	learn: 0.3288235	total: 450ms	remaining: 280ms
# 617:	learn: 0.3287357	total: 451ms	remaining: 279ms
# 618:	learn: 0.3287260	total: 452ms	remaining: 278ms
# 619:	learn: 0.3286635	total: 452ms	remaining: 277ms
# 620:	learn: 0.3286584	total: 453ms	remaining: 277ms
# 621:	learn: 0.3286009	total: 454ms	remaining: 276ms
# 622:	learn: 0.3285582	total: 455ms	remaining: 275ms
# 623:	learn: 0.3285369	total: 455ms	remaining: 274ms
# 624:	learn: 0.3284426	total: 456ms	remaining: 274ms
# 625:	learn: 0.3283362	total: 457ms	remaining: 273ms
# 626:	learn: 0.3283177	total: 458ms	remaining: 272ms
# 627:	learn: 0.3282898	total: 458ms	remaining: 272ms
# 628:	learn: 0.3281715	total: 459ms	remaining: 271ms
# 629:	learn: 0.3280943	total: 460ms	remaining: 270ms
# 630:	learn: 0.3280467	total: 461ms	remaining: 269ms
# 631:	learn: 0.3279572	total: 461ms	remaining: 269ms
# 632:	learn: 0.3279080	total: 462ms	remaining: 268ms
# 633:	learn: 0.3279079	total: 463ms	remaining: 267ms
# 634:	learn: 0.3278427	total: 463ms	remaining: 266ms
# 635:	learn: 0.3277931	total: 464ms	remaining: 266ms
# 636:	learn: 0.3277761	total: 465ms	remaining: 265ms
# 637:	learn: 0.3276952	total: 466ms	remaining: 264ms
# 638:	learn: 0.3276011	total: 466ms	remaining: 263ms
# 639:	learn: 0.3275723	total: 467ms	remaining: 263ms
# 640:	learn: 0.3275389	total: 468ms	remaining: 262ms
# 641:	learn: 0.3274133	total: 469ms	remaining: 261ms
# 642:	learn: 0.3274010	total: 470ms	remaining: 261ms
# 643:	learn: 0.3273574	total: 470ms	remaining: 260ms
# 644:	learn: 0.3272940	total: 471ms	remaining: 259ms
# 645:	learn: 0.3272525	total: 472ms	remaining: 259ms
# 646:	learn: 0.3271726	total: 473ms	remaining: 258ms
# 647:	learn: 0.3270703	total: 473ms	remaining: 257ms
# 648:	learn: 0.3269958	total: 474ms	remaining: 256ms
# 649:	learn: 0.3269538	total: 475ms	remaining: 256ms
# 650:	learn: 0.3268705	total: 476ms	remaining: 255ms
# 651:	learn: 0.3268210	total: 477ms	remaining: 255ms
# 652:	learn: 0.3267834	total: 478ms	remaining: 254ms
# 653:	learn: 0.3266971	total: 479ms	remaining: 253ms
# 654:	learn: 0.3266816	total: 479ms	remaining: 253ms
# 655:	learn: 0.3266022	total: 480ms	remaining: 252ms
# 656:	learn: 0.3265554	total: 481ms	remaining: 251ms
# 657:	learn: 0.3265105	total: 482ms	remaining: 250ms
# 658:	learn: 0.3264929	total: 482ms	remaining: 250ms
# 659:	learn: 0.3264212	total: 483ms	remaining: 249ms
# 660:	learn: 0.3263895	total: 484ms	remaining: 248ms
# 661:	learn: 0.3263126	total: 485ms	remaining: 248ms
# 662:	learn: 0.3262405	total: 486ms	remaining: 247ms
# 663:	learn: 0.3261600	total: 486ms	remaining: 246ms
# 664:	learn: 0.3261372	total: 487ms	remaining: 245ms
# 665:	learn: 0.3260688	total: 488ms	remaining: 245ms
# 666:	learn: 0.3259892	total: 488ms	remaining: 244ms
# 667:	learn: 0.3258997	total: 489ms	remaining: 243ms
# 668:	learn: 0.3258196	total: 490ms	remaining: 242ms
# 669:	learn: 0.3258180	total: 490ms	remaining: 242ms
# 670:	learn: 0.3257442	total: 491ms	remaining: 241ms
# 671:	learn: 0.3256242	total: 492ms	remaining: 240ms
# 672:	learn: 0.3255636	total: 493ms	remaining: 239ms
# 673:	learn: 0.3254851	total: 493ms	remaining: 239ms
# 674:	learn: 0.3254807	total: 494ms	remaining: 238ms
# 675:	learn: 0.3254046	total: 495ms	remaining: 237ms
# 676:	learn: 0.3253617	total: 495ms	remaining: 236ms
# 677:	learn: 0.3252943	total: 497ms	remaining: 236ms
# 678:	learn: 0.3252339	total: 497ms	remaining: 235ms
# 679:	learn: 0.3252159	total: 498ms	remaining: 234ms
# 680:	learn: 0.3251918	total: 499ms	remaining: 234ms
# 681:	learn: 0.3250430	total: 500ms	remaining: 233ms
# 682:	learn: 0.3249801	total: 500ms	remaining: 232ms
# 683:	learn: 0.3249493	total: 501ms	remaining: 232ms
# 684:	learn: 0.3248750	total: 502ms	remaining: 231ms
# 685:	learn: 0.3248413	total: 502ms	remaining: 230ms
# 686:	learn: 0.3247770	total: 503ms	remaining: 229ms
# 687:	learn: 0.3247288	total: 504ms	remaining: 229ms
# 688:	learn: 0.3246620	total: 505ms	remaining: 228ms
# 689:	learn: 0.3246553	total: 505ms	remaining: 227ms
# 690:	learn: 0.3246335	total: 506ms	remaining: 226ms
# 691:	learn: 0.3246250	total: 506ms	remaining: 225ms
# 692:	learn: 0.3245185	total: 507ms	remaining: 225ms
# 693:	learn: 0.3244379	total: 508ms	remaining: 224ms
# 694:	learn: 0.3244261	total: 508ms	remaining: 223ms
# 695:	learn: 0.3243226	total: 509ms	remaining: 222ms
# 696:	learn: 0.3242661	total: 510ms	remaining: 222ms
# 697:	learn: 0.3242121	total: 511ms	remaining: 221ms
# 698:	learn: 0.3241569	total: 511ms	remaining: 220ms
# 699:	learn: 0.3241056	total: 512ms	remaining: 220ms
# 700:	learn: 0.3240550	total: 513ms	remaining: 219ms
# 701:	learn: 0.3240482	total: 513ms	remaining: 218ms
# 702:	learn: 0.3240334	total: 514ms	remaining: 217ms
# 703:	learn: 0.3239685	total: 515ms	remaining: 216ms
# 704:	learn: 0.3239666	total: 515ms	remaining: 216ms
# 705:	learn: 0.3239330	total: 516ms	remaining: 215ms
# 706:	learn: 0.3238576	total: 517ms	remaining: 214ms
# 707:	learn: 0.3238359	total: 517ms	remaining: 213ms
# 708:	learn: 0.3238292	total: 518ms	remaining: 213ms
# 709:	learn: 0.3238172	total: 519ms	remaining: 212ms
# 710:	learn: 0.3237842	total: 519ms	remaining: 211ms
# 711:	learn: 0.3237273	total: 520ms	remaining: 210ms
# 712:	learn: 0.3236764	total: 521ms	remaining: 210ms
# 713:	learn: 0.3236705	total: 521ms	remaining: 209ms
# 714:	learn: 0.3235382	total: 522ms	remaining: 208ms
# 715:	learn: 0.3234414	total: 523ms	remaining: 207ms
# 716:	learn: 0.3233636	total: 524ms	remaining: 207ms
# 717:	learn: 0.3232920	total: 525ms	remaining: 206ms
# 718:	learn: 0.3232110	total: 526ms	remaining: 205ms
# 719:	learn: 0.3231824	total: 527ms	remaining: 205ms
# 720:	learn: 0.3231101	total: 527ms	remaining: 204ms
# 721:	learn: 0.3230658	total: 528ms	remaining: 203ms
# 722:	learn: 0.3229649	total: 529ms	remaining: 203ms
# 723:	learn: 0.3228783	total: 530ms	remaining: 202ms
# 724:	learn: 0.3228151	total: 530ms	remaining: 201ms
# 725:	learn: 0.3227842	total: 531ms	remaining: 200ms
# 726:	learn: 0.3227152	total: 532ms	remaining: 200ms
# 727:	learn: 0.3226879	total: 533ms	remaining: 199ms
# 728:	learn: 0.3225773	total: 533ms	remaining: 198ms
# 729:	learn: 0.3224877	total: 534ms	remaining: 198ms
# 730:	learn: 0.3224170	total: 535ms	remaining: 197ms
# 731:	learn: 0.3223347	total: 535ms	remaining: 196ms
# 732:	learn: 0.3223345	total: 536ms	remaining: 195ms
# 733:	learn: 0.3222861	total: 536ms	remaining: 194ms
# 734:	learn: 0.3222034	total: 537ms	remaining: 194ms
# 735:	learn: 0.3221859	total: 538ms	remaining: 193ms
# 736:	learn: 0.3221142	total: 539ms	remaining: 192ms
# 737:	learn: 0.3220418	total: 539ms	remaining: 192ms
# 738:	learn: 0.3219923	total: 540ms	remaining: 191ms
# 739:	learn: 0.3219646	total: 541ms	remaining: 190ms
# 740:	learn: 0.3219424	total: 542ms	remaining: 189ms
# 741:	learn: 0.3219252	total: 543ms	remaining: 189ms
# 742:	learn: 0.3218311	total: 543ms	remaining: 188ms
# 743:	learn: 0.3217279	total: 544ms	remaining: 187ms
# 744:	learn: 0.3217250	total: 545ms	remaining: 186ms
# 745:	learn: 0.3216887	total: 545ms	remaining: 186ms
# 746:	learn: 0.3216532	total: 546ms	remaining: 185ms
# 747:	learn: 0.3215866	total: 547ms	remaining: 184ms
# 748:	learn: 0.3214804	total: 547ms	remaining: 183ms
# 749:	learn: 0.3214657	total: 548ms	remaining: 183ms
# 750:	learn: 0.3213815	total: 549ms	remaining: 182ms
# 751:	learn: 0.3213424	total: 549ms	remaining: 181ms
# 752:	learn: 0.3212434	total: 550ms	remaining: 180ms
# 753:	learn: 0.3211939	total: 551ms	remaining: 180ms
# 754:	learn: 0.3211401	total: 552ms	remaining: 179ms
# 755:	learn: 0.3210700	total: 553ms	remaining: 178ms
# 756:	learn: 0.3209683	total: 553ms	remaining: 178ms
# 757:	learn: 0.3208796	total: 554ms	remaining: 177ms
# 758:	learn: 0.3208357	total: 555ms	remaining: 176ms
# 759:	learn: 0.3207175	total: 556ms	remaining: 175ms
# 760:	learn: 0.3206437	total: 556ms	remaining: 175ms
# 761:	learn: 0.3205756	total: 557ms	remaining: 174ms
# 762:	learn: 0.3205384	total: 558ms	remaining: 173ms
# 763:	learn: 0.3204601	total: 558ms	remaining: 173ms
# 764:	learn: 0.3203897	total: 559ms	remaining: 172ms
# 765:	learn: 0.3203430	total: 560ms	remaining: 171ms
# 766:	learn: 0.3202809	total: 561ms	remaining: 170ms
# 767:	learn: 0.3202344	total: 561ms	remaining: 170ms
# 768:	learn: 0.3201484	total: 562ms	remaining: 169ms
# 769:	learn: 0.3200668	total: 563ms	remaining: 168ms
# 770:	learn: 0.3200102	total: 563ms	remaining: 167ms
# 771:	learn: 0.3199416	total: 564ms	remaining: 167ms
# 772:	learn: 0.3198921	total: 565ms	remaining: 166ms
# 773:	learn: 0.3197740	total: 566ms	remaining: 165ms
# 774:	learn: 0.3197213	total: 566ms	remaining: 164ms
# 775:	learn: 0.3196226	total: 567ms	remaining: 164ms
# 776:	learn: 0.3195834	total: 568ms	remaining: 163ms
# 777:	learn: 0.3194726	total: 569ms	remaining: 162ms
# 778:	learn: 0.3193751	total: 570ms	remaining: 162ms
# 779:	learn: 0.3193558	total: 570ms	remaining: 161ms
# 780:	learn: 0.3192991	total: 571ms	remaining: 160ms
# 781:	learn: 0.3192337	total: 572ms	remaining: 159ms
# 782:	learn: 0.3191618	total: 573ms	remaining: 159ms
# 783:	learn: 0.3190924	total: 574ms	remaining: 158ms
# 784:	learn: 0.3190568	total: 574ms	remaining: 157ms
# 785:	learn: 0.3190242	total: 575ms	remaining: 157ms
# 786:	learn: 0.3189209	total: 576ms	remaining: 156ms
# 787:	learn: 0.3188293	total: 576ms	remaining: 155ms
# 788:	learn: 0.3187964	total: 577ms	remaining: 154ms
# 789:	learn: 0.3187466	total: 578ms	remaining: 154ms
# 790:	learn: 0.3186794	total: 579ms	remaining: 153ms
# 791:	learn: 0.3186205	total: 579ms	remaining: 152ms
# 792:	learn: 0.3185239	total: 580ms	remaining: 151ms
# 793:	learn: 0.3184741	total: 581ms	remaining: 151ms
# 794:	learn: 0.3184704	total: 581ms	remaining: 150ms
# 795:	learn: 0.3184250	total: 582ms	remaining: 149ms
# 796:	learn: 0.3183812	total: 583ms	remaining: 148ms
# 797:	learn: 0.3183175	total: 584ms	remaining: 148ms
# 798:	learn: 0.3182780	total: 584ms	remaining: 147ms
# 799:	learn: 0.3181283	total: 585ms	remaining: 146ms
# 800:	learn: 0.3180980	total: 586ms	remaining: 146ms
# 801:	learn: 0.3180468	total: 587ms	remaining: 145ms
# 802:	learn: 0.3179674	total: 587ms	remaining: 144ms
# 803:	learn: 0.3179373	total: 588ms	remaining: 143ms
# 804:	learn: 0.3178726	total: 589ms	remaining: 143ms
# 805:	learn: 0.3178257	total: 590ms	remaining: 142ms
# 806:	learn: 0.3177829	total: 590ms	remaining: 141ms
# 807:	learn: 0.3177041	total: 591ms	remaining: 140ms
# 808:	learn: 0.3175779	total: 592ms	remaining: 140ms
# 809:	learn: 0.3175623	total: 592ms	remaining: 139ms
# 810:	learn: 0.3175526	total: 593ms	remaining: 138ms
# 811:	learn: 0.3174854	total: 594ms	remaining: 137ms
# 812:	learn: 0.3174476	total: 594ms	remaining: 137ms
# 813:	learn: 0.3173855	total: 595ms	remaining: 136ms
# 814:	learn: 0.3173156	total: 596ms	remaining: 135ms
# 815:	learn: 0.3172516	total: 596ms	remaining: 134ms
# 816:	learn: 0.3171816	total: 597ms	remaining: 134ms
# 817:	learn: 0.3170956	total: 598ms	remaining: 133ms
# 818:	learn: 0.3170167	total: 599ms	remaining: 132ms
# 819:	learn: 0.3169445	total: 599ms	remaining: 132ms
# 820:	learn: 0.3169075	total: 600ms	remaining: 131ms
# 821:	learn: 0.3168685	total: 601ms	remaining: 130ms
# 822:	learn: 0.3168295	total: 602ms	remaining: 129ms
# 823:	learn: 0.3167919	total: 602ms	remaining: 129ms
# 824:	learn: 0.3167353	total: 603ms	remaining: 128ms
# 825:	learn: 0.3166879	total: 604ms	remaining: 127ms
# 826:	learn: 0.3166643	total: 604ms	remaining: 126ms
# 827:	learn: 0.3166065	total: 605ms	remaining: 126ms
# 828:	learn: 0.3165747	total: 606ms	remaining: 125ms
# 829:	learn: 0.3165060	total: 606ms	remaining: 124ms
# 830:	learn: 0.3164098	total: 607ms	remaining: 123ms
# 831:	learn: 0.3163407	total: 608ms	remaining: 123ms
# 832:	learn: 0.3163012	total: 608ms	remaining: 122ms
# 833:	learn: 0.3162261	total: 609ms	remaining: 121ms
# 834:	learn: 0.3161671	total: 610ms	remaining: 120ms
# 835:	learn: 0.3160795	total: 610ms	remaining: 120ms
# 836:	learn: 0.3160520	total: 611ms	remaining: 119ms
# 837:	learn: 0.3158965	total: 612ms	remaining: 118ms
# 838:	learn: 0.3158737	total: 613ms	remaining: 118ms
# 839:	learn: 0.3158525	total: 614ms	remaining: 117ms
# 840:	learn: 0.3157724	total: 614ms	remaining: 116ms
# 841:	learn: 0.3157343	total: 615ms	remaining: 115ms
# 842:	learn: 0.3157340	total: 616ms	remaining: 115ms
# 843:	learn: 0.3156923	total: 616ms	remaining: 114ms
# 844:	learn: 0.3156068	total: 617ms	remaining: 113ms
# 845:	learn: 0.3155601	total: 618ms	remaining: 112ms
# 846:	learn: 0.3154814	total: 618ms	remaining: 112ms
# 847:	learn: 0.3154225	total: 619ms	remaining: 111ms
# 848:	learn: 0.3153708	total: 620ms	remaining: 110ms
# 849:	learn: 0.3152843	total: 621ms	remaining: 110ms
# 850:	learn: 0.3152233	total: 621ms	remaining: 109ms
# 851:	learn: 0.3151538	total: 622ms	remaining: 108ms
# 852:	learn: 0.3150959	total: 623ms	remaining: 107ms
# 853:	learn: 0.3150955	total: 623ms	remaining: 107ms
# 854:	learn: 0.3149800	total: 624ms	remaining: 106ms
# 855:	learn: 0.3149191	total: 625ms	remaining: 105ms
# 856:	learn: 0.3148685	total: 625ms	remaining: 104ms
# 857:	learn: 0.3148205	total: 626ms	remaining: 104ms
# 858:	learn: 0.3147849	total: 627ms	remaining: 103ms
# 859:	learn: 0.3147356	total: 627ms	remaining: 102ms
# 860:	learn: 0.3146998	total: 628ms	remaining: 101ms
# 861:	learn: 0.3146425	total: 629ms	remaining: 101ms
# 862:	learn: 0.3145702	total: 630ms	remaining: 99.9ms
# 863:	learn: 0.3144892	total: 630ms	remaining: 99.2ms
# 864:	learn: 0.3144511	total: 631ms	remaining: 98.5ms
# 865:	learn: 0.3143821	total: 632ms	remaining: 97.7ms
# 866:	learn: 0.3143641	total: 632ms	remaining: 97ms
# 867:	learn: 0.3142859	total: 633ms	remaining: 96.2ms
# 868:	learn: 0.3142651	total: 634ms	remaining: 95.5ms
# 869:	learn: 0.3142153	total: 634ms	remaining: 94.8ms
# 870:	learn: 0.3141654	total: 635ms	remaining: 94.1ms
# 871:	learn: 0.3140874	total: 636ms	remaining: 93.3ms
# 872:	learn: 0.3140273	total: 637ms	remaining: 92.6ms
# 873:	learn: 0.3140022	total: 637ms	remaining: 91.9ms
# 874:	learn: 0.3139734	total: 638ms	remaining: 91.1ms
# 875:	learn: 0.3139275	total: 639ms	remaining: 90.4ms
# 876:	learn: 0.3138520	total: 640ms	remaining: 89.7ms
# 877:	learn: 0.3138171	total: 640ms	remaining: 89ms
# 878:	learn: 0.3137810	total: 641ms	remaining: 88.3ms
# 879:	learn: 0.3136933	total: 642ms	remaining: 87.5ms
# 880:	learn: 0.3136316	total: 643ms	remaining: 86.8ms
# 881:	learn: 0.3135932	total: 643ms	remaining: 86.1ms
# 882:	learn: 0.3135598	total: 644ms	remaining: 85.3ms
# 883:	learn: 0.3134903	total: 645ms	remaining: 84.6ms
# 884:	learn: 0.3133509	total: 645ms	remaining: 83.9ms
# 885:	learn: 0.3132912	total: 646ms	remaining: 83.1ms
# 886:	learn: 0.3132355	total: 647ms	remaining: 82.4ms
# 887:	learn: 0.3131811	total: 647ms	remaining: 81.7ms
# 888:	learn: 0.3130854	total: 648ms	remaining: 80.9ms
# 889:	learn: 0.3129787	total: 649ms	remaining: 80.2ms
# 890:	learn: 0.3129509	total: 650ms	remaining: 79.5ms
# 891:	learn: 0.3128965	total: 650ms	remaining: 78.7ms
# 892:	learn: 0.3128577	total: 651ms	remaining: 78ms
# 893:	learn: 0.3128012	total: 652ms	remaining: 77.3ms
# 894:	learn: 0.3127957	total: 652ms	remaining: 76.5ms
# 895:	learn: 0.3127592	total: 653ms	remaining: 75.8ms
# 896:	learn: 0.3126541	total: 654ms	remaining: 75.1ms
# 897:	learn: 0.3125683	total: 655ms	remaining: 74.4ms
# 898:	learn: 0.3125036	total: 655ms	remaining: 73.6ms
# 899:	learn: 0.3124781	total: 656ms	remaining: 72.9ms
# 900:	learn: 0.3124351	total: 657ms	remaining: 72.2ms
# 901:	learn: 0.3124048	total: 658ms	remaining: 71.5ms
# 902:	learn: 0.3123310	total: 658ms	remaining: 70.7ms
# 903:	learn: 0.3123017	total: 659ms	remaining: 70ms
# 904:	learn: 0.3122430	total: 660ms	remaining: 69.3ms
# 905:	learn: 0.3122012	total: 661ms	remaining: 68.5ms
# 906:	learn: 0.3121737	total: 661ms	remaining: 67.8ms
# 907:	learn: 0.3121385	total: 662ms	remaining: 67.1ms
# 908:	learn: 0.3121004	total: 663ms	remaining: 66.3ms
# 909:	learn: 0.3120447	total: 664ms	remaining: 65.6ms
# 910:	learn: 0.3119874	total: 664ms	remaining: 64.9ms
# 911:	learn: 0.3119531	total: 665ms	remaining: 64.2ms
# 912:	learn: 0.3118892	total: 666ms	remaining: 63.4ms
# 913:	learn: 0.3118470	total: 666ms	remaining: 62.7ms
# 914:	learn: 0.3118317	total: 667ms	remaining: 62ms
# 915:	learn: 0.3117585	total: 668ms	remaining: 61.2ms
# 916:	learn: 0.3116914	total: 668ms	remaining: 60.5ms
# 917:	learn: 0.3116573	total: 669ms	remaining: 59.8ms
# 918:	learn: 0.3116163	total: 670ms	remaining: 59.1ms
# 919:	learn: 0.3115734	total: 671ms	remaining: 58.3ms
# 920:	learn: 0.3115289	total: 672ms	remaining: 57.6ms
# ...
# 695:	learn: 0.3474050	total: 498ms	remaining: 218ms
# 696:	learn: 0.3473984	total: 499ms	remaining: 217ms
# 697:	learn: 0.3473926	total: 500ms	remaining: 216ms
# 698:	learn: 0.3473523	total: 500ms	remaining: 215ms
# 699:	learn: 0.3472519	total: 501ms	remaining: 215ms
# 700:	learn: 0.3472206	total: 502ms	remaining: 214ms
# 701:	learn: 0.3471535	total: 503ms	remaining: 213ms
# 702:	learn: 0.3470956	total: 503ms	remaining: 213ms
# 703:	learn: 0.3469857	total: 504ms	remaining: 212ms
# 704:	learn: 0.3468666	total: 505ms	remaining: 211ms
# 705:	learn: 0.3467781	total: 506ms	remaining: 211ms
# 706:	learn: 0.3466831	total: 507ms	remaining: 210ms
# 707:	learn: 0.3466287	total: 507ms	remaining: 209ms
# 708:	learn: 0.3465841	total: 508ms	remaining: 209ms
# 709:	learn: 0.3465100	total: 509ms	remaining: 208ms
# 710:	learn: 0.3464435	total: 510ms	remaining: 207ms
# 711:	learn: 0.3464287	total: 510ms	remaining: 206ms
# 712:	learn: 0.3463287	total: 511ms	remaining: 206ms
# 713:	learn: 0.3463166	total: 512ms	remaining: 205ms
# 714:	learn: 0.3462699	total: 512ms	remaining: 204ms
# 715:	learn: 0.3462184	total: 513ms	remaining: 204ms
# 716:	learn: 0.3461180	total: 514ms	remaining: 203ms
# 717:	learn: 0.3459652	total: 515ms	remaining: 202ms
# 718:	learn: 0.3459291	total: 516ms	remaining: 201ms
# 719:	learn: 0.3458514	total: 516ms	remaining: 201ms
# 720:	learn: 0.3458357	total: 517ms	remaining: 200ms
# 721:	learn: 0.3456707	total: 518ms	remaining: 199ms
# 722:	learn: 0.3456191	total: 518ms	remaining: 199ms
# 723:	learn: 0.3455246	total: 519ms	remaining: 198ms
# 724:	learn: 0.3454551	total: 520ms	remaining: 197ms
# 725:	learn: 0.3453862	total: 521ms	remaining: 196ms
# 726:	learn: 0.3453558	total: 521ms	remaining: 196ms
# 727:	learn: 0.3453114	total: 522ms	remaining: 195ms
# 728:	learn: 0.3452165	total: 523ms	remaining: 194ms
# 729:	learn: 0.3451081	total: 524ms	remaining: 194ms
# 730:	learn: 0.3450435	total: 524ms	remaining: 193ms
# 731:	learn: 0.3450132	total: 525ms	remaining: 192ms
# 732:	learn: 0.3449566	total: 526ms	remaining: 191ms
# 733:	learn: 0.3449565	total: 526ms	remaining: 191ms
# 734:	learn: 0.3448997	total: 527ms	remaining: 190ms
# 735:	learn: 0.3448661	total: 528ms	remaining: 189ms
# 736:	learn: 0.3448440	total: 529ms	remaining: 189ms
# 737:	learn: 0.3447829	total: 530ms	remaining: 188ms
# 738:	learn: 0.3446706	total: 530ms	remaining: 187ms
# 739:	learn: 0.3446361	total: 531ms	remaining: 187ms
# 740:	learn: 0.3445512	total: 532ms	remaining: 186ms
# 741:	learn: 0.3444456	total: 533ms	remaining: 185ms
# 742:	learn: 0.3443659	total: 534ms	remaining: 185ms
# 743:	learn: 0.3443309	total: 534ms	remaining: 184ms
# 744:	learn: 0.3442581	total: 535ms	remaining: 183ms
# 745:	learn: 0.3441690	total: 536ms	remaining: 182ms
# 746:	learn: 0.3440827	total: 537ms	remaining: 182ms
# 747:	learn: 0.3440745	total: 537ms	remaining: 181ms
# 748:	learn: 0.3439838	total: 538ms	remaining: 180ms
# 749:	learn: 0.3439351	total: 539ms	remaining: 180ms
# 750:	learn: 0.3438599	total: 539ms	remaining: 179ms
# 751:	learn: 0.3438141	total: 540ms	remaining: 178ms
# 752:	learn: 0.3437635	total: 541ms	remaining: 177ms
# 753:	learn: 0.3437325	total: 542ms	remaining: 177ms
# 754:	learn: 0.3436346	total: 542ms	remaining: 176ms
# 755:	learn: 0.3435617	total: 543ms	remaining: 175ms
# 756:	learn: 0.3434848	total: 544ms	remaining: 175ms
# 757:	learn: 0.3434520	total: 545ms	remaining: 174ms
# 758:	learn: 0.3433742	total: 545ms	remaining: 173ms
# 759:	learn: 0.3433090	total: 546ms	remaining: 172ms
# 760:	learn: 0.3432578	total: 547ms	remaining: 172ms
# 761:	learn: 0.3431772	total: 548ms	remaining: 171ms
# 762:	learn: 0.3431554	total: 548ms	remaining: 170ms
# 763:	learn: 0.3430737	total: 549ms	remaining: 170ms
# 764:	learn: 0.3430498	total: 550ms	remaining: 169ms
# 765:	learn: 0.3430354	total: 551ms	remaining: 168ms
# 766:	learn: 0.3429473	total: 551ms	remaining: 167ms
# 767:	learn: 0.3428455	total: 552ms	remaining: 167ms
# 768:	learn: 0.3427809	total: 553ms	remaining: 166ms
# 769:	learn: 0.3427346	total: 553ms	remaining: 165ms
# 770:	learn: 0.3426654	total: 554ms	remaining: 165ms
# 771:	learn: 0.3425609	total: 555ms	remaining: 164ms
# 772:	learn: 0.3424823	total: 555ms	remaining: 163ms
# 773:	learn: 0.3424781	total: 556ms	remaining: 162ms
# 774:	learn: 0.3423380	total: 557ms	remaining: 162ms
# 775:	learn: 0.3423088	total: 557ms	remaining: 161ms
# 776:	learn: 0.3422756	total: 558ms	remaining: 160ms
# 777:	learn: 0.3422149	total: 559ms	remaining: 160ms
# 778:	learn: 0.3421250	total: 560ms	remaining: 159ms
# 779:	learn: 0.3421220	total: 560ms	remaining: 158ms
# 780:	learn: 0.3420702	total: 561ms	remaining: 157ms
# 781:	learn: 0.3420360	total: 562ms	remaining: 157ms
# 782:	learn: 0.3420202	total: 563ms	remaining: 156ms
# 783:	learn: 0.3419848	total: 563ms	remaining: 155ms
# 784:	learn: 0.3419055	total: 564ms	remaining: 154ms
# 785:	learn: 0.3418460	total: 565ms	remaining: 154ms
# 786:	learn: 0.3418404	total: 565ms	remaining: 153ms
# 787:	learn: 0.3418189	total: 566ms	remaining: 152ms
# 788:	learn: 0.3416900	total: 567ms	remaining: 152ms
# 789:	learn: 0.3416605	total: 567ms	remaining: 151ms
# 790:	learn: 0.3416589	total: 568ms	remaining: 150ms
# 791:	learn: 0.3415297	total: 569ms	remaining: 149ms
# 792:	learn: 0.3415109	total: 569ms	remaining: 149ms
# 793:	learn: 0.3414641	total: 570ms	remaining: 148ms
# 794:	learn: 0.3414430	total: 571ms	remaining: 147ms
# 795:	learn: 0.3414167	total: 572ms	remaining: 146ms
# 796:	learn: 0.3413335	total: 572ms	remaining: 146ms
# 797:	learn: 0.3412857	total: 573ms	remaining: 145ms
# 798:	learn: 0.3412814	total: 574ms	remaining: 144ms
# 799:	learn: 0.3412359	total: 574ms	remaining: 144ms
# 800:	learn: 0.3411940	total: 575ms	remaining: 143ms
# 801:	learn: 0.3411570	total: 576ms	remaining: 142ms
# 802:	learn: 0.3411232	total: 577ms	remaining: 142ms
# 803:	learn: 0.3411201	total: 577ms	remaining: 141ms
# 804:	learn: 0.3410746	total: 578ms	remaining: 140ms
# 805:	learn: 0.3409906	total: 579ms	remaining: 139ms
# 806:	learn: 0.3409812	total: 580ms	remaining: 139ms
# 807:	learn: 0.3409275	total: 580ms	remaining: 138ms
# 808:	learn: 0.3408657	total: 581ms	remaining: 137ms
# 809:	learn: 0.3408001	total: 582ms	remaining: 136ms
# 810:	learn: 0.3407329	total: 583ms	remaining: 136ms
# 811:	learn: 0.3406567	total: 583ms	remaining: 135ms
# 812:	learn: 0.3406237	total: 584ms	remaining: 134ms
# 813:	learn: 0.3405779	total: 585ms	remaining: 134ms
# 814:	learn: 0.3405460	total: 586ms	remaining: 133ms
# 815:	learn: 0.3404794	total: 586ms	remaining: 132ms
# 816:	learn: 0.3403836	total: 587ms	remaining: 132ms
# 817:	learn: 0.3403641	total: 588ms	remaining: 131ms
# 818:	learn: 0.3403312	total: 589ms	remaining: 130ms
# 819:	learn: 0.3403288	total: 589ms	remaining: 129ms
# 820:	learn: 0.3402435	total: 590ms	remaining: 129ms
# 821:	learn: 0.3401416	total: 590ms	remaining: 128ms
# 822:	learn: 0.3400764	total: 591ms	remaining: 127ms
# 823:	learn: 0.3399856	total: 592ms	remaining: 126ms
# 824:	learn: 0.3399161	total: 593ms	remaining: 126ms
# 825:	learn: 0.3399027	total: 593ms	remaining: 125ms
# 826:	learn: 0.3398384	total: 594ms	remaining: 124ms
# 827:	learn: 0.3397827	total: 595ms	remaining: 124ms
# 828:	learn: 0.3397487	total: 596ms	remaining: 123ms
# 829:	learn: 0.3396887	total: 596ms	remaining: 122ms
# 830:	learn: 0.3395892	total: 597ms	remaining: 121ms
# 831:	learn: 0.3395184	total: 598ms	remaining: 121ms
# 832:	learn: 0.3394842	total: 598ms	remaining: 120ms
# 833:	learn: 0.3394836	total: 599ms	remaining: 119ms
# 834:	learn: 0.3394472	total: 600ms	remaining: 119ms
# 835:	learn: 0.3393758	total: 600ms	remaining: 118ms
# 836:	learn: 0.3393390	total: 601ms	remaining: 117ms
# 837:	learn: 0.3393073	total: 602ms	remaining: 116ms
# 838:	learn: 0.3392376	total: 603ms	remaining: 116ms
# 839:	learn: 0.3391910	total: 603ms	remaining: 115ms
# 840:	learn: 0.3391561	total: 604ms	remaining: 114ms
# 841:	learn: 0.3391355	total: 605ms	remaining: 114ms
# 842:	learn: 0.3390860	total: 606ms	remaining: 113ms
# 843:	learn: 0.3390287	total: 606ms	remaining: 112ms
# 844:	learn: 0.3389411	total: 607ms	remaining: 111ms
# 845:	learn: 0.3388050	total: 608ms	remaining: 111ms
# 846:	learn: 0.3387248	total: 609ms	remaining: 110ms
# 847:	learn: 0.3386609	total: 609ms	remaining: 109ms
# 848:	learn: 0.3385932	total: 610ms	remaining: 108ms
# 849:	learn: 0.3384992	total: 611ms	remaining: 108ms
# 850:	learn: 0.3384703	total: 611ms	remaining: 107ms
# 851:	learn: 0.3383679	total: 613ms	remaining: 106ms
# 852:	learn: 0.3383630	total: 613ms	remaining: 106ms
# 853:	learn: 0.3383237	total: 614ms	remaining: 105ms
# 854:	learn: 0.3382578	total: 615ms	remaining: 104ms
# 855:	learn: 0.3381901	total: 616ms	remaining: 104ms
# 856:	learn: 0.3381659	total: 616ms	remaining: 103ms
# 857:	learn: 0.3381368	total: 617ms	remaining: 102ms
# 858:	learn: 0.3380567	total: 618ms	remaining: 101ms
# 859:	learn: 0.3379769	total: 619ms	remaining: 101ms
# 860:	learn: 0.3379428	total: 619ms	remaining: 100ms
# 861:	learn: 0.3378673	total: 620ms	remaining: 99.3ms
# 862:	learn: 0.3378315	total: 621ms	remaining: 98.5ms
# 863:	learn: 0.3377941	total: 621ms	remaining: 97.8ms
# 864:	learn: 0.3377236	total: 622ms	remaining: 97.1ms
# 865:	learn: 0.3376563	total: 623ms	remaining: 96.4ms
# 866:	learn: 0.3375293	total: 624ms	remaining: 95.7ms
# 867:	learn: 0.3375296	total: 624ms	remaining: 94.9ms
# 868:	learn: 0.3374949	total: 625ms	remaining: 94.2ms
# 869:	learn: 0.3374274	total: 626ms	remaining: 93.5ms
# 870:	learn: 0.3373878	total: 626ms	remaining: 92.7ms
# 871:	learn: 0.3373486	total: 627ms	remaining: 92ms
# 872:	learn: 0.3373119	total: 628ms	remaining: 91.3ms
# 873:	learn: 0.3372257	total: 628ms	remaining: 90.6ms
# 874:	learn: 0.3371878	total: 629ms	remaining: 89.9ms
# 875:	learn: 0.3371085	total: 630ms	remaining: 89.2ms
# 876:	learn: 0.3370810	total: 631ms	remaining: 88.4ms
# 877:	learn: 0.3370120	total: 631ms	remaining: 87.7ms
# 878:	learn: 0.3369838	total: 632ms	remaining: 87ms
# 879:	learn: 0.3369409	total: 633ms	remaining: 86.3ms
# 880:	learn: 0.3368899	total: 634ms	remaining: 85.6ms
# 881:	learn: 0.3368432	total: 634ms	remaining: 84.9ms
# 882:	learn: 0.3367661	total: 635ms	remaining: 84.2ms
# 883:	learn: 0.3366666	total: 636ms	remaining: 83.4ms
# 884:	learn: 0.3366213	total: 637ms	remaining: 82.7ms
# 885:	learn: 0.3365471	total: 637ms	remaining: 82ms
# 886:	learn: 0.3365018	total: 638ms	remaining: 81.3ms
# 887:	learn: 0.3364140	total: 639ms	remaining: 80.6ms
# 888:	learn: 0.3363109	total: 639ms	remaining: 79.8ms
# 889:	learn: 0.3361950	total: 640ms	remaining: 79.1ms
# 890:	learn: 0.3360922	total: 641ms	remaining: 78.4ms
# 891:	learn: 0.3360641	total: 641ms	remaining: 77.7ms
# 892:	learn: 0.3360253	total: 642ms	remaining: 77ms
# 893:	learn: 0.3359577	total: 643ms	remaining: 76.2ms
# 894:	learn: 0.3359569	total: 644ms	remaining: 75.5ms
# 895:	learn: 0.3359351	total: 644ms	remaining: 74.8ms
# 896:	learn: 0.3358741	total: 645ms	remaining: 74.1ms
# 897:	learn: 0.3358674	total: 646ms	remaining: 73.3ms
# 898:	learn: 0.3358673	total: 646ms	remaining: 72.6ms
# 899:	learn: 0.3358674	total: 647ms	remaining: 71.9ms
# 900:	learn: 0.3357855	total: 648ms	remaining: 71.2ms
# 901:	learn: 0.3357339	total: 648ms	remaining: 70.4ms
# 902:	learn: 0.3356665	total: 649ms	remaining: 69.7ms
# 903:	learn: 0.3356401	total: 650ms	remaining: 69ms
# 904:	learn: 0.3356096	total: 651ms	remaining: 68.3ms
# 905:	learn: 0.3355568	total: 651ms	remaining: 67.6ms
# 906:	learn: 0.3354875	total: 652ms	remaining: 66.9ms
# 907:	learn: 0.3354526	total: 653ms	remaining: 66.2ms
# 908:	learn: 0.3354212	total: 654ms	remaining: 65.5ms
# 909:	learn: 0.3353744	total: 655ms	remaining: 64.8ms
# 910:	learn: 0.3353351	total: 656ms	remaining: 64ms
# 911:	learn: 0.3352609	total: 656ms	remaining: 63.3ms
# 912:	learn: 0.3351476	total: 657ms	remaining: 62.6ms
# 913:	learn: 0.3351204	total: 658ms	remaining: 61.9ms
# 914:	learn: 0.3350637	total: 658ms	remaining: 61.2ms
# 915:	learn: 0.3350335	total: 659ms	remaining: 60.5ms
# 916:	learn: 0.3349864	total: 660ms	remaining: 59.7ms
# 917:	learn: 0.3349583	total: 661ms	remaining: 59ms
# 918:	learn: 0.3349024	total: 662ms	remaining: 58.3ms
# 919:	learn: 0.3348366	total: 662ms	remaining: 57.6ms
# 920:	learn: 0.3348010	total: 663ms	remaining: 56.9ms
# 921:	learn: 0.3347415	total: 664ms	remaining: 56.2ms
# 922:	learn: 0.3346640	total: 665ms	remaining: 55.4ms
# 923:	learn: 0.3346230	total: 665ms	remaining: 54.7ms
# 924:	learn: 0.3345787	total: 666ms	remaining: 54ms
# 925:	learn: 0.3345370	total: 667ms	remaining: 53.3ms
# 926:	learn: 0.3344825	total: 668ms	remaining: 52.6ms
# 927:	learn: 0.3344396	total: 668ms	remaining: 51.9ms
# 928:	learn: 0.3343924	total: 669ms	remaining: 51.1ms
# 929:	learn: 0.3343131	total: 670ms	remaining: 50.4ms
# 930:	learn: 0.3342189	total: 670ms	remaining: 49.7ms
# 931:	learn: 0.3341610	total: 671ms	remaining: 49ms
# 932:	learn: 0.3341238	total: 672ms	remaining: 48.3ms
# 933:	learn: 0.3341072	total: 673ms	remaining: 47.5ms
# 934:	learn: 0.3340637	total: 674ms	remaining: 46.8ms
# 935:	learn: 0.3340288	total: 675ms	remaining: 46.1ms
# 936:	learn: 0.3339805	total: 675ms	remaining: 45.4ms
# 937:	learn: 0.3339531	total: 676ms	remaining: 44.7ms
# 938:	learn: 0.3338634	total: 677ms	remaining: 44ms
# 939:	learn: 0.3338419	total: 678ms	remaining: 43.2ms
# 940:	learn: 0.3338008	total: 678ms	remaining: 42.5ms
# 941:	learn: 0.3337822	total: 679ms	remaining: 41.8ms
# 942:	learn: 0.3337814	total: 680ms	remaining: 41.1ms
# 943:	learn: 0.3337589	total: 680ms	remaining: 40.4ms
# 944:	learn: 0.3336806	total: 681ms	remaining: 39.6ms
# 945:	learn: 0.3336570	total: 682ms	remaining: 38.9ms
# 946:	learn: 0.3336211	total: 682ms	remaining: 38.2ms
# 947:	learn: 0.3335749	total: 683ms	remaining: 37.5ms
# 948:	learn: 0.3335101	total: 684ms	remaining: 36.7ms
# 949:	learn: 0.3334746	total: 684ms	remaining: 36ms
# 950:	learn: 0.3334413	total: 685ms	remaining: 35.3ms
# 951:	learn: 0.3334201	total: 686ms	remaining: 34.6ms
# 952:	learn: 0.3333852	total: 687ms	remaining: 33.9ms
# 953:	learn: 0.3333305	total: 687ms	remaining: 33.1ms
# 954:	learn: 0.3332798	total: 688ms	remaining: 32.4ms
# 955:	learn: 0.3332522	total: 689ms	remaining: 31.7ms
# 956:	learn: 0.3331607	total: 690ms	remaining: 31ms
# 957:	learn: 0.3331219	total: 691ms	remaining: 30.3ms
# 958:	learn: 0.3330721	total: 692ms	remaining: 29.6ms
# 959:	learn: 0.3330259	total: 692ms	remaining: 28.8ms
# 960:	learn: 0.3330003	total: 693ms	remaining: 28.1ms
# 961:	learn: 0.3329245	total: 694ms	remaining: 27.4ms
# 962:	learn: 0.3328874	total: 695ms	remaining: 26.7ms
# 963:	learn: 0.3328671	total: 695ms	remaining: 26ms
# 964:	learn: 0.3328174	total: 696ms	remaining: 25.2ms
# 965:	learn: 0.3328174	total: 696ms	remaining: 24.5ms
# 966:	learn: 0.3327863	total: 697ms	remaining: 23.8ms
# 967:	learn: 0.3327350	total: 698ms	remaining: 23.1ms
# 968:	learn: 0.3326924	total: 699ms	remaining: 22.3ms
# 969:	learn: 0.3326706	total: 699ms	remaining: 21.6ms
# 970:	learn: 0.3326062	total: 700ms	remaining: 20.9ms
# 971:	learn: 0.3325743	total: 701ms	remaining: 20.2ms
# 972:	learn: 0.3325642	total: 702ms	remaining: 19.5ms
# 973:	learn: 0.3325326	total: 702ms	remaining: 18.7ms
# 974:	learn: 0.3324824	total: 703ms	remaining: 18ms
# 975:	learn: 0.3324342	total: 704ms	remaining: 17.3ms
# 976:	learn: 0.3323948	total: 705ms	remaining: 16.6ms
# 977:	learn: 0.3323698	total: 705ms	remaining: 15.9ms
# 978:	learn: 0.3323279	total: 706ms	remaining: 15.1ms
# 979:	learn: 0.3322833	total: 707ms	remaining: 14.4ms
# 980:	learn: 0.3322206	total: 708ms	remaining: 13.7ms
# 981:	learn: 0.3321526	total: 708ms	remaining: 13ms
# 982:	learn: 0.3320888	total: 709ms	remaining: 12.3ms
# 983:	learn: 0.3320442	total: 710ms	remaining: 11.5ms
# 984:	learn: 0.3319990	total: 711ms	remaining: 10.8ms
# 985:	learn: 0.3319684	total: 711ms	remaining: 10.1ms
# 986:	learn: 0.3319488	total: 712ms	remaining: 9.38ms
# 987:	learn: 0.3319088	total: 713ms	remaining: 8.66ms
# 988:	learn: 0.3318689	total: 713ms	remaining: 7.93ms
# 989:	learn: 0.3318229	total: 714ms	remaining: 7.21ms
# 990:	learn: 0.3318076	total: 715ms	remaining: 6.49ms
# 991:	learn: 0.3317819	total: 716ms	remaining: 5.77ms
# 992:	learn: 0.3317280	total: 717ms	remaining: 5.05ms
# 993:	learn: 0.3317276	total: 718ms	remaining: 4.33ms
# 994:	learn: 0.3316624	total: 719ms	remaining: 3.61ms
# 995:	learn: 0.3316079	total: 719ms	remaining: 2.89ms
# 996:	learn: 0.3315280	total: 720ms	remaining: 2.17ms
# 997:	learn: 0.3315050	total: 721ms	remaining: 1.45ms
# 998:	learn: 0.3314631	total: 722ms	remaining: 722us
# 999:	learn: 0.3314381	total: 723ms	remaining: 0us

# %%
# Mean and standard deviation of cross validation results for each classifier  

cross_val_mean = []
cross_val_std = []
for cross_val_result in cross_val_results:
    cross_val_mean.append(cross_val_result.mean())
    cross_val_std.append(cross_val_result.std())

    
    
#putting our cross val mean and standard deviation for each algorithm into a data frame
cross_val_res = pd.DataFrame({'Cross Validation Mean': cross_val_mean, 'Cross Validation Std': cross_val_std, 'Algorithm': [ 'Multilayer perceptron','Logistic Regression','Naive Bayes', 'K Nearest Neighbours', 'Support Vector Machines', 'Stochastic Gradient Decent', 'Linear SVC','Perceptron', 'Random Forest', 'Cat Boost','Decision Tree']})
cross_val_res.sort_values(by = 'Cross Validation Mean', ascending = False, ignore_index = True)
# Out:
#     Cross Validation Mean  Cross Validation Std                   Algorithm
# 0                0.823765              0.019224     Support Vector Machines
# 1                0.820438              0.019013                   Cat Boost
# 2                0.817105              0.030351               Random Forest
# 3                0.813722              0.021437               Decision Tree
# 4                0.805844              0.021121       Multilayer perceptron
# 5                0.793491              0.007433        K Nearest Neighbours
# 6                0.786780              0.012852         Logistic Regression
# 7                0.785626              0.009837                  Linear SVC
# 8                0.757661              0.039413                 Naive Bayes
# 9                0.690120              0.152502  Stochastic Gradient Decent
# 10               0.679342              0.154759                  Perceptron

# %%
sns.barplot('Cross Validation Mean', 'Algorithm', data = cross_val_res, order = cross_val_res.sort_values(by = 'Cross Validation Mean', ascending = False)['Algorithm'], palette = 'Set3', **{'xerr': cross_val_std})
plt.ylabel('Algorithm')
plt.title('Cross Validation Scores')
# Out:
# Text(0.5, 1.0, 'Cross Validation Scores')

# %% [markdown]
# ## 6.3.3. Learning curves

# %%
  # Plot learning curve
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=-1, train_sizes=np.linspace(.1, 1.0, 5)):
    """
    Generate a simple plot of the test and traning learning curve.

    Parameters
    ----------
    estimator : object type that implements the "fit" and "predict" methods
        An object of that type which is cloned for each validation.

    title : string
        Title for the chart.

    X : array-like, shape (n_samples, n_features)
        Training vector, where n_samples is the number of samples and
        n_features is the number of features.

    y : array-like, shape (n_samples) or (n_samples, n_features), optional
        Target relative to X for classification or regression;
        None for unsupervised learning.

    ylim : tuple, shape (ymin, ymax), optional
        Defines minimum and maximum yvalues plotted.

    cv : integer, cross-validation generator, optional
        If an integer is passed, it is the number of folds (defaults to 3).
        Specific cross-validation objects can be passed, see
        sklearn.cross_validation module for the list of possible objects

    n_jobs : integer, optional
        Number of jobs to run in parallel (default 1).
        
    x1 = np.linspace(0, 10, 8, endpoint=True) produces
        8 evenly spaced points in the range 0 to 10
    """
  
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
        
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    return plt

# %%
#KNN - Learning Curve 
plot_learning_curve(estimator = KNNtrained,title = "KNN -Learning Curve",
                    X = X_train, y = Y_train, cv = 5);

# %%
# Gaussian naive bayes - Learning Curve
plot_learning_curve(estimator = GNBtrained,title = "GNB -Learninc Curve",
                    X = X_train, y = Y_train, cv = 5);

# %%
# Logistic Regression - Learning Curve    gsLRM.best_estimator_
plot_learning_curve(estimator = LGtrained ,title = "Logistic Regression - Learning Curve",
                    X = X_train, y = Y_train, cv = 5);

# %%
# 
# this does not converge nicely

# %% [markdown]
# ## 6.3.3 Hyper Paramter tuning

# %% [markdown]
# As we can see, support vector machines has the highest cross validation mean and thus we will proceed with this model.

# %% [markdown]
# ### 6.3.3.1 Hyperparameter tuning for MLP
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Aiden will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# ### 6.3.3.2 Hyperparameter tuning for KNN
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Rael will tune the parameters of KNN using GridSearchCV.

# %%
#X_train.head
#X_train_new=X_train.drop(['Fare', 'IsALone'], axis = 1, inplace=True)
#X_test_new=X_test.drop(['Fare','IsALone'], axis = 1, inplace=True)

leaf_size = list(range(1,50))
n_neighbors = list(range(1,30))
p=[1,2]
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
knn_2 = KNeighborsClassifier()
clf = GridSearchCV(knn_2, hyperparameters, cv=5,n_jobs=-1 )
best_model = clf.fit(X_train, Y_train)
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
#print('Best n_neighbors:', best_model.best_score_()['n_neighbors'])

print('voting classifier cross validation scores :',cross_val_score( best_model.best_estimator_,X_train,Y_train,cv=5))
print('voting classifier cross validation score avg :',cross_val_score( best_model.best_estimator_,X_train,Y_train,cv=5).mean())
print('voting classifier cross validation score std :',cross_val_score( best_model.best_estimator_,X_train,Y_train,cv=5).std())
KNN_trained_tuned=best_model.best_estimator_.fit(X_train, Y_train)
survival_predications2=KNN_trained_tuned.predict(X_test)
# print('voting classifier cross validation score mean :',cross_val_score(best_model.best_estimator_,X_train,Y_train,cv=5).mean())
# print('voting classifier cross validation score standard deviation :',cross_val_score(best_model.best_estimator_,X_train,Y_train,cv=5).std())
# Out:
# Best leaf_size: 45
# Best p: 1
# Best n_neighbors: 7
# voting classifier cross validation score : [0.81564246 0.78651685 0.85393258 0.81460674 0.83707865]
# voting classifier cross validation score : 0.8215554579122466
# voting classifier cross validation score : 0.02280438488739494

# %%
X_train.head()
# Out:
#    Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0       3    0    1     0         2      2        0          3
# 1       1    1    1     3         0      3        0          1
# 2       3    1    1     1         2      1        1          3
# 3       1    1    1     3         2      3        0          1
# 4       3    0    1     1         2      2        1          3

# %% [markdown]
# ### 6.3.3.3 Hyperparameter tuning for GNB
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Ben will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# ### 6.3.3.4 Hyperparameter tuning for LogReg
#
# Hyperparameter tuning is the process of tuning the parameters of a model. Here Gia will tune the parameters of support vector classifier using GridSearchCV.

# %% [markdown]
# Our mean cross validation score improved slightly.

# %% [markdown]
# ### 6.3.4 Ensembles

# %%
best_trained_MLP = MLPtrained #the rhs  will be replaced with the tuned models, right now 
best_trained_knn = KNNtrained
best_trained_lg = LGtrained
best_trained_GNB= GNBtrained



voting_classifier_hard = VotingClassifier(estimators = [('mlp',best_trained_MLP),('knn',best_trained_knn),('lg',best_trained_lg),('gnb',best_trained_GNB)], voting = 'hard') 
voting_classifier_hard_trained=voting_classifier_hard.fit(X_train, Y_train)
survival_predications=voting_classifier_hard_trained.predict(X_test)

print('voting classifier cross validation score :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5))
print('voting classifier cross validation score mean :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5).mean())
print('voting classifier cross validation score standard deviation :',cross_val_score(voting_classifier_hard,X_train,Y_train,cv=5).std())
# Out:
# voting classifier cross validation score : [0.79888268 0.79775281 0.80898876 0.78651685 0.8258427 ]
# voting classifier cross validation score mean : 0.80023225158496
# voting classifier cross validation score standard deviation : 0.012494340032308184

# %% [markdown]
# # 7. Preparing data for submission

# %%
#ss.head()

# %%
#ss.shape

# %% [markdown]
# We want our submission dataframe to have 418 rows and 2 columns, PassengerId and Survived.

# %%
# Create submission dataframe

submit = pd.DataFrame({'PassengerId': test['PassengerId'], 'Survived': survival_predications2})
submit.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         0

# %%
submit.shape
# Out:
# (418, 2)

# %% [markdown]
# Our dataframe is ready for submission!

# %%
# Create and save csv file 

submit.to_csv("submission.csv", index = False)

# %% [markdown]
# # 8. Possible extensions to improve model accuracy
#
# 1. Analyse ticket and cabin features
#     - Do these features help predict passenger survival?
#     - If yes, consider including them in the training set instead of dropping
# 2. Come up with alternative features in feature engineering
#     - Is there any other features you can potentially create from existing features in the dataset
# 3. Remove features that are less important
#     - Does removing features help reduce overfitting in the model?
# 4. Ensemble modelling
#     - This is a more advanced technique whereby you combine prediction results from multiple machine learning models

# %% [markdown]
# # 9. Conclusion
#
# You should achieve a submission score of 0.77511 if you follow exactly what I have done in this notebook. In other words, I have correctly predicted 77.5% of the test set. I highly encourage you to work through this project again and see if you can improve on this result.
#
# If you found any mistakes in the notebook or places where I can potentially improve on, feel free to reach out to me. Let's help each other get better - happy learning!
#
# My platforms:
# - [Facebook](https://www.facebook.com/chongjason914)
# - [Instagram](https://www.instagram.com/chongjason914)
# - [Twitter](https://www.twitter.com/chongjason914)
# - [LinkedIn](https://www.linkedin.com/in/chongjason914)
# - [YouTube](https://www.youtube.com/channel/UCQXiCnjatxiAKgWjoUlM-Xg?view_as=subscriber)
# - [Medium](https://www.medium.com/@chongjason)

# %% [markdown]
# ## References
# https://github.com/chongjason914/kaggle-titanic
#
# https://www.kaggle.com/code/ldfreeman3/a-data-science-framework-to-achieve-99-accuracy
#
# https://github.com/murilogustineli/Titanic-Classification
#
# https://www.kaggle.com/code/kenjee/titanic-project-example/notebook
